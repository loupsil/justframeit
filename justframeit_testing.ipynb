# %%
#PRODUCT CREATION FROM WEB ORDER DEMO

import os
from dotenv import load_dotenv
import xmlrpc.client
from datetime import datetime

# Example payload for creating a sale order
payload = {
    "product": {
        "name": f"Finished Product {datetime.now().strftime('%Y%m%d_%H%M%S')}",
        "width": 500,
        "height": 500, 
        "price": 200.00,
        "reference": f"TEST_FINISHED_PRODUCT_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
        "components": [
            {
                "name": "Frame A",
                "reference": "TEST_FRAME_A"
            },
            {
                "name": "Glass A", 
                "reference": "TEST_GLASS_A"
            },
            {
                "name": "Passe-Partout A",
                "reference": "TEST_PP_A"
            }
        ]
    }
}

# Reload environment variables
load_dotenv(override=True)

## Odoo connection details from environment variables
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB') 
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo
common = xmlrpc.client.ServerProxy(f'{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common')
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
models = xmlrpc.client.ServerProxy(f'{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object')

# Create product
product_vals = {
    'name': payload['product']['name'],
    'type': 'consu',  # Changed from 'product' to 'consu' as it's a valid selection value
    'x_studio_width': payload['product']['width'],
    'x_studio_height': payload['product']['height'],
    'list_price': payload['product']['price'],
    'default_code': payload['product']['reference'],
    'categ_id': 8,  # Set category ID to 8
}

product_id = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'product.product', 'create', [product_vals])

# Get the product template ID from the created product
product_data = models.execute_kw(
    JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'product.product', 'read', [product_id], {'fields': ['product_tmpl_id']}
)
product_tmpl_id = product_data[0]['product_tmpl_id'][0]

# Create components and BOM
bom_components = []
bom_operations = []
width = payload['product']['width']
height = payload['product']['height']
surface = width * height
circumference = 2 * (width + height)

print(f"Surface: {surface} mm²")
print(f"Surface: {surface/1000000} m²")
print(f"Circumference: {circumference} mm")

# Convert dimensions to meters for duration rules
surface_m2 = surface / 1000000  # Convert mm² to m²
circumference_m = circumference / 1000  # Convert mm to m

for component in payload['product']['components']:
    # Search for existing component
    component_ids = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'product.product', 'search',
        [[['default_code', '=', component['reference']]]])
    
    if not component_ids:
        # Create component if it doesn't exist
        component_vals = {
            'name': component['name'],
            'type': 'product',
            'default_code': component['reference'],
            'categ_id': 8,
        }
        component_id = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
            'product.product', 'create', [component_vals])
    else:
        component_id = component_ids[0]
    
    # Get component details to check price computation method and associated service
    component_info = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'product.product', 'read',
        [component_id],
        {'fields': ['x_studio_price_computation', 'x_studio_associated_service', 'x_studio_associated_service_duration_rule']})
    
    # Calculate quantity based on price computation method
    if component_info and component_info[0]['x_studio_price_computation'] == 'Circumference':
        quantity = circumference_m
    elif component_info and component_info[0]['x_studio_price_computation'] == 'Surface':
        quantity = surface_m2
    else:
        quantity = 1
    
    # Add to BOM components
    bom_components.append((0, 0, {
        'product_id': component_id,
        'product_qty': quantity,
    }))

    # Handle associated service/operation
    if component_info[0]['x_studio_associated_service']:
        service_id = component_info[0]['x_studio_associated_service'][0]
        
        # Get service details
        service_info = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
            'x_services', 'read',
            [service_id],
            {'fields': ['x_name', 'x_soort', 'x_studio_associated_work_center']})

        # Get duration rules directly from component
        duration_rules = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
            'x_services_duration_rules', 'read',
            [component_info[0]['x_studio_associated_service_duration_rule']],
            {'fields': ['x_omtrek', 'x_oppervlakte', 'x_duurtijd_totaal']})

        # Find appropriate duration based on x_soort
        if service_info[0]['x_soort'] == 'Oppervlakte':
            relevant_value = surface_m2  # Use m² value
            rules_sorted = sorted(duration_rules, key=lambda x: x['x_oppervlakte'])
            matching_rule = next((rule for rule in rules_sorted if rule['x_oppervlakte'] >= relevant_value), rules_sorted[-1])
            duration_seconds = matching_rule['x_duurtijd_totaal']
        else:  # 'Omtrek'
            relevant_value = circumference_m  # Use m value
            rules_sorted = sorted(duration_rules, key=lambda x: x['x_omtrek'])
            matching_rule = next((rule for rule in rules_sorted if rule['x_omtrek'] >= relevant_value), rules_sorted[-1])
            duration_seconds = matching_rule['x_duurtijd_totaal']

        # Convert duration from seconds to minutes and calculate MM:SS format
        duration_minutes = duration_seconds / 60
        minutes = int(duration_minutes)
        seconds = int((duration_minutes - minutes) * 60)
        odoo_display = f"{minutes:02d}:{seconds:02d}"
        print(f"Converting duration for {service_info[0]['x_name']}: {duration_seconds} seconds = {duration_minutes} minutes (will display as {odoo_display} in Odoo)")

        # Add operation to BOM
        bom_operations.append((0, 0, {
            'name': service_info[0]['x_name'],
            'time_cycle_manual': duration_minutes,
            'workcenter_id': service_info[0]['x_studio_associated_work_center'][0] if service_info[0]['x_studio_associated_work_center'] else False
        }))

# Create Bill of Materials using the template ID
bom_vals = {
    'product_tmpl_id': product_tmpl_id,
    'product_qty': 1,
    'type': 'normal',
    'bom_line_ids': bom_components,
    'operation_ids': bom_operations,
}

bom_id = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'mrp.bom', 'create', [bom_vals])

# Create sale order
order_vals = {
    'partner_id': 1,  # Default customer ID, adjust as needed
    'order_line': [(0, 0, {
        'product_id': product_id,
        'product_uom_qty': 1,
        'price_unit': payload['product']['price']
    })]
}

order_id = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'sale.order', 'create', [order_vals])

print(f"Created product ID: {product_id}")
print(f"Created BOM ID: {bom_id}")
print(f"Created sale order ID: {order_id}")
print("Sale order from web simulation finished")
# Out:
# Surface: 250000 mm²
# Surface: 0.25 m²
# Circumference: 2000 mm
# Converting duration for Cutting Wood: 300 seconds = 5.0 minutes (will display as 05:00 in Odoo)
# Converting duration for Cutting Glass: 620 seconds = 10.333333333333334 minutes (will display as 10:20 in Odoo)
# Created product ID: 14810
# Created BOM ID: 57
# Created sale order ID: 50
# Sale order from web simulation finished

# %%
#PRODUCT CREATION FROM EXISTING SALE ORDER (MANUAL PROCESS)

import os
from dotenv import load_dotenv
import xmlrpc.client
from datetime import datetime

# Reload environment variables
load_dotenv(override=True)

## Odoo connection details from environment variables
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB') 
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo
common = xmlrpc.client.ServerProxy(f'{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common')
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
models = xmlrpc.client.ServerProxy(f'{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object')

# Get sale order
sale_order_id = 48
sale_order = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'sale.order', 'read',
    [sale_order_id],
    {'fields': ['order_line']})

# Get first product from sale order
order_line = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'sale.order.line', 'read',
    [sale_order[0]['order_line'][0]],
    {'fields': ['product_id', 'price_unit']})

product_info = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'product.product', 'read',
    [order_line[0]['product_id'][0]],
    {'fields': ['x_studio_width', 'x_studio_height', 'name', 'default_code']})

# Get product details
width = product_info[0]['x_studio_width']
height = product_info[0]['x_studio_height']
price = order_line[0]['price_unit']

# Get BOM for the product
bom_ids = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'mrp.bom', 'search',
    [[['product_tmpl_id', '=', product_info[0]['id']]]])

bom_info = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'mrp.bom', 'read',
    [bom_ids[0]],
    {'fields': ['bom_line_ids']})

# Get components from BOM
components = []
for bom_line_id in bom_info[0]['bom_line_ids']:
    bom_line = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'mrp.bom.line', 'read',
        [bom_line_id],
        {'fields': ['product_id']})
    component_info = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'product.product', 'read',
        [bom_line[0]['product_id'][0]],
        {'fields': ['name', 'default_code']})
    components.append({
        'name': component_info[0]['name'],
        'reference': component_info[0]['default_code']
    })

# Create new product with copied details
product_vals = {
    'name': f"Finished Product {datetime.now().strftime('%Y%m%d_%H%M%S')}",
    'type': 'consu',
    'x_studio_width': width,
    'x_studio_height': height,
    'list_price': price,
    'default_code': f"TEST_FINISHED_PRODUCT_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
    'categ_id': 8,
}

product_id = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'product.product', 'create', [product_vals])

# Create components and BOM
bom_components = []
bom_operations = []
surface = width * height
circumference = 2 * (width + height)

print(f"Surface: {surface} mm²")
print(f"Surface: {surface/1000000} m²")
print(f"Circumference: {circumference} mm")

# Convert dimensions to meters for duration rules
surface_m2 = surface / 1000000  # Convert mm² to m²
circumference_m = circumference / 1000  # Convert mm to m

for component in components:
    # Search for existing component
    component_ids = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'product.product', 'search',
        [[['default_code', '=', component['reference']]]])
    
    component_id = component_ids[0]
    
    # Get component details to check price computation method and associated service
    component_info = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'product.product', 'read',
        [component_id],
        {'fields': ['x_studio_price_computation', 'x_studio_associated_service', 'x_studio_associated_service_duration_rule']})
    
    # Calculate quantity based on price computation method
    if component_info and component_info[0]['x_studio_price_computation'] == 'Circumference':
        quantity = 2 * (width + height)
    elif component_info and component_info[0]['x_studio_price_computation'] == 'Surface':
        quantity = width * height
    else:
        quantity = 1
    
    # Add to BOM components
    bom_components.append((0, 0, {
        'product_id': component_id,
        'product_qty': quantity,
    }))

    # Handle associated service/operation
    if component_info[0]['x_studio_associated_service']:
        service_id = component_info[0]['x_studio_associated_service'][0]
        
        # Get service details
        service_info = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
            'x_services', 'read',
            [service_id],
            {'fields': ['x_name', 'x_soort', 'x_studio_associated_work_center']})

        # Get duration rules directly from component
        duration_rules = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
            'x_services_duration_rules', 'read',
            [component_info[0]['x_studio_associated_service_duration_rule']],
            {'fields': ['x_omtrek', 'x_oppervlakte', 'x_duurtijd_totaal']})

        # Find appropriate duration based on x_soort
        if service_info[0]['x_soort'] == 'Oppervlakte':
            relevant_value = surface_m2  # Use m² value
            rules_sorted = sorted(duration_rules, key=lambda x: x['x_oppervlakte'])
            matching_rule = next((rule for rule in rules_sorted if rule['x_oppervlakte'] >= relevant_value), rules_sorted[-1])
            duration_seconds = matching_rule['x_duurtijd_totaal']
        else:  # 'Omtrek'
            relevant_value = circumference_m  # Use m value
            rules_sorted = sorted(duration_rules, key=lambda x: x['x_omtrek'])
            matching_rule = next((rule for rule in rules_sorted if rule['x_omtrek'] >= relevant_value), rules_sorted[-1])
            duration_seconds = matching_rule['x_duurtijd_totaal']

        # Convert duration from seconds to minutes and calculate MM:SS format
        duration_minutes = duration_seconds / 60
        minutes = int(duration_minutes)
        seconds = int((duration_minutes - minutes) * 60)
        odoo_display = f"{minutes:02d}:{seconds:02d}"
        print(f"Converting duration for {service_info[0]['x_name']}: {duration_seconds} seconds = {duration_minutes} minutes (will display as {odoo_display} in Odoo)")

        # Add operation to BOM
        bom_operations.append((0, 0, {
            'name': service_info[0]['x_name'],
            'time_cycle_manual': duration_minutes,
            'workcenter_id': service_info[0]['x_studio_associated_work_center'][0] if service_info[0]['x_studio_associated_work_center'] else False
        }))

# Create Bill of Materials
bom_vals = {
    'product_tmpl_id': product_id,
    'product_qty': 1,
    'type': 'normal',
    'bom_line_ids': bom_components,
    'operation_ids': bom_operations
}

bom_id = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'mrp.bom', 'create', [bom_vals])

# Update existing sale order with new product
models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'sale.order', 'write',
    [sale_order_id, {
        'order_line': [(1, sale_order[0]['order_line'][0], {
            'product_id': product_id,
            'product_uom_qty': 1,
            'price_unit': price
        })]
    }])

print(f"Created product ID: {product_id}")
print(f"Created BOM ID: {bom_id}")
print(f"Updated sale order ID: {sale_order_id}")
print("Manual process simulation finished")
# Out:
# Surface: 10000.0 mm²
# Surface: 0.01 m²
# Circumference: 400.0 mm
# Converting duration for Cutting Wood: 300 seconds = 5.0 minutes (will display as 05:00 in Odoo)
# Converting duration for Cutting Glass: 620 seconds = 10.333333333333334 minutes (will display as 10:20 in Odoo)
# Created product ID: 73
# Created BOM ID: 53
# Updated sale order ID: 48
# Manual process simulation finished

# %%
#PRODUCT CREATION DEMO (OLD, before operations)


import os
from dotenv import load_dotenv
import xmlrpc.client
from datetime import datetime

# Example payload for creating a sale order
payload = {
    "product": {
        "name": f"Finished Product {datetime.now().strftime('%Y%m%d_%H%M%S')}",
        "width": 50,
        "height": 100, 
        "price": 200.00,
        "reference": f"TEST_FINISHED_PRODUCT_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
        "components": [
            {
                "name": "Frame A",
                "reference": "TEST_FRAME_B"
            },
            {
                "name": "Glass A", 
                "reference": "TEST_GLASS_A"
            },
            {
                "name": "Passe-Partout A",
                "reference": "TEST_PP_A"
            }
        ]
    }
}


# Reload environment variables
load_dotenv(override=True)

## Odoo connection details from environment variables
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB') 
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo
common = xmlrpc.client.ServerProxy(f'{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common')
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
models = xmlrpc.client.ServerProxy(f'{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object')

# Create product
product_vals = {
    'name': payload['product']['name'],
    'type': 'consu',  # Changed from 'product' to 'consu' as it's a valid selection value
    'x_studio_width': payload['product']['width'],
    'x_studio_height': payload['product']['height'],
    'list_price': payload['product']['price'],
    'default_code': payload['product']['reference'],
    'categ_id': 8,  # Set category ID to 8
}

product_id = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'product.product', 'create', [product_vals])

# Create components and BOM
bom_components = []
width = payload['product']['width']
height = payload['product']['height']

for component in payload['product']['components']:
    # Search for existing component
    component_ids = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'product.product', 'search',
        [[['default_code', '=', component['reference']]]])
    
    if not component_ids:
        # Create component if it doesn't exist
        component_vals = {
            'name': component['name'],
            'type': 'product',
            'default_code': component['reference'],
            'categ_id': 8,
        }
        component_id = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
            'product.product', 'create', [component_vals])
    else:
        component_id = component_ids[0]
    
    # Get component details to check price computation method
    component_info = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'product.product', 'read',
        [component_id],
        {'fields': ['x_studio_price_computation']})
    
    # Calculate quantity based on price computation method
    if component_info and component_info[0]['x_studio_price_computation'] == 'Circumference':
        quantity = 2 * (width + height)
    elif component_info and component_info[0]['x_studio_price_computation'] == 'Surface':
        quantity = width * height
    else:
        quantity = 1
    
    # Add to BOM components
    bom_components.append((0, 0, {
        'product_id': component_id,
        'product_qty': quantity,
    }))

# Create Bill of Materials
bom_vals = {
    'product_tmpl_id': product_id,
    'product_qty': 1,
    'type': 'normal',
    'bom_line_ids': bom_components
}

bom_id = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'mrp.bom', 'create', [bom_vals])

# Create sale order
order_vals = {
    'partner_id': 1,  # Default customer ID, adjust as needed
    'order_line': [(0, 0, {
        'product_id': product_id,
        'product_uom_qty': 1,
        'price_unit': payload['product']['price']
    })]
}

order_id = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'sale.order', 'create', [order_vals])

print(f"Created product ID: {product_id}")
print(f"Created BOM ID: {bom_id}")
print(f"Created sale order ID: {order_id}")

# %%
#FETCHING SUPPLIER INFO TO MANAGE SEQUENCE

import os
from dotenv import load_dotenv
import xmlrpc.client

# Reload environment variables
load_dotenv(override=True)

## Odoo connection details from environment variables
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB') 
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo
common = xmlrpc.client.ServerProxy(f'{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common')
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

# Create object proxy
models = xmlrpc.client.ServerProxy(f'{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object')

# Fetch product with ID 4 and get seller_ids field
product = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'product.template', 'read',
    [4],
    {'fields': ['seller_ids']}
)

if product:
    seller_ids = product[0]['seller_ids']
    print("Seller IDs:", seller_ids)
    
    # Fetch detailed supplier info for each seller_id
    supplier_info = models.execute_kw(JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'product.supplierinfo', 'read',
        [seller_ids],
        {'fields': ['id', 'display_name', 'sequence', 'product_tmpl_id']}
    )
    print("\nDetailed Supplier Information:")
    for info in supplier_info:
        print(info)
else:
    print("Product not found")
# Out:
# Seller IDs: [1, 4, 2]
#
# Detailed Supplier Information:
# {'id': 1, 'display_name': 'Louis Test (0.0 Units - 15.00\xa0€)', 'sequence': 1, 'product_tmpl_id': [4, 'Frame A']}
# {'id': 4, 'display_name': 'Louis Test 3 (0.0 Units - 19.00\xa0€)', 'sequence': 2, 'product_tmpl_id': [4, 'Frame A']}
# {'id': 2, 'display_name': 'Louis Test 2 (0.0 Units - 6.00\xa0€)', 'sequence': 3, 'product_tmpl_id': [4, 'Frame A']}

# %%
#EXPORTING SPREADSHEET FINAL APPROACH
#(fetching spreadsheet.dashboard not working as it only get the odoo. formula, without the associated value)
#Using spreadsheet.dashboard.share is a workaround

import os
import json
import base64
import xmlrpc.client
from dotenv import load_dotenv
import xlsxwriter
import openpyxl

# Load environment variables
load_dotenv(override=True)

JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo
common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common")
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object")

# Step 1: Get spreadsheet JSON (binary field)
spreadsheets = models.execute_kw(
    JUSTFRAMEIT_ODOO_DB,
    uid,
    JUSTFRAMEIT_ODOO_API_KEY,
    'spreadsheet.dashboard.share',
    'search_read',
    [[('display_name', '=', 'Price List 1 (copy 4)')]],
    {'fields': ['id', 'display_name', 'spreadsheet_data'], 'limit': 1, 'order': 'create_date desc'}
)

if not spreadsheets:
    raise Exception("❌ No spreadsheet found with name 'Price List 1'.")

spreadsheet = spreadsheets[0]
print(f"✅ Found spreadsheet: {spreadsheet['display_name']} (ID {spreadsheet['id']})")

# Parse the spreadsheet data
data = json.loads(spreadsheet['spreadsheet_data'])

# Create workbook
workbook = xlsxwriter.Workbook('pricelist5.xlsx')

for sheet in data['sheets']:
    worksheet = workbook.add_worksheet(sheet['name'])
    worksheet.use_future_functions = True
    
    # Set values
    for cell_ref, value in sheet['cells'].items():
        col = openpyxl.utils.column_index_from_string(''.join(filter(str.isalpha, cell_ref))) - 1
        row = int(''.join(filter(str.isdigit, cell_ref))) - 1
        
        # Convert string numbers to float if possible
        if isinstance(value, str):
            try:
                value = float(value)
            except ValueError:
                pass
                
        worksheet.write(row, col, value)

workbook.close()
print(f"✅ Spreadsheet exported successfully to pricelist5.xlsx")
# Out:
# ✅ Found spreadsheet: Price List 1 (copy 4) (ID 41)
# ✅ Formula written to cell N6
# ✅ Formula written to cell O6
# ✅ Formula written to cell P6
# ✅ Formula written to cell Q6
# ✅ Formula written to cell R6
# ✅ Formula written to cell S6
# ✅ Formula written to cell T6
# ✅ Formula written to cell U6
# ✅ Formula written to cell V6
# ✅ Formula written to cell W6
# ✅ Formula written to cell X6
# ✅ Formula written to cell Y6
# ✅ Formula written to cell Z6
# ✅ Formula written to cell AA6
# ✅ Formula written to cell AB6
# ✅ Formula written to cell AC6
# ✅ Formula written to cell AD6
# ✅ Formula written to cell AE6
# ✅ Formula written to cell AF6
# ✅ Formula written to cell AG6
# ✅ Formula written to cell AH6
# ✅ Formula written to cell AI6
# ✅ Formula written to cell AJ6
# ✅ Formula written to cell AK6
# ✅ Formula written to cell AL6
# ✅ Formula written to cell AM6
# ✅ Formula written to cell AN6
# ✅ Formula written to cell AO6
# ✅ Formula written to cell AP6
# ✅ Formula written to cell AQ6
# ✅ Formula written to cell AR6
# ✅ Formula written to cell AS6
# ✅ Formula written to cell AT6
# ✅ Formula written to cell AU6
# ✅ Formula written to cell AV6
# ✅ Formula written to cell AW6
# ✅ Formula written to cell AX6
# ✅ Formula written to cell AY6
# ✅ Formula written to cell AZ6
# ✅ Formula written to cell BA6
# ✅ Formula written to cell BB6
# ✅ Formula written to cell BC6
# ✅ Formula written to cell BD6
# ✅ Formula written to cell BE6
# ✅ Formula written to cell BF6
# ✅ Formula written to cell BG6
# ✅ Formula written to cell BH6
# ✅ Formula written to cell BI6
# ✅ Formula written to cell BJ6
# ✅ Formula written to cell BK6
# ✅ Formula written to cell BL6
# ✅ Formula written to cell BM6
# ✅ Formula written to cell BN6
# ✅ Formula written to cell BO6
# ✅ Formula written to cell BP6
# ✅ Formula written to cell BQ6
# ✅ Formula written to cell BR6
# ✅ Formula written to cell BS6
# ✅ Formula written to cell BT6
# ✅ Formula written to cell BU6
# ✅ Formula written to cell BV6
# ✅ Formula written to cell BW6
# ✅ Formula written to cell BX6
# ✅ Formula written to cell BY6
# ✅ Formula written to cell BZ6
# ✅ Formula written to cell CA6
# ✅ Formula written to cell CB6
# ✅ Formula written to cell CC6
# ✅ Formula written to cell CD6
# ✅ Formula written to cell CE6
# ✅ Formula written to cell CF6
# ✅ Formula written to cell CG6
# ✅ Formula written to cell CH6
# ✅ Formula written to cell CI6
# ✅ Formula written to cell CJ6
# ✅ Formula written to cell CK6
# ✅ Formula written to cell CL6
# ✅ Formula written to cell CM6
# ✅ Formula written to cell CN6
# ✅ Formula written to cell CO6
# ✅ Formula written to cell CP6
# ✅ Formula written to cell CQ6
# ✅ Formula written to cell CR6
# ✅ Formula written to cell CS6
# ✅ Formula written to cell CT6
# ✅ Formula written to cell CU6
# ✅ Formula written to cell CV6
# ✅ Formula written to cell CW6
# ✅ Formula written to cell CX6
# ✅ Formula written to cell CY6
# ✅ Formula written to cell CZ6
# ✅ Formula written to cell DA6
# ✅ Formula written to cell DB6
# ✅ Formula written to cell DC6
# ✅ Formula written to cell DD6
# ✅ Formula written to cell DE6
# ✅ Formula written to cell DF6
# ✅ Formula written to cell DG6
# ✅ Formula written to cell DH6
# ✅ Formula written to cell DI6
# ✅ Formula written to cell DJ6
# ✅ Formula written to cell DK6
# ✅ Formula written to cell DL6
# ✅ Formula written to cell DM6
# ✅ Formula written to cell DN6
# ✅ Formula written to cell DO6
# ✅ Formula written to cell DP6
# ✅ Formula written to cell DQ6
# ✅ Formula written to cell DR6
# ✅ Formula written to cell DS6
# ✅ Formula written to cell DT6
# ✅ Formula written to cell DU6
# ✅ Formula written to cell DV6
# ✅ Formula written to cell DW6
# ✅ Formula written to cell DX6
# ✅ Formula written to cell DY6
# ✅ Formula written to cell DZ6
# ✅ Formula written to cell EA6
# ✅ Formula written to cell EB6
# ✅ Formula written to cell EC6
# ✅ Formula written to cell ED6
# ✅ Formula written to cell EE6
# ✅ Formula written to cell EF6
# ✅ Formula written to cell EG6
# ✅ Formula written to cell EH6
# ✅ Formula written to cell EI6
# ✅ Formula written to cell EJ6
# ✅ Formula written to cell EK6
# ✅ Formula written to cell EL6
# ✅ Formula written to cell EM6
# ✅ Formula written to cell EN6
# ✅ Formula written to cell EO6
# ✅ Formula written to cell EP6
# ✅ Formula written to cell EQ6
# ✅ Formula written to cell ER6
# ✅ Formula written to cell ES6
# ✅ Formula written to cell ET6
# ✅ Formula written to cell EU6
# ✅ Formula written to cell EV6
# ✅ Formula written to cell EW6
# ✅ Formula written to cell EX6
# ✅ Formula written to cell EY6
# ✅ Formula written to cell EZ6
# ✅ Formula written to cell FA6
# ✅ Formula written to cell FB6
# ✅ Formula written to cell FC6
# ✅ Formula written to cell FD6
# ✅ Formula written to cell FE6
# ✅ Formula written to cell FF6
# ✅ Formula written to cell N7
# ✅ Formula written to cell O7
# ✅ Formula written to cell P7
# ✅ Formula written to cell Q7
# ✅ Formula written to cell R7
# ✅ Formula written to cell S7
# ✅ Formula written to cell T7
# ✅ Formula written to cell U7
# ✅ Formula written to cell V7
# ✅ Formula written to cell W7
# ✅ Formula written to cell X7
# ✅ Formula written to cell Y7
# ✅ Formula written to cell Z7
# ✅ Formula written to cell AA7
# ✅ Formula written to cell AB7
# ✅ Formula written to cell AC7
# ✅ Formula written to cell AD7
# ✅ Formula written to cell AE7
# ✅ Formula written to cell AF7
# ✅ Formula written to cell AG7
# ✅ Formula written to cell AH7
# ✅ Formula written to cell AI7
# ✅ Formula written to cell AJ7
# ✅ Formula written to cell AK7
# ✅ Formula written to cell AL7
# ✅ Formula written to cell AM7
# ✅ Formula written to cell AN7
# ✅ Formula written to cell AO7
# ✅ Formula written to cell AP7
# ✅ Formula written to cell AQ7
# ✅ Formula written to cell AR7
# ✅ Formula written to cell AS7
# ✅ Formula written to cell AT7
# ✅ Formula written to cell AU7
# ✅ Formula written to cell AV7
# ✅ Formula written to cell AW7
# ✅ Formula written to cell AX7
# ✅ Formula written to cell AY7
# ✅ Formula written to cell AZ7
# ✅ Formula written to cell BA7
# ✅ Formula written to cell BB7
# ✅ Formula written to cell BC7
# ✅ Formula written to cell BD7
# ✅ Formula written to cell BE7
# ✅ Formula written to cell BF7
# ✅ Formula written to cell BG7
# ✅ Formula written to cell BH7
# ✅ Formula written to cell BI7
# ✅ Formula written to cell BJ7
# ✅ Formula written to cell BK7
# ✅ Formula written to cell BL7
# ✅ Formula written to cell BM7
# ✅ Formula written to cell BN7
# ✅ Formula written to cell BO7
# ✅ Formula written to cell BP7
# ✅ Formula written to cell BQ7
# ✅ Formula written to cell BR7
# ✅ Formula written to cell BS7
# ✅ Formula written to cell BT7
# ✅ Formula written to cell BU7
# ✅ Formula written to cell BV7
# ✅ Formula written to cell BW7
# ✅ Formula written to cell BX7
# ✅ Formula written to cell BY7
# ✅ Formula written to cell BZ7
# ✅ Formula written to cell CA7
# ✅ Formula written to cell CB7
# ✅ Formula written to cell CC7
# ✅ Formula written to cell CD7
# ✅ Formula written to cell CE7
# ✅ Formula written to cell CF7
# ✅ Formula written to cell CG7
# ✅ Formula written to cell CH7
# ✅ Formula written to cell CI7
# ✅ Formula written to cell CJ7
# ✅ Formula written to cell CK7
# ✅ Formula written to cell CL7
# ✅ Formula written to cell CM7
# ✅ Formula written to cell CN7
# ✅ Formula written to cell CO7
# ✅ Formula written to cell CP7
# ✅ Formula written to cell CQ7
# ✅ Formula written to cell CR7
# ✅ Formula written to cell CS7
# ✅ Formula written to cell CT7
# ✅ Formula written to cell CU7
# ✅ Formula written to cell CV7
# ✅ Formula written to cell CW7
# ✅ Formula written to cell CX7
# ✅ Formula written to cell CY7
# ✅ Formula written to cell CZ7
# ✅ Formula written to cell DA7
# ✅ Formula written to cell DB7
# ✅ Formula written to cell DC7
# ✅ Formula written to cell DD7
# ✅ Formula written to cell DE7
# ✅ Formula written to cell DF7
# ✅ Formula written to cell DG7
# ✅ Formula written to cell DH7
# ✅ Formula written to cell DI7
# ✅ Formula written to cell DJ7
# ✅ Formula written to cell DK7
# ✅ Formula written to cell DL7
# ✅ Formula written to cell DM7
# ✅ Formula written to cell DN7
# ✅ Formula written to cell DO7
# ✅ Formula written to cell DP7
# ✅ Formula written to cell DQ7
# ✅ Formula written to cell DR7
# ✅ Formula written to cell DS7
# ✅ Formula written to cell DT7
# ✅ Formula written to cell DU7
# ✅ Formula written to cell DV7
# ✅ Formula written to cell DW7
# ✅ Formula written to cell DX7
# ✅ Formula written to cell DY7
# ✅ Formula written to cell DZ7
# ✅ Formula written to cell EA7
# ✅ Formula written to cell EB7
# ✅ Formula written to cell EC7
# ✅ Formula written to cell ED7
# ✅ Formula written to cell EE7
# ✅ Formula written to cell EF7
# ✅ Formula written to cell EG7
# ✅ Formula written to cell EH7
# ✅ Formula written to cell EI7
# ✅ Formula written to cell EJ7
# ✅ Formula written to cell EK7
# ✅ Formula written to cell EL7
# ✅ Formula written to cell EM7
# ✅ Formula written to cell EN7
# ✅ Formula written to cell EO7
# ✅ Formula written to cell EP7
# ✅ Formula written to cell EQ7
# ✅ Formula written to cell ER7
# ✅ Formula written to cell ES7
# ✅ Formula written to cell ET7
# ✅ Formula written to cell EU7
# ✅ Formula written to cell EV7
# ✅ Formula written to cell EW7
# ✅ Formula written to cell EX7
# ✅ Formula written to cell EY7
# ✅ Formula written to cell EZ7
# ✅ Formula written to cell FA7
# ✅ Formula written to cell FB7
# ✅ Formula written to cell FC7
# ✅ Formula written to cell FD7
# ✅ Formula written to cell FE7
# ✅ Formula written to cell FF7
# ✅ Formula written to cell N8
# ✅ Formula written to cell O8
# ✅ Formula written to cell P8
# ✅ Formula written to cell Q8
# ✅ Formula written to cell R8
# ✅ Formula written to cell S8
# ✅ Formula written to cell T8
# ✅ Formula written to cell U8
# ✅ Formula written to cell V8
# ✅ Formula written to cell W8
# ✅ Formula written to cell X8
# ✅ Formula written to cell Y8
# ✅ Formula written to cell Z8
# ✅ Formula written to cell AA8
# ✅ Formula written to cell AB8
# ✅ Formula written to cell AC8
# ✅ Formula written to cell AD8
# ✅ Formula written to cell AE8
# ✅ Formula written to cell AF8
# ✅ Formula written to cell AG8
# ✅ Formula written to cell AH8
# ✅ Formula written to cell AI8
# ✅ Formula written to cell AJ8
# ✅ Formula written to cell AK8
# ✅ Formula written to cell AL8
# ✅ Formula written to cell AM8
# ✅ Formula written to cell AN8
# ✅ Formula written to cell AO8
# ✅ Formula written to cell AP8
# ✅ Formula written to cell AQ8
# ✅ Formula written to cell AR8
# ✅ Formula written to cell AS8
# ✅ Formula written to cell AT8
# ✅ Formula written to cell AU8
# ✅ Formula written to cell AV8
# ✅ Formula written to cell AW8
# ✅ Formula written to cell AX8
# ✅ Formula written to cell AY8
# ✅ Formula written to cell AZ8
# ✅ Formula written to cell BA8
# ✅ Formula written to cell BB8
# ✅ Formula written to cell BC8
# ✅ Formula written to cell BD8
# ✅ Formula written to cell BE8
# ✅ Formula written to cell BF8
# ✅ Formula written to cell BG8
# ✅ Formula written to cell BH8
# ✅ Formula written to cell BI8
# ✅ Formula written to cell BJ8
# ✅ Formula written to cell BK8
# ✅ Formula written to cell BL8
# ✅ Formula written to cell BM8
# ✅ Formula written to cell BN8
# ✅ Formula written to cell BO8
# ✅ Formula written to cell BP8
# ✅ Formula written to cell BQ8
# ✅ Formula written to cell BR8
# ✅ Formula written to cell BS8
# ✅ Formula written to cell BT8
# ✅ Formula written to cell BU8
# ✅ Formula written to cell BV8
# ✅ Formula written to cell BW8
# ✅ Formula written to cell BX8
# ✅ Formula written to cell BY8
# ✅ Formula written to cell BZ8
# ✅ Formula written to cell CA8
# ✅ Formula written to cell CB8
# ✅ Formula written to cell CC8
# ✅ Formula written to cell CD8
# ✅ Formula written to cell CE8
# ✅ Formula written to cell CF8
# ✅ Formula written to cell CG8
# ✅ Formula written to cell CH8
# ✅ Formula written to cell CI8
# ✅ Formula written to cell CJ8
# ✅ Formula written to cell CK8
# ✅ Formula written to cell CL8
# ✅ Formula written to cell CM8
# ✅ Formula written to cell CN8
# ✅ Formula written to cell CO8
# ✅ Formula written to cell CP8
# ✅ Formula written to cell CQ8
# ✅ Formula written to cell CR8
# ✅ Formula written to cell CS8
# ✅ Formula written to cell CT8
# ✅ Formula written to cell CU8
# ✅ Formula written to cell CV8
# ✅ Formula written to cell CW8
# ✅ Formula written to cell CX8
# ✅ Formula written to cell CY8
# ✅ Formula written to cell CZ8
# ✅ Formula written to cell DA8
# ✅ Formula written to cell DB8
# ✅ Formula written to cell DC8
# ✅ Formula written to cell DD8
# ✅ Formula written to cell DE8
# ✅ Formula written to cell DF8
# ✅ Formula written to cell DG8
# ✅ Formula written to cell DH8
# ✅ Formula written to cell DI8
# ✅ Formula written to cell DJ8
# ✅ Formula written to cell DK8
# ✅ Formula written to cell DL8
# ✅ Formula written to cell DM8
# ✅ Formula written to cell DN8
# ✅ Formula written to cell DO8
# ✅ Formula written to cell DP8
# ✅ Formula written to cell DQ8
# ✅ Formula written to cell DR8
# ✅ Formula written to cell DS8
# ✅ Formula written to cell DT8
# ✅ Formula written to cell DU8
# ✅ Formula written to cell DV8
# ✅ Formula written to cell DW8
# ✅ Formula written to cell DX8
# ✅ Formula written to cell DY8
# ✅ Formula written to cell DZ8
# ✅ Formula written to cell EA8
# ✅ Formula written to cell EB8
# ✅ Formula written to cell EC8
# ✅ Formula written to cell ED8
# ✅ Formula written to cell EE8
# ✅ Formula written to cell EF8
# ✅ Formula written to cell EG8
# ✅ Formula written to cell EH8
# ✅ Formula written to cell EI8
# ✅ Formula written to cell EJ8
# ✅ Formula written to cell EK8
# ✅ Formula written to cell EL8
# ✅ Formula written to cell EM8
# ✅ Formula written to cell EN8
# ✅ Formula written to cell EO8
# ✅ Formula written to cell EP8
# ✅ Formula written to cell EQ8
# ✅ Formula written to cell ER8
# ✅ Formula written to cell ES8
# ✅ Formula written to cell ET8
# ✅ Formula written to cell EU8
# ✅ Formula written to cell EV8
# ✅ Formula written to cell EW8
# ✅ Formula written to cell EX8
# ✅ Formula written to cell EY8
# ✅ Formula written to cell EZ8
# ✅ Formula written to cell FA8
# ✅ Formula written to cell FB8
# ✅ Formula written to cell FC8
# ✅ Formula written to cell FD8
# ✅ Formula written to cell FE8
# ✅ Formula written to cell FF8
# ✅ Formula written to cell N9
# ✅ Formula written to cell O9
# ✅ Formula written to cell P9
# ✅ Formula written to cell Q9
# ✅ Formula written to cell R9
# ✅ Formula written to cell S9
# ✅ Formula written to cell T9
# ✅ Formula written to cell U9
# ✅ Formula written to cell V9
# ✅ Formula written to cell W9
# ✅ Formula written to cell X9
# ✅ Formula written to cell Y9
# ✅ Formula written to cell Z9
# ✅ Formula written to cell AA9
# ✅ Formula written to cell AB9
# ✅ Formula written to cell AC9
# ✅ Formula written to cell AD9
# ✅ Formula written to cell AE9
# ✅ Formula written to cell AF9
# ✅ Formula written to cell AG9
# ✅ Formula written to cell AH9
# ✅ Formula written to cell AI9
# ✅ Formula written to cell AJ9
# ✅ Formula written to cell AK9
# ✅ Formula written to cell AL9
# ✅ Formula written to cell AM9
# ✅ Formula written to cell AN9
# ✅ Formula written to cell AO9
# ✅ Formula written to cell AP9
# ✅ Formula written to cell AQ9
# ✅ Formula written to cell AR9
# ✅ Formula written to cell AS9
# ✅ Formula written to cell AT9
# ✅ Formula written to cell AU9
# ✅ Formula written to cell AV9
# ✅ Formula written to cell AW9
# ✅ Formula written to cell AX9
# ✅ Formula written to cell AY9
# ✅ Formula written to cell AZ9
# ✅ Formula written to cell BA9
# ✅ Formula written to cell BB9
# ✅ Formula written to cell BC9
# ✅ Formula written to cell BD9
# ✅ Formula written to cell BE9
# ✅ Formula written to cell BF9
# ✅ Formula written to cell BG9
# ✅ Formula written to cell BH9
# ✅ Formula written to cell BI9
# ✅ Formula written to cell BJ9
# ✅ Formula written to cell BK9
# ✅ Formula written to cell BL9
# ✅ Formula written to cell BM9
# ✅ Formula written to cell BN9
# ✅ Formula written to cell BO9
# ✅ Formula written to cell BP9
# ✅ Formula written to cell BQ9
# ✅ Formula written to cell BR9
# ✅ Formula written to cell BS9
# ✅ Formula written to cell BT9
# ✅ Formula written to cell BU9
# ✅ Formula written to cell BV9
# ✅ Formula written to cell BW9
# ✅ Formula written to cell BX9
# ✅ Formula written to cell BY9
# ✅ Formula written to cell BZ9
# ✅ Formula written to cell CA9
# ✅ Formula written to cell CB9
# ✅ Formula written to cell CC9
# ✅ Formula written to cell CD9
# ✅ Formula written to cell CE9
# ✅ Formula written to cell CF9
# ✅ Formula written to cell CG9
# ✅ Formula written to cell CH9
# ✅ Formula written to cell CI9
# ✅ Formula written to cell CJ9
# ✅ Formula written to cell CK9
# ✅ Formula written to cell CL9
# ✅ Formula written to cell CM9
# ✅ Formula written to cell CN9
# ✅ Formula written to cell CO9
# ✅ Formula written to cell CP9
# ✅ Formula written to cell CQ9
# ✅ Formula written to cell CR9
# ✅ Formula written to cell CS9
# ✅ Formula written to cell CT9
# ✅ Formula written to cell CU9
# ✅ Formula written to cell CV9
# ✅ Formula written to cell CW9
# ✅ Formula written to cell CX9
# ✅ Formula written to cell CY9
# ✅ Formula written to cell CZ9
# ✅ Formula written to cell DA9
# ✅ Formula written to cell DB9
# ✅ Formula written to cell DC9
# ✅ Formula written to cell DD9
# ✅ Formula written to cell DE9
# ✅ Formula written to cell DF9
# ✅ Formula written to cell DG9
# ✅ Formula written to cell DH9
# ✅ Formula written to cell DI9
# ✅ Formula written to cell DJ9
# ✅ Formula written to cell DK9
# ✅ Formula written to cell DL9
# ✅ Formula written to cell DM9
# ✅ Formula written to cell DN9
# ✅ Formula written to cell DO9
# ✅ Formula written to cell DP9
# ✅ Formula written to cell DQ9
# ✅ Formula written to cell DR9
# ✅ Formula written to cell DS9
# ✅ Formula written to cell DT9
# ✅ Formula written to cell DU9
# ✅ Formula written to cell DV9
# ✅ Formula written to cell DW9
# ✅ Formula written to cell DX9
# ✅ Formula written to cell DY9
# ✅ Formula written to cell DZ9
# ✅ Formula written to cell EA9
# ✅ Formula written to cell EB9
# ✅ Formula written to cell EC9
# ✅ Formula written to cell ED9
# ✅ Formula written to cell EE9
# ✅ Formula written to cell EF9
# ✅ Formula written to cell EG9
# ✅ Formula written to cell EH9
# ✅ Formula written to cell EI9
# ✅ Formula written to cell EJ9
# ✅ Formula written to cell EK9
# ✅ Formula written to cell EL9
# ✅ Formula written to cell EM9
# ✅ Formula written to cell EN9
# ✅ Formula written to cell EO9
# ✅ Formula written to cell EP9
# ✅ Formula written to cell EQ9
# ✅ Formula written to cell ER9
# ✅ Formula written to cell ES9
# ✅ Formula written to cell ET9
# ✅ Formula written to cell EU9
# ✅ Formula written to cell EV9
# ✅ Formula written to cell EW9
# ✅ Formula written to cell EX9
# ✅ Formula written to cell EY9
# ✅ Formula written to cell EZ9
# ✅ Formula written to cell FA9
# ✅ Formula written to cell FB9
# ✅ Formula written to cell FC9
# ✅ Formula written to cell FD9
# ✅ Formula written to cell FE9
# ✅ Formula written to cell FF9
# ✅ Formula written to cell N10
# ✅ Formula written to cell O10
# ✅ Formula written to cell P10
# ✅ Formula written to cell Q10
# ✅ Formula written to cell R10
# ✅ Formula written to cell S10
# ✅ Formula written to cell T10
# ✅ Formula written to cell U10
# ✅ Formula written to cell V10
# ✅ Formula written to cell W10
# ✅ Formula written to cell X10
# ✅ Formula written to cell Y10
# ✅ Formula written to cell Z10
# ✅ Formula written to cell AA10
# ✅ Formula written to cell AB10
# ✅ Formula written to cell AC10
# ✅ Formula written to cell AD10
# ✅ Formula written to cell AE10
# ✅ Formula written to cell AF10
# ✅ Formula written to cell AG10
# ✅ Formula written to cell AH10
# ✅ Formula written to cell AI10
# ✅ Formula written to cell AJ10
# ✅ Formula written to cell AK10
# ✅ Formula written to cell AL10
# ✅ Formula written to cell AM10
# ✅ Formula written to cell AN10
# ✅ Formula written to cell AO10
# ✅ Formula written to cell AP10
# ✅ Formula written to cell AQ10
# ✅ Formula written to cell AR10
# ✅ Formula written to cell AS10
# ✅ Formula written to cell AT10
# ✅ Formula written to cell AU10
# ✅ Formula written to cell AV10
# ✅ Formula written to cell AW10
# ✅ Formula written to cell AX10
# ✅ Formula written to cell AY10
# ✅ Formula written to cell AZ10
# ✅ Formula written to cell BA10
# ✅ Formula written to cell BB10
# ✅ Formula written to cell BC10
# ✅ Formula written to cell BD10
# ✅ Formula written to cell BE10
# ✅ Formula written to cell BF10
# ✅ Formula written to cell BG10
# ✅ Formula written to cell BH10
# ✅ Formula written to cell BI10
# ✅ Formula written to cell BJ10
# ✅ Formula written to cell BK10
# ✅ Formula written to cell BL10
# ✅ Formula written to cell BM10
# ✅ Formula written to cell BN10
# ✅ Formula written to cell BO10
# ✅ Formula written to cell BP10
# ✅ Formula written to cell BQ10
# ✅ Formula written to cell BR10
# ✅ Formula written to cell BS10
# ✅ Formula written to cell BT10
# ✅ Formula written to cell BU10
# ✅ Formula written to cell BV10
# ✅ Formula written to cell BW10
# ✅ Formula written to cell BX10
# ✅ Formula written to cell BY10
# ✅ Formula written to cell BZ10
# ✅ Formula written to cell CA10
# ✅ Formula written to cell CB10
# ✅ Formula written to cell CC10
# ✅ Formula written to cell CD10
# ✅ Formula written to cell CE10
# ✅ Formula written to cell CF10
# ✅ Formula written to cell CG10
# ✅ Formula written to cell CH10
# ✅ Formula written to cell CI10
# ✅ Formula written to cell CJ10
# ✅ Formula written to cell CK10
# ✅ Formula written to cell CL10
# ✅ Formula written to cell CM10
# ✅ Formula written to cell CN10
# ✅ Formula written to cell CO10
# ✅ Formula written to cell CP10
# ✅ Formula written to cell CQ10
# ✅ Formula written to cell CR10
# ✅ Formula written to cell CS10
# ✅ Formula written to cell CT10
# ✅ Formula written to cell CU10
# ✅ Formula written to cell CV10
# ✅ Formula written to cell CW10
# ✅ Formula written to cell CX10
# ✅ Formula written to cell CY10
# ✅ Formula written to cell CZ10
# ✅ Formula written to cell DA10
# ✅ Formula written to cell DB10
# ✅ Formula written to cell DC10
# ✅ Formula written to cell DD10
# ✅ Formula written to cell DE10
# ✅ Formula written to cell DF10
# ✅ Formula written to cell DG10
# ✅ Formula written to cell DH10
# ✅ Formula written to cell DI10
# ✅ Formula written to cell DJ10
# ✅ Formula written to cell DK10
# ✅ Formula written to cell DL10
# ✅ Formula written to cell DM10
# ✅ Formula written to cell DN10
# ✅ Formula written to cell DO10
# ✅ Formula written to cell DP10
# ✅ Formula written to cell DQ10
# ✅ Formula written to cell DR10
# ✅ Formula written to cell DS10
# ✅ Formula written to cell DT10
# ✅ Formula written to cell DU10
# ✅ Formula written to cell DV10
# ✅ Formula written to cell DW10
# ✅ Formula written to cell DX10
# ✅ Formula written to cell DY10
# ✅ Formula written to cell DZ10
# ✅ Formula written to cell EA10
# ✅ Formula written to cell EB10
# ✅ Formula written to cell EC10
# ✅ Formula written to cell ED10
# ✅ Formula written to cell EE10
# ✅ Formula written to cell EF10
# ✅ Formula written to cell EG10
# ✅ Formula written to cell EH10
# ✅ Formula written to cell EI10
# ✅ Formula written to cell EJ10
# ✅ Formula written to cell EK10
# ✅ Formula written to cell EL10
# ✅ Formula written to cell EM10
# ✅ Formula written to cell EN10
# ✅ Formula written to cell EO10
# ✅ Formula written to cell EP10
# ✅ Formula written to cell EQ10
# ✅ Formula written to cell ER10
# ✅ Formula written to cell ES10
# ✅ Formula written to cell ET10
# ✅ Formula written to cell EU10
# ✅ Formula written to cell EV10
# ✅ Formula written to cell EW10
# ✅ Formula written to cell EX10
# ✅ Formula written to cell EY10
# ✅ Formula written to cell EZ10
# ✅ Formula written to cell FA10
# ✅ Formula written to cell FB10
# ✅ Formula written to cell FC10
# ✅ Formula written to cell FD10
# ✅ Formula written to cell FE10
# ✅ Formula written to cell FF10
# ✅ Formula written to cell N11
# ✅ Formula written to cell O11
# ✅ Formula written to cell P11
# ✅ Formula written to cell Q11
# ✅ Formula written to cell R11
# ✅ Formula written to cell S11
# ✅ Formula written to cell T11
# ✅ Formula written to cell U11
# ✅ Formula written to cell V11
# ✅ Formula written to cell W11
# ✅ Formula written to cell X11
# ✅ Formula written to cell Y11
# ✅ Formula written to cell Z11
# ✅ Formula written to cell AA11
# ✅ Formula written to cell AB11
# ✅ Formula written to cell AC11
# ✅ Formula written to cell AD11
# ✅ Formula written to cell AE11
# ✅ Formula written to cell AF11
# ✅ Formula written to cell AG11
# ✅ Formula written to cell AH11
# ✅ Formula written to cell AI11
# ✅ Formula written to cell AJ11
# ✅ Formula written to cell AK11
# ✅ Formula written to cell AL11
# ✅ Formula written to cell AM11
# ✅ Formula written to cell AN11
# ✅ Formula written to cell AO11
# ✅ Formula written to cell AP11
# ✅ Formula written to cell AQ11
# ✅ Formula written to cell AR11
# ✅ Formula written to cell AS11
# ✅ Formula written to cell AT11
# ✅ Formula written to cell AU11
# ✅ Formula written to cell AV11
# ✅ Formula written to cell AW11
# ✅ Formula written to cell AX11
# ✅ Formula written to cell AY11
# ✅ Formula written to cell AZ11
# ✅ Formula written to cell BA11
# ✅ Formula written to cell BB11
# ✅ Formula written to cell BC11
# ✅ Formula written to cell BD11
# ✅ Formula written to cell BE11
# ✅ Formula written to cell BF11
# ✅ Formula written to cell BG11
# ✅ Formula written to cell BH11
# ✅ Formula written to cell BI11
# ✅ Formula written to cell BJ11
# ✅ Formula written to cell BK11
# ✅ Formula written to cell BL11
# ✅ Formula written to cell BM11
# ✅ Formula written to cell BN11
# ✅ Formula written to cell BO11
# ✅ Formula written to cell BP11
# ✅ Formula written to cell BQ11
# ✅ Formula written to cell BR11
# ✅ Formula written to cell BS11
# ✅ Formula written to cell BT11
# ✅ Formula written to cell BU11
# ✅ Formula written to cell BV11
# ✅ Formula written to cell BW11
# ✅ Formula written to cell BX11
# ✅ Formula written to cell BY11
# ✅ Formula written to cell BZ11
# ✅ Formula written to cell CA11
# ✅ Formula written to cell CB11
# ✅ Formula written to cell CC11
# ✅ Formula written to cell CD11
# ✅ Formula written to cell CE11
# ✅ Formula written to cell CF11
# ✅ Formula written to cell CG11
# ✅ Formula written to cell CH11
# ✅ Formula written to cell CI11
# ✅ Formula written to cell CJ11
# ✅ Formula written to cell CK11
# ✅ Formula written to cell CL11
# ✅ Formula written to cell CM11
# ✅ Formula written to cell CN11
# ✅ Formula written to cell CO11
# ✅ Formula written to cell CP11
# ✅ Formula written to cell CQ11
# ✅ Formula written to cell CR11
# ✅ Formula written to cell CS11
# ✅ Formula written to cell CT11
# ✅ Formula written to cell CU11
# ✅ Formula written to cell CV11
# ✅ Formula written to cell CW11
# ✅ Formula written to cell CX11
# ✅ Formula written to cell CY11
# ✅ Formula written to cell CZ11
# ✅ Formula written to cell DA11
# ✅ Formula written to cell DB11
# ✅ Formula written to cell DC11
# ✅ Formula written to cell DD11
# ✅ Formula written to cell DE11
# ✅ Formula written to cell DF11
# ✅ Formula written to cell DG11
# ✅ Formula written to cell DH11
# ✅ Formula written to cell DI11
# ✅ Formula written to cell DJ11
# ✅ Formula written to cell DK11
# ✅ Formula written to cell DL11
# ✅ Formula written to cell DM11
# ✅ Formula written to cell DN11
# ✅ Formula written to cell DO11
# ✅ Formula written to cell DP11
# ✅ Formula written to cell DQ11
# ✅ Formula written to cell DR11
# ✅ Formula written to cell DS11
# ✅ Formula written to cell DT11
# ✅ Formula written to cell DU11
# ✅ Formula written to cell DV11
# ✅ Formula written to cell DW11
# ✅ Formula written to cell DX11
# ✅ Formula written to cell DY11
# ✅ Formula written to cell DZ11
# ✅ Formula written to cell EA11
# ✅ Formula written to cell EB11
# ✅ Formula written to cell EC11
# ✅ Formula written to cell ED11
# ✅ Formula written to cell EE11
# ✅ Formula written to cell EF11
# ✅ Formula written to cell EG11
# ✅ Formula written to cell EH11
# ✅ Formula written to cell EI11
# ✅ Formula written to cell EJ11
# ✅ Formula written to cell EK11
# ✅ Formula written to cell EL11
# ✅ Formula written to cell EM11
# ✅ Formula written to cell EN11
# ✅ Formula written to cell EO11
# ✅ Formula written to cell EP11
# ✅ Formula written to cell EQ11
# ✅ Formula written to cell ER11
# ✅ Formula written to cell ES11
# ✅ Formula written to cell ET11
# ✅ Formula written to cell EU11
# ✅ Formula written to cell EV11
# ✅ Formula written to cell EW11
# ✅ Formula written to cell EX11
# ✅ Formula written to cell EY11
# ✅ Formula written to cell EZ11
# ✅ Formula written to cell FA11
# ✅ Formula written to cell FB11
# ✅ Formula written to cell FC11
# ✅ Formula written to cell FD11
# ✅ Formula written to cell FE11
# ✅ Formula written to cell FF11
# ✅ Formula written to cell N12
# ✅ Formula written to cell O12
# ✅ Formula written to cell P12
# ✅ Formula written to cell Q12
# ✅ Formula written to cell R12
# ✅ Formula written to cell S12
# ✅ Formula written to cell T12
# ✅ Formula written to cell U12
# ✅ Formula written to cell V12
# ✅ Formula written to cell W12
# ✅ Formula written to cell X12
# ✅ Formula written to cell Y12
# ✅ Formula written to cell Z12
# ✅ Formula written to cell AA12
# ✅ Formula written to cell AB12
# ✅ Formula written to cell AC12
# ✅ Formula written to cell AD12
# ✅ Formula written to cell AE12
# ✅ Formula written to cell AF12
# ✅ Formula written to cell AG12
# ✅ Formula written to cell AH12
# ✅ Formula written to cell AI12
# ✅ Formula written to cell AJ12
# ✅ Formula written to cell AK12
# ✅ Formula written to cell AL12
# ✅ Formula written to cell AM12
# ✅ Formula written to cell AN12
# ✅ Formula written to cell AO12
# ✅ Formula written to cell AP12
# ✅ Formula written to cell AQ12
# ✅ Formula written to cell AR12
# ✅ Formula written to cell AS12
# ✅ Formula written to cell AT12
# ✅ Formula written to cell AU12
# ✅ Formula written to cell AV12
# ✅ Formula written to cell AW12
# ✅ Formula written to cell AX12
# ✅ Formula written to cell AY12
# ✅ Formula written to cell AZ12
# ✅ Formula written to cell BA12
# ✅ Formula written to cell BB12
# ✅ Formula written to cell BC12
# ✅ Formula written to cell BD12
# ✅ Formula written to cell BE12
# ✅ Formula written to cell BF12
# ✅ Formula written to cell BG12
# ✅ Formula written to cell BH12
# ✅ Formula written to cell BI12
# ✅ Formula written to cell BJ12
# ✅ Formula written to cell BK12
# ✅ Formula written to cell BL12
# ✅ Formula written to cell BM12
# ✅ Formula written to cell BN12
# ✅ Formula written to cell BO12
# ✅ Formula written to cell BP12
# ✅ Formula written to cell BQ12
# ✅ Formula written to cell BR12
# ✅ Formula written to cell BS12
# ✅ Formula written to cell BT12
# ✅ Formula written to cell BU12
# ✅ Formula written to cell BV12
# ✅ Formula written to cell BW12
# ✅ Formula written to cell BX12
# ✅ Formula written to cell BY12
# ✅ Formula written to cell BZ12
# ✅ Formula written to cell CA12
# ✅ Formula written to cell CB12
# ✅ Formula written to cell CC12
# ✅ Formula written to cell CD12
# ✅ Formula written to cell CE12
# ✅ Formula written to cell CF12
# ✅ Formula written to cell CG12
# ✅ Formula written to cell CH12
# ✅ Formula written to cell CI12
# ✅ Formula written to cell CJ12
# ✅ Formula written to cell CK12
# ✅ Formula written to cell CL12
# ✅ Formula written to cell CM12
# ✅ Formula written to cell CN12
# ✅ Formula written to cell CO12
# ✅ Formula written to cell CP12
# ✅ Formula written to cell CQ12
# ✅ Formula written to cell CR12
# ✅ Formula written to cell CS12
# ✅ Formula written to cell CT12
# ✅ Formula written to cell CU12
# ✅ Formula written to cell CV12
# ✅ Formula written to cell CW12
# ✅ Formula written to cell CX12
# ✅ Formula written to cell CY12
# ✅ Formula written to cell CZ12
# ✅ Formula written to cell DA12
# ✅ Formula written to cell DB12
# ✅ Formula written to cell DC12
# ✅ Formula written to cell DD12
# ✅ Formula written to cell DE12
# ✅ Formula written to cell DF12
# ✅ Formula written to cell DG12
# ✅ Formula written to cell DH12
# ✅ Formula written to cell DI12
# ✅ Formula written to cell DJ12
# ✅ Formula written to cell DK12
# ✅ Formula written to cell DL12
# ✅ Formula written to cell DM12
# ✅ Formula written to cell DN12
# ✅ Formula written to cell DO12
# ✅ Formula written to cell DP12
# ✅ Formula written to cell DQ12
# ✅ Formula written to cell DR12
# ✅ Formula written to cell DS12
# ✅ Formula written to cell DT12
# ✅ Formula written to cell DU12
# ✅ Formula written to cell DV12
# ✅ Formula written to cell DW12
# ✅ Formula written to cell DX12
# ✅ Formula written to cell DY12
# ✅ Formula written to cell DZ12
# ✅ Formula written to cell EA12
# ✅ Formula written to cell EB12
# ✅ Formula written to cell EC12
# ✅ Formula written to cell ED12
# ✅ Formula written to cell EE12
# ✅ Formula written to cell EF12
# ✅ Formula written to cell EG12
# ✅ Formula written to cell EH12
# ✅ Formula written to cell EI12
# ✅ Formula written to cell EJ12
# ✅ Formula written to cell EK12
# ✅ Formula written to cell EL12
# ✅ Formula written to cell EM12
# ✅ Formula written to cell EN12
# ✅ Formula written to cell EO12
# ✅ Formula written to cell EP12
# ✅ Formula written to cell EQ12
# ✅ Formula written to cell ER12
# ✅ Formula written to cell ES12
# ✅ Formula written to cell ET12
# ✅ Formula written to cell EU12
# ✅ Formula written to cell EV12
# ✅ Formula written to cell EW12
# ✅ Formula written to cell EX12
# ✅ Formula written to cell EY12
# ✅ Formula written to cell EZ12
# ✅ Formula written to cell FA12
# ✅ Formula written to cell FB12
# ✅ Formula written to cell FC12
# ✅ Formula written to cell FD12
# ✅ Formula written to cell FE12
# ✅ Formula written to cell FF12
# ✅ Formula written to cell N13
# ✅ Formula written to cell O13
# ✅ Formula written to cell P13
# ✅ Formula written to cell Q13
# ✅ Formula written to cell R13
# ✅ Formula written to cell S13
# ✅ Formula written to cell T13
# ✅ Formula written to cell U13
# ✅ Formula written to cell V13
# ✅ Formula written to cell W13
# ✅ Formula written to cell X13
# ✅ Formula written to cell Y13
# ✅ Formula written to cell Z13
# ✅ Formula written to cell AA13
# ✅ Formula written to cell AB13
# ✅ Formula written to cell AC13
# ✅ Formula written to cell AD13
# ✅ Formula written to cell AE13
# ✅ Formula written to cell AF13
# ✅ Formula written to cell AG13
# ✅ Formula written to cell AH13
# ✅ Formula written to cell AI13
# ✅ Formula written to cell AJ13
# ✅ Formula written to cell AK13
# ✅ Formula written to cell AL13
# ✅ Formula written to cell AM13
# ✅ Formula written to cell AN13
# ✅ Formula written to cell AO13
# ✅ Formula written to cell AP13
# ✅ Formula written to cell AQ13
# ✅ Formula written to cell AR13
# ✅ Formula written to cell AS13
# ✅ Formula written to cell AT13
# ✅ Formula written to cell AU13
# ✅ Formula written to cell AV13
# ✅ Formula written to cell AW13
# ✅ Formula written to cell AX13
# ✅ Formula written to cell AY13
# ✅ Formula written to cell AZ13
# ✅ Formula written to cell BA13
# ✅ Formula written to cell BB13
# ✅ Formula written to cell BC13
# ✅ Formula written to cell BD13
# ✅ Formula written to cell BE13
# ✅ Formula written to cell BF13
# ✅ Formula written to cell BG13
# ✅ Formula written to cell BH13
# ✅ Formula written to cell BI13
# ✅ Formula written to cell BJ13
# ✅ Formula written to cell BK13
# ✅ Formula written to cell BL13
# ✅ Formula written to cell BM13
# ✅ Formula written to cell BN13
# ✅ Formula written to cell BO13
# ✅ Formula written to cell BP13
# ✅ Formula written to cell BQ13
# ✅ Formula written to cell BR13
# ✅ Formula written to cell BS13
# ✅ Formula written to cell BT13
# ✅ Formula written to cell BU13
# ✅ Formula written to cell BV13
# ✅ Formula written to cell BW13
# ✅ Formula written to cell BX13
# ✅ Formula written to cell BY13
# ✅ Formula written to cell BZ13
# ✅ Formula written to cell CA13
# ✅ Formula written to cell CB13
# ✅ Formula written to cell CC13
# ✅ Formula written to cell CD13
# ✅ Formula written to cell CE13
# ✅ Formula written to cell CF13
# ✅ Formula written to cell CG13
# ✅ Formula written to cell CH13
# ✅ Formula written to cell CI13
# ✅ Formula written to cell CJ13
# ✅ Formula written to cell CK13
# ✅ Formula written to cell CL13
# ✅ Formula written to cell CM13
# ✅ Formula written to cell CN13
# ✅ Formula written to cell CO13
# ✅ Formula written to cell CP13
# ✅ Formula written to cell CQ13
# ✅ Formula written to cell CR13
# ✅ Formula written to cell CS13
# ✅ Formula written to cell CT13
# ✅ Formula written to cell CU13
# ✅ Formula written to cell CV13
# ✅ Formula written to cell CW13
# ✅ Formula written to cell CX13
# ✅ Formula written to cell CY13
# ✅ Formula written to cell CZ13
# ✅ Formula written to cell DA13
# ✅ Formula written to cell DB13
# ✅ Formula written to cell DC13
# ✅ Formula written to cell DD13
# ✅ Formula written to cell DE13
# ✅ Formula written to cell DF13
# ✅ Formula written to cell DG13
# ✅ Formula written to cell DH13
# ✅ Formula written to cell DI13
# ✅ Formula written to cell DJ13
# ✅ Formula written to cell DK13
# ✅ Formula written to cell DL13
# ✅ Formula written to cell DM13
# ✅ Formula written to cell DN13
# ✅ Formula written to cell DO13
# ✅ Formula written to cell DP13
# ✅ Formula written to cell DQ13
# ✅ Formula written to cell DR13
# ✅ Formula written to cell DS13
# ✅ Formula written to cell DT13
# ✅ Formula written to cell DU13
# ✅ Formula written to cell DV13
# ✅ Formula written to cell DW13
# ✅ Formula written to cell DX13
# ✅ Formula written to cell DY13
# ✅ Formula written to cell DZ13
# ✅ Formula written to cell EA13
# ✅ Formula written to cell EB13
# ✅ Formula written to cell EC13
# ✅ Formula written to cell ED13
# ✅ Formula written to cell EE13
# ✅ Formula written to cell EF13
# ✅ Formula written to cell EG13
# ✅ Formula written to cell EH13
# ✅ Formula written to cell EI13
# ✅ Formula written to cell EJ13
# ✅ Formula written to cell EK13
# ✅ Formula written to cell EL13
# ✅ Formula written to cell EM13
# ✅ Formula written to cell EN13
# ✅ Formula written to cell EO13
# ✅ Formula written to cell EP13
# ✅ Formula written to cell EQ13
# ✅ Formula written to cell ER13
# ✅ Formula written to cell ES13
# ✅ Formula written to cell ET13
# ✅ Formula written to cell EU13
# ✅ Formula written to cell EV13
# ✅ Formula written to cell EW13
# ✅ Formula written to cell EX13
# ✅ Formula written to cell EY13
# ✅ Formula written to cell EZ13
# ✅ Formula written to cell FA13
# ✅ Formula written to cell FB13
# ✅ Formula written to cell FC13
# ✅ Formula written to cell FD13
# ✅ Formula written to cell FE13
# ✅ Formula written to cell FF13
# ✅ Formula written to cell N14
# ✅ Formula written to cell O14
# ✅ Formula written to cell P14
# ✅ Formula written to cell Q14
# ✅ Formula written to cell R14
# ✅ Formula written to cell S14
# ✅ Formula written to cell T14
# ✅ Formula written to cell U14
# ✅ Formula written to cell V14
# ✅ Formula written to cell W14
# ✅ Formula written to cell X14
# ✅ Formula written to cell Y14
# ✅ Formula written to cell Z14
# ✅ Formula written to cell AA14
# ✅ Formula written to cell AB14
# ✅ Formula written to cell AC14
# ✅ Formula written to cell AD14
# ✅ Formula written to cell AE14
# ✅ Formula written to cell AF14
# ✅ Formula written to cell AG14
# ✅ Formula written to cell AH14
# ✅ Formula written to cell AI14
# ✅ Formula written to cell AJ14
# ✅ Formula written to cell AK14
# ✅ Formula written to cell AL14
# ✅ Formula written to cell AM14
# ✅ Formula written to cell AN14
# ✅ Formula written to cell AO14
# ✅ Formula written to cell AP14
# ✅ Formula written to cell AQ14
# ✅ Formula written to cell AR14
# ✅ Formula written to cell AS14
# ✅ Formula written to cell AT14
# ✅ Formula written to cell AU14
# ✅ Formula written to cell AV14
# ✅ Formula written to cell AW14
# ✅ Formula written to cell AX14
# ✅ Formula written to cell AY14
# ✅ Formula written to cell AZ14
# ✅ Formula written to cell BA14
# ✅ Formula written to cell BB14
# ✅ Formula written to cell BC14
# ✅ Formula written to cell BD14
# ✅ Formula written to cell BE14
# ✅ Formula written to cell BF14
# ✅ Formula written to cell BG14
# ✅ Formula written to cell BH14
# ✅ Formula written to cell BI14
# ✅ Formula written to cell BJ14
# ✅ Formula written to cell BK14
# ✅ Formula written to cell BL14
# ✅ Formula written to cell BM14
# ✅ Formula written to cell BN14
# ✅ Formula written to cell BO14
# ✅ Formula written to cell BP14
# ✅ Formula written to cell BQ14
# ✅ Formula written to cell BR14
# ✅ Formula written to cell BS14
# ✅ Formula written to cell BT14
# ✅ Formula written to cell BU14
# ✅ Formula written to cell BV14
# ✅ Formula written to cell BW14
# ✅ Formula written to cell BX14
# ✅ Formula written to cell BY14
# ✅ Formula written to cell BZ14
# ✅ Formula written to cell CA14
# ✅ Formula written to cell CB14
# ✅ Formula written to cell CC14
# ✅ Formula written to cell CD14
# ✅ Formula written to cell CE14
# ✅ Formula written to cell CF14
# ✅ Formula written to cell CG14
# ✅ Formula written to cell CH14
# ✅ Formula written to cell CI14
# ✅ Formula written to cell CJ14
# ✅ Formula written to cell CK14
# ✅ Formula written to cell CL14
# ✅ Formula written to cell CM14
# ✅ Formula written to cell CN14
# ✅ Formula written to cell CO14
# ✅ Formula written to cell CP14
# ✅ Formula written to cell CQ14
# ✅ Formula written to cell CR14
# ✅ Formula written to cell CS14
# ✅ Formula written to cell CT14
# ✅ Formula written to cell CU14
# ✅ Formula written to cell CV14
# ✅ Formula written to cell CW14
# ✅ Formula written to cell CX14
# ✅ Formula written to cell CY14
# ✅ Formula written to cell CZ14
# ✅ Formula written to cell DA14
# ✅ Formula written to cell DB14
# ✅ Formula written to cell DC14
# ✅ Formula written to cell DD14
# ✅ Formula written to cell DE14
# ✅ Formula written to cell DF14
# ✅ Formula written to cell DG14
# ✅ Formula written to cell DH14
# ✅ Formula written to cell DI14
# ✅ Formula written to cell DJ14
# ✅ Formula written to cell DK14
# ✅ Formula written to cell DL14
# ✅ Formula written to cell DM14
# ✅ Formula written to cell DN14
# ✅ Formula written to cell DO14
# ✅ Formula written to cell DP14
# ✅ Formula written to cell DQ14
# ✅ Formula written to cell DR14
# ✅ Formula written to cell DS14
# ✅ Formula written to cell DT14
# ✅ Formula written to cell DU14
# ✅ Formula written to cell DV14
# ✅ Formula written to cell DW14
# ✅ Formula written to cell DX14
# ✅ Formula written to cell DY14
# ✅ Formula written to cell DZ14
# ✅ Formula written to cell EA14
# ✅ Formula written to cell EB14
# ✅ Formula written to cell EC14
# ✅ Formula written to cell ED14
# ✅ Formula written to cell EE14
# ✅ Formula written to cell EF14
# ✅ Formula written to cell EG14
# ✅ Formula written to cell EH14
# ✅ Formula written to cell EI14
# ✅ Formula written to cell EJ14
# ✅ Formula written to cell EK14
# ✅ Formula written to cell EL14
# ✅ Formula written to cell EM14
# ✅ Formula written to cell EN14
# ✅ Formula written to cell EO14
# ✅ Formula written to cell EP14
# ✅ Formula written to cell EQ14
# ✅ Formula written to cell ER14
# ✅ Formula written to cell ES14
# ✅ Formula written to cell ET14
# ✅ Formula written to cell EU14
# ✅ Formula written to cell EV14
# ✅ Formula written to cell EW14
# ✅ Formula written to cell EX14
# ✅ Formula written to cell EY14
# ✅ Formula written to cell EZ14
# ✅ Formula written to cell FA14
# ✅ Formula written to cell FB14
# ✅ Formula written to cell FC14
# ✅ Formula written to cell FD14
# ✅ Formula written to cell FE14
# ✅ Formula written to cell FF14
# ✅ Formula written to cell N15
# ✅ Formula written to cell O15
# ✅ Formula written to cell P15
# ✅ Formula written to cell Q15
# ✅ Formula written to cell R15
# ✅ Formula written to cell S15
# ✅ Formula written to cell T15
# ✅ Formula written to cell U15
# ✅ Formula written to cell V15
# ✅ Formula written to cell W15
# ✅ Formula written to cell X15
# ✅ Formula written to cell Y15
# ✅ Formula written to cell Z15
# ✅ Formula written to cell AA15
# ✅ Formula written to cell AB15
# ✅ Formula written to cell AC15
# ✅ Formula written to cell AD15
# ✅ Formula written to cell AE15
# ✅ Formula written to cell AF15
# ✅ Formula written to cell AG15
# ✅ Formula written to cell AH15
# ✅ Formula written to cell AI15
# ✅ Formula written to cell AJ15
# ✅ Formula written to cell AK15
# ✅ Formula written to cell AL15
# ✅ Formula written to cell AM15
# ✅ Formula written to cell AN15
# ✅ Formula written to cell AO15
# ✅ Formula written to cell AP15
# ✅ Formula written to cell AQ15
# ✅ Formula written to cell AR15
# ✅ Formula written to cell AS15
# ✅ Formula written to cell AT15
# ✅ Formula written to cell AU15
# ✅ Formula written to cell AV15
# ✅ Formula written to cell AW15
# ✅ Formula written to cell AX15
# ✅ Formula written to cell AY15
# ✅ Formula written to cell AZ15
# ✅ Formula written to cell BA15
# ✅ Formula written to cell BB15
# ✅ Formula written to cell BC15
# ✅ Formula written to cell BD15
# ✅ Formula written to cell BE15
# ✅ Formula written to cell BF15
# ✅ Formula written to cell BG15
# ✅ Formula written to cell BH15
# ✅ Formula written to cell BI15
# ✅ Formula written to cell BJ15
# ✅ Formula written to cell BK15
# ✅ Formula written to cell BL15
# ✅ Formula written to cell BM15
# ✅ Formula written to cell BN15
# ✅ Formula written to cell BO15
# ✅ Formula written to cell BP15
# ✅ Formula written to cell BQ15
# ✅ Formula written to cell BR15
# ✅ Formula written to cell BS15
# ✅ Formula written to cell BT15
# ✅ Formula written to cell BU15
# ✅ Formula written to cell BV15
# ✅ Formula written to cell BW15
# ✅ Formula written to cell BX15
# ✅ Formula written to cell BY15
# ✅ Formula written to cell BZ15
# ✅ Formula written to cell CA15
# ✅ Formula written to cell CB15
# ✅ Formula written to cell CC15
# ✅ Formula written to cell CD15
# ✅ Formula written to cell CE15
# ✅ Formula written to cell CF15
# ✅ Formula written to cell CG15
# ✅ Formula written to cell CH15
# ✅ Formula written to cell CI15
# ✅ Formula written to cell CJ15
# ✅ Formula written to cell CK15
# ✅ Formula written to cell CL15
# ✅ Formula written to cell CM15
# ✅ Formula written to cell CN15
# ✅ Formula written to cell CO15
# ✅ Formula written to cell CP15
# ✅ Formula written to cell CQ15
# ✅ Formula written to cell CR15
# ✅ Formula written to cell CS15
# ✅ Formula written to cell CT15
# ✅ Formula written to cell CU15
# ✅ Formula written to cell CV15
# ✅ Formula written to cell CW15
# ✅ Formula written to cell CX15
# ✅ Formula written to cell CY15
# ✅ Formula written to cell CZ15
# ✅ Formula written to cell DA15
# ✅ Formula written to cell DB15
# ✅ Formula written to cell DC15
# ✅ Formula written to cell DD15
# ✅ Formula written to cell DE15
# ✅ Formula written to cell DF15
# ✅ Formula written to cell DG15
# ✅ Formula written to cell DH15
# ✅ Formula written to cell DI15
# ✅ Formula written to cell DJ15
# ✅ Formula written to cell DK15
# ✅ Formula written to cell DL15
# ✅ Formula written to cell DM15
# ✅ Formula written to cell DN15
# ✅ Formula written to cell DO15
# ✅ Formula written to cell DP15
# ✅ Formula written to cell DQ15
# ✅ Formula written to cell DR15
# ✅ Formula written to cell DS15
# ✅ Formula written to cell DT15
# ✅ Formula written to cell DU15
# ✅ Formula written to cell DV15
# ✅ Formula written to cell DW15
# ✅ Formula written to cell DX15
# ✅ Formula written to cell DY15
# ✅ Formula written to cell DZ15
# ✅ Formula written to cell EA15
# ✅ Formula written to cell EB15
# ✅ Formula written to cell EC15
# ✅ Formula written to cell ED15
# ✅ Formula written to cell EE15
# ✅ Formula written to cell EF15
# ✅ Formula written to cell EG15
# ✅ Formula written to cell EH15
# ✅ Formula written to cell EI15
# ✅ Formula written to cell EJ15
# ✅ Formula written to cell EK15
# ✅ Formula written to cell EL15
# ✅ Formula written to cell EM15
# ✅ Formula written to cell EN15
# ✅ Formula written to cell EO15
# ✅ Formula written to cell EP15
# ✅ Formula written to cell EQ15
# ✅ Formula written to cell ER15
# ✅ Formula written to cell ES15
# ✅ Formula written to cell ET15
# ✅ Formula written to cell EU15
# ✅ Formula written to cell EV15
# ✅ Formula written to cell EW15
# ✅ Formula written to cell EX15
# ✅ Formula written to cell EY15
# ✅ Formula written to cell EZ15
# ✅ Formula written to cell FA15
# ✅ Formula written to cell FB15
# ✅ Formula written to cell FC15
# ✅ Formula written to cell FD15
# ✅ Formula written to cell FE15
# ✅ Formula written to cell FF15
# ✅ Formula written to cell N16
# ✅ Formula written to cell O16
# ✅ Formula written to cell P16
# ✅ Formula written to cell Q16
# ✅ Formula written to cell R16
# ✅ Formula written to cell S16
# ✅ Formula written to cell T16
# ✅ Formula written to cell U16
# ✅ Formula written to cell V16
# ✅ Formula written to cell W16
# ✅ Formula written to cell X16
# ✅ Formula written to cell Y16
# ✅ Formula written to cell Z16
# ✅ Formula written to cell AA16
# ✅ Formula written to cell AB16
# ✅ Formula written to cell AC16
# ✅ Formula written to cell AD16
# ✅ Formula written to cell AE16
# ✅ Formula written to cell AF16
# ✅ Formula written to cell AG16
# ✅ Formula written to cell AH16
# ✅ Formula written to cell AI16
# ✅ Formula written to cell AJ16
# ✅ Formula written to cell AK16
# ✅ Formula written to cell AL16
# ✅ Formula written to cell AM16
# ✅ Formula written to cell AN16
# ✅ Formula written to cell AO16
# ✅ Formula written to cell AP16
# ✅ Formula written to cell AQ16
# ✅ Formula written to cell AR16
# ✅ Formula written to cell AS16
# ✅ Formula written to cell AT16
# ✅ Formula written to cell AU16
# ✅ Formula written to cell AV16
# ✅ Formula written to cell AW16
# ✅ Formula written to cell AX16
# ✅ Formula written to cell AY16
# ✅ Formula written to cell AZ16
# ✅ Formula written to cell BA16
# ✅ Formula written to cell BB16
# ✅ Formula written to cell BC16
# ✅ Formula written to cell BD16
# ✅ Formula written to cell BE16
# ✅ Formula written to cell BF16
# ✅ Formula written to cell BG16
# ✅ Formula written to cell BH16
# ✅ Formula written to cell BI16
# ✅ Formula written to cell BJ16
# ✅ Formula written to cell BK16
# ✅ Formula written to cell BL16
# ✅ Formula written to cell BM16
# ✅ Formula written to cell BN16
# ✅ Formula written to cell BO16
# ✅ Formula written to cell BP16
# ✅ Formula written to cell BQ16
# ✅ Formula written to cell BR16
# ✅ Formula written to cell BS16
# ✅ Formula written to cell BT16
# ✅ Formula written to cell BU16
# ✅ Formula written to cell BV16
# ✅ Formula written to cell BW16
# ✅ Formula written to cell BX16
# ✅ Formula written to cell BY16
# ✅ Formula written to cell BZ16
# ✅ Formula written to cell CA16
# ✅ Formula written to cell CB16
# ✅ Formula written to cell CC16
# ✅ Formula written to cell CD16
# ✅ Formula written to cell CE16
# ✅ Formula written to cell CF16
# ✅ Formula written to cell CG16
# ✅ Formula written to cell CH16
# ✅ Formula written to cell CI16
# ✅ Formula written to cell CJ16
# ✅ Formula written to cell CK16
# ✅ Formula written to cell CL16
# ✅ Formula written to cell CM16
# ✅ Formula written to cell CN16
# ✅ Formula written to cell CO16
# ...
# ✅ Formula written to cell CQ17
# ✅ Formula written to cell CR17
# ✅ Formula written to cell CS17
# ✅ Formula written to cell CT17
# ✅ Formula written to cell CU17
# ✅ Formula written to cell CV17
# ✅ Formula written to cell CW17
# ✅ Formula written to cell CX17
# ✅ Formula written to cell CY17
# ✅ Formula written to cell CZ17
# ✅ Formula written to cell DA17
# ✅ Formula written to cell DB17
# ✅ Formula written to cell DC17
# ✅ Formula written to cell DD17
# ✅ Formula written to cell DE17
# ✅ Formula written to cell DF17
# ✅ Formula written to cell DG17
# ✅ Formula written to cell DH17
# ✅ Formula written to cell DI17
# ✅ Formula written to cell DJ17
# ✅ Formula written to cell DK17
# ✅ Formula written to cell DL17
# ✅ Formula written to cell DM17
# ✅ Formula written to cell DN17
# ✅ Formula written to cell DO17
# ✅ Formula written to cell DP17
# ✅ Formula written to cell DQ17
# ✅ Formula written to cell DR17
# ✅ Formula written to cell DS17
# ✅ Formula written to cell DT17
# ✅ Formula written to cell DU17
# ✅ Formula written to cell DV17
# ✅ Formula written to cell DW17
# ✅ Formula written to cell DX17
# ✅ Formula written to cell DY17
# ✅ Formula written to cell DZ17
# ✅ Formula written to cell EA17
# ✅ Formula written to cell EB17
# ✅ Formula written to cell EC17
# ✅ Formula written to cell ED17
# ✅ Formula written to cell EE17
# ✅ Formula written to cell EF17
# ✅ Formula written to cell EG17
# ✅ Formula written to cell EH17
# ✅ Formula written to cell EI17
# ✅ Formula written to cell EJ17
# ✅ Formula written to cell EK17
# ✅ Formula written to cell EL17
# ✅ Formula written to cell EM17
# ✅ Formula written to cell EN17
# ✅ Formula written to cell EO17
# ✅ Formula written to cell EP17
# ✅ Formula written to cell EQ17
# ✅ Formula written to cell ER17
# ✅ Formula written to cell ES17
# ✅ Formula written to cell ET17
# ✅ Formula written to cell EU17
# ✅ Formula written to cell EV17
# ✅ Formula written to cell EW17
# ✅ Formula written to cell EX17
# ✅ Formula written to cell EY17
# ✅ Formula written to cell EZ17
# ✅ Formula written to cell FA17
# ✅ Formula written to cell FB17
# ✅ Formula written to cell FC17
# ✅ Formula written to cell FD17
# ✅ Formula written to cell FE17
# ✅ Formula written to cell FF17
# ✅ Formula written to cell N18
# ✅ Formula written to cell O18
# ✅ Formula written to cell P18
# ✅ Formula written to cell Q18
# ✅ Formula written to cell R18
# ✅ Formula written to cell S18
# ✅ Formula written to cell T18
# ✅ Formula written to cell U18
# ✅ Formula written to cell V18
# ✅ Formula written to cell W18
# ✅ Formula written to cell X18
# ✅ Formula written to cell Y18
# ✅ Formula written to cell Z18
# ✅ Formula written to cell AA18
# ✅ Formula written to cell AB18
# ✅ Formula written to cell AC18
# ✅ Formula written to cell AD18
# ✅ Formula written to cell AE18
# ✅ Formula written to cell AF18
# ✅ Formula written to cell AG18
# ✅ Formula written to cell AH18
# ✅ Formula written to cell AI18
# ✅ Formula written to cell AJ18
# ✅ Formula written to cell AK18
# ✅ Formula written to cell AL18
# ✅ Formula written to cell AM18
# ✅ Formula written to cell AN18
# ✅ Formula written to cell AO18
# ✅ Formula written to cell AP18
# ✅ Formula written to cell AQ18
# ✅ Formula written to cell AR18
# ✅ Formula written to cell AS18
# ✅ Formula written to cell AT18
# ✅ Formula written to cell AU18
# ✅ Formula written to cell AV18
# ✅ Formula written to cell AW18
# ✅ Formula written to cell AX18
# ✅ Formula written to cell AY18
# ✅ Formula written to cell AZ18
# ✅ Formula written to cell BA18
# ✅ Formula written to cell BB18
# ✅ Formula written to cell BC18
# ✅ Formula written to cell BD18
# ✅ Formula written to cell BE18
# ✅ Formula written to cell BF18
# ✅ Formula written to cell BG18
# ✅ Formula written to cell BH18
# ✅ Formula written to cell BI18
# ✅ Formula written to cell BJ18
# ✅ Formula written to cell BK18
# ✅ Formula written to cell BL18
# ✅ Formula written to cell BM18
# ✅ Formula written to cell BN18
# ✅ Formula written to cell BO18
# ✅ Formula written to cell BP18
# ✅ Formula written to cell BQ18
# ✅ Formula written to cell BR18
# ✅ Formula written to cell BS18
# ✅ Formula written to cell BT18
# ✅ Formula written to cell BU18
# ✅ Formula written to cell BV18
# ✅ Formula written to cell BW18
# ✅ Formula written to cell BX18
# ✅ Formula written to cell BY18
# ✅ Formula written to cell BZ18
# ✅ Formula written to cell CA18
# ✅ Formula written to cell CB18
# ✅ Formula written to cell CC18
# ✅ Formula written to cell CD18
# ✅ Formula written to cell CE18
# ✅ Formula written to cell CF18
# ✅ Formula written to cell CG18
# ✅ Formula written to cell CH18
# ✅ Formula written to cell CI18
# ✅ Formula written to cell CJ18
# ✅ Formula written to cell CK18
# ✅ Formula written to cell CL18
# ✅ Formula written to cell CM18
# ✅ Formula written to cell CN18
# ✅ Formula written to cell CO18
# ✅ Formula written to cell CP18
# ✅ Formula written to cell CQ18
# ✅ Formula written to cell CR18
# ✅ Formula written to cell CS18
# ✅ Formula written to cell CT18
# ✅ Formula written to cell CU18
# ✅ Formula written to cell CV18
# ✅ Formula written to cell CW18
# ✅ Formula written to cell CX18
# ✅ Formula written to cell CY18
# ✅ Formula written to cell CZ18
# ✅ Formula written to cell DA18
# ✅ Formula written to cell DB18
# ✅ Formula written to cell DC18
# ✅ Formula written to cell DD18
# ✅ Formula written to cell DE18
# ✅ Formula written to cell DF18
# ✅ Formula written to cell DG18
# ✅ Formula written to cell DH18
# ✅ Formula written to cell DI18
# ✅ Formula written to cell DJ18
# ✅ Formula written to cell DK18
# ✅ Formula written to cell DL18
# ✅ Formula written to cell DM18
# ✅ Formula written to cell DN18
# ✅ Formula written to cell DO18
# ✅ Formula written to cell DP18
# ✅ Formula written to cell DQ18
# ✅ Formula written to cell DR18
# ✅ Formula written to cell DS18
# ✅ Formula written to cell DT18
# ✅ Formula written to cell DU18
# ✅ Formula written to cell DV18
# ✅ Formula written to cell DW18
# ✅ Formula written to cell DX18
# ✅ Formula written to cell DY18
# ✅ Formula written to cell DZ18
# ✅ Formula written to cell EA18
# ✅ Formula written to cell EB18
# ✅ Formula written to cell EC18
# ✅ Formula written to cell ED18
# ✅ Formula written to cell EE18
# ✅ Formula written to cell EF18
# ✅ Formula written to cell EG18
# ✅ Formula written to cell EH18
# ✅ Formula written to cell EI18
# ✅ Formula written to cell EJ18
# ✅ Formula written to cell EK18
# ✅ Formula written to cell EL18
# ✅ Formula written to cell EM18
# ✅ Formula written to cell EN18
# ✅ Formula written to cell EO18
# ✅ Formula written to cell EP18
# ✅ Formula written to cell EQ18
# ✅ Formula written to cell ER18
# ✅ Formula written to cell ES18
# ✅ Formula written to cell ET18
# ✅ Formula written to cell EU18
# ✅ Formula written to cell EV18
# ✅ Formula written to cell EW18
# ✅ Formula written to cell EX18
# ✅ Formula written to cell EY18
# ✅ Formula written to cell EZ18
# ✅ Formula written to cell FA18
# ✅ Formula written to cell FB18
# ✅ Formula written to cell FC18
# ✅ Formula written to cell FD18
# ✅ Formula written to cell FE18
# ✅ Formula written to cell FF18
# ✅ Formula written to cell N19
# ✅ Formula written to cell O19
# ✅ Formula written to cell P19
# ✅ Formula written to cell Q19
# ✅ Formula written to cell R19
# ✅ Formula written to cell S19
# ✅ Formula written to cell T19
# ✅ Formula written to cell U19
# ✅ Formula written to cell V19
# ✅ Formula written to cell W19
# ✅ Formula written to cell X19
# ✅ Formula written to cell Y19
# ✅ Formula written to cell Z19
# ✅ Formula written to cell AA19
# ✅ Formula written to cell AB19
# ✅ Formula written to cell AC19
# ✅ Formula written to cell AD19
# ✅ Formula written to cell AE19
# ✅ Formula written to cell AF19
# ✅ Formula written to cell AG19
# ✅ Formula written to cell AH19
# ✅ Formula written to cell AI19
# ✅ Formula written to cell AJ19
# ✅ Formula written to cell AK19
# ✅ Formula written to cell AL19
# ✅ Formula written to cell AM19
# ✅ Formula written to cell AN19
# ✅ Formula written to cell AO19
# ✅ Formula written to cell AP19
# ✅ Formula written to cell AQ19
# ✅ Formula written to cell AR19
# ✅ Formula written to cell AS19
# ✅ Formula written to cell AT19
# ✅ Formula written to cell AU19
# ✅ Formula written to cell AV19
# ✅ Formula written to cell AW19
# ✅ Formula written to cell AX19
# ✅ Formula written to cell AY19
# ✅ Formula written to cell AZ19
# ✅ Formula written to cell BA19
# ✅ Formula written to cell BB19
# ✅ Formula written to cell BC19
# ✅ Formula written to cell BD19
# ✅ Formula written to cell BE19
# ✅ Formula written to cell BF19
# ✅ Formula written to cell BG19
# ✅ Formula written to cell BH19
# ✅ Formula written to cell BI19
# ✅ Formula written to cell BJ19
# ✅ Formula written to cell BK19
# ✅ Formula written to cell BL19
# ✅ Formula written to cell BM19
# ✅ Formula written to cell BN19
# ✅ Formula written to cell BO19
# ✅ Formula written to cell BP19
# ✅ Formula written to cell BQ19
# ✅ Formula written to cell BR19
# ✅ Formula written to cell BS19
# ✅ Formula written to cell BT19
# ✅ Formula written to cell BU19
# ✅ Formula written to cell BV19
# ✅ Formula written to cell BW19
# ✅ Formula written to cell BX19
# ✅ Formula written to cell BY19
# ✅ Formula written to cell BZ19
# ✅ Formula written to cell CA19
# ✅ Formula written to cell CB19
# ✅ Formula written to cell CC19
# ✅ Formula written to cell CD19
# ✅ Formula written to cell CE19
# ✅ Formula written to cell CF19
# ✅ Formula written to cell CG19
# ✅ Formula written to cell CH19
# ✅ Formula written to cell CI19
# ✅ Formula written to cell CJ19
# ✅ Formula written to cell CK19
# ✅ Formula written to cell CL19
# ✅ Formula written to cell CM19
# ✅ Formula written to cell CN19
# ✅ Formula written to cell CO19
# ✅ Formula written to cell CP19
# ✅ Formula written to cell CQ19
# ✅ Formula written to cell CR19
# ✅ Formula written to cell CS19
# ✅ Formula written to cell CT19
# ✅ Formula written to cell CU19
# ✅ Formula written to cell CV19
# ✅ Formula written to cell CW19
# ✅ Formula written to cell CX19
# ✅ Formula written to cell CY19
# ✅ Formula written to cell CZ19
# ✅ Formula written to cell DA19
# ✅ Formula written to cell DB19
# ✅ Formula written to cell DC19
# ✅ Formula written to cell DD19
# ✅ Formula written to cell DE19
# ✅ Formula written to cell DF19
# ✅ Formula written to cell DG19
# ✅ Formula written to cell DH19
# ✅ Formula written to cell DI19
# ✅ Formula written to cell DJ19
# ✅ Formula written to cell DK19
# ✅ Formula written to cell DL19
# ✅ Formula written to cell DM19
# ✅ Formula written to cell DN19
# ✅ Formula written to cell DO19
# ✅ Formula written to cell DP19
# ✅ Formula written to cell DQ19
# ✅ Formula written to cell DR19
# ✅ Formula written to cell DS19
# ✅ Formula written to cell DT19
# ✅ Formula written to cell DU19
# ✅ Formula written to cell DV19
# ✅ Formula written to cell DW19
# ✅ Formula written to cell DX19
# ✅ Formula written to cell DY19
# ✅ Formula written to cell DZ19
# ✅ Formula written to cell EA19
# ✅ Formula written to cell EB19
# ✅ Formula written to cell EC19
# ✅ Formula written to cell ED19
# ✅ Formula written to cell EE19
# ✅ Formula written to cell EF19
# ✅ Formula written to cell EG19
# ✅ Formula written to cell EH19
# ✅ Formula written to cell EI19
# ✅ Formula written to cell EJ19
# ✅ Formula written to cell EK19
# ✅ Formula written to cell EL19
# ✅ Formula written to cell EM19
# ✅ Formula written to cell EN19
# ✅ Formula written to cell EO19
# ✅ Formula written to cell EP19
# ✅ Formula written to cell EQ19
# ✅ Formula written to cell ER19
# ✅ Formula written to cell ES19
# ✅ Formula written to cell ET19
# ✅ Formula written to cell EU19
# ✅ Formula written to cell EV19
# ✅ Formula written to cell EW19
# ✅ Formula written to cell EX19
# ✅ Formula written to cell EY19
# ✅ Formula written to cell EZ19
# ✅ Formula written to cell FA19
# ✅ Formula written to cell FB19
# ✅ Formula written to cell FC19
# ✅ Formula written to cell FD19
# ✅ Formula written to cell FE19
# ✅ Formula written to cell FF19
# ✅ Formula written to cell N20
# ✅ Formula written to cell O20
# ✅ Formula written to cell P20
# ✅ Formula written to cell Q20
# ✅ Formula written to cell R20
# ✅ Formula written to cell S20
# ✅ Formula written to cell T20
# ✅ Formula written to cell U20
# ✅ Formula written to cell V20
# ✅ Formula written to cell W20
# ✅ Formula written to cell X20
# ✅ Formula written to cell Y20
# ✅ Formula written to cell Z20
# ✅ Formula written to cell AA20
# ✅ Formula written to cell AB20
# ✅ Formula written to cell AC20
# ✅ Formula written to cell AD20
# ✅ Formula written to cell AE20
# ✅ Formula written to cell AF20
# ✅ Formula written to cell AG20
# ✅ Formula written to cell AH20
# ✅ Formula written to cell AI20
# ✅ Formula written to cell AJ20
# ✅ Formula written to cell AK20
# ✅ Formula written to cell AL20
# ✅ Formula written to cell AM20
# ✅ Formula written to cell AN20
# ✅ Formula written to cell AO20
# ✅ Formula written to cell AP20
# ✅ Formula written to cell AQ20
# ✅ Formula written to cell AR20
# ✅ Formula written to cell AS20
# ✅ Formula written to cell AT20
# ✅ Formula written to cell AU20
# ✅ Formula written to cell AV20
# ✅ Formula written to cell AW20
# ✅ Formula written to cell AX20
# ✅ Formula written to cell AY20
# ✅ Formula written to cell AZ20
# ✅ Formula written to cell BA20
# ✅ Formula written to cell BB20
# ✅ Formula written to cell BC20
# ✅ Formula written to cell BD20
# ✅ Formula written to cell BE20
# ✅ Formula written to cell BF20
# ✅ Formula written to cell BG20
# ✅ Formula written to cell BH20
# ✅ Formula written to cell BI20
# ✅ Formula written to cell BJ20
# ✅ Formula written to cell BK20
# ✅ Formula written to cell BL20
# ✅ Formula written to cell BM20
# ✅ Formula written to cell BN20
# ✅ Formula written to cell BO20
# ✅ Formula written to cell BP20
# ✅ Formula written to cell BQ20
# ✅ Formula written to cell BR20
# ✅ Formula written to cell BS20
# ✅ Formula written to cell BT20
# ✅ Formula written to cell BU20
# ✅ Formula written to cell BV20
# ✅ Formula written to cell BW20
# ✅ Formula written to cell BX20
# ✅ Formula written to cell BY20
# ✅ Formula written to cell BZ20
# ✅ Formula written to cell CA20
# ✅ Formula written to cell CB20
# ✅ Formula written to cell CC20
# ✅ Formula written to cell CD20
# ✅ Formula written to cell CE20
# ✅ Formula written to cell CF20
# ✅ Formula written to cell CG20
# ✅ Formula written to cell CH20
# ✅ Formula written to cell CI20
# ✅ Formula written to cell CJ20
# ✅ Formula written to cell CK20
# ✅ Formula written to cell CL20
# ✅ Formula written to cell CM20
# ✅ Formula written to cell CN20
# ✅ Formula written to cell CO20
# ✅ Formula written to cell CP20
# ✅ Formula written to cell CQ20
# ✅ Formula written to cell CR20
# ✅ Formula written to cell CS20
# ✅ Formula written to cell CT20
# ✅ Formula written to cell CU20
# ✅ Formula written to cell CV20
# ✅ Formula written to cell CW20
# ✅ Formula written to cell CX20
# ✅ Formula written to cell CY20
# ✅ Formula written to cell CZ20
# ✅ Formula written to cell DA20
# ✅ Formula written to cell DB20
# ✅ Formula written to cell DC20
# ✅ Formula written to cell DD20
# ✅ Formula written to cell DE20
# ✅ Formula written to cell DF20
# ✅ Formula written to cell DG20
# ✅ Formula written to cell DH20
# ✅ Formula written to cell DI20
# ✅ Formula written to cell DJ20
# ✅ Formula written to cell DK20
# ✅ Formula written to cell DL20
# ✅ Formula written to cell DM20
# ✅ Formula written to cell DN20
# ✅ Formula written to cell DO20
# ✅ Formula written to cell DP20
# ✅ Formula written to cell DQ20
# ✅ Formula written to cell DR20
# ✅ Formula written to cell DS20
# ✅ Formula written to cell DT20
# ✅ Formula written to cell DU20
# ✅ Formula written to cell DV20
# ✅ Formula written to cell DW20
# ✅ Formula written to cell DX20
# ✅ Formula written to cell DY20
# ✅ Formula written to cell DZ20
# ✅ Formula written to cell EA20
# ✅ Formula written to cell EB20
# ✅ Formula written to cell EC20
# ✅ Formula written to cell ED20
# ✅ Formula written to cell EE20
# ✅ Formula written to cell EF20
# ✅ Formula written to cell EG20
# ✅ Formula written to cell EH20
# ✅ Formula written to cell EI20
# ✅ Formula written to cell EJ20
# ✅ Formula written to cell EK20
# ✅ Formula written to cell EL20
# ✅ Formula written to cell EM20
# ✅ Formula written to cell EN20
# ✅ Formula written to cell EO20
# ✅ Formula written to cell EP20
# ✅ Formula written to cell EQ20
# ✅ Formula written to cell ER20
# ✅ Formula written to cell ES20
# ✅ Formula written to cell ET20
# ✅ Formula written to cell EU20
# ✅ Formula written to cell EV20
# ✅ Formula written to cell EW20
# ✅ Formula written to cell EX20
# ✅ Formula written to cell EY20
# ✅ Formula written to cell EZ20
# ✅ Formula written to cell FA20
# ✅ Formula written to cell FB20
# ✅ Formula written to cell FC20
# ✅ Formula written to cell FD20
# ✅ Formula written to cell FE20
# ✅ Formula written to cell FF20
# ✅ Spreadsheet exported successfully to pricelist5.xlsx

# %%
#EXPORTING SPREADSHEET FINAL APPROACH WITH N6 EDIT
#(fetching spreadsheet.dashboard not working as it only get the odoo. formula, without the associated value)
#Using spreadsheet.dashboard.share is a workaround

import os
import json
import base64
import xmlrpc.client
from dotenv import load_dotenv
import xlsxwriter
import openpyxl
import time

# Load environment variables
load_dotenv(override=True)

JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo
common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common")
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object")

# Step 1: Get spreadsheet JSON (binary field)
spreadsheets = models.execute_kw(
    JUSTFRAMEIT_ODOO_DB,
    uid,
    JUSTFRAMEIT_ODOO_API_KEY,
    'spreadsheet.dashboard.share',
    'search_read',
    [[('display_name', '=', 'Price List 1 (to share)')]],
    {'fields': ['id', 'display_name', 'spreadsheet_data'], 'limit': 1, 'order': 'create_date desc'}
)

if not spreadsheets:
    raise Exception("❌ No spreadsheet found with name 'Price List 1 (to share)'.")

spreadsheet = spreadsheets[0]
print(f"✅ Found spreadsheet: {spreadsheet['display_name']} (ID {spreadsheet['id']})")

# Parse the spreadsheet data
data = json.loads(spreadsheet['spreadsheet_data'])

# Create workbook
workbook = xlsxwriter.Workbook('pricelist5.xlsx')

for sheet_index, sheet in enumerate(data['sheets']):
    worksheet = workbook.add_worksheet(sheet['name'])
    worksheet.use_future_functions = True
    
    # Set values
    for cell_ref, value in sheet['cells'].items():
        col = openpyxl.utils.column_index_from_string(''.join(filter(str.isalpha, cell_ref))) - 1
        row = int(''.join(filter(str.isdigit, cell_ref))) - 1
        
        # Convert string numbers to float if possible
        if isinstance(value, str):
            try:
                value = float(value)
            except ValueError:
                pass
                
        worksheet.write(row, col, value)
    
    # Add formula to N6:FF2000 only for the first sheet
    if sheet_index == 0:
        formula = '=(IF($H6=$M$4,N$4*$I6,N$3*$I6)+(INDEX(FILTER(\'Service Duration\'!$D$1:$D$400,(\'Service Duration\'!$A$1:$A$400=$J6)*(\'Service Duration\'!$C$1:$C$400=MINIFS(\'Service Duration\'!$C$1:$C$400,\'Service Duration\'!$A$1:$A$400,$J6,\'Service Duration\'!$C$1:$C$400,">="&IF($H6=$M$4,N$4,N$3)))),1))*$L6/3600)*(1+$M6)'
        
        # N is column 13 (0-indexed), FF is column 161
        start_col = 13  # N
        end_col = 161   # FF
        start_row = 5   # Row 6 (0-indexed)
        end_row = 1999  # Row 2000 (0-indexed)
        
        total_rows = end_row - start_row + 1
        start_time = time.time()
        
        for row in range(start_row, end_row + 1):
            for col in range(start_col, end_col + 1):
                # Adjust formula for each row and column
                col_letter = openpyxl.utils.get_column_letter(col + 1)
                
                # Log check for each column to determine when to display dimension
                if row == start_row:  # Only log once per column (first row)
                    print(f"📊 Column {col_letter} (index {col}): Processing formulas for rows {start_row+1} to {end_row+1}")
                
                adjusted_formula = formula.replace('N$4', f'{col_letter}$4').replace('N$3', f'{col_letter}$3').replace('$H6', f'$H{row+1}').replace('$I6', f'$I{row+1}').replace('$J6', f'$J{row+1}').replace('$L6', f'$L{row+1}').replace('$M6', f'$M{row+1}')
                worksheet.write_formula(row, col, adjusted_formula)
            
            # Log every 10 rows with estimated time remaining
            if (row - start_row + 1) % 10 == 0:
                rows_processed = row - start_row + 1
                elapsed_time = time.time() - start_time
                avg_time_per_row = elapsed_time / rows_processed
                rows_remaining = total_rows - rows_processed
                estimated_time_remaining = avg_time_per_row * rows_remaining
                
                # Format time as minutes and seconds
                minutes = int(estimated_time_remaining // 60)
                seconds = int(estimated_time_remaining % 60)
                time_str = f"{minutes}m {seconds}s"
                
                print(f"✅ Processed {rows_processed}/{total_rows} rows (up to row {row+1}) - Estimated time remaining: {time_str}")

workbook.close()
print(f"✅ Spreadsheet exported successfully to pricelist5.xlsx")
# Out:
# ✅ Found spreadsheet: Price List 1 (to share) (ID 42)
# 📊 Column N (index 13): Processing formulas for rows 6 to 2000
# 📊 Column O (index 14): Processing formulas for rows 6 to 2000
# 📊 Column P (index 15): Processing formulas for rows 6 to 2000
# 📊 Column Q (index 16): Processing formulas for rows 6 to 2000
# 📊 Column R (index 17): Processing formulas for rows 6 to 2000
# 📊 Column S (index 18): Processing formulas for rows 6 to 2000
# 📊 Column T (index 19): Processing formulas for rows 6 to 2000
# 📊 Column U (index 20): Processing formulas for rows 6 to 2000
# 📊 Column V (index 21): Processing formulas for rows 6 to 2000
# 📊 Column W (index 22): Processing formulas for rows 6 to 2000
# 📊 Column X (index 23): Processing formulas for rows 6 to 2000
# 📊 Column Y (index 24): Processing formulas for rows 6 to 2000
# 📊 Column Z (index 25): Processing formulas for rows 6 to 2000
# 📊 Column AA (index 26): Processing formulas for rows 6 to 2000
# 📊 Column AB (index 27): Processing formulas for rows 6 to 2000
# 📊 Column AC (index 28): Processing formulas for rows 6 to 2000
# 📊 Column AD (index 29): Processing formulas for rows 6 to 2000
# 📊 Column AE (index 30): Processing formulas for rows 6 to 2000
# 📊 Column AF (index 31): Processing formulas for rows 6 to 2000
# 📊 Column AG (index 32): Processing formulas for rows 6 to 2000
# 📊 Column AH (index 33): Processing formulas for rows 6 to 2000
# 📊 Column AI (index 34): Processing formulas for rows 6 to 2000
# 📊 Column AJ (index 35): Processing formulas for rows 6 to 2000
# 📊 Column AK (index 36): Processing formulas for rows 6 to 2000
# 📊 Column AL (index 37): Processing formulas for rows 6 to 2000
# 📊 Column AM (index 38): Processing formulas for rows 6 to 2000
# 📊 Column AN (index 39): Processing formulas for rows 6 to 2000
# 📊 Column AO (index 40): Processing formulas for rows 6 to 2000
# 📊 Column AP (index 41): Processing formulas for rows 6 to 2000
# 📊 Column AQ (index 42): Processing formulas for rows 6 to 2000
# 📊 Column AR (index 43): Processing formulas for rows 6 to 2000
# 📊 Column AS (index 44): Processing formulas for rows 6 to 2000
# 📊 Column AT (index 45): Processing formulas for rows 6 to 2000
# 📊 Column AU (index 46): Processing formulas for rows 6 to 2000
# 📊 Column AV (index 47): Processing formulas for rows 6 to 2000
# 📊 Column AW (index 48): Processing formulas for rows 6 to 2000
# 📊 Column AX (index 49): Processing formulas for rows 6 to 2000
# 📊 Column AY (index 50): Processing formulas for rows 6 to 2000
# 📊 Column AZ (index 51): Processing formulas for rows 6 to 2000
# 📊 Column BA (index 52): Processing formulas for rows 6 to 2000
# 📊 Column BB (index 53): Processing formulas for rows 6 to 2000
# 📊 Column BC (index 54): Processing formulas for rows 6 to 2000
# 📊 Column BD (index 55): Processing formulas for rows 6 to 2000
# 📊 Column BE (index 56): Processing formulas for rows 6 to 2000
# 📊 Column BF (index 57): Processing formulas for rows 6 to 2000
# 📊 Column BG (index 58): Processing formulas for rows 6 to 2000
# 📊 Column BH (index 59): Processing formulas for rows 6 to 2000
# 📊 Column BI (index 60): Processing formulas for rows 6 to 2000
# 📊 Column BJ (index 61): Processing formulas for rows 6 to 2000
# 📊 Column BK (index 62): Processing formulas for rows 6 to 2000
# 📊 Column BL (index 63): Processing formulas for rows 6 to 2000
# 📊 Column BM (index 64): Processing formulas for rows 6 to 2000
# 📊 Column BN (index 65): Processing formulas for rows 6 to 2000
# 📊 Column BO (index 66): Processing formulas for rows 6 to 2000
# 📊 Column BP (index 67): Processing formulas for rows 6 to 2000
# 📊 Column BQ (index 68): Processing formulas for rows 6 to 2000
# 📊 Column BR (index 69): Processing formulas for rows 6 to 2000
# 📊 Column BS (index 70): Processing formulas for rows 6 to 2000
# 📊 Column BT (index 71): Processing formulas for rows 6 to 2000
# 📊 Column BU (index 72): Processing formulas for rows 6 to 2000
# 📊 Column BV (index 73): Processing formulas for rows 6 to 2000
# 📊 Column BW (index 74): Processing formulas for rows 6 to 2000
# 📊 Column BX (index 75): Processing formulas for rows 6 to 2000
# 📊 Column BY (index 76): Processing formulas for rows 6 to 2000
# 📊 Column BZ (index 77): Processing formulas for rows 6 to 2000
# 📊 Column CA (index 78): Processing formulas for rows 6 to 2000
# 📊 Column CB (index 79): Processing formulas for rows 6 to 2000
# 📊 Column CC (index 80): Processing formulas for rows 6 to 2000
# 📊 Column CD (index 81): Processing formulas for rows 6 to 2000
# 📊 Column CE (index 82): Processing formulas for rows 6 to 2000
# 📊 Column CF (index 83): Processing formulas for rows 6 to 2000
# 📊 Column CG (index 84): Processing formulas for rows 6 to 2000
# 📊 Column CH (index 85): Processing formulas for rows 6 to 2000
# 📊 Column CI (index 86): Processing formulas for rows 6 to 2000
# 📊 Column CJ (index 87): Processing formulas for rows 6 to 2000
# 📊 Column CK (index 88): Processing formulas for rows 6 to 2000
# 📊 Column CL (index 89): Processing formulas for rows 6 to 2000
# 📊 Column CM (index 90): Processing formulas for rows 6 to 2000
# 📊 Column CN (index 91): Processing formulas for rows 6 to 2000
# 📊 Column CO (index 92): Processing formulas for rows 6 to 2000
# 📊 Column CP (index 93): Processing formulas for rows 6 to 2000
# 📊 Column CQ (index 94): Processing formulas for rows 6 to 2000
# 📊 Column CR (index 95): Processing formulas for rows 6 to 2000
# 📊 Column CS (index 96): Processing formulas for rows 6 to 2000
# 📊 Column CT (index 97): Processing formulas for rows 6 to 2000
# 📊 Column CU (index 98): Processing formulas for rows 6 to 2000
# 📊 Column CV (index 99): Processing formulas for rows 6 to 2000
# 📊 Column CW (index 100): Processing formulas for rows 6 to 2000
# 📊 Column CX (index 101): Processing formulas for rows 6 to 2000
# 📊 Column CY (index 102): Processing formulas for rows 6 to 2000
# 📊 Column CZ (index 103): Processing formulas for rows 6 to 2000
# 📊 Column DA (index 104): Processing formulas for rows 6 to 2000
# 📊 Column DB (index 105): Processing formulas for rows 6 to 2000
# 📊 Column DC (index 106): Processing formulas for rows 6 to 2000
# 📊 Column DD (index 107): Processing formulas for rows 6 to 2000
# 📊 Column DE (index 108): Processing formulas for rows 6 to 2000
# 📊 Column DF (index 109): Processing formulas for rows 6 to 2000
# 📊 Column DG (index 110): Processing formulas for rows 6 to 2000
# 📊 Column DH (index 111): Processing formulas for rows 6 to 2000
# 📊 Column DI (index 112): Processing formulas for rows 6 to 2000
# 📊 Column DJ (index 113): Processing formulas for rows 6 to 2000
# 📊 Column DK (index 114): Processing formulas for rows 6 to 2000
# 📊 Column DL (index 115): Processing formulas for rows 6 to 2000
# 📊 Column DM (index 116): Processing formulas for rows 6 to 2000
# 📊 Column DN (index 117): Processing formulas for rows 6 to 2000
# 📊 Column DO (index 118): Processing formulas for rows 6 to 2000
# 📊 Column DP (index 119): Processing formulas for rows 6 to 2000
# 📊 Column DQ (index 120): Processing formulas for rows 6 to 2000
# 📊 Column DR (index 121): Processing formulas for rows 6 to 2000
# 📊 Column DS (index 122): Processing formulas for rows 6 to 2000
# 📊 Column DT (index 123): Processing formulas for rows 6 to 2000
# 📊 Column DU (index 124): Processing formulas for rows 6 to 2000
# 📊 Column DV (index 125): Processing formulas for rows 6 to 2000
# 📊 Column DW (index 126): Processing formulas for rows 6 to 2000
# 📊 Column DX (index 127): Processing formulas for rows 6 to 2000
# 📊 Column DY (index 128): Processing formulas for rows 6 to 2000
# 📊 Column DZ (index 129): Processing formulas for rows 6 to 2000
# 📊 Column EA (index 130): Processing formulas for rows 6 to 2000
# 📊 Column EB (index 131): Processing formulas for rows 6 to 2000
# 📊 Column EC (index 132): Processing formulas for rows 6 to 2000
# 📊 Column ED (index 133): Processing formulas for rows 6 to 2000
# 📊 Column EE (index 134): Processing formulas for rows 6 to 2000
# 📊 Column EF (index 135): Processing formulas for rows 6 to 2000
# 📊 Column EG (index 136): Processing formulas for rows 6 to 2000
# 📊 Column EH (index 137): Processing formulas for rows 6 to 2000
# 📊 Column EI (index 138): Processing formulas for rows 6 to 2000
# 📊 Column EJ (index 139): Processing formulas for rows 6 to 2000
# 📊 Column EK (index 140): Processing formulas for rows 6 to 2000
# 📊 Column EL (index 141): Processing formulas for rows 6 to 2000
# 📊 Column EM (index 142): Processing formulas for rows 6 to 2000
# 📊 Column EN (index 143): Processing formulas for rows 6 to 2000
# 📊 Column EO (index 144): Processing formulas for rows 6 to 2000
# 📊 Column EP (index 145): Processing formulas for rows 6 to 2000
# 📊 Column EQ (index 146): Processing formulas for rows 6 to 2000
# 📊 Column ER (index 147): Processing formulas for rows 6 to 2000
# 📊 Column ES (index 148): Processing formulas for rows 6 to 2000
# 📊 Column ET (index 149): Processing formulas for rows 6 to 2000
# 📊 Column EU (index 150): Processing formulas for rows 6 to 2000
# 📊 Column EV (index 151): Processing formulas for rows 6 to 2000
# 📊 Column EW (index 152): Processing formulas for rows 6 to 2000
# 📊 Column EX (index 153): Processing formulas for rows 6 to 2000
# 📊 Column EY (index 154): Processing formulas for rows 6 to 2000
# 📊 Column EZ (index 155): Processing formulas for rows 6 to 2000
# 📊 Column FA (index 156): Processing formulas for rows 6 to 2000
# 📊 Column FB (index 157): Processing formulas for rows 6 to 2000
# 📊 Column FC (index 158): Processing formulas for rows 6 to 2000
# 📊 Column FD (index 159): Processing formulas for rows 6 to 2000
# 📊 Column FE (index 160): Processing formulas for rows 6 to 2000
# 📊 Column FF (index 161): Processing formulas for rows 6 to 2000
# ✅ Processed 10/1995 rows (up to row 15) - Estimated time remaining: 6m 2s
# ✅ Processed 20/1995 rows (up to row 25) - Estimated time remaining: 5m 57s
# ✅ Processed 30/1995 rows (up to row 35) - Estimated time remaining: 5m 57s
# ✅ Processed 40/1995 rows (up to row 45) - Estimated time remaining: 6m 0s
# ✅ Processed 50/1995 rows (up to row 55) - Estimated time remaining: 6m 0s
# ✅ Processed 60/1995 rows (up to row 65) - Estimated time remaining: 5m 58s
# ✅ Processed 70/1995 rows (up to row 75) - Estimated time remaining: 6m 1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 95
#      92         print(f"📊 Column {col_letter} (index {col}): Processing formulas for rows {start_row+1} to {end_row+1}")
#      94     adjusted_formula = formula.replace('N$4', f'{col_letter}$4').replace('N$3', f'{col_letter}$3').replace('$H6', f'$H{row+1}').replace('$I6', f'$I{row+1}').replace('$J6', f'$J{row+1}').replace('$L6', f'$L{row+1}').replace('$M6', f'$M{row+1}')
# ---> 95     worksheet.write_formula(row, col, adjusted_formula)
#      97 # Log every 10 rows with estimated time remaining
#      98 if (row - start_row + 1) % 10 == 0:
#
# File c:\Users\louis\anaconda3\envs\web_scraping_test\Lib\site-packages\xlsxwriter\worksheet.py:114, in convert_cell_args.<locals>.cell_wrapper(self, *args, **kwargs)
#     111     new_args = xl_cell_to_rowcol(first_arg)
#     112     args = new_args + args[1:]
# --> 114 return method(self, *args, **kwargs)
#
# File c:\Users\louis\anaconda3\envs\web_scraping_test\Lib\site-packages\xlsxwriter\worksheet.py:759, in Worksheet.write_formula(self, row, col, formula, cell_format, value)
#     742 """
#     743 Write a formula to a worksheet cell.
#     744
#    (...)
#     756
#     757 """
#     758 # Check that row and col are valid and store max and min values.
# --> 759 return self._write_formula(row, col, formula, cell_format, value)
#
# File c:\Users\louis\anaconda3\envs\web_scraping_test\Lib\site-packages\xlsxwriter\worksheet.py:779, in Worksheet._write_formula(self, row, col, formula, cell_format, value)
#     777 # Check for dynamic array functions.
#     778 if re_dynamic_function.search(formula):
# --> 779     return self.write_dynamic_array_formula(
#     780         row, col, row, col, formula, cell_format, value
#     781     )
#     783 # Hand off array formulas.
#     784 if formula.startswith("{") and formula.endswith("}"):
#
# File c:\Users\louis\anaconda3\envs\web_scraping_test\Lib\site-packages\xlsxwriter\worksheet.py:146, in convert_range_args.<locals>.cell_wrapper(self, *args, **kwargs)
#     143     new_args.extend(args[1:])
#     144     args = new_args
# --> 146 return method(self, *args, **kwargs)
#
# File c:\Users\louis\anaconda3\envs\web_scraping_test\Lib\site-packages\xlsxwriter\worksheet.py:874, in Worksheet.write_dynamic_array_formula(self, first_row, first_col, last_row, last_col, formula, cell_format, value)
#     846 @convert_range_args
#     847 def write_dynamic_array_formula(
#     848     self,
#    (...)
#     855     value=0,
#     856 ) -> Literal[0, -1]:
#     857     """
#     858     Write a dynamic array formula to a worksheet cell/range.
#     859
#    (...)
#     872
#     873     """
# --> 874     error = self._write_array_formula(
#     875         first_row,
#     876         first_col,
#     877         last_row,
#     878         last_col,
#     879         formula,
#     880         cell_format,
#     881         value,
#     882         "dynamic",
#     883     )
#     885     if error == 0:
#     886         self.has_dynamic_arrays = True
#
# File c:\Users\louis\anaconda3\envs\web_scraping_test\Lib\site-packages\xlsxwriter\worksheet.py:1139, in Worksheet._write_array_formula(self, first_row, first_col, last_row, last_col, formula, cell_format, value, atype)
#    1132     cell_range = (
#    1133         xl_rowcol_to_cell(first_row, first_col)
#    1134         + ":"
#    1135         + xl_rowcol_to_cell(last_row, last_col)
#    1136     )
#    1138 # Modify the formula string, as needed.
# -> 1139 formula = self._prepare_formula(formula)
#    1141 # Write previous row if in in-line string constant_memory mode.
#    1142 if self.constant_memory and first_row > self.previous_row:
#
# File c:\Users\louis\anaconda3\envs\web_scraping_test\Lib\site-packages\xlsxwriter\worksheet.py:1065, in Worksheet._prepare_formula(self, formula, expand_future_functions)
#    1063 formula = re.sub(r"\bVAR.S\(", "_xlfn.VAR.S(", formula)
#    1064 formula = re.sub(r"\bWEBSERVICE\(", "_xlfn.WEBSERVICE(", formula)
# -> 1065 formula = re.sub(r"\bWEIBULL.DIST\(", "_xlfn.WEIBULL.DIST(", formula)
#    1066 formula = re.sub(r"\bXMATCH\(", "_xlfn.XMATCH(", formula)
#    1067 formula = re.sub(r"\bXOR\(", "_xlfn.XOR(", formula)
#
# File c:\Users\louis\anaconda3\envs\web_scraping_test\Lib\re\__init__.py:178, in sub(pattern, repl, string, count, flags)
#     174     """Scan through string looking for a match to the pattern, returning
#     175     a Match object, or None if no match was found."""
#     176     return _compile(pattern, flags).search(string)
# --> 178 def sub(pattern, repl, string, count=0, flags=0):
#     179     """Return the string obtained by replacing the leftmost
#     180     non-overlapping occurrences of the pattern in string by the
#     181     replacement repl.  repl can be either a string or a callable;
#     182     if a string, backslash escapes in it are processed.  If it is
#     183     a callable, it's passed the Match object and must return
#     184     a replacement string to be used."""
#     185     return _compile(pattern, flags).sub(repl, string, count)
#
# KeyboardInterrupt:

# %%
#DELETING SHARED SPREADSHEETS

import os
import json
import base64
import xmlrpc.client
from dotenv import load_dotenv
from openpyxl import Workbook

# Load environment variables
load_dotenv(override=True)

JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo
common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common")
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object")

# Step 1: Search for all Price List 1 spreadsheets
spreadsheets = models.execute_kw(
    JUSTFRAMEIT_ODOO_DB,
    uid,
    JUSTFRAMEIT_ODOO_API_KEY,
    'spreadsheet.dashboard.share',
    'search_read',
    [[('display_name', '=', 'Price List 1 (copy 4)')]],
    {'fields': ['id']}
)

if not spreadsheets:
    print("No spreadsheets found with name 'Price List 1 (copy 4)'")
else:
    # Get all IDs
    spreadsheet_ids = [s['id'] for s in spreadsheets]
    print(f"Found {len(spreadsheet_ids)} spreadsheets to delete")
    
    # Delete all found spreadsheets
    try:
        models.execute_kw(
            JUSTFRAMEIT_ODOO_DB,
            uid,
            JUSTFRAMEIT_ODOO_API_KEY,
            'spreadsheet.dashboard.share',
            'unlink',
            [spreadsheet_ids]
        )
        print(f"✅ Successfully deleted {len(spreadsheet_ids)} spreadsheets")
    except Exception as e:
        print(f"❌ Failed to delete spreadsheets: {str(e)}")
# Out:
# Found 2 spreadsheets to delete
# ✅ Successfully deleted 2 spreadsheets

# %%
#COMPUTE PRICE FROM BOM

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo with allow_none=True to handle None values
common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)

# Get initial cost before computing BOM
product_id = 60
initial_cost = models.execute_kw(
    JUSTFRAMEIT_ODOO_DB,
    uid,
    JUSTFRAMEIT_ODOO_API_KEY,
    'product.template',
    'read',
    [[product_id]],
    {'fields': ['standard_price']}
)[0]['standard_price']

print(f"Initial cost: {initial_cost}")

# Compute BOM cost for product template ID 60
try:
    # Ignore return value from button_bom_cost
    models.execute_kw(
        JUSTFRAMEIT_ODOO_DB,
        uid,
        JUSTFRAMEIT_ODOO_API_KEY,
        'product.template',
        'button_bom_cost',
        [[product_id]]
    )
    
    # Get new cost after computation
    new_cost = models.execute_kw(
        JUSTFRAMEIT_ODOO_DB,
        uid,
        JUSTFRAMEIT_ODOO_API_KEY,
        'product.template',
        'read',
        [[product_id]],
        {'fields': ['standard_price']}
    )[0]['standard_price']
    
    print(f"New cost: {new_cost}")
    
    if new_cost != initial_cost:
        print("✅ Cost change detected - BOM computation successful")
    else:
        print("⚠️ Warning: No cost change detected after BOM computation")
        
except:
    # Silently continue if button_bom_cost returns None
    # Get new cost after computation
    new_cost = models.execute_kw(
        JUSTFRAMEIT_ODOO_DB,
        uid,
        JUSTFRAMEIT_ODOO_API_KEY,
        'product.template',
        'read',
        [[product_id]],
        {'fields': ['standard_price']}
    )[0]['standard_price']
    
    print(f"New cost: {new_cost}")
    
    if new_cost != initial_cost:
        print("✅ Cost change detected - BOM computation successful")
    else:
        print("⚠️ Warning: No cost change detected after BOM computation")
# Out:
# Initial cost: 1000.0
# New cost: 1334417.22
# ✅ Cost change detected - BOM computation successful

# %%
import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo
common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)

sale_order_id = 55

try:
    # Trigger "Update Price (based on price list)"
    result = models.execute_kw(
        JUSTFRAMEIT_ODOO_DB,
        uid,
        JUSTFRAMEIT_ODOO_API_KEY,
        'sale.order',
        'action_update_prices',  # ✅ correct method name
        [[sale_order_id]]
    )
    print(f"✅ Successfully triggered 'Update Price (based on price list)' for Sale Order ID {sale_order_id}")
    if result:
        print("Returned value:", result)

except Exception as e:
    print(f"❌ Failed to trigger price update: {e}")
# Out:
# ❌ Failed to trigger price update: <Fault 1: 'Traceback (most recent call last):\n  File "/home/odoo/src/odoo/saas-18.4/addons/rpc/controllers.py", line 164, in xmlrpc_2\n    response = self._xmlrpc(service)\n               ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/odoo/src/custom/trial/saas_trial/controllers/main.py", line 442, in _xmlrpc\n    res = super()._xmlrpc(service)\n          ^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/odoo/src/odoo/saas-18.4/addons/rpc/controllers.py", line 139, in _xmlrpc\n    return dumps((result,))\n           ^^^^^^^^^^^^^^^^\n  File "/home/odoo/src/odoo/saas-18.4/addons/rpc/controllers.py", line 112, in dumps\n    response = OdooMarshaller(allow_none=False).dumps(params)\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/lib/python3.12/xmlrpc/client.py", line 514, in dumps\n    dump(v, write)\n  File "/usr/lib/python3.12/xmlrpc/client.py", line 536, in __dump\n    f(self, value, write)\n  File "/usr/lib/python3.12/xmlrpc/client.py", line 540, in dump_nil\n    raise TypeError("cannot marshal None unless allow_none is enabled")\nTypeError: cannot marshal None unless allow_none is enabled\n'>

# %%
import os
import xmlrpc.client
from dotenv import load_dotenv

# =============================================
# 🔧 Load environment variables
# =============================================
load_dotenv(override=True)

ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# =============================================
# 🔗 Connect to Odoo
# =============================================
print("Connecting to Odoo...")

common = xmlrpc.client.ServerProxy(f"{ODOO_URL}/xmlrpc/2/common", allow_none=True)
uid = common.authenticate(ODOO_DB, ODOO_USERNAME, ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

print(f"✅ Connected as {ODOO_USERNAME} (uid={uid})")

models = xmlrpc.client.ServerProxy(f"{ODOO_URL}/xmlrpc/2/object", allow_none=True)

# =============================================
# 📦 Fetch all products (optimized)
# =============================================
print("\n🔍 Fetching all products...")

try:
    # Get total count first
    product_count = models.execute_kw(
        ODOO_DB, uid, ODOO_API_KEY,
        'product.product', 'search_count',
        [[]]  # Empty domain = all products
    )
    
    print(f"📊 Total products found: {product_count}")
    
    # Fetch only the 'name' field for all products (optimized query)
    products = models.execute_kw(
        ODOO_DB, uid, ODOO_API_KEY,
        'product.product', 'search_read',
        [[]],  # Empty domain = all products
        {'fields': ['name']}  # Only fetch name field
    )
    
    print(f"\n📋 Product Names ({len(products)} products):")
    print("="*60)
    
    for idx, product in enumerate(products, 1):
        print(f"#{idx:4d} - {product.get('name')}")
    
    print("="*60)
    print(f"✅ Displayed {len(products)} products")
    
except Exception as e:
    print(f"❌ Failed to fetch products: {e}")
    import traceback
    traceback.print_exc()

print("\n✅ Done!")
# Out:
# Connecting to Odoo...
# ✅ Connected as louisdresse@gmail.com (uid=2)
#
# 🔍 Fetching all products...
# 📊 Total products found: 5031
#
# 📋 Product Names (5031 products):
# ============================================================
# #   1 - Noten Gouden Bies 1,5 cm
# #   2 - Notelaar Antiek Gouden Bies 1,5 Cm
# #   3 - '' Metall '' Wit 2 Cm
# #   4 - Copy of Template A_20250923_224107
# #   5 - Finished Product 20250923_224630
# #   6 - Standard delivery
# #   7 - Finished Product 20251029_181053
# #   8 - Finished Product 20251029_182527
# #   9 - Finished Product 20251029_182622
# #  10 - Finished Product 20251029_184738
# #  11 - Finished Product 20251029_185015
# #  12 - Finished Product 20251029_185627
# #  13 - Finished Product 20251029_185746
# #  14 - Finished Product 20251029_191224
# #  15 - Finished Product 20251029_191251
# #  16 - Finished Product 20251029_191321
# #  17 - Finished Product 20251029_191340
# #  18 - Finished Product 20251029_191623
# #  19 - Finished Product 20251029_191707
# #  20 - Finished Product 20251029_210626
# #  21 - Finished Product 20251029_210720
# #  22 - Finished Product 20251029_210738
# #  23 - Finished Product 20251105_132853
# #  24 - Finished Product 20251105_132937
# #  25 - Finished Product 20251105_133100
# #  26 - Finished Product 20251105_133118
# #  27 - Finished Product 20251105_143049
# #  28 - Finished Product 20251105_143402
# #  29 - Finished Product 20251105_143435
# #  30 - Finished Product 20251105_143707
# #  31 - Finished Product 20251105_143948
# #  32 - Finished Product 20251105_144152
# #  33 - Finished Product 20251105_144512
# #  34 - Finished Product 20251105_145138
# #  35 - Finished Product 20251110_110403
# #  36 - Finished Product 20251110_111413
# #  37 - Finished Product 20251110_111517
# #  38 - Finished Product 20251110_112321
# #  39 - Finished Product 20251110_112605
# #  40 - Finished Product 20251110_121836
# #  41 - Finished Product 20251110_122542
# #  42 - Finished Product 20251110_122801
# #  43 - Finished Product 20251110_123731
# #  44 - Finished Product 20251110_123843
# #  45 - Finished Product 20251110_124109
# #  46 - Finished Product 20251110_124136
# #  47 - Finished Product 20251110_151608
# #  48 - Finished Product 20251110_151632
# #  49 - Finished Product 20251110_164918
# #  50 - Finished Product 20251110_165352
# #  51 - Finished Product 20251110_165702
# #  52 - Finished Product 20251110_165830
# #  53 - Finished Product 20251110_170658
# #  54 - Finished Product 20251110_170826
# #  55 - Finished Product 20251110_170919
# #  56 - Finished Product 20251110_170939
# #  57 - Finished Product 20251110_171120
# #  58 - Finished Product 20251110_171143
# #  59 - Finished Product 20251110_171144
# #  60 - Finished Product 20251110_171204
# #  61 - Finished Product 20251110_171400
# #  62 - Finished Product 20251110_171453
# #  63 - Finished Product 20251110_172349
# #  64 - Finished Product 20251110_172935
# #  65 - Finished Product 20251110_173904
# #  66 - Finished Product 20251110_174313
# #  67 - Finished Product 20251110_174454
# #  68 - Finished Product 20251110_180231
# #  69 - White
# #  70 - MDF 3MM BRUT Verpakking
# #  71 - Mat plexiglas
# #  72 - Finished Product 20250923_214350
# #  73 - Finished Product 20250923_214558
# #  74 - Finished Product 20250923_214811
# #  75 - Finished Product 20250923_215010
# #  76 - Finished Product 20250923_215318
# #  77 - Finished Product 20250923_215428
# #  78 - Finished Product 20250923_215436
# #  79 - Finished Product 20250923_220104
# #  80 - Finished Product 20250923_220226
# #  81 - Finished Product 20250923_220932
# #  82 - Finished Product 20250923_221208
# #  83 - Finished Product 20250923_221228
# #  84 - Finished Product 20250923_221456
# #  85 - Finished Product 20250923_221511
# #  86 - Finished Product 20250923_223616
# #  87 - Finished Product 20250923_224752
# #  88 - Finished Product 20250923_224917
# #  89 - Finished Product 20250923_225020
# #  90 - Finished Product 20250923_225221
# #  91 - Finished Product 20250923_225325
# #  92 - Finished Product 20250923_225431
# #  93 - Finished Product 20250924_114025
# #  94 - Finished Product 20250924_114635
# #  95 - Finished Product 20250925_134430
# #  96 - Finished Product 20250925_134812
# #  97 - Finished Product 20250925_141729
# #  98 - Finished Product 20250925_143203
# #  99 - Finished Product 20250930_133335
# # 100 - Finished Product 20250930_140815
# # 101 - Finished Product 20250930_141112
# # 102 - Finished Product 20250930_144203
# # 103 - Finished Product 20250930_145555
# # 104 - Finished Product 20250930_152800
# # 105 - Finished Product 20250930_154652
# # 106 - Finished Product 20251016_171458
# # 107 - Finished Product 20251016_173410
# # 108 - Finished Product 20251016_173646
# # 109 - Finished Product 20251016_174056
# # 110 - Finished Product 20251016_174116
# # 111 - Finished Product 20251029_181601
# # 112 - Finished Product 20251029_181816
# # 113 - Finished Product 20251029_182324
# # 114 - Finished product A
# # 115 - Frame A
# # 116 - Frame B
# # 117 - Frame C
# # 118 - Glass A
# # 119 - Glass B
# # 120 - Passe-Partout A
# # 121 - Passe-Partout B
# # 122 - Service A - Luxury Touch
# # 123 - Standard A - Stylo
# # 124 -  "COLORBOX" BAKLIJST GROEN DONKERGRIJS 40X33
# # 125 - "Altis" Baklijst Eik Fineer 38X25
# # 126 - "Anilin" Ramin Donkerblauw 14/13
# # 127 - "Aniline" Ramin Antraciet 14/13
# # 128 - "Aniline" Ramin Antraciet 23/13
# # 129 - "Aniline" Ramin Donkerblauw 23/13
# # 130 - "Aniline" Ramin Donkergroen 14/13
# # 131 - "Aniline" Ramin Donkergroen 23/13
# # 132 - "Aniline" Ramin Donkerrood 14/13
# # 133 - "Aniline" Ramin Donkerrood 23/13
# # 134 - "Aniline" Ramin Groen/Blauw 14/13
# # 135 - "Aniline" Ramin Groen/Blauw 23/13
# # 136 - "Aniline" Ramin Lichtbruin 14/13
# # 137 - "Aniline" Ramin Lichtbruin 23/13
# # 138 - "Aniline" Ramin Mahonie 14/13
# # 139 - "Aniline" Ramin Mahonie 23/13
# # 140 - "Aniline" Ramin Natuurkleur Vernist 14/13
# # 141 - "Aniline" Ramin Natuurkleur Vernist 23/13
# # 142 - "Antigua" Vlak Wit 4Cm K1037
# # 143 - "Antigua" Vlak Zwart 40X14
# # 144 - "Authentica" Kaslijst 20X50Mm Wit
# # 145 - "BIANCO&NERO" AFSTANDLAT ZWART MAT 5x40
# # 146 - "BIANCO&NERO" KASLIJST ZWART MAT 15x60
# # 147 - "Black & White" Kaslijst Wit 40X40 K1097
# # 148 - "Black & White" Kaslijst Zwart 40X40 K1114
# # 149 - "Black & White" Kaslijst Zwart 5Cm K1115
# # 150 - "Black & White"Kaslijst Wit 5Cm K1098
# # 151 - "CARNEVALE" LAK BAROK DONKERGRIJS 40x33
# # 152 - "COLORBOX" BAKLIJST  BEIGE DONKERGRIJS 40x33
# # 153 - "COLORBOX" BAKLIJST BLAUW DONKERGRIJS 76121
# # 154 - "COLORBOX" BAKLIJST GRIJS DONKERGRIJS 40x33
# # 155 - "COLORBOX" BAKLIJST GRIJSBLAUW DONKERGRIJS 40x33
# # 156 - "COLORBOX" BAKLIJST ROOD DONKERGRIJS 40X33
# # 157 - "COLORBOX" BAKLIJST WITTE TOP DONKERGRIJS 40X33
# # 158 - "COLORBOX" BAKLIJST ZWART TOP DONKERGRIJS 40X33
# # 159 - "CONFIRMATION" KASLIJST KOPER OP COMPO 30x25
# # 160 - "CONFIRMATION" KASLIJST KOPER OP COMPO 40x35
# # 161 - "CONFIRMATION" KASLIJST WIT OP COMPO
# # 162 - "Carnevale" Lak Barok Blauw
# # 163 - "Carnevale" Lak Barok Donkergroen
# # 164 - "Carnevale" Lak Barok Duivengrijs
# # 165 - "Carnevale" Lak Barok Geel
# # 166 - "Carnevale" Lak Barok Lichtgroen
# # 167 - "Carnevale" Lak Barok Rood
# # 168 - "Carnevale" Lak Barok Wit
# # 169 - "Carnevale" Lak Barok Zwart
# # 170 - "Charles V" Spaanse Barok Goud
# # 171 - "Chique" Barok Grijs Geborsteld 2,5Cm
# # 172 - "Chique" Barok Grijs Geborsteld 5Cm
# # 173 - "Chique" Barok Groen Geborsteld 5Cm
# # 174 - "Chique" Barok Ivoor Geborsteld 2,5Cm
# # 175 - "Chique" Barok Ivoor Geborsteld 5Cm
# # 176 - "Chique" Barok Wit Geborsteld 2,5Cm
# # 177 - "Chique" Barok Wit Geborsteld 5Cm
# # 178 - "Chique" Barok Zwart Geborsteld 2,5Cm
# # 179 - "Chique" Barok Zwart Geborsteld 5Cm
# # 180 - "Conccinelle 2" Zwart
# # 181 - "Confirmation" Kaslijst Blank Witte Ayous
# # 182 - "Confirmation" Kaslijst Blank Witte Ayous
# # 183 - "Confirmation" Kaslijst Blank Witte Ayous 15X30Mm K1128
# # 184 - "Confirmation" Kaslijst Wit 20X40Mm
# # 185 - "Confirmation" Kaslijst Wit Op Compo 15X30 Mm
# # 186 - "Confirmation" Kaslijst Zwart 20X40Mm
# # 187 - "Confirmation" Kaslijst Zwart Op Compo 15X30 Mm
# # 188 - "Cool Shabby" Creme/Bruin Doorgeschuurd
# # 189 - "Cordella" Zwart 3Cm
# # 190 - "Cordus" Baklijst Fineer Eik
# # 191 - "Cordus" Baklijst Fineer Es
# # 192 - "Cordus" Baklijst Fineer Ital Noten
# # 193 - "Cordus" Baklijst Fineer Italiaanse Noten
# # 194 - "Cordus" Baklijst Fineer Wenge
# # 195 - "Costa Rica" Kaslijst Abrikoos
# # 196 - "Costa Rica" Kaslijst Bruin
# # 197 - "Costa Rica" Kaslijst Citroengeel K1036
# # 198 - "Costa Rica" Kaslijst Donkerbruin
# # 199 - "Costa Rica" Kaslijst Engels Roze
# # 200 - "Costa Rica" Kaslijst Feloranje
# # 201 - "Costa Rica" Kaslijst Frans Blauw
# # 202 - "Costa Rica" Kaslijst Grijsgroen
# # 203 - "Costa Rica" Kaslijst Grijsgroen Donker 2Cm
# # 204 - "Costa Rica" Kaslijst Grijsgroen Licht
# # 205 - "Costa Rica" Kaslijst Grijsgroen Licht
# # 206 - "Costa Rica" Kaslijst Lavendelblauw
# # 207 - "Costa Rica" Kaslijst Maisgeel
# # 208 - "Costa Rica" Kaslijst Melkchocolade
# # 209 - "Costa Rica" Kaslijst Mosterdkleur
# # 210 - "Costa Rica" Kaslijst Olijfgroen
# # 211 - "Costa Rica" Kaslijst Roodbruin
# # 212 - "Costa Rica" Kaslijst Roze K1105
# # 213 - "Costa Rica" Kaslijst Violet
# # 214 - "Eesenziale" Lichtbruin
# # 215 - "Essenza" Hellend Bruin Loodwit
# # 216 - "Essenza" Hellend Grijs Loodwit
# # 217 - "Essenza" Hellend Grijs Loodwit 19X35
# # 218 - "Essenza" Hellend Natuurkleur Loodwit
# # 219 - "Essenza" Hellend Natuurkleur Loodwit 19X35
# # 220 - "Essenza" Hellend Wenge Loodwit
# # 221 - "Essenza" Hellend Wenge Loodwit 19X35
# # 222 - "Essenza" Hellend Wit Loodwit
# # 223 - "Essenza" Hellend Wit Loodwit 19X35
# # 224 - "Essenziale" Aubergine
# # 225 - "Essenziale" Grijs
# # 226 - "Essenziale" Groen
# # 227 - "Essenziale" Wit
# # 228 - "Essenziale" Zwart 15x20
# # 229 - "Explosion" Goud
# # 230 - "FOILS" IMITATIE STERLING ZILVER ZWART 36x18
# # 231 - "Firenze" Beige 3,8 Cm
# # 232 - "Firenze" Zwart 3,8 Cm
# # 233 - "Firenze" Zwart 3,8 Cm
# # 234 - "GLORIA" SCHELP ZILVER 27x25
# # 235 - "GLOSS" BAKLIJST LAK WIT 50x40
# # 236 - "GLOSS" BAKLIJST LAK ZWART 50x40
# # 237 - "GUSTO" KASLIJST WIT/ZILVER
# # 238 - "Gloss" Baklijst Lak Wit 5Cm K1162
# # 239 - "Gloss" Baklijst Lak Zwart K1155
# # 240 - "Jazz" Schelp Palissander Gouden Lip
# # 241 - "Kopenhagen" Kaslijst Zwart Lak
# # 242 - "Kristal" Bruin/Goud 8Cm
# # 243 - "LARCH" BLANC 2,2 CM - H 3,3CM
# # 244 - "LIME" BAKLIJST LINDE BLANK 30x30
# # 245 - "LIME" BAKLIJST LINDE BLANK 40X45
# # 246 - "LIME" BAKLIJST LINDE BLANK GOUDEN TOP 40X45
# # 247 - "LIME" BAKLIJST LINDE BLANK MET GOUDEN TOP 30x30
# # 248 - "LIME" BAKLIJST LINDE BLANK ZILVER TOP 30X30
# # 249 - "LIME" BAKLIJST LINDE ZWART 30x30
# # 250 - "LOUVRE" BAKLIJST ZWART/GOUDEN LIJN 60x40
# # 251 - "Louvre" Hellend Zwart/Gouden Lijn
# # 252 - "Louvre" Hellend Zwart/Zilver
# # 253 - "Louvre" Hellend Zwart/Zilver Lijn
# # 254 - "MINIMALE" KASLIJST EIKFINEER BEIGE MET ZWARTE RUG
# # 255 - "MINIMALE" KASLIJST EIKFINEER LICHTBRUIN MET ZWARTE RUG 12x25
# # 256 - "MINIMALE" KASLIJST EIKFINEER NATUUR MET ZWARTE RUG
# # 257 - "MINIMALE" KASLIJST EIKFINEER NOTENKLEUR MET ZWARTE RUG
# # 258 - "Magnificent" Imitatie Karaatgoud
# # 259 - "Magnificent" Imitatie Karaatgoud Wit Doorgeschuurd
# # 260 - "Magnificent" Imitatie Karaatgoud Zwart Doorgeschuurd
# # 261 - "Matrix " Baklijst Chroom 4,5Cm K1021
# # 262 - "Matrix" Kaslijst Chroom
# # 263 - "Matrix" Kaslijst Chroom 4Cm K1020
# # 264 - "Minimal" Eik
# # 265 - "Minimal" Kers
# # 266 - "Minimal" Noten
# # 267 - "Minimal" Olijf
# # 268 - "Minimal" Wenge
# # 269 - "Minimal" Wit
# # 270 - "Minimale" Kaslijst Eikfineer Donkerbruin 12x25 103036
# # 271 - "Minimale" Kaslijst Eikfineer Lichtgrijs met zwarte rug 12x25
# # 272 - "Minimale" Kaslijst Eikfineer creme met zwarte Rug 12x25
# # 273 - "Modern Shabby" Bruin Vlak/Schuin 13/25
# # 274 - "Modern Shabby" Bruin Vlak/Schuin 17/35
# # 275 - "Modern Shabby" Lichtgrijs Vlak/Schuin 13/25
# # 276 - "Modern Shabby" Lichtgrijs Vlak/Schuin 17/35
# # 277 - "Modern Shabby" Wit Vlak/Schuin 13/25
# # 278 - "Modern Shabby" Wit Vlak/Schuin 17/35
# # 279 - "Modern Shabby" Zwart Vlak/Schuin 13/25
# # 280 - "Modern Shabby" Zwart Vlak/Schuin 17/35
# # 281 - "Moderno" Schelp Goud/Zilver Lip
# # 282 - "Nature" Kaslijst Eik Composiet Fineer
# # 283 - "Nature" Kaslijst Eik Composiet Fineer 15X30
# # 284 - "Olijf" Kaslijst Antraciet
# # 285 - "Olijf" Kaslijst Lichtnoten
# # 286 - "Olijf" Kaslijst Natuur
# # 287 - "Olijf" Kaslijst Noten
# # 288 - "Olijf" Kaslijst Tabak
# # 289 - "Pinus" Grenen Bruingrijs 4,5 Cm
# # 290 - "Pinus" Grenen Creme 2,5 Cm
# # 291 - "Pinus" Grenen Creme 4,5 Cm
# # 292 - "Pinus" Grenen Lichtgrijs 2,5 Cm
# # 293 - "Rainbow" Blauw Gouden Lip 27Mm
# # 294 - "Rainbow" Blauw Gouden Lip 44Mm
# # 295 - "Rainbow" Blauw Gouden Lip 64Mm
# # 296 - "Rainbow" Geel Gouden Lip 27Mm
# # 297 - "Rainbow" Geel Gouden Lip 44Mm
# # 298 - "Rainbow" Geel Gouden Lip 64Mm
# # 299 - "Rainbow" Groen Gouden Lip 27Mm
# # 300 - "Rainbow" Groen Gouden Lip 44Mm
# # 301 - "Rainbow" Groen Gouden Lip 64Mm
# # 302 - "Rainbow" Rood Gouden Lip 27Mm
# # 303 - "Rainbow" Rood Gouden Lip 44Mm
# # 304 - "Rainbow" Rood Gouden Lip 64Mm
# # 305 - "Rainbow" Wit Gouden Lip 27Mm
# # 306 - "Rainbow" Wit Gouden Lip 44Mm
# # 307 - "Rainbow" Wit Gouden Lip 64Mm
# # 308 - "Rainbow" Zwart Gouden Lip 27Mm
# # 309 - "Rainbow" Zwart Gouden Lip 44Mm
# # 310 - "Rainbow" Zwart Gouden Lip 64Mm
# # 311 - "Riviera" Schelp Pastelblauw
# # 312 - "Riviera" Schelp Wit
# # 313 - "Riviera" Schelp Zwart
# # 314 - "SOLID WOOD" WITTE AMERIKAANSE EIK 40x15 76567
# # 315 - "SPAZZOLATO" GEBORSTELD GUN METAL 23x14
# # 316 - "Sensation" Oranje Glanzend Doorgeschuurd
# # 317 - "Solid Wood" Amerikaanse Baklijst Eik 40X30
# # 318 - "Solid Wood" Amerikaanse Baklijst Eik K1090
# # 319 - "Solid Wood" Beuk 20/15
# # 320 - "Solid Wood" Eik 1,5Cm K1124
# # 321 - "Solid Wood" Eik 12X25 Mm
# # 322 - "Solid Wood" Eik 12X35Mm
# # 323 - "Solid Wood" Eik 15/40 K1125
# # 324 - "Solid Wood" Eik 25X20
# # 325 - "Solid Wood" Eik Loft 20X30
# # 326 - "Solid Wood" Es 2 X 1,5 Cm (Sponning 1 X 0,5)
# # 327 - "Solid Wood" Es 3 X 1,5 (Sponning 1,1 X 0,6)
# # 328 - "Solid Wood" Esdoorn
# # 329 - "Solid Wood" Esdoorn 1,5Cm K1127
# # 330 - "Solid Wood" Kaslijst Eik 3Cm K1123
# # 331 - "Solid Wood" Kaslijst Eik 4Cm
# # 332 - "Solid Wood" Spacer Eik 5X15Mm
# # 333 - "Solid Wood" Witte Amerikaanse Eik
# # 334 - "Solid Wood" Witte Amerikaanse Eik
# # 335 - "Spazzolato" Geborsteld Goud
# # 336 - "Spazzolato" Geborsteld Zilver
# # 337 - "Spiaggia" Grijs 3,5 Cm
# # 338 - "Spiaggia" Taupe 3,5 Cm
# # 339 - "Strich" Antraciet Zilver 2,5 Cm
# # 340 - "VENUS" ZILVER MET ZWARTE RUG 30x20
# # 341 - "Vecchio" Grijs 5,5 Cm
# # 342 - "Vecchio" Grijs Gewit 2,5 Cm
# # 343 - "Vecchio" Naturel 5,5 Cm
# # 344 - "Vecchio" Wit 5,5 Cm
# # 345 - "Vecchio" Zwart 5,5 Cm
# # 346 - "Vecchio" Zwart Gewit 2,5 Cm
# # 347 - "Venus" Goud Met Zwarte Rug
# # 348 - "Venus" Lood Met Zwarte Rug
# # 349 - "Venus" Zilver Met Zwarte Rug
# # 350 - "Venus"Goud Met Zwarte Rug
# # 351 - "Zeppa" Wit/Zilver Met De Hand Afgewerkt 6,3Cm K1022
# # 352 - ' Tondi , Chroom-Antraciet 1,3 Cm
# # 353 - ' Tondi , Hoogglans Wit 1,3 Cm
# # 354 - ' Tondi , Hoogglans Zwart 1,3 Cm
# # 355 - ' Tondi , Ivoor 1,3 Cm
# # 356 - ' Tondi , Mat Zwart 1,3 Cm
# # 357 - ' Tondi , Zilver Chroom 1,3 Cm
# # 358 - '' BEMA '' ROZE 3,5 CM 35x17
# # 359 - '' Bolero ,, Chroom 1,5 Cm  3,5 Cm Hoog
# # 360 - '' Bright '' Wit 6 Cm
# # 361 - '' CUBA '' MAHONIE 4,2 CM
# # 362 - '' Curl '' Goud 1,5 Cm
# # 363 - '' Curl '' Zilver 1,5 Cm
# # 364 - '' Curl '' Zwart 1,5 Cm
# # 365 - '' Elegance '' Zwart Met  Zilver 2,5 Cm
# # 366 - '' Inox ,, Zilveren Rug - Grijs -
# # 367 - '' Inox ,, Zilveren Rug - Taupe
# # 368 - '' Kristal '' Grijs / Zilver 8 Cm
# # 369 - '' Kristal '' Zwart 8 Cm
# # 370 - '' Meribel '' Lichtbruin 4,2 Cm
# # 371 - '' Meribel '' Lichtbruin 9 Cm
# # 372 - '' Meribel '' Naturel Met Wit Gepatineerd 4,2 Cm
# # 373 - '' Meribel '' Naturel Wit Gepatineerd 9 Cm
# # 374 - '' Meribel '' Wit 4,2 Cm
# # 375 - '' Meribel '' Wit 9 Cm
# # 376 - '' Metall '' Donker Bruin 2 Cm
# # 377 - '' Metall '' Zwart 2 Cm
# # 378 - '' POPI ,, GRIJS EN ZILVER 2,8 CM
# # 379 - '' Scarp '' Bruin 7 Cm
# # 380 - '' Scarp '' Zwart 7 Cm
# # 381 - '' Soft '' Eik 6 Cm
# # 382 - '' Soft '' Grijs 6 Cm
# # 383 - '' Soft '' Taupe 6 Cm
# # 384 - '' Spalti '' Anthraciet 3,3 Cm
# # 385 - '' Spalti '' Noten 3,3 Cm
# # 386 - '' Sterling '' Donker Zilver 1,2 Cm
# # 387 - '' Sterling '' Donker Zilver 2 Cm
# # 388 - '' Sterling '' Goud 1,2 Cm
# # 389 - '' Sterling '' Zilver 1,2 Cm
# # 390 - '' Sterling '' Zilver 2 Cm
# # 391 - '' Trans '' Grijs 1,5 Cm
# # 392 - '' Trans '' Ivoor 1,5 Cm
# # 393 - '' Vinci '' Grijs 3 Cm
# # 394 - '' Vinci '' Wit 3 Cm
# # 395 - '' Vinci '' Zwart 3 Cm
# # 396 - ''Bharami'' Plat Donkerrood 2 Cm
# # 397 - ''Bharami'' Plat Gebroken  Wit 2 Cm
# # 398 - ''Bharami'' Plat Groen 2 Cm
# # 399 - ''Bharami'' Plat Lichtbruin 2 Cm
# # 400 - ''Bharami'' Plat Wenge 2 Cm
# # 401 - ''Bharami'' Rond Donkerrood 2,5 Cm
# # 402 - ''Bharami'' Rond Gebroken Wit 2,5 Cm
# # 403 - ''Bharami'' Rond Wenge 2,5 Cm
# # 404 - ''Bolero ,, Chroom / Antraciet 1,5 Cm 3,5 Cm Hoog
# # 405 - ''Bolero,, Naturel 1,5 Cm  3,5 Cm Hoog
# # 406 - ''Bolero,, Taupe 1,5 Cm - 3,5 Cm Hoog
# # 407 - ''Bolero,, Wit 1,5 Cm - 3,5 Cm Hoog
# # 408 - ''Bolero,, Zwart 1,5 Cm - 3,5 Cm Hoog
# # 409 - ''Botanique'' Antiek Grijs 2,5 Cm
# # 410 - ''Botanique'' Antiek Taupe 2,5 Cm
# # 411 - ''CURVO,, BEIGE 30x24
# # 412 - ''Cigale'' Beige 2 Cm
# # 413 - ''Cigale'' Creme 2 Cm
# # 414 - ''Cigale'' Donkerblauw 2 Cm
# # 415 - ''Cigale'' Donkergroen 2 Cm
# # 416 - ''Cigale'' Gebroken Wit 2 Cm
# # 417 - ''Cigale'' Geel 2 Cm
# # 418 - ''Cigale'' Grijs 2 Cm
# # 419 - ''Cigale'' Kakigroen 2 Cm
# # 420 - ''Cigale'' Rood 2 Cm
# # 421 - ''Cigale'' Roodbruin 2 Cm
# # 422 - ''Cigno,, Bruin 4 Cm
# # 423 - ''Cigno,, Teak 4 Cm
# # 424 - ''Cigno,, Wit 4 Cm
# # 425 - ''Cigno,, Zwart 4 Cm
# # 426 - ''Cordella,, Beige 3 Cm
# # 427 - ''Cordella,, Taupe Donker 3 Cm
# # 428 - ''Cordella,, Wit 3 Cm
# # 429 - ''Country'' Bruin 2 Cm
# # 430 - ''Country'' Ivoor 2 Cm
# # 431 - ''Demoiselle'' Donkerblauw 3 Cm
# # 432 - ''Demoiselle'' Fel Rood 3 Cm
# # 433 - ''Demoiselle'' Geel 3 Cm
# # 434 - ''Demoiselle'' Groen 3 Cm
# # 435 - ''Demoiselle'' Ivoor 3 Cm
# # 436 - ''Demoiselle'' Lichtblauw 3 Cm
# # 437 - ''Demoiselle'' Oranje 3 Cm
# # 438 - ''Demoiselle'' Rood 3 Cm
# # 439 - ''Demoiselle'' Wenge 3 Cm
# # 440 - ''Demoiselle'' Wit 3 Cm
# # 441 - ''Demoiselle'' Zwart 3 Cm
# # 442 - ''Dublin'' Donker Bruin 3,2 Cm
# # 443 - ''Dublin'' Donker Bruin 6,8 Cm
# # 444 - ''Dublin'' Naturel 3,2 Cm
# # 445 - ''Dublin'' Naturel 6,8 Cm
# # 446 - ''Eco Wood'' Naturel 2 Cm
# # 447 - ''Eco Wood'' Naturel 4 Cm
# # 448 - ''Eco Wood'' Noten 2 Cm
# # 449 - ''Eco Wood'' Noten 3 Cm
# # 450 - ''Eco Wood'' Wit 3 Cm
# # 451 - ''Eco Wood'' Zwart 2 Cm
# # 452 - ''Eco Wood'' Zwart 3 Cm
# # 453 - ''Electra'' Blok Zilver 3,1 Cm Breed/4,8 Hoog
# # 454 - ''Filetto'' Blauw 1,4 Cm
# # 455 - ''Filetto'' Bordeaux 1,4 Cm
# # 456 - ''Filetto'' Creme 1,4 Cm
# # 457 - ''Filetto'' Groen 1,4 Cm
# # 458 - ''Filetto'' Wenge 1,4 Cm
# # 459 - ''Fourmi'' Creme 2 Cm
# # 460 - ''Fourmi'' Donkerblauw 2 Cm
# # 461 - ''Fourmi'' Fel Rood 2 Cm
# # 462 - ''Fourmi'' Geel 2 Cm
# # 463 - ''Fourmi'' Groen 2 Cm
# # 464 - ''Fourmi'' Lichtblauw 2 Cm
# # 465 - ''Fourmi'' Oranje 2 Cm
# # 466 - ''Fourmi'' Rood 2 Cm
# # 467 - ''Fourmi'' Wenge 2 Cm
# # 468 - ''Fourmi'' Wit 2 Cm
# # 469 - ''Fourmi'' Zwart 2 Cm
# # 470 - ''INOX'' GUN METAL ZWARTE LIP 3,2 CM
# # 471 - ''Inox'' Aluminium Gun Lip 3,2 Cm
# # 472 - ''Inox'' Gun Metal Zilver Lip 20X30
# # 473 - ''Inox'' Gun Metal Zilveren Lip 3,2 Cm
# # 474 - ''Inox'' Zilveren Rug-Wit Zilver 3,2 Cm
# # 475 - ''Inox'' Zilveren Rug-Zwart Zilver 3,2 Cm
# # 476 - ''Inox'' Zwart Zilveren Lip 3,2 Cm
# # 477 - ''Lino,, Gestreept Bruin 2 Cm
# # 478 - ''Lino,, Gestreept Bruin 3 Cm
# # 479 - ''Lino,, Gestreept Grijs 2 Cm
# # 480 - ''Lino,, Gestreept Grijs 3 Cm
# # 481 - ''Lino,, Gestreept Wit 2 Cm
# # 482 - ''Lino,, Gestreept Wit 3 Cm
# # 483 - ''Lino,, Gestreept Zwart 2 Cm
# # 484 - ''Lino,, Gestreept Zwart 3 Cm
# # 485 - ''Luminor,, Taupe Zilveren Bies 1,8 Cm
# # 486 - ''Luminor,, Wit Zilveren Bies 1,8 Cm
# # 487 - ''Luminor,, Zwart Zilveren Bies 1,8 Cm
# # 488 - ''Mira,, Grijs 1,5 Cm
# # 489 - ''Mouche'' Wit 5 Cm
# # 490 - ''Mouche'' Zwart 5 Cm
# # 491 - ''Papillon'' Creme 3,4 Cm
# # 492 - ''Papillon'' Donkerblauw 3,4 Cm
# # 493 - ''Papillon'' Donkergroen 3,4 Cm
# # 494 - ''Papillon'' Gebroken Wit 3,4 Cm
# # 495 - ''Papillon'' Geel 3,4 Cm
# # 496 - ''Papillon'' Grijs 3,4 Cm
# # 497 - ''Papillon'' Kakigroen 3,4 Cm
# # 498 - ''Papillon'' Rood 3,4 Cm
# # 499 - ''Papillon'' Roodbruin 3,4 Cm
# # 500 - ''Picco" Donkergrijs Met Zilver 3,6Cm
# # 501 - ''Picco" Ivoor Met Zilver 3,6Cm
# # 502 - ''Picco" Lichtgrijs Met Zilver 3,6Cm
# # 503 - ''Picco" Wit Met Zilver 3,6Cm
# # 504 - ''SAUNA,, Grijs 25x15
# # 505 - ''SAUNA,, WIT 25x15
# # 506 - ''Seta,, Zwart Met Zilver 3 Cm
# # 507 - ''Sky,, Kaslijst Donker Grijs 3 Cm / H 4 Cm
# # 508 - ''Strich,, Roestbruin / Zilver
# # 509 - ''Strich,, Taupe / Zilver2,5 Cm
# # 510 - 'Solid Wood, Teak B 2,8 Cm / H 3,3 Cm
# # 511 - 'Solid Wood, Wit 2 Cm
# # 512 - 'Solid Wood, Wit 2,8 Cm
# # 513 - 'Solid Wood, Wit B 2,8 Cm / H 3,3 Cm
# # 514 - 'Solid Wood, Zwart 2 Cm
# # 515 - 'Solid Wood, Zwart 2,8 Cm
# # 516 - 'Swing, Houtskool-Grijs 3,7 Cm
# # 517 - 'Swing, Ivoor 3,7 Cm
# # 518 - 'Swing, Lichtbruin 3,7 Cm
# # 519 - 'Swing, Zilvergrijs 3,7 Cm
# # 520 - 0011af7 - 52x42
# # 521 - 001e128 - 15x22.5
# # 522 - 001e128 - 22.5x15
# # 523 - 002e425 - 42.1x29.7
# # 524 - 002e425 - 50x70
# # 525 - 003-004
# # 526 - 003-016
# # 527 - 003-019
# # 528 - 003-021
# # 529 - 004d055 - 26.1x30.3
# # 530 - 00762a1 - 31x22.6
# # 531 - 00762a1 - 99x73.6
# # 532 - 008-004
# # 533 - 008-021
# # 534 - 00c4b0f - 41x51
# # 535 - 00eacae - 40x30
# # 536 - 011-002
# # 537 - 011-004
# # 538 - 011-019
# # 539 - 015-001
# # 540 - 015-004
# # 541 - 019b0b5 - 15.1x22.5
# # 542 - 021e4f3 - 36x51
# # 543 - 021f420 - 30x43
# # 544 - 023a839 - 23x23
# # 545 - 025a1b8 - 19x23.8
# # 546 - 034-003
# # 547 - 034-019
# # 548 - 034-522
# # 549 - 034-523
# # 550 - 036c6aa - 34x25.5
# # 551 - 03795fd - 79.6x54.2
# # 552 - 039a45e - 30.4x40.2
# # 553 - 039a45e - 30x30
# # 554 - 039a45e - 40x30
# # 555 - 039a45e - 40x50
# # 556 - 039a45e - 50x40
# # 557 - 039a45e - 50x40
# # 558 - 039a45e - 60x70
# # 559 - 039a45e - 60x80
# # 560 - 03ca69f - CONFIG-DEFAULT - Geconfigureerd product - 61x61
# # 561 - 03d26a1 - 25x25
# # 562 - 03d26a1 - 25x25
# # 563 - 03e040f - CONFIG-DEFAULT - Geconfigureerd product - 91x64
# # 564 - 041b6c1 - CONFIG-DEFAULT - Geconfigureerd product - 15x20
# # 565 - 0441e42 - 102.3x102.3
# # 566 - 0441e42 - 62x62
# # 567 - 0494b3f - CONFIG-DEFAULT - Geconfigureerd product - 15x15
# # 568 - 049dae4 - 35.8x29
# # 569 - 049dae4 - 35.8x29
# # 570 - 04cb3a2 - CONFIG-DEFAULT - Geconfigureerd product - 36x48
# # 571 - 051-001
# # 572 - 051-156
# # 573 - 054c08c - CONFIG-DEFAULT - Geconfigureerd product - 51x80
# # 574 - 054c08c - CONFIG-DEFAULT - Geconfigureerd product - 85x71
# # 575 - 0585c39 - CONFIG-DEFAULT - Geconfigureerd product - 68x60
# # 576 - 05a0460 - CONFIG-DEFAULT - Geconfigureerd product - 36.2x26.1
# # 577 - 05a0460 - CONFIG-DEFAULT - Geconfigureerd product - 36.2x26.1
# # 578 - 05ca84e - 40x30.8
# # 579 - 05ca84e - 40x30.8
# # 580 - 060b229 - 35.1x20.4
# # 581 - 060b229 - 37x24.6
# # 582 - 060d714 - 60x30
# # 583 - 060d714 - 66x36
# # 584 - 063df61 - 26x22
# # 585 - 0648107 - 83x96.8
# # 586 - 0648107 - 83x96.8
# # 587 - 066033a - CONFIG-DEFAULT - Geconfigureerd product - 34.7x47
# # 588 - 066dc04 - 20x22.5
# # 589 - 066dc04 - 21.1x23.2
# # 590 - 066dc04 - 21.4x20
# # 591 - 066dc04 - 23.1x20
# # 592 - 066dc04 - 25x20
# # 593 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 20x22.5
# # 594 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 20x22.5
# # 595 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 20x22.5
# # 596 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 20x22.5
# # 597 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 21.1x23.2
# # 598 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 21.1x23.2
# # 599 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 21.1x23.2
# # 600 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 21.1x23.2
# # 601 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 21.4x20
# # 602 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 21.4x20
# # 603 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 21.4x20
# # 604 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 21.4x20
# # 605 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 23.1x20
# # 606 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 23.1x20
# # 607 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 23.1x20
# # 608 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 23.1x20
# # 609 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 25x20
# # 610 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 25x20
# # 611 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 25x20
# # 612 - 066dc04 - CONFIG-DEFAULT - Geconfigureerd product - 25x20
# # 613 - 06de2b0 - 79x116
# # 614 - 073b3a3 - CONFIG-DEFAULT - Geconfigureerd product - 20x20
# # 615 - 077b1cd - 22x22
# # 616 - 07b2e95 - 17x22
# # 617 - 0866860 - 41x68.3
# # 618 - 0885098 - 58.8x76.4
# # 619 - 0893a18 - CONFIG-DEFAULT - Geconfigureerd product - 30x23.4
# # 620 - 08ed0f7 - 18x24
# # 621 - 08eef95 - MG.GLAS - Mat glas - 45x45
# # 622 - 08f98a0 - CONFIG-DEFAULT - Geconfigureerd product - 56x42
# # 623 - 09706fe - CONFIG-DEFAULT - Geconfigureerd product - 15x22.2
# # 624 - 098ee5d - 50x37.3
# # 625 - 099ce3d - CONFIG-DEFAULT - Geconfigureerd product - 48x68
# # 626 - 09ab362 - 45x60
# # 627 - 09c84b4 - 10x15
# # 628 - 09c84b4 - 10x15
# # 629 - 09c8b20 - 21x35.4
# # 630 - 09cb911 - 62x82
# # 631 - 09f0f1e - 27x27
# # 632 - 09f0f1e - 27x31.7
# # 633 - 0a3182f - CONFIG-DEFAULT - Geconfigureerd product - 20x20
# # 634 - 0a96aea - CONFIG-DEFAULT - Geconfigureerd product - 51x44.3
# # 635 - 0b93979 - 21x26
# # 636 - 0c05ea0 - CONFIG-DEFAULT - Geconfigureerd product - 15x20.2
# # 637 - 0c05ea0 - CONFIG-DEFAULT - Geconfigureerd product - 18.4x15
# # 638 - 0c44b83 - CONFIG-DEFAULT - Geconfigureerd product - 15.1x23.6
# # 639 - 0cfcd89 - 32x45.6
# # 640 - 0d45c83 - 24.6x19.5
# # 641 - 0d78d29 - 20x15
# # 642 - 0e07467 - 35.6x35.6
# # 643 - 0e0de6e - 29.7x21
# # 644 - 0ee16ca - 20.1x15.2
# # 645 - 0f05014 - 35x25.5
# # 646 - 0f0f067 - 45x87
# # 647 - 100367
# # 648 - 100467
# # 649 - 1018
# # 650 - 10190
# # 651 - 10192
# # 652 - 10195
# # 653 - 102903
# # 654 - 105467 Altis Eik fineer 20x20
# # 655 - 1056c8e - 40.1x53.4
# # 656 - 1059e44 - 66x55
# # 657 - 1069496 - 80x120
# # 658 - 1073
# # 659 - 1081
# # 660 - 1084
# # 661 - 10992 Verstevigingsprofiel 10x39
# # 662 - 10a8cfa - 30x40
# # 663 - 11002.R8 Verstevigingsprofiel 12x42
# # 664 - 1102c3b - 19.5x28.5
# # 665 - 1136acb - 27x38.2
# # 666 - 1136acb - 27x38.2
# # 667 - 11a54ff - 31.4x61
# # 668 - 11d3bf5 - 30.1x30.1
# # 669 - 11d3bf5 - 30x30
# # 670 - 11dc88b - 15.7x20
# # 671 - 12-004 Alpha Aluminium Zilver + spacer
# # 672 - 12-027 Alpha Aluminium Wit + spacer
# # 673 - 12-250 Alpha Aluminium zwart + spacer
# # 674 - 12c5f64 - 54x54
# # 675 - 12c5f64 - 54x54
# # 676 - 12c5f64 - 54x54
# # 677 - 12e8c3d - 20.1x15
# # 678 - 1393db1 - 24x32
# # 679 - 1393f47 - CONFIG-DEFAULT - Geconfigureerd product - 93.3x91.3
# # 680 - 14004
# # 681 - 1403783 - CONFIG-DEFAULT - Geconfigureerd product - 80x120
# # 682 - 1403783 - GSRM918.C7 - Very White - 80x120
# # 683 - 140f5f8 - 32x42
# # 684 - 140f5f8 - 32x42
# # 685 - 141efe2 - 74.3x47
# # 686 - 142395b - 60x80
# # 687 - 142395b - 84.1x59.4
# # 688 - 14307
# # 689 - 14315
# # 690 - 14414d8 - CONFIG-DEFAULT - Geconfigureerd product - 75x100
# # 691 - 146a049 - 81468.N07 - Oak - Solid Wood Eik 20/15 - 10x15
# # 692 - 150f128 - CONFIG-DEFAULT - Geconfigureerd product - 37.8x51
# # 693 - 1543566 - 63x69.8
# # 694 - 158b6ef - 23x23
# # 695 - 1596
# # 696 - 1617ac3 - CONFIG-DEFAULT - Geconfigureerd product - 73x103.5
# # 697 - 162fa6b - CONFIG-DEFAULT - Geconfigureerd product - 35x40
# # 698 - 16371.D33 zwart 15x40
# # 699 - 16380.D34  Wit 15x40
# # 700 - 16393a4 - CONFIG-DEFAULT - Geconfigureerd product - 49.7x32.5
# # 701 - 16471cc - 50x69
# # 702 - 16471cc - 50x69
# # 703 - 1655e72 - 30x40
# # 704 - 1693b2c - 33.1x24.1
# # 705 - 16b0912 - 32.7x67
# # 706 - 16b0912 - 50.5x62.2
# # 707 - 1743b8f - CONFIG-DEFAULT - Geconfigureerd product - 49x83
# # 708 - 178dd00 - CONFIG-DEFAULT - Geconfigureerd product - 51x41
# # 709 - 17915
# # 710 - 17931
# # 711 - 17945
# # 712 - 17950ae - 64.5x82
# # 713 - 17b52d9 - 52x122
# # 714 - 17effd3 - 30.5x35.5
# # 715 - 180-019
# # 716 - 1850b16 - 15x16.5
# # 717 - 1850b16 - 20x15
# # 718 - 18670c4 - CONFIG-DEFAULT - Geconfigureerd product - 18.1x25
# # 719 - 18f7026 - 42x60
# # 720 - 18f7026 - 45x58
# # 721 - 18f7026 - 58.8x84.5
# # 722 - 18f7026 - 80x120
# # 723 - 1923d69 - 28x28
# # 724 - 1928a84 - 62x102
# # 725 - 195315e - 122.1x85.1
# # 726 - 195315e - 20x20
# # 727 - 197db7e - 60x40
# # 728 - 19d6aa2 - CONFIG-DEFAULT - Geconfigureerd product - 30x20
# # 729 - 19f4e0f - CONFIG-DEFAULT - Geconfigureerd product - 82x82
# # 730 - 1a5849a - 10x15
# # 731 - 1a5849a - 24.5x47
# # 732 - 1a5849a - 35.8x26.2
# # 733 - 1a5849a - 50x41.2
# # 734 - 1a649fd - 60.8x79
# # 735 - 1a884a1 - 15x15
# # 736 - 1a884a1 - 20x15
# # 737 - 1a884a1 - 22.4x15
# # 738 - 1a884a1 - 23.5x15.7
# # 739 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 15x15
# # 740 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 15x15
# # 741 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 15x15
# # 742 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 15x15
# # 743 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 20x15
# # 744 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 20x15
# # 745 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 20x15
# # 746 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 20x15
# # 747 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 22.4x15
# # 748 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 22.4x15
# # 749 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 22.4x15
# # 750 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 22.4x15
# # 751 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 23.5x15.7
# # 752 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 23.5x15.7
# # 753 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 23.5x15.7
# # 754 - 1a884a1 - CONFIG-DEFAULT - Geconfigureerd product - 23.5x15.7
# # 755 - 1adc57b - 15x15
# # 756 - 1aee9b8 - CONFIG-DEFAULT - Geconfigureerd product - 34x53
# # 757 - 1af16bd - 48x21
# # 758 - 1b126e0 - 28x34.3
# # 759 - 1b29c4c - 131.5x77.8
# # 760 - 1c860cd - 74.1x94.8
# # 761 - 1cd5209 - 29x39
# # 762 - 1d1d553 - 50x70
# # 763 - 1d21800 - 114x134
# # 764 - 1d447f9 - 34x42
# # 765 - 1dc18a6 - 79x80.4
# # 766 - 1dd5c4d - 20x15
# # 767 - 1dd5c4d - 20x15
# # 768 - 1dd5c4d - 20x15
# # 769 - 1dee735 - CONFIG-DEFAULT - Geconfigureerd product - 15.1x17.2
# # 770 - 1e82432 - CONFIG-DEFAULT - Geconfigureerd product - 29.7x42
# # 771 - 1e99040 - CONFIG-DEFAULT - Geconfigureerd product - 50x70
# # 772 - 1e9eef9 - CONFIG-DEFAULT - Geconfigureerd product - 20x25
# # 773 - 1eb6e48 - CONFIG-DEFAULT - Geconfigureerd product - 85x111
# # 774 - 1ebf9af - 133x100
# # 775 - 1ebf9af - 150x100
# # 776 - 1edb68b - 21x29.7
# # 777 - 1edb68b - 21x29.7
# # 778 - 1edb68b - 21x29.7
# # 779 - 1f062ad - CONFIG-DEFAULT - Geconfigureerd product - 25.1x33.4
# # 780 - 1f062ad - CONFIG-DEFAULT - Geconfigureerd product - 25x25
# # 781 - 1f5a76a - 97x72.8
# # 782 - 1fe447a - 32x28
# # 783 - 2036e9a - CONFIG-DEFAULT - Geconfigureerd product - 28x39
# # 784 - 2073588 - 30x40
# # 785 - 2073588 - 40x60
# # 786 - 20d5ee2 - 19.7x29.8
# # 787 - 20ddd5c - 21x28
# # 788 - 213c348 - CONFIG-DEFAULT - Geconfigureerd product - 42x29.6
# # 789 - 214-004
# # 790 - 215-250
# # 791 - 21871ab - 47x58.6
# # 792 - 21bf7e6 - 18x24
# # 793 - 21bf7e6 - 18x24
# # 794 - 21fd9d7 - 82x102
# # 795 - 224adf3 - 19x19
# # 796 - 22e8818 - CONFIG-DEFAULT - Geconfigureerd product - 62x92
# # 797 - 231e58d - 41x32.4
# # 798 - 232550d - 40.6x15
# # 799 - 23448b0 - CONFIG-DEFAULT - Geconfigureerd product - 42x31
# # 800 - 23546
# # 801 - 2372818 - 42x59.5
# # 802 - 2372818 - 48x34
# # 803 - 2398e52 - 50x70
# # 804 - 2398e52 - 50x70
# # 805 - 2398e52 - 50x70
# # 806 - 2446ed3 - 33x49
# # 807 - 24a10e0 - CONFIG-DEFAULT - Geconfigureerd product - 35.9x27.8
# # 808 - 250b1d2 - 99x68
# # 809 - 2515dd8 - 76x106
# # 810 - 2536851 - 15x19.8
# # 811 - 25ad135 - CONFIG-DEFAULT - Geconfigureerd product - 93x75.8
# # 812 - 265ea40 - CONFIG-DEFAULT - Geconfigureerd product - 37x26.8
# # 813 - 266fdc2 - 97x72.8
# # 814 - 26ea4cb - CONFIG-DEFAULT - Geconfigureerd product - 42x59
# # 815 - 26f55e1 - CONFIG-DEFAULT - Geconfigureerd product - 21.1x29.8
# # 816 - 270e2b5 - 20x30
# # 817 - 273-019
# # 818 - 273-523
# # 819 - 273250
# # 820 - 275
# # 821 - 2757c7a - CONFIG-DEFAULT - Geconfigureerd product - 53x70.7
# # 822 - 27aa6c4 - 18x24
# # 823 - 27afc39 - BG.GLAS - Blinkend glas - 49x39
# # 824 - 28d3585 - CONFIG-DEFAULT - Geconfigureerd product - 21x28.1
# # 825 - 293947f - 50x70
# # 826 - 293bdbe - 26.2x35
# # 827 - 29e72e9 - 60x40
# # 828 - 2a4f6d4 - 20x6
# # 829 - 2a5bc2d - 30x21
# # 830 - 2a882d8 - 33x40
# # 831 - 2afeea8 - 27x36
# # 832 - 2b49492 - 36x51.1
# # 833 - 2b625a1 - 15x15
# # 834 - 2b9a6c2 - 50x36.6
# # 835 - 2bc09d6 - CONFIG-DEFAULT - Geconfigureerd product - 51x60
# # 836 - 2bc09d6 - CONFIG-DEFAULT - Geconfigureerd product - 99.1x58.3
# # 837 - 2bd0f9f - 14.8x21
# # 838 - 2bd0f9f - 21x29.7
# # 839 - 2bdf4e6 - MPG.GLAS - Mat plexiglas - 40x30
# # 840 - 2be3685 - CONFIG-DEFAULT - Geconfigureerd product - 125x150
# # 841 - 2c2661f - 38x51
# # 842 - 2ce5ef8 - CONFIG-DEFAULT - Geconfigureerd product - 35x23.4
# # 843 - 2d837f0 - CONFIG-DEFAULT - Geconfigureerd product - 32x38.7
# # 844 - 2d837f0 - CONFIG-DEFAULT - Geconfigureerd product - 32x38.7
# # 845 - 2de47fb - 54.1x76
# # 846 - 2e05372 - CONFIG-DEFAULT - Geconfigureerd product - 68.2x44.2
# # 847 - 2e369f2 - CONFIG-DEFAULT - Geconfigureerd product - 21.2x15
# # 848 - 2f09b52 - 75x44.9
# # 849 - 2f5e100 - 44.1x52
# # 850 - 2f6a457 - 60x80
# # 851 - 2f6a457 - 60x80
# # 852 - 2f96aa0 - 46x59.4
# # 853 - 3006830 - CONFIG-DEFAULT - Geconfigureerd product - 80.2x55.2
# # 854 - 3012976 - 46367.N12/13 - Oak Breed - Solid Wood Eik 3 cm - 18x24
# # 855 - 3012976 - 65415.I01-02 - Fourmi Wit 2 cm - 18x24
# # 856 - 304de12 - CONFIG-DEFAULT - Geconfigureerd product - 56.5x43.5
# # 857 - 30e4ba7 - 31x55.5
# # 858 - 314bd3d - 18x24
# # 859 - 3162aed - 30x20
# # 860 - 3162aed - 40x40
# # 861 - 32314c3 - 39x39
# # 862 - 32ac996 - 39x28.2
# # 863 - 32aed02 - CONFIG-DEFAULT - Geconfigureerd product - 22.7x34
# # 864 - 32aed02 - CONFIG-DEFAULT - Geconfigureerd product - 26.6x40
# # 865 - 32aed02 - CONFIG-DEFAULT - Geconfigureerd product - 29.2x38.8
# # 866 - 32aed02 - CONFIG-DEFAULT - Geconfigureerd product - 29.9x37.8
# # 867 - 32aed02 - CONFIG-DEFAULT - Geconfigureerd product - 40.6x54.8
# # 868 - 32b8457 - 50x70
# # 869 - 32b8457 - 70x70.2
# # 870 - 32da4c5 - 15.1x21.6
# # 871 - 32e501f - 30x42.5
# # 872 - 331a694 - 26x35
# # 873 - 3346e7a - 40.1x50.1
# # 874 - 3346e7a - 43x24.2
# # 875 - 3355e2d - 26.5x61
# # 876 - 337e6e5 - CONFIG-DEFAULT - Geconfigureerd product - 32.5x40
# # 877 - 33e4366 - CONFIG-DEFAULT - Geconfigureerd product - 33.7x42.2
# # 878 - 33f1fdf - 92x92
# # 879 - 3494728 - BG.GLAS - Blinkend glas - 50x70
# # 880 - 349e1e5 - 46x66
# # 881 - 34a64a9 - 40x60
# # 882 - 35009.G33 Ramin Wit 14x35
# # 883 - 35010.G33 Ramin Zwart 14x35
# # 884 - 35103.G33 Ramin Blank 14x35
# # 885 - 35b22f4 - 80x45.1
# # 886 - 35b22f4 - 93x52.4
# # 887 - 35d7e07 - 20x23.3
# # 888 - 35f7441 - 12.5x8.7
# # 889 - 35f7441 - 40.5x25.5
# # 890 - 36312
# # 891 - 36412
# # 892 - 364f76c - 22x16.6
# # 893 - 36d47bb - 46.3x61.8
# # 894 - 36dee21 - CONFIG-DEFAULT - Geconfigureerd product - 86x122
# # 895 - 36e4f17 - 39.5x55
# # 896 - 371637e - 27x20.6
# # 897 - 377e931 - 18x24
# # 898 - 377e931 - 18x24
# # 899 - 377e931 - 18x24
# # 900 - 38030b1 - 59x59
# # 901 - 382c77a - 74x74
# # 902 - 387ba0c - 60.5x48.5
# # 903 - 389f827 - 39.7x54.2
# # 904 - 38d685b - 24x33
# # 905 - 38db98c - CONFIG-DEFAULT - Geconfigureerd product - 29.7x29.7
# # 906 - 38db98c - CONFIG-DEFAULT - Geconfigureerd product - 50x29.8
# # 907 - 38f9c4e - 92x140.3
# # 908 - 39009b5 - 21x29.8
# # 909 - 39110
# # 910 - 3933166 - 17.1x22.1
# # 911 - 3933166 - 17.1x22.1
# # 912 - 3933166 - 19.8x27.9
# # 913 - 3933166 - 19.8x27.9
# # 914 - 3933166 - 22.8x27.6
# # 915 - 3933166 - 22.8x27.6
# # 916 - 3933166 - 29.7x42
# # 917 - 3933166 - 29.7x42
# # 918 - 3933166 - 29.7x42
# # 919 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 17.1x22.1
# # 920 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 17.1x22.1
# # 921 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 17.1x22.1
# # 922 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 17.1x22.1
# # 923 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 17.1x22.1
# # 924 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 19.8x27.9
# # 925 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 19.8x27.9
# # 926 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 19.8x27.9
# # 927 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 19.8x27.9
# # 928 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 19.8x27.9
# # 929 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 22.8x27.6
# # 930 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 22.8x27.6
# # 931 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 22.8x27.6
# # 932 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 22.8x27.6
# # 933 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 22.8x27.6
# # 934 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 29.7x42
# # 935 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 29.7x42
# # 936 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 29.7x42
# # 937 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 29.7x42
# # 938 - 3933166 - CONFIG-DEFAULT - Geconfigureerd product - 29.7x42
# # 939 - 3952b38 - 60x90
# # 940 - 3998ba4 - 100x70
# # 941 - 39be389 - 26x36
# # 942 - 39be389 - 51x36
# # 943 - 39be389 - 51x36
# # 944 - 39be389 - 52x72
# # 945 - 39be389 - 57x42
# # 946 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 26x36
# # 947 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 26x36
# # 948 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 26x36
# # 949 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 26x36
# # 950 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 26x36
# # 951 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 26x36
# # 952 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 26x36
# # 953 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 51x36
# # 954 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 51x36
# # 955 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 51x36
# # 956 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 51x36
# # 957 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 51x36
# # 958 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 51x36
# # 959 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 51x36
# # 960 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 52x72
# # 961 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 52x72
# # 962 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 52x72
# # 963 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 52x72
# # 964 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 52x72
# # 965 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 52x72
# # 966 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 52x72
# # 967 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 57x42
# # 968 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 57x42
# # 969 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 57x42
# # 970 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 57x42
# # 971 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 57x42
# # 972 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 57x42
# # 973 - 39be389 - CONFIG-DEFAULT - Geconfigureerd product - 57x42
# # 974 - 3a15eeb - CONFIG-DEFAULT - Geconfigureerd product - 41x41
# # 975 - 3a5676a - 40x40
# # 976 - 3ab2dc5 - CONFIG-DEFAULT - Geconfigureerd product - 60x45
# # 977 - 3c460e6 - 13x18
# # 978 - 3c460e6 - 13x18
# # 979 - 3c460e6 - 13x18
# # 980 - 3c460e6 - 18x24
# # 981 - 3c460e6 - 18x24
# # 982 - 3c460e6 - 18x24
# # 983 - 3c460e6 - 18x24
# # 984 - 3c460e6 - 18x24
# # 985 - 3c460e6 - 18x24
# # 986 - 3c460e6 - 18x24
# # 987 - 3c460e6 - 18x24
# # 988 - 3c460e6 - 18x24
# # 989 - 3c460e6 - 18x24
# # 990 - 3c460e6 - 18x24
# # 991 - 3c460e6 - 18x24
# # 992 - 3caa7af - CONFIG-DEFAULT - Geconfigureerd product - 83x70
# # 993 - 3d70949 - 82x112
# # 994 - 3e3444d - 18x24
# # 995 - 3e7acd0 - 34x26
# # 996 - 3e868e4 - 70.3x49.9
# # 997 - 3e8e94a - CONFIG-DEFAULT - Geconfigureerd product - 21x21
# # 998 - 3e9af02 - CONFIG-DEFAULT - Geconfigureerd product - 28x39
# # 999 - 3e9af02 - CONFIG-DEFAULT - Geconfigureerd product - 28x39
# #1000 - 3e9af02 - CONFIG-DEFAULT - Geconfigureerd product - 39x29.4
# #1001 - 3f0d85a - 18x24
# #1002 - 3f0d85a - 20x20
# #1003 - 3f0d85a - 20x20
# #1004 - 3f0d85a - 20x20
# #1005 - 3f10f03 - 58x86
# #1006 - 3f10f03 - 61x81
# #1007 - 3f13cb4 - CONFIG-DEFAULT - Geconfigureerd product - 35.3x42.9
# #1008 - 3f3618b - 37x37
# #1009 - 3f859ef - 21x26
# #1010 - 3f859ef - 28x22.5
# #1011 - 3fb096e - 13x18
# #1012 - 3fb096e - 13x18
# #1013 - 3fb096e - 18x24
# #1014 - 3fb096e - 18x24
# #1015 - 3fb096e - 18x24
# #1016 - 3ff7170 - CONFIG-DEFAULT - Geconfigureerd product - 46x56
# #1017 - 4031f9e - 37x33.5
# #1018 - 40467.J36 Spacer eik 15mm
# #1019 - 4071
# #1020 - 40b342f - 55.5x49
# #1021 - 41182
# #1022 - 411e227 - 17.5x25
# #1023 - 411e227 - 23x17
# #1024 - 411e227 - 24x18
# #1025 - 4131
# #1026 - 4132
# #1027 - 414fff4 - CONFIG-DEFAULT - Geconfigureerd product - 60x50
# #1028 - 414fff4 - CONFIG-DEFAULT - Geconfigureerd product - 80x60
# #1029 - 41d3c9a - 98x68
# #1030 - 41e83c5 - 33.3x42
# #1031 - 420b809 - CONFIG-DEFAULT - Geconfigureerd product - 20x27
# #1032 - 42871a9 - CONFIG-DEFAULT - Geconfigureerd product - 68x84
# #1033 - 42e2d5c - CONFIG-DEFAULT - Geconfigureerd product - 63x45.7
# #1034 - 42f2f9c - CONFIG-DEFAULT - Geconfigureerd product - 26x33
# #1035 - 42f2f9c - CONFIG-DEFAULT - Geconfigureerd product - 38.5x45
# #1036 - 430e49a - 60x39.5
# #1037 - 43202
# #1038 - 43a5bd0 - CONFIG-DEFAULT - Geconfigureerd product - 44x76
# #1039 - 4442421 - CONFIG-DEFAULT - Geconfigureerd product - 30x24.7
# #1040 - 44702
# #1041 - 44806
# #1042 - 44906
# #1043 - 44cc9e1 - 20.3x16.9
# #1044 - 4567cef - 33.7x27.5
# #1045 - 4567cef - 46x36
# #1046 - 46166
# #1047 - 46366
# #1048 - 46465
# #1049 - 46ce789 - 31x41.4
# #1050 - 46e49f6 - CONFIG-DEFAULT - Geconfigureerd product - 79x114
# #1051 - 470189c - 29.8x40.5
# #1052 - 47265
# #1053 - 4730561 - 28.1x39.5
# #1054 - 4730561 - 30x42.5
# #1055 - 47aa312 - CONFIG-DEFAULT - Geconfigureerd product - 87x63
# #1056 - 47f162f - CONFIG-DEFAULT - Geconfigureerd product - 50x70
# #1057 - 484a724 - 26x26
# #1058 - 484d703 - CONFIG-DEFAULT - Geconfigureerd product - 31x23.5
# #1059 - 48502
# #1060 - 4850493 - CONFIG-DEFAULT - Geconfigureerd product - 65.5x50
# #1061 - 48554d0 - 21x28.5
# #1062 - 4872fcb - 32.5x45.5
# #1063 - 4872fcb - 36.5x26
# #1064 - 4920858 - 5.4x7.4
# #1065 - 494a1cd - 30x21
# #1066 - 49679d7 - 55.8x80.8
# #1067 - 4982ff3 - CONFIG-DEFAULT - Geconfigureerd product - 35.5x61
# #1068 - 49856a6 - CONFIG-DEFAULT - Geconfigureerd product - 30x24.7
# #1069 - 49856a6 - CONFIG-DEFAULT - Geconfigureerd product - 30x45.7
# #1070 - 49c8ff8 - 54.7x44
# #1071 - 49c8ff8 - 54.7x44.1
# #1072 - 49d2012 - 36.3x48.9
# #1073 - 49e3617 - 56x38
# #1074 - 49eb370 - 21x29.7
# #1075 - 49eb370 - 33.5x48
# #1076 - 49eb370 - 42x29.7
# #1077 - 4a99cf5 - CONFIG-DEFAULT - Geconfigureerd product - 90x120
# #1078 - 4ab0bd9 - 38.5x50
# #1079 - 4b65ce9 - 26.7x40
# #1080 - 4b65ce9 - 26.9x40
# #1081 - 4b811e8 - 42x59.4
# #1082 - 4b8665c - 29.9x36.3
# #1083 - 4bf2741 - CONFIG-DEFAULT - Geconfigureerd product - 36x46
# #1084 - 4c4b7e6 - 21x21
# #1085 - 4c9698f - 92x130
# #1086 - 4ca3f26 - 26x36
# #1087 - 4cd0e13 - 42x42
# #1088 - 4d214c7 - 20x15
# #1089 - 4d24113 - 38.7x38.7
# #1090 - 4dc1226 - CONFIG-DEFAULT - Geconfigureerd product - 90x50.7
# #1091 - 4dd2db2 - 40x50
# #1092 - 4dd2db2 - 66.1x45
# #1093 - 4dd6939 - CONFIG-DEFAULT - Geconfigureerd product - 33x40
# #1094 - 4df7669 - 45x58
# #1095 - 4e5c25c - CONFIG-DEFAULT - Geconfigureerd product - 51.9x52
# #1096 - 4efba93 - 25x31
# #1097 - 4f50896 - 53x73.5
# #1098 - 4faab81 - CONFIG-DEFAULT - Geconfigureerd product - 23x23
# #1099 - 4ff5b90 - CONFIG-DEFAULT - Geconfigureerd product - 27x36
# #1100 - 4ff5b90 - CONFIG-DEFAULT - Geconfigureerd product - 37x29.5
# #1101 - 5070b31 - 50x38.8
# #1102 - 50802b3 - CONFIG-DEFAULT - Geconfigureerd product - 40x40
# #1103 - 50802b3 - CONFIG-DEFAULT - Geconfigureerd product - 76x54
# #1104 - 50802b3 - CONFIG-DEFAULT - Geconfigureerd product - 80x80
# #1105 - 50a16f5 - 58x58
# #1106 - 50b5dd0 - 56x76
# #1107 - 50d95ba - 132x102
# #1108 - 50f0732 - 42.1x42.1
# #1109 - 50f0732 - 47x35.4
# #1110 - 5104edf - CONFIG-DEFAULT - Geconfigureerd product - 20x20.4
# #1111 - 5132121 - 30x40
# #1112 - 51632
# #1113 - 52370f8 - 18x27
# #1114 - 5282b74 - 42x52
# #1115 - 52c2cf1 - 25x29.8
# #1116 - 52d1933 - 26.1x36
# #1117 - 52eba49 - 24x33.4
# #1118 - 53676e9 - 33x41.7
# #1119 - 537fe57 - 50.5x65.4
# #1120 - 53837
# #1121 - 53a57c3 - CONFIG-DEFAULT - Geconfigureerd product - 28.3x40
# #1122 - 53a9703 - 20x15
# #1123 - 53c20c0 - 50.3x69.4
# #1124 - 53d26f0 - 68x49.2
# #1125 - 542929f - 20x25
# #1126 - 542929f - 25x30
# #1127 - 542929f - 30x35
# #1128 - 544019d - 72.3x50.3
# #1129 - 54c94a2 - 69.9x33.3
# #1130 - 54d7ba0 - 30.7x23.2
# #1131 - 5506808 - 33x48.2
# #1132 - 5506808 - 48x69
# #1133 - 5506808 - 50.7x72.3
# #1134 - 55337f7 - 39x39
# #1135 - 5535790 - CONFIG-DEFAULT - Geconfigureerd product - 44.5x62.5
# #1136 - 5535790 - CONFIG-DEFAULT - Geconfigureerd product - 44x75
# #1137 - 558d482 - CONFIG-DEFAULT - Geconfigureerd product - 28x42
# #1138 - 55caf08 - 17.5x17.5
# #1139 - 55e01fb - 34x27
# #1140 - 5611
# #1141 - 5647fb1 - AR70.GLAS - Artglass AR70 - 50x40
# #1142 - 5650d25 - 91x61
# #1143 - 56567
# #1144 - 566141f - 33.5x68.7
# #1145 - 57326b2 - CONFIG-DEFAULT - Geconfigureerd product - 21x26
# #1146 - 5737dd7 - CONFIG-DEFAULT - Geconfigureerd product - 45.5x62.5
# #1147 - 5771f5e - 42.5x52.2
# #1148 - 577c13a - 30x22.6
# #1149 - 577c13a - 30x45.4
# #1150 - 577c13a - 36x30.7
# #1151 - 577c13a - 36x51
# #1152 - 578bf22 - 60x40
# #1153 - 57a2493 - 28.5x64.5
# #1154 - 57d5967 - 24.7x24.7
# #1155 - 57d5967 - 55x75
# #1156 - 57dc7e7 - 29x37.5
# #1157 - 582d9e1 - CONFIG-DEFAULT - Geconfigureerd product - 58x31.6
# #1158 - 589361a - CONFIG-DEFAULT - Geconfigureerd product - 30.8x37.1
# #1159 - 589f86a - 26x26
# #1160 - 58aae17 - 81468.N07 - Oak - Solid Wood Eik 20/15 - 50x50
# #1161 - 58df1dd - 45x45
# #1162 - 590667b - CONFIG-DEFAULT - Geconfigureerd product - 99x58.5
# #1163 - 590667b - CONFIG-DEFAULT - Geconfigureerd product - 99x66
# #1164 - 5995373 - CONFIG-DEFAULT - Geconfigureerd product - 57x78
# #1165 - 59b47a1 - 24.8x32.5
# #1166 - 59ba36e - 36x30
# #1167 - 5a1239d - 10x15
# #1168 - 5a1239d - 15x9.8
# #1169 - 5a1239d - 18x12.5
# #1170 - 5a1239d - 18x18
# #1171 - 5a1239d - 19x11.8
# #1172 - 5a1239d - 20x15
# #1173 - 5a1239d - 7.6x7.6
# #1174 - 5a1239d - 9.3x9.3
# #1175 - 5a1239d - 9x13.2
# #1176 - 5a1239d - 9x18
# #1177 - 5abd2f7 - 100x58.6
# #1178 - 5ac8150 - 66x96
# #1179 - 5afd5d2 - 10x15
# #1180 - 5afd5d2 - 15x15
# #1181 - 5afd5d2 - 9.5x14.5
# #1182 - 5b0ba70 - CONFIG-DEFAULT - Geconfigureerd product - 45.5x23
# #1183 - 5b56fbd - 25x25
# #1184 - 5b7e8c1 - 22x26
# #1185 - 5b7e8c1 - 40x36
# #1186 - 5bc1208 - 10x15
# #1187 - 5bc1208 - 13x18
# #1188 - 5c20ded - 28x18.7
# #1189 - 5c8b72b - 30x36
# #1190 - 5c8b72b - 30x40
# #1191 - 5c8b72b - 39.5x49.5
# #1192 - 5ce26b3 - 57.3x42.2
# #1193 - 5ce26b3 - 57.6x42.4
# #1194 - 5ceb7c7 - AR92.GLAS - Artglass AR92 - 35x43
# #1195 - 5d40e02 - MG.GLAS - Mat glas - 43x43
# #1196 - 5d64888 - 50x70
# #1197 - 5dcf9e8 - 24x33
# #1198 - 5dd275f - CONFIG-DEFAULT - Geconfigureerd product - 21x21
# #1199 - 5dd275f - CONFIG-DEFAULT - Geconfigureerd product - 22x22
# #1200 - 5dd275f - CONFIG-DEFAULT - Geconfigureerd product - 26.1x21.1
# #1201 - 5dd275f - CONFIG-DEFAULT - Geconfigureerd product - 28x21.1
# #1202 - 5e24ade - 72x45.5
# #1203 - 5e35b7d - CONFIG-DEFAULT - Geconfigureerd product - 38.7x55.1
# #1204 - 5e42131 - 67.5x100
# #1205 - 5e95d05 - CONFIG-DEFAULT - Geconfigureerd product - 41.5x67
# #1206 - 5efefd3 - 120x81.5
# #1207 - 5f008b5 - 104x58
# #1208 - 5fb4130 - 10x15
# #1209 - 5fb4130 - 10x15
# #1210 - 5fb4130 - 16x16
# #1211 - 5fb4130 - 17.5x17
# #1212 - 5fb4130 - 18x24
# #1213 - 5fb4130 - 9x13
# #1214 - 6039f6f - 50x40
# #1215 - 60453b9 - 42x52
# #1216 - 6059620 - 41x56
# #1217 - 60767
# #1218 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 21x29.7
# #1219 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 21x29.7
# #1220 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 21x29.7
# #1221 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 21x29.7
# #1222 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 21x29.7
# #1223 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 21x29.7
# #1224 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 21x29.7
# #1225 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 21x29.7
# #1226 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 21x29.7
# #1227 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 29.7x21
# #1228 - 607d18a - CONFIG-DEFAULT - Geconfigureerd product - 29.7x21
# ...
# #4772 - nielsen wood picture frame Quadrum, 18x24 cm, Black
# #4773 - nielsen wood picture frame Quadrum, 18x24 cm, Covering White
# #4774 - nielsen wood picture frame Quadrum, 18x24 cm, Gold
# #4775 - nielsen wood picture frame Quadrum, 18x24 cm, Grey
# #4776 - nielsen wood picture frame Quadrum, 18x24 cm, Maple
# #4777 - nielsen wood picture frame Quadrum, 18x24 cm, Oak Natural
# #4778 - nielsen wood picture frame Quadrum, 18x24 cm, Silver
# #4779 - nielsen wood picture frame Quadrum, 18x24 cm, Wenge
# #4780 - nielsen wood picture frame Quadrum, 18x24 cm, White
# #4781 - nielsen wood picture frame Quadrum, 20x20 cm, Black
# #4782 - nielsen wood picture frame Quadrum, 20x20 cm, Covering White
# #4783 - nielsen wood picture frame Quadrum, 20x20 cm, Gold
# #4784 - nielsen wood picture frame Quadrum, 20x20 cm, Green
# #4785 - nielsen wood picture frame Quadrum, 20x20 cm, Grey
# #4786 - nielsen wood picture frame Quadrum, 20x20 cm, Maple
# #4787 - nielsen wood picture frame Quadrum, 20x20 cm, Oak Natural
# #4788 - nielsen wood picture frame Quadrum, 20x20 cm, Silver
# #4789 - nielsen wood picture frame Quadrum, 20x20 cm, Wenge
# #4790 - nielsen wood picture frame Quadrum, 20x20 cm, White
# #4791 - nielsen wood picture frame Quadrum, 20x30 cm, Black
# #4792 - nielsen wood picture frame Quadrum, 20x30 cm, Blue
# #4793 - nielsen wood picture frame Quadrum, 20x30 cm, Covering White
# #4794 - nielsen wood picture frame Quadrum, 20x30 cm, Gold
# #4795 - nielsen wood picture frame Quadrum, 20x30 cm, Grey
# #4796 - nielsen wood picture frame Quadrum, 20x30 cm, Maple
# #4797 - nielsen wood picture frame Quadrum, 20x30 cm, Oak Natural
# #4798 - nielsen wood picture frame Quadrum, 20x30 cm, Silver
# #4799 - nielsen wood picture frame Quadrum, 20x30 cm, Silver Anthracite
# #4800 - nielsen wood picture frame Quadrum, 20x30 cm, Wenge
# #4801 - nielsen wood picture frame Quadrum, 20x30 cm, White
# #4802 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Black
# #4803 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Blue
# #4804 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Cement Grey
# #4805 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Covering White
# #4806 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Dove Grey
# #4807 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Gold
# #4808 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Green
# #4809 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Grey
# #4810 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Jet Black
# #4811 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Loam Brown
# #4812 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Maple
# #4813 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Oak Natural
# #4814 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Red
# #4815 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Silver
# #4816 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Silver Anthracite
# #4817 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Snow White
# #4818 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) Wenge
# #4819 - nielsen wood picture frame Quadrum, 21x29,7 cm, (A4) White
# #4820 - nielsen wood picture frame Quadrum, 24x30 cm, Black
# #4821 - nielsen wood picture frame Quadrum, 24x30 cm, Blue
# #4822 - nielsen wood picture frame Quadrum, 24x30 cm, Cement Grey
# #4823 - nielsen wood picture frame Quadrum, 24x30 cm, Covering White
# #4824 - nielsen wood picture frame Quadrum, 24x30 cm, Dove Grey
# #4825 - nielsen wood picture frame Quadrum, 24x30 cm, Gold
# #4826 - nielsen wood picture frame Quadrum, 24x30 cm, Green
# #4827 - nielsen wood picture frame Quadrum, 24x30 cm, Grey
# #4828 - nielsen wood picture frame Quadrum, 24x30 cm, Jet Black
# #4829 - nielsen wood picture frame Quadrum, 24x30 cm, Loam Brown
# #4830 - nielsen wood picture frame Quadrum, 24x30 cm, Maple
# #4831 - nielsen wood picture frame Quadrum, 24x30 cm, Oak Natural
# #4832 - nielsen wood picture frame Quadrum, 24x30 cm, Red
# #4833 - nielsen wood picture frame Quadrum, 24x30 cm, Silver
# #4834 - nielsen wood picture frame Quadrum, 24x30 cm, Snow White
# #4835 - nielsen wood picture frame Quadrum, 24x30 cm, Wenge
# #4836 - nielsen wood picture frame Quadrum, 24x30 cm, White
# #4837 - nielsen wood picture frame Quadrum, 28x35 cm, Black
# #4838 - nielsen wood picture frame Quadrum, 28x35 cm, Cement Grey
# #4839 - nielsen wood picture frame Quadrum, 28x35 cm, Covering White
# #4840 - nielsen wood picture frame Quadrum, 28x35 cm, Dove Grey
# #4841 - nielsen wood picture frame Quadrum, 28x35 cm, Gold
# #4842 - nielsen wood picture frame Quadrum, 28x35 cm, Grey
# #4843 - nielsen wood picture frame Quadrum, 28x35 cm, Jet Black
# #4844 - nielsen wood picture frame Quadrum, 28x35 cm, Loam Brown
# #4845 - nielsen wood picture frame Quadrum, 28x35 cm, Maple
# #4846 - nielsen wood picture frame Quadrum, 28x35 cm, Nut Brown
# #4847 - nielsen wood picture frame Quadrum, 28x35 cm, Oak Natural
# #4848 - nielsen wood picture frame Quadrum, 28x35 cm, Silver
# #4849 - nielsen wood picture frame Quadrum, 28x35 cm, Snow White
# #4850 - nielsen wood picture frame Quadrum, 28x35 cm, Wenge
# #4851 - nielsen wood picture frame Quadrum, 28x35 cm, White
# #4852 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Black
# #4853 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Blue
# #4854 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Cement Grey
# #4855 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Covering White
# #4856 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Dove Grey
# #4857 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Gold
# #4858 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Green
# #4859 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Grey
# #4860 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Jet Black
# #4861 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Loam Brown
# #4862 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Maple
# #4863 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Oak Natural
# #4864 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Red
# #4865 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Silver
# #4866 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Snow White
# #4867 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) Wenge
# #4868 - nielsen wood picture frame Quadrum, 29,7x42 cm, (A3) White
# #4869 - nielsen wood picture frame Quadrum, 30x30 cm, Black
# #4870 - nielsen wood picture frame Quadrum, 30x30 cm, Blue
# #4871 - nielsen wood picture frame Quadrum, 30x30 cm, Cement Grey
# #4872 - nielsen wood picture frame Quadrum, 30x30 cm, Covering White
# #4873 - nielsen wood picture frame Quadrum, 30x30 cm, Dove Grey
# #4874 - nielsen wood picture frame Quadrum, 30x30 cm, Gold
# #4875 - nielsen wood picture frame Quadrum, 30x30 cm, Grey
# #4876 - nielsen wood picture frame Quadrum, 30x30 cm, Jet Black
# #4877 - nielsen wood picture frame Quadrum, 30x30 cm, Loam Brown
# #4878 - nielsen wood picture frame Quadrum, 30x30 cm, Maple
# #4879 - nielsen wood picture frame Quadrum, 30x30 cm, Nut Brown
# #4880 - nielsen wood picture frame Quadrum, 30x30 cm, Oak Natural
# #4881 - nielsen wood picture frame Quadrum, 30x30 cm, Red
# #4882 - nielsen wood picture frame Quadrum, 30x30 cm, Silver
# #4883 - nielsen wood picture frame Quadrum, 30x30 cm, Snow White
# #4884 - nielsen wood picture frame Quadrum, 30x30 cm, Wenge
# #4885 - nielsen wood picture frame Quadrum, 30x30 cm, White
# #4886 - nielsen wood picture frame Quadrum, 30x40 cm, Blue
# #4887 - nielsen wood picture frame Quadrum, 30x40 cm, Cement Grey
# #4888 - nielsen wood picture frame Quadrum, 30x40 cm, Covering White
# #4889 - nielsen wood picture frame Quadrum, 30x40 cm, Dove Grey
# #4890 - nielsen wood picture frame Quadrum, 30x40 cm, Green
# #4891 - nielsen wood picture frame Quadrum, 30x40 cm, Grey
# #4892 - nielsen wood picture frame Quadrum, 30x40 cm, Jet Black
# #4893 - nielsen wood picture frame Quadrum, 30x40 cm, Loam Brown
# #4894 - nielsen wood picture frame Quadrum, 30x40 cm, Nut Brown
# #4895 - nielsen wood picture frame Quadrum, 30x40 cm, Red
# #4896 - nielsen wood picture frame Quadrum, 30x40 cm, Snow White
# #4897 - nielsen wood picture frame Quadrum, 30x45 cm, Black
# #4898 - nielsen wood picture frame Quadrum, 30x45 cm, Covering White
# #4899 - nielsen wood picture frame Quadrum, 30x45 cm, Grey
# #4900 - nielsen wood picture frame Quadrum, 30x45 cm, Maple
# #4901 - nielsen wood picture frame Quadrum, 30x45 cm, Oak Natural
# #4902 - nielsen wood picture frame Quadrum, 30x45 cm, Silver
# #4903 - nielsen wood picture frame Quadrum, 30x45 cm, Snow White
# #4904 - nielsen wood picture frame Quadrum, 30x45 cm, Wenge
# #4905 - nielsen wood picture frame Quadrum, 30x45 cm, White
# #4906 - nielsen wood picture frame Quadrum, 40x40 cm, Black
# #4907 - nielsen wood picture frame Quadrum, 40x40 cm, Cement Grey
# #4908 - nielsen wood picture frame Quadrum, 40x40 cm, Covering White
# #4909 - nielsen wood picture frame Quadrum, 40x40 cm, Grey
# #4910 - nielsen wood picture frame Quadrum, 40x40 cm, Jet Black
# #4911 - nielsen wood picture frame Quadrum, 40x40 cm, Maple
# #4912 - nielsen wood picture frame Quadrum, 40x40 cm, Oak Natural
# #4913 - nielsen wood picture frame Quadrum, 40x40 cm, Silver
# #4914 - nielsen wood picture frame Quadrum, 40x40 cm, Snow White
# #4915 - nielsen wood picture frame Quadrum, 40x40 cm, Wenge
# #4916 - nielsen wood picture frame Quadrum, 40x40 cm, White
# #4917 - nielsen wood picture frame Quadrum, 40x50 cm, Blue
# #4918 - nielsen wood picture frame Quadrum, 40x50 cm, Cement Grey
# #4919 - nielsen wood picture frame Quadrum, 40x50 cm, Covering White
# #4920 - nielsen wood picture frame Quadrum, 40x50 cm, Dove Grey
# #4921 - nielsen wood picture frame Quadrum, 40x50 cm, Green
# #4922 - nielsen wood picture frame Quadrum, 40x50 cm, Grey
# #4923 - nielsen wood picture frame Quadrum, 40x50 cm, Jet Black
# #4924 - nielsen wood picture frame Quadrum, 40x50 cm, Loam Brown
# #4925 - nielsen wood picture frame Quadrum, 40x50 cm, Nut Brown
# #4926 - nielsen wood picture frame Quadrum, 40x50 cm, Red
# #4927 - nielsen wood picture frame Quadrum, 40x50 cm, Snow White
# #4928 - nielsen wood picture frame Quadrum, 40x60 cm, Black
# #4929 - nielsen wood picture frame Quadrum, 40x60 cm, Cement Grey
# #4930 - nielsen wood picture frame Quadrum, 40x60 cm, Covering White
# #4931 - nielsen wood picture frame Quadrum, 40x60 cm, Gold
# #4932 - nielsen wood picture frame Quadrum, 40x60 cm, Grey
# #4933 - nielsen wood picture frame Quadrum, 40x60 cm, Jet Black
# #4934 - nielsen wood picture frame Quadrum, 40x60 cm, Loam Brown
# #4935 - nielsen wood picture frame Quadrum, 40x60 cm, Maple
# #4936 - nielsen wood picture frame Quadrum, 40x60 cm, Oak Natural
# #4937 - nielsen wood picture frame Quadrum, 40x60 cm, Silver
# #4938 - nielsen wood picture frame Quadrum, 40x60 cm, Snow White
# #4939 - nielsen wood picture frame Quadrum, 40x60 cm, Wenge
# #4940 - nielsen wood picture frame Quadrum, 40x60 cm, White
# #4941 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Black
# #4942 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Blue
# #4943 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Cement Grey
# #4944 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Covering White
# #4945 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Gold
# #4946 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Green
# #4947 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Grey
# #4948 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Jet Black
# #4949 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Maple
# #4950 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Oak Natural
# #4951 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Red
# #4952 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Silver
# #4953 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Snow White
# #4954 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) Wenge
# #4955 - nielsen wood picture frame Quadrum, 42x59,4 cm, (A2) White
# #4956 - nielsen wood picture frame Quadrum, 50x60 cm, Cement Grey
# #4957 - nielsen wood picture frame Quadrum, 50x60 cm, Covering White
# #4958 - nielsen wood picture frame Quadrum, 50x60 cm, Dove Grey
# #4959 - nielsen wood picture frame Quadrum, 50x60 cm, Grey
# #4960 - nielsen wood picture frame Quadrum, 50x60 cm, Jet Black
# #4961 - nielsen wood picture frame Quadrum, 50x60 cm, Loam Brown
# #4962 - nielsen wood picture frame Quadrum, 50x60 cm, Snow White
# #4963 - nielsen wood picture frame Quadrum, 50x70 cm, Black
# #4964 - nielsen wood picture frame Quadrum, 50x70 cm, Blue
# #4965 - nielsen wood picture frame Quadrum, 50x70 cm, Cement Grey
# #4966 - nielsen wood picture frame Quadrum, 50x70 cm, Covering White
# #4967 - nielsen wood picture frame Quadrum, 50x70 cm, Dove Grey
# #4968 - nielsen wood picture frame Quadrum, 50x70 cm, Gold
# #4969 - nielsen wood picture frame Quadrum, 50x70 cm, Green
# #4970 - nielsen wood picture frame Quadrum, 50x70 cm, Grey
# #4971 - nielsen wood picture frame Quadrum, 50x70 cm, Jet Black
# #4972 - nielsen wood picture frame Quadrum, 50x70 cm, Loam Brown
# #4973 - nielsen wood picture frame Quadrum, 50x70 cm, Maple
# #4974 - nielsen wood picture frame Quadrum, 50x70 cm, Oak Natural
# #4975 - nielsen wood picture frame Quadrum, 50x70 cm, Red
# #4976 - nielsen wood picture frame Quadrum, 50x70 cm, Silver
# #4977 - nielsen wood picture frame Quadrum, 50x70 cm, Snow White
# #4978 - nielsen wood picture frame Quadrum, 50x70 cm, Wenge
# #4979 - nielsen wood picture frame Quadrum, 50x70 cm, White
# #4980 - nielsen wood picture frame Quadrum, 60x80 cm, Black
# #4981 - nielsen wood picture frame Quadrum, 60x80 cm, Cement Grey
# #4982 - nielsen wood picture frame Quadrum, 60x80 cm, Covering White
# #4983 - nielsen wood picture frame Quadrum, 60x80 cm, Dove Grey
# #4984 - nielsen wood picture frame Quadrum, 60x80 cm, Gold
# #4985 - nielsen wood picture frame Quadrum, 60x80 cm, Grey
# #4986 - nielsen wood picture frame Quadrum, 60x80 cm, Jet Black
# #4987 - nielsen wood picture frame Quadrum, 60x80 cm, Loam Brown
# #4988 - nielsen wood picture frame Quadrum, 60x80 cm, Maple
# #4989 - nielsen wood picture frame Quadrum, 60x80 cm, Oak Natural
# #4990 - nielsen wood picture frame Quadrum, 60x80 cm, Silver
# #4991 - nielsen wood picture frame Quadrum, 60x80 cm, Snow White
# #4992 - nielsen wood picture frame Quadrum, 60x80 cm, Wenge
# #4993 - nielsen wood picture frame Quadrum, 60x80 cm, White
# #4994 - nielsen wood picture frame Quadrum, 70x100 cm, Black
# #4995 - nielsen wood picture frame Quadrum, 70x100 cm, Covering White
# #4996 - nielsen wood picture frame Quadrum, 70x100 cm, Grey
# #4997 - nielsen wood picture frame Quadrum, 70x100 cm, Maple
# #4998 - nielsen wood picture frame Quadrum, 70x100 cm, Oak Natural
# #4999 - nielsen wood picture frame Quadrum, 70x100 cm, Silver
# #5000 - nielsen wood picture frame Quadrum, 70x100 cm, Snow White
# #5001 - nielsen wood picture frame Quadrum, 70x100 cm, Wenge
# #5002 - nielsen wood picture frame Quadrum, 70x100 cm, White
# #5003 - p108
# #5004 - p1p
# #5005 - p4p
# #5006 - p5p
# #5007 - p6p
# #5008 - p7p
# #5009 - plexi
# #5010 - plexi maatwerk
# #5011 - rug
# #5012 - tesa® 4313 PV12 50MM (kopie)
# #5013 - tesa® 4313 PV12 50MM (kopie)
# #5014 - tesa® 4341 30mm (kopie)
# #5015 - tesa® 4341 50MM (kopie)
# #5016 - tesa® 4341 75mm (kopie)
# #5017 - tesa® 4959 19mm (kopie)
# #5018 - tesa® 4959 19mm (kopie)
# #5019 - tesa® 4970 30mm (kopie)
# #5020 - tesa® 4970 50m 19mm (kopie)
# #5021 - tesa® 62934 19mm (kopie)
# #5022 - tesa® 62934 50m 25mm (kopie)
# #5023 - tesa® 64014 50mm (kopie)
# #5024 - tesa® 64958 19mm (kopie)
# #5025 - tesa® Klevende Spijker voor behang & pleisterwerk 2kg (kopie)
# #5026 - tesa® Professional Lijmverwijderaar 200ml (kopie)
# #5027 - test
# #5028 - verstevigin
# #5029 - verzed
# #5030 - warm
# #5031 - warm kle
# ============================================================
# ✅ Displayed 5031 products
#
# ✅ Done!
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
import xmlrpc.client
from dotenv import load_dotenv
from openpyxl import load_workbook
import time
from datetime import datetime, timedelta
import shutil

load_dotenv(override=True)

ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

print("Connecting to Odoo...")

common = xmlrpc.client.ServerProxy(f"{ODOO_URL}/xmlrpc/2/common", allow_none=True)
uid = common.authenticate(ODOO_DB, ODOO_USERNAME, ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

print(f"✅ Connected as {ODOO_USERNAME} (uid={uid})")

models = xmlrpc.client.ServerProxy(f"{ODOO_URL}/xmlrpc/2/object", allow_none=True)

print("\n🔍 Fetching products with price computation = Surface or Circumference...")

try:
    # Fetch ALL products with price computation = Surface or Circumference
    products = models.execute_kw(
        ODOO_DB, uid, ODOO_API_KEY,
        'product.product', 'search_read',
        [[['x_studio_price_computation', 'in', ['Surface', 'Circumference']]]],  # Filter by price computation
        {
            'fields': [
                'name', 
                'id', 
                'x_studio_product_code', 
                'x_studio_location_code', 
                'description_ecommerce', 
                'x_studio_price_computation', 
                'standard_price',
                'x_studio_associated_service', 
                'x_studio_associated_work_center', 
                'x_studio_associated_cost_per_employee_per_hour'
            ]
            # No limit - fetch all products
        }
    )
    
    total_products = len(products)
    print(f"📊 Fetched {total_products} products")
    
    # Create a new filename with timestamp
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    template_file = 'justframeit pricelist template empty.xlsx'
    output_file = f'justframeit_pricelist_{timestamp}.xlsx'
    
    # Copy the template to create a new file
    shutil.copy(template_file, output_file)
    print(f"📄 Created new file: {output_file}")
    
    # Load the newly created Excel file
    wb = load_workbook(output_file)
    
    # =============================================
    # 📋 Fill TAB 1 with products
    # =============================================
    ws1 = wb.worksheets[0]  # First tab (index 0)
    
    # Starting row is A7 (row 7)
    start_row = 7
    start_time = time.time()
    
    # Fill data for each product
    for idx, product in enumerate(products):
        current_row = start_row + idx
        
        # Helper function to convert list/tuple values to string
        def convert_value(value):
            if isinstance(value, (list, tuple)):
                # If it's a list/tuple, join elements or take the second element (name)
                if len(value) > 1:
                    return str(value[1])  # Return the name part
                return str(value[0]) if value else ''
            return value
        
        # Fill columns A through J with the product data
        ws1[f'A{current_row}'] = convert_value(product.get('name'))
        ws1[f'B{current_row}'] = convert_value(product.get('id'))
        ws1[f'C{current_row}'] = convert_value(product.get('x_studio_product_code'))
        ws1[f'D{current_row}'] = convert_value(product.get('x_studio_location_code'))
        ws1[f'E{current_row}'] = convert_value(product.get('description_ecommerce'))
        ws1[f'F{current_row}'] = convert_value(product.get('x_studio_price_computation'))
        ws1[f'G{current_row}'] = convert_value(product.get('standard_price'))
        ws1[f'H{current_row}'] = convert_value(product.get('x_studio_associated_service'))
        ws1[f'I{current_row}'] = convert_value(product.get('x_studio_associated_work_center'))
        ws1[f'J{current_row}'] = convert_value(product.get('x_studio_associated_cost_per_employee_per_hour'))
        
        print(f"✅ Filled row {current_row} on tab 1 with product: {product.get('name')}")
    
    # Save the workbook
    wb.save(output_file)
    print(f"\n✅ Successfully filled {len(products)} products into tab 1")
    
    # =============================================
    # 📋 Fetch pricelists and fill TAB 2
    # =============================================
    print("\n🔍 Fetching pricelists...")
    
    pricelists = models.execute_kw(
        ODOO_DB, uid, ODOO_API_KEY,
        'product.pricelist', 'search_read',
        [[]],  # Empty domain = all pricelists
        {
            'fields': ['name', 'x_studio_price_discount']
        }
    )
    
    print(f"📊 Fetched {len(pricelists)} pricelists")
    
    # Access the second tab (sheet)
    if len(wb.sheetnames) > 1:
        ws2 = wb.worksheets[1]
    else:
        print("⚠️ Warning: Second tab not found in workbook")
        ws2 = None
    
    if ws2:
        # Starting row is A3 (row 3)
        pricelist_start_row = 3
        
        # Fill data for each pricelist
        for idx, pricelist in enumerate(pricelists):
            current_row = pricelist_start_row + idx
            
            # Helper function to convert list/tuple values to string
            def convert_value(value):
                if isinstance(value, (list, tuple)):
                    if len(value) > 1:
                        return str(value[1])
                    return str(value[0]) if value else ''
                return value
            
            # Fill columns A and B with pricelist data
            ws2[f'A{current_row}'] = convert_value(pricelist.get('name'))
            ws2[f'B{current_row}'] = convert_value(pricelist.get('x_studio_price_discount'))
            
            print(f"✅ Filled row {current_row} on tab 2 with pricelist: {pricelist.get('name')}")
        
        # Save the workbook again with pricelist data
        wb.save(output_file)
        print(f"\n✅ Successfully filled {len(pricelists)} pricelists into tab 2")
    
    # =============================================
    # 📋 Fetch service duration rules and fill TAB 3
    # =============================================
    print("\n🔍 Fetching service duration rules...")
    
    duration_rules = models.execute_kw(
        ODOO_DB, uid, ODOO_API_KEY,
        'x_services_duration_rules', 'search_read',
        [[]],  # Empty domain = all duration rules
        {
            'fields': [
                'x_associated_service',
                'x_studio_work_center',
                'x_studio_quantity',
                'x_duurtijd_totaal'
            ]
        }
    )
    
    print(f"📊 Fetched {len(duration_rules)} service duration rules")
    
    # Access the third tab (sheet)
    if len(wb.sheetnames) > 2:
        ws3 = wb.worksheets[2]
    else:
        print("⚠️ Warning: Third tab not found in workbook")
        ws3 = None
    
    if ws3:
        # Starting row is A3 (row 3)
        duration_start_row = 3
        
        # Fill data for each duration rule
        for idx, rule in enumerate(duration_rules):
            current_row = duration_start_row + idx
            
            # Helper function to convert list/tuple values to string
            def convert_value(value):
                if isinstance(value, (list, tuple)):
                    if len(value) > 1:
                        return str(value[1])
                    return str(value[0]) if value else ''
                return value
            
            # Fill columns A through D with duration rule data
            ws3[f'A{current_row}'] = convert_value(rule.get('x_associated_service'))
            ws3[f'B{current_row}'] = convert_value(rule.get('x_studio_work_center'))
            ws3[f'C{current_row}'] = convert_value(rule.get('x_studio_quantity'))
            ws3[f'D{current_row}'] = convert_value(rule.get('x_duurtijd_totaal'))
            
            print(f"✅ Filled row {current_row} on tab 3 with service: {rule.get('x_associated_service')}")
        
        # Save the workbook again with duration rules data
        wb.save(output_file)
        print(f"\n✅ Successfully filled {len(duration_rules)} service duration rules into tab 3")
    
except Exception as e:
    print(f"❌ Failed to fetch products or fill template: {e}")
    import traceback
    traceback.print_exc()

print("\n✅ Done!")
# Out:
# Connecting to Odoo...
# ✅ Connected as louisdresse@gmail.com (uid=2)
#
# 🔍 Fetching products with price computation = Surface or Circumference...
# 📊 Fetched 1893 products
# 📄 Created new file: justframeit_pricelist_20251113_184919.xlsx
# ✅ Filled row 7 on tab 1 with product: Noten Gouden Bies 1,5 cm
# ✅ Filled row 8 on tab 1 with product: Notelaar Antiek Gouden Bies 1,5 Cm
# ✅ Filled row 9 on tab 1 with product: '' Metall '' Wit 2 Cm
# ✅ Filled row 10 on tab 1 with product: White
# ✅ Filled row 11 on tab 1 with product: MDF 3MM BRUT Verpakking
# ✅ Filled row 12 on tab 1 with product: Mat plexiglas
# ✅ Filled row 13 on tab 1 with product: Frame A
# ✅ Filled row 14 on tab 1 with product: Frame B
# ✅ Filled row 15 on tab 1 with product: Frame C
# ✅ Filled row 16 on tab 1 with product: Glass A
# ✅ Filled row 17 on tab 1 with product: Glass B
# ✅ Filled row 18 on tab 1 with product: Passe-Partout A
# ✅ Filled row 19 on tab 1 with product: Passe-Partout B
# ✅ Filled row 20 on tab 1 with product:  "COLORBOX" BAKLIJST GROEN DONKERGRIJS 40X33
# ✅ Filled row 21 on tab 1 with product: "Altis" Baklijst Eik Fineer 38X25
# ✅ Filled row 22 on tab 1 with product: "Anilin" Ramin Donkerblauw 14/13
# ✅ Filled row 23 on tab 1 with product: "Aniline" Ramin Antraciet 14/13
# ✅ Filled row 24 on tab 1 with product: "Aniline" Ramin Antraciet 23/13
# ✅ Filled row 25 on tab 1 with product: "Aniline" Ramin Donkerblauw 23/13
# ✅ Filled row 26 on tab 1 with product: "Aniline" Ramin Donkergroen 14/13
# ✅ Filled row 27 on tab 1 with product: "Aniline" Ramin Donkergroen 23/13
# ✅ Filled row 28 on tab 1 with product: "Aniline" Ramin Donkerrood 14/13
# ✅ Filled row 29 on tab 1 with product: "Aniline" Ramin Donkerrood 23/13
# ✅ Filled row 30 on tab 1 with product: "Aniline" Ramin Groen/Blauw 14/13
# ✅ Filled row 31 on tab 1 with product: "Aniline" Ramin Groen/Blauw 23/13
# ✅ Filled row 32 on tab 1 with product: "Aniline" Ramin Lichtbruin 14/13
# ✅ Filled row 33 on tab 1 with product: "Aniline" Ramin Lichtbruin 23/13
# ✅ Filled row 34 on tab 1 with product: "Aniline" Ramin Mahonie 14/13
# ✅ Filled row 35 on tab 1 with product: "Aniline" Ramin Mahonie 23/13
# ✅ Filled row 36 on tab 1 with product: "Aniline" Ramin Natuurkleur Vernist 14/13
# ✅ Filled row 37 on tab 1 with product: "Aniline" Ramin Natuurkleur Vernist 23/13
# ✅ Filled row 38 on tab 1 with product: "Antigua" Vlak Wit 4Cm K1037
# ✅ Filled row 39 on tab 1 with product: "Antigua" Vlak Zwart 40X14
# ✅ Filled row 40 on tab 1 with product: "Authentica" Kaslijst 20X50Mm Wit
# ✅ Filled row 41 on tab 1 with product: "BIANCO&NERO" AFSTANDLAT ZWART MAT 5x40
# ✅ Filled row 42 on tab 1 with product: "BIANCO&NERO" KASLIJST ZWART MAT 15x60
# ✅ Filled row 43 on tab 1 with product: "Black & White" Kaslijst Wit 40X40 K1097
# ✅ Filled row 44 on tab 1 with product: "Black & White" Kaslijst Zwart 40X40 K1114
# ✅ Filled row 45 on tab 1 with product: "Black & White" Kaslijst Zwart 5Cm K1115
# ✅ Filled row 46 on tab 1 with product: "Black & White"Kaslijst Wit 5Cm K1098
# ✅ Filled row 47 on tab 1 with product: "CARNEVALE" LAK BAROK DONKERGRIJS 40x33
# ✅ Filled row 48 on tab 1 with product: "COLORBOX" BAKLIJST  BEIGE DONKERGRIJS 40x33
# ✅ Filled row 49 on tab 1 with product: "COLORBOX" BAKLIJST BLAUW DONKERGRIJS 76121
# ✅ Filled row 50 on tab 1 with product: "COLORBOX" BAKLIJST GRIJS DONKERGRIJS 40x33
# ✅ Filled row 51 on tab 1 with product: "COLORBOX" BAKLIJST GRIJSBLAUW DONKERGRIJS 40x33
# ✅ Filled row 52 on tab 1 with product: "COLORBOX" BAKLIJST ROOD DONKERGRIJS 40X33
# ✅ Filled row 53 on tab 1 with product: "COLORBOX" BAKLIJST WITTE TOP DONKERGRIJS 40X33
# ✅ Filled row 54 on tab 1 with product: "COLORBOX" BAKLIJST ZWART TOP DONKERGRIJS 40X33
# ✅ Filled row 55 on tab 1 with product: "CONFIRMATION" KASLIJST KOPER OP COMPO 30x25
# ✅ Filled row 56 on tab 1 with product: "CONFIRMATION" KASLIJST KOPER OP COMPO 40x35
# ✅ Filled row 57 on tab 1 with product: "CONFIRMATION" KASLIJST WIT OP COMPO
# ✅ Filled row 58 on tab 1 with product: "Carnevale" Lak Barok Blauw
# ✅ Filled row 59 on tab 1 with product: "Carnevale" Lak Barok Donkergroen
# ✅ Filled row 60 on tab 1 with product: "Carnevale" Lak Barok Duivengrijs
# ✅ Filled row 61 on tab 1 with product: "Carnevale" Lak Barok Geel
# ✅ Filled row 62 on tab 1 with product: "Carnevale" Lak Barok Lichtgroen
# ✅ Filled row 63 on tab 1 with product: "Carnevale" Lak Barok Rood
# ✅ Filled row 64 on tab 1 with product: "Carnevale" Lak Barok Wit
# ✅ Filled row 65 on tab 1 with product: "Carnevale" Lak Barok Zwart
# ✅ Filled row 66 on tab 1 with product: "Charles V" Spaanse Barok Goud
# ✅ Filled row 67 on tab 1 with product: "Chique" Barok Grijs Geborsteld 2,5Cm
# ✅ Filled row 68 on tab 1 with product: "Chique" Barok Grijs Geborsteld 5Cm
# ✅ Filled row 69 on tab 1 with product: "Chique" Barok Groen Geborsteld 5Cm
# ✅ Filled row 70 on tab 1 with product: "Chique" Barok Ivoor Geborsteld 2,5Cm
# ✅ Filled row 71 on tab 1 with product: "Chique" Barok Ivoor Geborsteld 5Cm
# ✅ Filled row 72 on tab 1 with product: "Chique" Barok Wit Geborsteld 2,5Cm
# ✅ Filled row 73 on tab 1 with product: "Chique" Barok Wit Geborsteld 5Cm
# ✅ Filled row 74 on tab 1 with product: "Chique" Barok Zwart Geborsteld 2,5Cm
# ✅ Filled row 75 on tab 1 with product: "Chique" Barok Zwart Geborsteld 5Cm
# ✅ Filled row 76 on tab 1 with product: "Conccinelle 2" Zwart
# ✅ Filled row 77 on tab 1 with product: "Confirmation" Kaslijst Blank Witte Ayous
# ✅ Filled row 78 on tab 1 with product: "Confirmation" Kaslijst Blank Witte Ayous
# ✅ Filled row 79 on tab 1 with product: "Confirmation" Kaslijst Blank Witte Ayous 15X30Mm K1128
# ✅ Filled row 80 on tab 1 with product: "Confirmation" Kaslijst Wit 20X40Mm
# ✅ Filled row 81 on tab 1 with product: "Confirmation" Kaslijst Wit Op Compo 15X30 Mm
# ✅ Filled row 82 on tab 1 with product: "Confirmation" Kaslijst Zwart 20X40Mm
# ✅ Filled row 83 on tab 1 with product: "Confirmation" Kaslijst Zwart Op Compo 15X30 Mm
# ✅ Filled row 84 on tab 1 with product: "Cool Shabby" Creme/Bruin Doorgeschuurd
# ✅ Filled row 85 on tab 1 with product: "Cordella" Zwart 3Cm
# ✅ Filled row 86 on tab 1 with product: "Cordus" Baklijst Fineer Eik
# ✅ Filled row 87 on tab 1 with product: "Cordus" Baklijst Fineer Es
# ✅ Filled row 88 on tab 1 with product: "Cordus" Baklijst Fineer Ital Noten
# ✅ Filled row 89 on tab 1 with product: "Cordus" Baklijst Fineer Italiaanse Noten
# ✅ Filled row 90 on tab 1 with product: "Cordus" Baklijst Fineer Wenge
# ✅ Filled row 91 on tab 1 with product: "Costa Rica" Kaslijst Abrikoos
# ✅ Filled row 92 on tab 1 with product: "Costa Rica" Kaslijst Bruin
# ✅ Filled row 93 on tab 1 with product: "Costa Rica" Kaslijst Citroengeel K1036
# ✅ Filled row 94 on tab 1 with product: "Costa Rica" Kaslijst Donkerbruin
# ✅ Filled row 95 on tab 1 with product: "Costa Rica" Kaslijst Engels Roze
# ✅ Filled row 96 on tab 1 with product: "Costa Rica" Kaslijst Feloranje
# ✅ Filled row 97 on tab 1 with product: "Costa Rica" Kaslijst Frans Blauw
# ✅ Filled row 98 on tab 1 with product: "Costa Rica" Kaslijst Grijsgroen
# ✅ Filled row 99 on tab 1 with product: "Costa Rica" Kaslijst Grijsgroen Donker 2Cm
# ✅ Filled row 100 on tab 1 with product: "Costa Rica" Kaslijst Grijsgroen Licht
# ✅ Filled row 101 on tab 1 with product: "Costa Rica" Kaslijst Grijsgroen Licht
# ✅ Filled row 102 on tab 1 with product: "Costa Rica" Kaslijst Lavendelblauw
# ✅ Filled row 103 on tab 1 with product: "Costa Rica" Kaslijst Maisgeel
# ✅ Filled row 104 on tab 1 with product: "Costa Rica" Kaslijst Melkchocolade
# ✅ Filled row 105 on tab 1 with product: "Costa Rica" Kaslijst Mosterdkleur
# ✅ Filled row 106 on tab 1 with product: "Costa Rica" Kaslijst Olijfgroen
# ✅ Filled row 107 on tab 1 with product: "Costa Rica" Kaslijst Roodbruin
# ✅ Filled row 108 on tab 1 with product: "Costa Rica" Kaslijst Roze K1105
# ✅ Filled row 109 on tab 1 with product: "Costa Rica" Kaslijst Violet
# ✅ Filled row 110 on tab 1 with product: "Eesenziale" Lichtbruin
# ✅ Filled row 111 on tab 1 with product: "Essenza" Hellend Bruin Loodwit
# ✅ Filled row 112 on tab 1 with product: "Essenza" Hellend Grijs Loodwit
# ✅ Filled row 113 on tab 1 with product: "Essenza" Hellend Grijs Loodwit 19X35
# ✅ Filled row 114 on tab 1 with product: "Essenza" Hellend Natuurkleur Loodwit
# ✅ Filled row 115 on tab 1 with product: "Essenza" Hellend Natuurkleur Loodwit 19X35
# ✅ Filled row 116 on tab 1 with product: "Essenza" Hellend Wenge Loodwit
# ✅ Filled row 117 on tab 1 with product: "Essenza" Hellend Wenge Loodwit 19X35
# ✅ Filled row 118 on tab 1 with product: "Essenza" Hellend Wit Loodwit
# ✅ Filled row 119 on tab 1 with product: "Essenza" Hellend Wit Loodwit 19X35
# ✅ Filled row 120 on tab 1 with product: "Essenziale" Aubergine
# ✅ Filled row 121 on tab 1 with product: "Essenziale" Grijs
# ✅ Filled row 122 on tab 1 with product: "Essenziale" Groen
# ✅ Filled row 123 on tab 1 with product: "Essenziale" Wit
# ✅ Filled row 124 on tab 1 with product: "Essenziale" Zwart 15x20
# ✅ Filled row 125 on tab 1 with product: "Explosion" Goud
# ✅ Filled row 126 on tab 1 with product: "FOILS" IMITATIE STERLING ZILVER ZWART 36x18
# ✅ Filled row 127 on tab 1 with product: "Firenze" Beige 3,8 Cm
# ✅ Filled row 128 on tab 1 with product: "Firenze" Zwart 3,8 Cm
# ✅ Filled row 129 on tab 1 with product: "Firenze" Zwart 3,8 Cm
# ✅ Filled row 130 on tab 1 with product: "GLORIA" SCHELP ZILVER 27x25
# ✅ Filled row 131 on tab 1 with product: "GLOSS" BAKLIJST LAK WIT 50x40
# ✅ Filled row 132 on tab 1 with product: "GLOSS" BAKLIJST LAK ZWART 50x40
# ✅ Filled row 133 on tab 1 with product: "GUSTO" KASLIJST WIT/ZILVER
# ✅ Filled row 134 on tab 1 with product: "Gloss" Baklijst Lak Wit 5Cm K1162
# ✅ Filled row 135 on tab 1 with product: "Gloss" Baklijst Lak Zwart K1155
# ✅ Filled row 136 on tab 1 with product: "Jazz" Schelp Palissander Gouden Lip
# ✅ Filled row 137 on tab 1 with product: "Kopenhagen" Kaslijst Zwart Lak
# ✅ Filled row 138 on tab 1 with product: "Kristal" Bruin/Goud 8Cm
# ✅ Filled row 139 on tab 1 with product: "LARCH" BLANC 2,2 CM - H 3,3CM
# ✅ Filled row 140 on tab 1 with product: "LIME" BAKLIJST LINDE BLANK 30x30
# ✅ Filled row 141 on tab 1 with product: "LIME" BAKLIJST LINDE BLANK 40X45
# ✅ Filled row 142 on tab 1 with product: "LIME" BAKLIJST LINDE BLANK GOUDEN TOP 40X45
# ✅ Filled row 143 on tab 1 with product: "LIME" BAKLIJST LINDE BLANK MET GOUDEN TOP 30x30
# ✅ Filled row 144 on tab 1 with product: "LIME" BAKLIJST LINDE BLANK ZILVER TOP 30X30
# ✅ Filled row 145 on tab 1 with product: "LIME" BAKLIJST LINDE ZWART 30x30
# ✅ Filled row 146 on tab 1 with product: "LOUVRE" BAKLIJST ZWART/GOUDEN LIJN 60x40
# ✅ Filled row 147 on tab 1 with product: "Louvre" Hellend Zwart/Gouden Lijn
# ✅ Filled row 148 on tab 1 with product: "Louvre" Hellend Zwart/Zilver
# ✅ Filled row 149 on tab 1 with product: "Louvre" Hellend Zwart/Zilver Lijn
# ✅ Filled row 150 on tab 1 with product: "MINIMALE" KASLIJST EIKFINEER BEIGE MET ZWARTE RUG
# ✅ Filled row 151 on tab 1 with product: "MINIMALE" KASLIJST EIKFINEER LICHTBRUIN MET ZWARTE RUG 12x25
# ✅ Filled row 152 on tab 1 with product: "MINIMALE" KASLIJST EIKFINEER NATUUR MET ZWARTE RUG
# ✅ Filled row 153 on tab 1 with product: "MINIMALE" KASLIJST EIKFINEER NOTENKLEUR MET ZWARTE RUG
# ✅ Filled row 154 on tab 1 with product: "Magnificent" Imitatie Karaatgoud
# ✅ Filled row 155 on tab 1 with product: "Magnificent" Imitatie Karaatgoud Wit Doorgeschuurd
# ✅ Filled row 156 on tab 1 with product: "Magnificent" Imitatie Karaatgoud Zwart Doorgeschuurd
# ✅ Filled row 157 on tab 1 with product: "Matrix " Baklijst Chroom 4,5Cm K1021
# ✅ Filled row 158 on tab 1 with product: "Matrix" Kaslijst Chroom
# ✅ Filled row 159 on tab 1 with product: "Matrix" Kaslijst Chroom 4Cm K1020
# ✅ Filled row 160 on tab 1 with product: "Minimal" Eik
# ✅ Filled row 161 on tab 1 with product: "Minimal" Kers
# ✅ Filled row 162 on tab 1 with product: "Minimal" Noten
# ✅ Filled row 163 on tab 1 with product: "Minimal" Olijf
# ✅ Filled row 164 on tab 1 with product: "Minimal" Wenge
# ✅ Filled row 165 on tab 1 with product: "Minimal" Wit
# ✅ Filled row 166 on tab 1 with product: "Minimale" Kaslijst Eikfineer Donkerbruin 12x25 103036
# ✅ Filled row 167 on tab 1 with product: "Minimale" Kaslijst Eikfineer Lichtgrijs met zwarte rug 12x25
# ✅ Filled row 168 on tab 1 with product: "Minimale" Kaslijst Eikfineer creme met zwarte Rug 12x25
# ✅ Filled row 169 on tab 1 with product: "Modern Shabby" Bruin Vlak/Schuin 13/25
# ✅ Filled row 170 on tab 1 with product: "Modern Shabby" Bruin Vlak/Schuin 17/35
# ✅ Filled row 171 on tab 1 with product: "Modern Shabby" Lichtgrijs Vlak/Schuin 13/25
# ✅ Filled row 172 on tab 1 with product: "Modern Shabby" Lichtgrijs Vlak/Schuin 17/35
# ✅ Filled row 173 on tab 1 with product: "Modern Shabby" Wit Vlak/Schuin 13/25
# ✅ Filled row 174 on tab 1 with product: "Modern Shabby" Wit Vlak/Schuin 17/35
# ✅ Filled row 175 on tab 1 with product: "Modern Shabby" Zwart Vlak/Schuin 13/25
# ✅ Filled row 176 on tab 1 with product: "Modern Shabby" Zwart Vlak/Schuin 17/35
# ✅ Filled row 177 on tab 1 with product: "Moderno" Schelp Goud/Zilver Lip
# ✅ Filled row 178 on tab 1 with product: "Nature" Kaslijst Eik Composiet Fineer
# ✅ Filled row 179 on tab 1 with product: "Nature" Kaslijst Eik Composiet Fineer 15X30
# ✅ Filled row 180 on tab 1 with product: "Olijf" Kaslijst Antraciet
# ✅ Filled row 181 on tab 1 with product: "Olijf" Kaslijst Lichtnoten
# ✅ Filled row 182 on tab 1 with product: "Olijf" Kaslijst Natuur
# ✅ Filled row 183 on tab 1 with product: "Olijf" Kaslijst Noten
# ✅ Filled row 184 on tab 1 with product: "Olijf" Kaslijst Tabak
# ✅ Filled row 185 on tab 1 with product: "Pinus" Grenen Bruingrijs 4,5 Cm
# ✅ Filled row 186 on tab 1 with product: "Pinus" Grenen Creme 2,5 Cm
# ✅ Filled row 187 on tab 1 with product: "Pinus" Grenen Creme 4,5 Cm
# ✅ Filled row 188 on tab 1 with product: "Pinus" Grenen Lichtgrijs 2,5 Cm
# ✅ Filled row 189 on tab 1 with product: "Rainbow" Blauw Gouden Lip 27Mm
# ✅ Filled row 190 on tab 1 with product: "Rainbow" Blauw Gouden Lip 44Mm
# ✅ Filled row 191 on tab 1 with product: "Rainbow" Blauw Gouden Lip 64Mm
# ✅ Filled row 192 on tab 1 with product: "Rainbow" Geel Gouden Lip 27Mm
# ✅ Filled row 193 on tab 1 with product: "Rainbow" Geel Gouden Lip 44Mm
# ✅ Filled row 194 on tab 1 with product: "Rainbow" Geel Gouden Lip 64Mm
# ✅ Filled row 195 on tab 1 with product: "Rainbow" Groen Gouden Lip 27Mm
# ✅ Filled row 196 on tab 1 with product: "Rainbow" Groen Gouden Lip 44Mm
# ✅ Filled row 197 on tab 1 with product: "Rainbow" Groen Gouden Lip 64Mm
# ✅ Filled row 198 on tab 1 with product: "Rainbow" Rood Gouden Lip 27Mm
# ✅ Filled row 199 on tab 1 with product: "Rainbow" Rood Gouden Lip 44Mm
# ✅ Filled row 200 on tab 1 with product: "Rainbow" Rood Gouden Lip 64Mm
# ✅ Filled row 201 on tab 1 with product: "Rainbow" Wit Gouden Lip 27Mm
# ✅ Filled row 202 on tab 1 with product: "Rainbow" Wit Gouden Lip 44Mm
# ✅ Filled row 203 on tab 1 with product: "Rainbow" Wit Gouden Lip 64Mm
# ✅ Filled row 204 on tab 1 with product: "Rainbow" Zwart Gouden Lip 27Mm
# ✅ Filled row 205 on tab 1 with product: "Rainbow" Zwart Gouden Lip 44Mm
# ✅ Filled row 206 on tab 1 with product: "Rainbow" Zwart Gouden Lip 64Mm
# ✅ Filled row 207 on tab 1 with product: "Riviera" Schelp Pastelblauw
# ✅ Filled row 208 on tab 1 with product: "Riviera" Schelp Wit
# ✅ Filled row 209 on tab 1 with product: "Riviera" Schelp Zwart
# ✅ Filled row 210 on tab 1 with product: "SOLID WOOD" WITTE AMERIKAANSE EIK 40x15 76567
# ✅ Filled row 211 on tab 1 with product: "SPAZZOLATO" GEBORSTELD GUN METAL 23x14
# ✅ Filled row 212 on tab 1 with product: "Sensation" Oranje Glanzend Doorgeschuurd
# ✅ Filled row 213 on tab 1 with product: "Solid Wood" Amerikaanse Baklijst Eik 40X30
# ✅ Filled row 214 on tab 1 with product: "Solid Wood" Amerikaanse Baklijst Eik K1090
# ✅ Filled row 215 on tab 1 with product: "Solid Wood" Beuk 20/15
# ✅ Filled row 216 on tab 1 with product: "Solid Wood" Eik 1,5Cm K1124
# ✅ Filled row 217 on tab 1 with product: "Solid Wood" Eik 12X25 Mm
# ✅ Filled row 218 on tab 1 with product: "Solid Wood" Eik 12X35Mm
# ✅ Filled row 219 on tab 1 with product: "Solid Wood" Eik 15/40 K1125
# ✅ Filled row 220 on tab 1 with product: "Solid Wood" Eik 25X20
# ✅ Filled row 221 on tab 1 with product: "Solid Wood" Eik Loft 20X30
# ✅ Filled row 222 on tab 1 with product: "Solid Wood" Es 2 X 1,5 Cm (Sponning 1 X 0,5)
# ✅ Filled row 223 on tab 1 with product: "Solid Wood" Es 3 X 1,5 (Sponning 1,1 X 0,6)
# ✅ Filled row 224 on tab 1 with product: "Solid Wood" Esdoorn
# ✅ Filled row 225 on tab 1 with product: "Solid Wood" Esdoorn 1,5Cm K1127
# ✅ Filled row 226 on tab 1 with product: "Solid Wood" Kaslijst Eik 3Cm K1123
# ✅ Filled row 227 on tab 1 with product: "Solid Wood" Kaslijst Eik 4Cm
# ✅ Filled row 228 on tab 1 with product: "Solid Wood" Spacer Eik 5X15Mm
# ✅ Filled row 229 on tab 1 with product: "Solid Wood" Witte Amerikaanse Eik
# ✅ Filled row 230 on tab 1 with product: "Solid Wood" Witte Amerikaanse Eik
# ✅ Filled row 231 on tab 1 with product: "Spazzolato" Geborsteld Goud
# ✅ Filled row 232 on tab 1 with product: "Spazzolato" Geborsteld Zilver
# ✅ Filled row 233 on tab 1 with product: "Spiaggia" Grijs 3,5 Cm
# ✅ Filled row 234 on tab 1 with product: "Spiaggia" Taupe 3,5 Cm
# ✅ Filled row 235 on tab 1 with product: "Strich" Antraciet Zilver 2,5 Cm
# ✅ Filled row 236 on tab 1 with product: "VENUS" ZILVER MET ZWARTE RUG 30x20
# ✅ Filled row 237 on tab 1 with product: "Vecchio" Grijs 5,5 Cm
# ✅ Filled row 238 on tab 1 with product: "Vecchio" Grijs Gewit 2,5 Cm
# ✅ Filled row 239 on tab 1 with product: "Vecchio" Naturel 5,5 Cm
# ✅ Filled row 240 on tab 1 with product: "Vecchio" Wit 5,5 Cm
# ✅ Filled row 241 on tab 1 with product: "Vecchio" Zwart 5,5 Cm
# ✅ Filled row 242 on tab 1 with product: "Vecchio" Zwart Gewit 2,5 Cm
# ✅ Filled row 243 on tab 1 with product: "Venus" Goud Met Zwarte Rug
# ✅ Filled row 244 on tab 1 with product: "Venus" Lood Met Zwarte Rug
# ✅ Filled row 245 on tab 1 with product: "Venus" Zilver Met Zwarte Rug
# ✅ Filled row 246 on tab 1 with product: "Venus"Goud Met Zwarte Rug
# ✅ Filled row 247 on tab 1 with product: "Zeppa" Wit/Zilver Met De Hand Afgewerkt 6,3Cm K1022
# ✅ Filled row 248 on tab 1 with product: ' Tondi , Chroom-Antraciet 1,3 Cm
# ✅ Filled row 249 on tab 1 with product: ' Tondi , Hoogglans Wit 1,3 Cm
# ✅ Filled row 250 on tab 1 with product: ' Tondi , Hoogglans Zwart 1,3 Cm
# ✅ Filled row 251 on tab 1 with product: ' Tondi , Ivoor 1,3 Cm
# ✅ Filled row 252 on tab 1 with product: ' Tondi , Mat Zwart 1,3 Cm
# ✅ Filled row 253 on tab 1 with product: ' Tondi , Zilver Chroom 1,3 Cm
# ✅ Filled row 254 on tab 1 with product: '' BEMA '' ROZE 3,5 CM 35x17
# ✅ Filled row 255 on tab 1 with product: '' Bolero ,, Chroom 1,5 Cm  3,5 Cm Hoog
# ✅ Filled row 256 on tab 1 with product: '' Bright '' Wit 6 Cm
# ✅ Filled row 257 on tab 1 with product: '' CUBA '' MAHONIE 4,2 CM
# ✅ Filled row 258 on tab 1 with product: '' Curl '' Goud 1,5 Cm
# ✅ Filled row 259 on tab 1 with product: '' Curl '' Zilver 1,5 Cm
# ✅ Filled row 260 on tab 1 with product: '' Curl '' Zwart 1,5 Cm
# ✅ Filled row 261 on tab 1 with product: '' Elegance '' Zwart Met  Zilver 2,5 Cm
# ✅ Filled row 262 on tab 1 with product: '' Inox ,, Zilveren Rug - Grijs -
# ✅ Filled row 263 on tab 1 with product: '' Inox ,, Zilveren Rug - Taupe
# ✅ Filled row 264 on tab 1 with product: '' Kristal '' Grijs / Zilver 8 Cm
# ✅ Filled row 265 on tab 1 with product: '' Kristal '' Zwart 8 Cm
# ✅ Filled row 266 on tab 1 with product: '' Meribel '' Lichtbruin 4,2 Cm
# ✅ Filled row 267 on tab 1 with product: '' Meribel '' Lichtbruin 9 Cm
# ✅ Filled row 268 on tab 1 with product: '' Meribel '' Naturel Met Wit Gepatineerd 4,2 Cm
# ✅ Filled row 269 on tab 1 with product: '' Meribel '' Naturel Wit Gepatineerd 9 Cm
# ✅ Filled row 270 on tab 1 with product: '' Meribel '' Wit 4,2 Cm
# ✅ Filled row 271 on tab 1 with product: '' Meribel '' Wit 9 Cm
# ✅ Filled row 272 on tab 1 with product: '' Metall '' Donker Bruin 2 Cm
# ✅ Filled row 273 on tab 1 with product: '' Metall '' Zwart 2 Cm
# ✅ Filled row 274 on tab 1 with product: '' POPI ,, GRIJS EN ZILVER 2,8 CM
# ✅ Filled row 275 on tab 1 with product: '' Scarp '' Bruin 7 Cm
# ✅ Filled row 276 on tab 1 with product: '' Scarp '' Zwart 7 Cm
# ✅ Filled row 277 on tab 1 with product: '' Soft '' Eik 6 Cm
# ✅ Filled row 278 on tab 1 with product: '' Soft '' Grijs 6 Cm
# ✅ Filled row 279 on tab 1 with product: '' Soft '' Taupe 6 Cm
# ✅ Filled row 280 on tab 1 with product: '' Spalti '' Anthraciet 3,3 Cm
# ✅ Filled row 281 on tab 1 with product: '' Spalti '' Noten 3,3 Cm
# ✅ Filled row 282 on tab 1 with product: '' Sterling '' Donker Zilver 1,2 Cm
# ✅ Filled row 283 on tab 1 with product: '' Sterling '' Donker Zilver 2 Cm
# ✅ Filled row 284 on tab 1 with product: '' Sterling '' Goud 1,2 Cm
# ✅ Filled row 285 on tab 1 with product: '' Sterling '' Zilver 1,2 Cm
# ✅ Filled row 286 on tab 1 with product: '' Sterling '' Zilver 2 Cm
# ✅ Filled row 287 on tab 1 with product: '' Trans '' Grijs 1,5 Cm
# ✅ Filled row 288 on tab 1 with product: '' Trans '' Ivoor 1,5 Cm
# ✅ Filled row 289 on tab 1 with product: '' Vinci '' Grijs 3 Cm
# ✅ Filled row 290 on tab 1 with product: '' Vinci '' Wit 3 Cm
# ✅ Filled row 291 on tab 1 with product: '' Vinci '' Zwart 3 Cm
# ✅ Filled row 292 on tab 1 with product: ''Bharami'' Plat Donkerrood 2 Cm
# ✅ Filled row 293 on tab 1 with product: ''Bharami'' Plat Gebroken  Wit 2 Cm
# ✅ Filled row 294 on tab 1 with product: ''Bharami'' Plat Groen 2 Cm
# ✅ Filled row 295 on tab 1 with product: ''Bharami'' Plat Lichtbruin 2 Cm
# ✅ Filled row 296 on tab 1 with product: ''Bharami'' Plat Wenge 2 Cm
# ✅ Filled row 297 on tab 1 with product: ''Bharami'' Rond Donkerrood 2,5 Cm
# ✅ Filled row 298 on tab 1 with product: ''Bharami'' Rond Gebroken Wit 2,5 Cm
# ✅ Filled row 299 on tab 1 with product: ''Bharami'' Rond Wenge 2,5 Cm
# ✅ Filled row 300 on tab 1 with product: ''Bolero ,, Chroom / Antraciet 1,5 Cm 3,5 Cm Hoog
# ✅ Filled row 301 on tab 1 with product: ''Bolero,, Naturel 1,5 Cm  3,5 Cm Hoog
# ✅ Filled row 302 on tab 1 with product: ''Bolero,, Taupe 1,5 Cm - 3,5 Cm Hoog
# ✅ Filled row 303 on tab 1 with product: ''Bolero,, Wit 1,5 Cm - 3,5 Cm Hoog
# ✅ Filled row 304 on tab 1 with product: ''Bolero,, Zwart 1,5 Cm - 3,5 Cm Hoog
# ✅ Filled row 305 on tab 1 with product: ''Botanique'' Antiek Grijs 2,5 Cm
# ✅ Filled row 306 on tab 1 with product: ''Botanique'' Antiek Taupe 2,5 Cm
# ✅ Filled row 307 on tab 1 with product: ''CURVO,, BEIGE 30x24
# ✅ Filled row 308 on tab 1 with product: ''Cigale'' Beige 2 Cm
# ✅ Filled row 309 on tab 1 with product: ''Cigale'' Creme 2 Cm
# ✅ Filled row 310 on tab 1 with product: ''Cigale'' Donkerblauw 2 Cm
# ✅ Filled row 311 on tab 1 with product: ''Cigale'' Donkergroen 2 Cm
# ✅ Filled row 312 on tab 1 with product: ''Cigale'' Gebroken Wit 2 Cm
# ✅ Filled row 313 on tab 1 with product: ''Cigale'' Geel 2 Cm
# ✅ Filled row 314 on tab 1 with product: ''Cigale'' Grijs 2 Cm
# ✅ Filled row 315 on tab 1 with product: ''Cigale'' Kakigroen 2 Cm
# ✅ Filled row 316 on tab 1 with product: ''Cigale'' Rood 2 Cm
# ✅ Filled row 317 on tab 1 with product: ''Cigale'' Roodbruin 2 Cm
# ✅ Filled row 318 on tab 1 with product: ''Cigno,, Bruin 4 Cm
# ✅ Filled row 319 on tab 1 with product: ''Cigno,, Teak 4 Cm
# ✅ Filled row 320 on tab 1 with product: ''Cigno,, Wit 4 Cm
# ✅ Filled row 321 on tab 1 with product: ''Cigno,, Zwart 4 Cm
# ✅ Filled row 322 on tab 1 with product: ''Cordella,, Beige 3 Cm
# ✅ Filled row 323 on tab 1 with product: ''Cordella,, Taupe Donker 3 Cm
# ✅ Filled row 324 on tab 1 with product: ''Cordella,, Wit 3 Cm
# ✅ Filled row 325 on tab 1 with product: ''Country'' Bruin 2 Cm
# ✅ Filled row 326 on tab 1 with product: ''Country'' Ivoor 2 Cm
# ✅ Filled row 327 on tab 1 with product: ''Demoiselle'' Donkerblauw 3 Cm
# ✅ Filled row 328 on tab 1 with product: ''Demoiselle'' Fel Rood 3 Cm
# ✅ Filled row 329 on tab 1 with product: ''Demoiselle'' Geel 3 Cm
# ✅ Filled row 330 on tab 1 with product: ''Demoiselle'' Groen 3 Cm
# ✅ Filled row 331 on tab 1 with product: ''Demoiselle'' Ivoor 3 Cm
# ✅ Filled row 332 on tab 1 with product: ''Demoiselle'' Lichtblauw 3 Cm
# ✅ Filled row 333 on tab 1 with product: ''Demoiselle'' Oranje 3 Cm
# ✅ Filled row 334 on tab 1 with product: ''Demoiselle'' Rood 3 Cm
# ✅ Filled row 335 on tab 1 with product: ''Demoiselle'' Wenge 3 Cm
# ✅ Filled row 336 on tab 1 with product: ''Demoiselle'' Wit 3 Cm
# ✅ Filled row 337 on tab 1 with product: ''Demoiselle'' Zwart 3 Cm
# ✅ Filled row 338 on tab 1 with product: ''Dublin'' Donker Bruin 3,2 Cm
# ✅ Filled row 339 on tab 1 with product: ''Dublin'' Donker Bruin 6,8 Cm
# ✅ Filled row 340 on tab 1 with product: ''Dublin'' Naturel 3,2 Cm
# ✅ Filled row 341 on tab 1 with product: ''Dublin'' Naturel 6,8 Cm
# ✅ Filled row 342 on tab 1 with product: ''Eco Wood'' Naturel 2 Cm
# ✅ Filled row 343 on tab 1 with product: ''Eco Wood'' Naturel 4 Cm
# ✅ Filled row 344 on tab 1 with product: ''Eco Wood'' Noten 2 Cm
# ✅ Filled row 345 on tab 1 with product: ''Eco Wood'' Noten 3 Cm
# ✅ Filled row 346 on tab 1 with product: ''Eco Wood'' Wit 3 Cm
# ✅ Filled row 347 on tab 1 with product: ''Eco Wood'' Zwart 2 Cm
# ✅ Filled row 348 on tab 1 with product: ''Eco Wood'' Zwart 3 Cm
# ✅ Filled row 349 on tab 1 with product: ''Electra'' Blok Zilver 3,1 Cm Breed/4,8 Hoog
# ✅ Filled row 350 on tab 1 with product: ''Filetto'' Blauw 1,4 Cm
# ✅ Filled row 351 on tab 1 with product: ''Filetto'' Bordeaux 1,4 Cm
# ✅ Filled row 352 on tab 1 with product: ''Filetto'' Creme 1,4 Cm
# ✅ Filled row 353 on tab 1 with product: ''Filetto'' Groen 1,4 Cm
# ✅ Filled row 354 on tab 1 with product: ''Filetto'' Wenge 1,4 Cm
# ✅ Filled row 355 on tab 1 with product: ''Fourmi'' Creme 2 Cm
# ✅ Filled row 356 on tab 1 with product: ''Fourmi'' Donkerblauw 2 Cm
# ✅ Filled row 357 on tab 1 with product: ''Fourmi'' Fel Rood 2 Cm
# ✅ Filled row 358 on tab 1 with product: ''Fourmi'' Geel 2 Cm
# ✅ Filled row 359 on tab 1 with product: ''Fourmi'' Groen 2 Cm
# ✅ Filled row 360 on tab 1 with product: ''Fourmi'' Lichtblauw 2 Cm
# ✅ Filled row 361 on tab 1 with product: ''Fourmi'' Oranje 2 Cm
# ✅ Filled row 362 on tab 1 with product: ''Fourmi'' Rood 2 Cm
# ✅ Filled row 363 on tab 1 with product: ''Fourmi'' Wenge 2 Cm
# ✅ Filled row 364 on tab 1 with product: ''Fourmi'' Wit 2 Cm
# ✅ Filled row 365 on tab 1 with product: ''Fourmi'' Zwart 2 Cm
# ✅ Filled row 366 on tab 1 with product: ''INOX'' GUN METAL ZWARTE LIP 3,2 CM
# ✅ Filled row 367 on tab 1 with product: ''Inox'' Aluminium Gun Lip 3,2 Cm
# ✅ Filled row 368 on tab 1 with product: ''Inox'' Gun Metal Zilver Lip 20X30
# ✅ Filled row 369 on tab 1 with product: ''Inox'' Gun Metal Zilveren Lip 3,2 Cm
# ✅ Filled row 370 on tab 1 with product: ''Inox'' Zilveren Rug-Wit Zilver 3,2 Cm
# ✅ Filled row 371 on tab 1 with product: ''Inox'' Zilveren Rug-Zwart Zilver 3,2 Cm
# ✅ Filled row 372 on tab 1 with product: ''Inox'' Zwart Zilveren Lip 3,2 Cm
# ✅ Filled row 373 on tab 1 with product: ''Lino,, Gestreept Bruin 2 Cm
# ✅ Filled row 374 on tab 1 with product: ''Lino,, Gestreept Bruin 3 Cm
# ✅ Filled row 375 on tab 1 with product: ''Lino,, Gestreept Grijs 2 Cm
# ✅ Filled row 376 on tab 1 with product: ''Lino,, Gestreept Grijs 3 Cm
# ✅ Filled row 377 on tab 1 with product: ''Lino,, Gestreept Wit 2 Cm
# ✅ Filled row 378 on tab 1 with product: ''Lino,, Gestreept Wit 3 Cm
# ✅ Filled row 379 on tab 1 with product: ''Lino,, Gestreept Zwart 2 Cm
# ✅ Filled row 380 on tab 1 with product: ''Lino,, Gestreept Zwart 3 Cm
# ✅ Filled row 381 on tab 1 with product: ''Luminor,, Taupe Zilveren Bies 1,8 Cm
# ✅ Filled row 382 on tab 1 with product: ''Luminor,, Wit Zilveren Bies 1,8 Cm
# ✅ Filled row 383 on tab 1 with product: ''Luminor,, Zwart Zilveren Bies 1,8 Cm
# ✅ Filled row 384 on tab 1 with product: ''Mira,, Grijs 1,5 Cm
# ✅ Filled row 385 on tab 1 with product: ''Mouche'' Wit 5 Cm
# ✅ Filled row 386 on tab 1 with product: ''Mouche'' Zwart 5 Cm
# ✅ Filled row 387 on tab 1 with product: ''Papillon'' Creme 3,4 Cm
# ✅ Filled row 388 on tab 1 with product: ''Papillon'' Donkerblauw 3,4 Cm
# ✅ Filled row 389 on tab 1 with product: ''Papillon'' Donkergroen 3,4 Cm
# ✅ Filled row 390 on tab 1 with product: ''Papillon'' Gebroken Wit 3,4 Cm
# ✅ Filled row 391 on tab 1 with product: ''Papillon'' Geel 3,4 Cm
# ✅ Filled row 392 on tab 1 with product: ''Papillon'' Grijs 3,4 Cm
# ✅ Filled row 393 on tab 1 with product: ''Papillon'' Kakigroen 3,4 Cm
# ✅ Filled row 394 on tab 1 with product: ''Papillon'' Rood 3,4 Cm
# ✅ Filled row 395 on tab 1 with product: ''Papillon'' Roodbruin 3,4 Cm
# ✅ Filled row 396 on tab 1 with product: ''Picco" Donkergrijs Met Zilver 3,6Cm
# ✅ Filled row 397 on tab 1 with product: ''Picco" Ivoor Met Zilver 3,6Cm
# ✅ Filled row 398 on tab 1 with product: ''Picco" Lichtgrijs Met Zilver 3,6Cm
# ✅ Filled row 399 on tab 1 with product: ''Picco" Wit Met Zilver 3,6Cm
# ✅ Filled row 400 on tab 1 with product: ''SAUNA,, Grijs 25x15
# ✅ Filled row 401 on tab 1 with product: ''SAUNA,, WIT 25x15
# ✅ Filled row 402 on tab 1 with product: ''Seta,, Zwart Met Zilver 3 Cm
# ✅ Filled row 403 on tab 1 with product: ''Sky,, Kaslijst Donker Grijs 3 Cm / H 4 Cm
# ✅ Filled row 404 on tab 1 with product: ''Strich,, Roestbruin / Zilver
# ✅ Filled row 405 on tab 1 with product: ''Strich,, Taupe / Zilver2,5 Cm
# ✅ Filled row 406 on tab 1 with product: 'Solid Wood, Teak B 2,8 Cm / H 3,3 Cm
# ✅ Filled row 407 on tab 1 with product: 'Solid Wood, Wit 2 Cm
# ✅ Filled row 408 on tab 1 with product: 'Solid Wood, Wit 2,8 Cm
# ✅ Filled row 409 on tab 1 with product: 'Solid Wood, Wit B 2,8 Cm / H 3,3 Cm
# ✅ Filled row 410 on tab 1 with product: 'Solid Wood, Zwart 2 Cm
# ✅ Filled row 411 on tab 1 with product: 'Solid Wood, Zwart 2,8 Cm
# ✅ Filled row 412 on tab 1 with product: 'Swing, Houtskool-Grijs 3,7 Cm
# ✅ Filled row 413 on tab 1 with product: 'Swing, Ivoor 3,7 Cm
# ✅ Filled row 414 on tab 1 with product: 'Swing, Lichtbruin 3,7 Cm
# ✅ Filled row 415 on tab 1 with product: 'Swing, Zilvergrijs 3,7 Cm
# ✅ Filled row 416 on tab 1 with product: 003-004
# ✅ Filled row 417 on tab 1 with product: 003-016
# ✅ Filled row 418 on tab 1 with product: 003-019
# ✅ Filled row 419 on tab 1 with product: 003-021
# ✅ Filled row 420 on tab 1 with product: 008-004
# ✅ Filled row 421 on tab 1 with product: 008-021
# ✅ Filled row 422 on tab 1 with product: 011-002
# ✅ Filled row 423 on tab 1 with product: 011-004
# ✅ Filled row 424 on tab 1 with product: 011-019
# ✅ Filled row 425 on tab 1 with product: 015-001
# ✅ Filled row 426 on tab 1 with product: 015-004
# ✅ Filled row 427 on tab 1 with product: 034-003
# ✅ Filled row 428 on tab 1 with product: 034-019
# ✅ Filled row 429 on tab 1 with product: 034-522
# ✅ Filled row 430 on tab 1 with product: 034-523
# ✅ Filled row 431 on tab 1 with product: 051-001
# ✅ Filled row 432 on tab 1 with product: 051-156
# ✅ Filled row 433 on tab 1 with product: 100367
# ✅ Filled row 434 on tab 1 with product: 100467
# ✅ Filled row 435 on tab 1 with product: 1018
# ✅ Filled row 436 on tab 1 with product: 10190
# ✅ Filled row 437 on tab 1 with product: 10192
# ✅ Filled row 438 on tab 1 with product: 10195
# ✅ Filled row 439 on tab 1 with product: 105467 Altis Eik fineer 20x20
# ✅ Filled row 440 on tab 1 with product: 1073
# ✅ Filled row 441 on tab 1 with product: 1081
# ✅ Filled row 442 on tab 1 with product: 1084
# ✅ Filled row 443 on tab 1 with product: 10992 Verstevigingsprofiel 10x39
# ✅ Filled row 444 on tab 1 with product: 11002.R8 Verstevigingsprofiel 12x42
# ✅ Filled row 445 on tab 1 with product: 12-004 Alpha Aluminium Zilver + spacer
# ✅ Filled row 446 on tab 1 with product: 12-027 Alpha Aluminium Wit + spacer
# ✅ Filled row 447 on tab 1 with product: 12-250 Alpha Aluminium zwart + spacer
# ✅ Filled row 448 on tab 1 with product: 14004
# ✅ Filled row 449 on tab 1 with product: 14307
# ✅ Filled row 450 on tab 1 with product: 14315
# ✅ Filled row 451 on tab 1 with product: 1596
# ✅ Filled row 452 on tab 1 with product: 16371.D33 zwart 15x40
# ✅ Filled row 453 on tab 1 with product: 16380.D34  Wit 15x40
# ✅ Filled row 454 on tab 1 with product: 17915
# ✅ Filled row 455 on tab 1 with product: 17931
# ✅ Filled row 456 on tab 1 with product: 17945
# ✅ Filled row 457 on tab 1 with product: 180-019
# ✅ Filled row 458 on tab 1 with product: 214-004
# ✅ Filled row 459 on tab 1 with product: 215-250
# ✅ Filled row 460 on tab 1 with product: 23546
# ✅ Filled row 461 on tab 1 with product: 273-019
# ✅ Filled row 462 on tab 1 with product: 273-523
# ✅ Filled row 463 on tab 1 with product: 275
# ✅ Filled row 464 on tab 1 with product: 35009.G33 Ramin Wit 14x35
# ✅ Filled row 465 on tab 1 with product: 35010.G33 Ramin Zwart 14x35
# ✅ Filled row 466 on tab 1 with product: 35103.G33 Ramin Blank 14x35
# ✅ Filled row 467 on tab 1 with product: 36312
# ✅ Filled row 468 on tab 1 with product: 36412
# ✅ Filled row 469 on tab 1 with product: 39110
# ✅ Filled row 470 on tab 1 with product: 40467.J36 Spacer eik 15mm
# ✅ Filled row 471 on tab 1 with product: 41182
# ✅ Filled row 472 on tab 1 with product: 4131
# ✅ Filled row 473 on tab 1 with product: 4132
# ✅ Filled row 474 on tab 1 with product: 43202
# ✅ Filled row 475 on tab 1 with product: 44702
# ✅ Filled row 476 on tab 1 with product: 44806
# ✅ Filled row 477 on tab 1 with product: 44906
# ✅ Filled row 478 on tab 1 with product: 46166
# ✅ Filled row 479 on tab 1 with product: 46366
# ✅ Filled row 480 on tab 1 with product: 46465
# ✅ Filled row 481 on tab 1 with product: 47265
# ✅ Filled row 482 on tab 1 with product: 48502
# ✅ Filled row 483 on tab 1 with product: 53837
# ✅ Filled row 484 on tab 1 with product: 5611
# ✅ Filled row 485 on tab 1 with product: 56567
# ✅ Filled row 486 on tab 1 with product: 60767
# ✅ Filled row 487 on tab 1 with product: 61335
# ✅ Filled row 488 on tab 1 with product: 6203/10
# ✅ Filled row 489 on tab 1 with product: 6204/06
# ✅ Filled row 490 on tab 1 with product: 6204/10
# ✅ Filled row 491 on tab 1 with product: 63787
# ✅ Filled row 492 on tab 1 with product: 65430
# ✅ Filled row 493 on tab 1 with product: 66202
# ✅ Filled row 494 on tab 1 with product: 67510
# ✅ Filled row 495 on tab 1 with product: 67515
# ✅ Filled row 496 on tab 1 with product: 67610
# ✅ Filled row 497 on tab 1 with product: 67682
# ✅ Filled row 498 on tab 1 with product: 67687
# ✅ Filled row 499 on tab 1 with product: 68710
# ✅ Filled row 500 on tab 1 with product: 68810
# ✅ Filled row 501 on tab 1 with product: 69385
# ✅ Filled row 502 on tab 1 with product: 71810
# ✅ Filled row 503 on tab 1 with product: 72408
# ✅ Filled row 504 on tab 1 with product: 72410
# ✅ Filled row 505 on tab 1 with product: 72480
# ✅ Filled row 506 on tab 1 with product: 72702
# ✅ Filled row 507 on tab 1 with product: 72810C
# ✅ Filled row 508 on tab 1 with product: 73902
# ✅ Filled row 509 on tab 1 with product: 74215
# ✅ Filled row 510 on tab 1 with product: 74215
# ✅ Filled row 511 on tab 1 with product: 74235
# ✅ Filled row 512 on tab 1 with product: 74237
# ✅ Filled row 513 on tab 1 with product: 74246
# ✅ Filled row 514 on tab 1 with product: 74315
# ✅ Filled row 515 on tab 1 with product: 74337
# ✅ Filled row 516 on tab 1 with product: 74346
# ✅ Filled row 517 on tab 1 with product: 74910
# ✅ Filled row 518 on tab 1 with product: 74915
# ✅ Filled row 519 on tab 1 with product: 74948
# ✅ Filled row 520 on tab 1 with product: 74985
# ✅ Filled row 521 on tab 1 with product: 75235
# ✅ Filled row 522 on tab 1 with product: 75702
# ✅ Filled row 523 on tab 1 with product: 75764
# ✅ Filled row 524 on tab 1 with product: 75769
# ✅ Filled row 525 on tab 1 with product: 75867
# ✅ Filled row 526 on tab 1 with product: 76045
# ✅ Filled row 527 on tab 1 with product: 76667
# ✅ Filled row 528 on tab 1 with product: 76763.N30 italiaanse noten 20x20
# ✅ Filled row 529 on tab 1 with product: 77010
# ✅ Filled row 530 on tab 1 with product: 77026
# ✅ Filled row 531 on tab 1 with product: 77163.N31 Italiaanse noten 15x25
# ✅ Filled row 532 on tab 1 with product: 77263.C32 Italiaanse noten 20x32
# ✅ Filled row 533 on tab 1 with product: 77915
# ✅ Filled row 534 on tab 1 with product: 77930
# ✅ Filled row 535 on tab 1 with product: 77945
# ✅ Filled row 536 on tab 1 with product: 77946
# ✅ Filled row 537 on tab 1 with product: 77954
# ✅ Filled row 538 on tab 1 with product: 78467
# ✅ Filled row 539 on tab 1 with product: 78710
# ✅ Filled row 540 on tab 1 with product: 78715
# ✅ Filled row 541 on tab 1 with product: 78725
# ✅ Filled row 542 on tab 1 with product: 78730
# ✅ Filled row 543 on tab 1 with product: 78735
# ✅ Filled row 544 on tab 1 with product: 78745
# ✅ Filled row 545 on tab 1 with product: 79011
# ✅ Filled row 546 on tab 1 with product: 79012
# ✅ Filled row 547 on tab 1 with product: 79082
# ✅ Filled row 548 on tab 1 with product: 79087
# ✅ Filled row 549 on tab 1 with product: 79211
# ✅ Filled row 550 on tab 1 with product: 79211
# ✅ Filled row 551 on tab 1 with product: 79282
# ✅ Filled row 552 on tab 1 with product: 79810.C1 Baklijst Noir30x30
# ✅ Filled row 553 on tab 1 with product: 79815.C1 Baklijst Wit 30x30
# ✅ Filled row 554 on tab 1 with product: 79880.C4 - Baklijst blank goud 30x30
# ✅ Filled row 555 on tab 1 with product: 79910.C1 Baklijst Zwart 40x45
# ✅ Filled row 556 on tab 1 with product: 79915.C1 Baklijst Wit 40x45
# ✅ Filled row 557 on tab 1 with product: 8010
# ✅ Filled row 558 on tab 1 with product: 81585
# ✅ Filled row 559 on tab 1 with product: 81780
# ✅ Filled row 560 on tab 1 with product: 81885
# ✅ Filled row 561 on tab 1 with product: 81936
# ✅ Filled row 562 on tab 1 with product: 81980
# ✅ Filled row 563 on tab 1 with product: 81985
# ✅ Filled row 564 on tab 1 with product: 83610
# ✅ Filled row 565 on tab 1 with product: 85310
# ✅ Filled row 566 on tab 1 with product: 85315
# ✅ Filled row 567 on tab 1 with product: 85330
# ✅ Filled row 568 on tab 1 with product: 85335
# ✅ Filled row 569 on tab 1 with product: 85345
# ✅ Filled row 570 on tab 1 with product: 85350
# ✅ Filled row 571 on tab 1 with product: 85880
# ✅ Filled row 572 on tab 1 with product: 85881
# ✅ Filled row 573 on tab 1 with product: 85884
# ✅ Filled row 574 on tab 1 with product: 88212.K29 BOX Wit 20x100
# ✅ Filled row 575 on tab 1 with product: 88213.K29 BOX Zwart 20x100
# ✅ Filled row 576 on tab 1 with product: 88221.K29 BOX Blank 20x100
# ✅ Filled row 577 on tab 1 with product: 88222.K29 BOX donkerbruin 20x 100
# ✅ Filled row 578 on tab 1 with product: 93511
# ✅ Filled row 579 on tab 1 with product: 93711
# ✅ Filled row 580 on tab 1 with product: 94085
# ✅ Filled row 581 on tab 1 with product: AHTHENTICA BLOK DONKERGRIJS 40x40
# ✅ Filled row 582 on tab 1 with product: ANTIEK GOUD GESPIKKELD 50x41
# ✅ Filled row 583 on tab 1 with product: AUTHENTICA BLANC 3 CM 715.A05
# ✅ Filled row 584 on tab 1 with product: Afgerond Profiel Goud 70X20
# ✅ Filled row 585 on tab 1 with product: Afstandshouder "Solid Wood" Eik 5 X 15 Mm
# ✅ Filled row 586 on tab 1 with product: Afstandshouder Zwart 5X15 Mm
# ✅ Filled row 587 on tab 1 with product: Afstandshouder Zwart Op Compo 5X10 Mm
# ✅ Filled row 588 on tab 1 with product: Alabaster
# ✅ Filled row 589 on tab 1 with product: Alabaster
# ✅ Filled row 590 on tab 1 with product: Alabaster - Black Core
# ✅ Filled row 591 on tab 1 with product: Alabaster - Black Core
# ✅ Filled row 592 on tab 1 with product: Allsize Spielat 20mm
# ✅ Filled row 593 on tab 1 with product: Allsize Spielat 40mm
# ✅ Filled row 594 on tab 1 with product: Allsize tussen-en kruislat
# ✅ Filled row 595 on tab 1 with product: Altis Baklijst Eik 55x45
# ✅ Filled row 596 on tab 1 with product: Altis Baklijst eik fineer 6.6x55
# ✅ Filled row 597 on tab 1 with product: Altis kaslijst Eikfineer 30x30
# ✅ Filled row 598 on tab 1 with product: Altis" Baklijst Eik Fineer
# ✅ Filled row 599 on tab 1 with product: Alu Bruin 2 Cm
# ✅ Filled row 600 on tab 1 with product: Alu Donker Grijs 2 Cm
# ✅ Filled row 601 on tab 1 with product: Alu Zilver Mat 12mm
# ✅ Filled row 602 on tab 1 with product: Alu Zwart 2 Cm
# ✅ Filled row 603 on tab 1 with product: Aluminium Antraciet Glans 7x20
# ✅ Filled row 604 on tab 1 with product: Aluminium AntracietStructuur 7x20
# ✅ Filled row 605 on tab 1 with product: Aluminium Baklijst  Zwart 2 x 48mm
# ✅ Filled row 606 on tab 1 with product: Aluminium Baklijst 2mm Zwart
# ✅ Filled row 607 on tab 1 with product: Aluminium Bleu
# ✅ Filled row 608 on tab 1 with product: Aluminium Brushed Silber 1 Cm
# ✅ Filled row 609 on tab 1 with product: Aluminium Dibondprofiel 3 mm Wit
# ✅ Filled row 610 on tab 1 with product: Aluminium Dibondprofiel Max. 3 Mm Mat Zwart
# ✅ Filled row 611 on tab 1 with product: Aluminium Florentijns Zilver 1,5 cm
# ✅ Filled row 612 on tab 1 with product: Aluminium GEBORSTELD MAT GRIJS 10x18
# ✅ Filled row 613 on tab 1 with product: Aluminium GEBORSTELD MAT ZILVER 10x18
# ✅ Filled row 614 on tab 1 with product: Aluminium GEBORSTELD MAT ZWART 10x18
# ✅ Filled row 615 on tab 1 with product: Aluminium Glanzend Zilver 1,5 cm
# ✅ Filled row 616 on tab 1 with product: Aluminium Goud Structuur 7x20
# ✅ Filled row 617 on tab 1 with product: Aluminium Mat Zwart 13x33
# ✅ Filled row 618 on tab 1 with product: Aluminium Mercury Mat 1,5 cm
# ✅ Filled row 619 on tab 1 with product: Aluminium Mercury Structuur 7x20
# ✅ Filled row 620 on tab 1 with product: Aluminium Platina Mat 1,5 cm
# ✅ Filled row 621 on tab 1 with product: Aluminium Wit Glanzend 10x18
# ✅ Filled row 622 on tab 1 with product: Aluminium Zilver Glanzend 7x20
# ✅ Filled row 623 on tab 1 with product: Aluminium Zilver Mat  1,5 cm
# ✅ Filled row 624 on tab 1 with product: Aluminium Zilver mat 10x25 93-004
# ✅ Filled row 625 on tab 1 with product: Aluminium Zwart Structuur 7x20
# ✅ Filled row 626 on tab 1 with product: Amber 3,2 Cm
# ✅ Filled row 627 on tab 1 with product: Amber Gekrast 1 Cm
# ✅ Filled row 628 on tab 1 with product: Amerikaanse Baklijst Wit Op Hout
# ✅ Filled row 629 on tab 1 with product: Amerikaanse Lijst Blank 65/60 K1160
# ✅ Filled row 630 on tab 1 with product: Amerikaanse Lijst Wit 4 Cm K1157
# ✅ Filled row 631 on tab 1 with product: Amerikaanse Lijst Zwart 4 Cm K1154
# ✅ Filled row 632 on tab 1 with product: Amerikaanse Lijst Zwart Zilveren Top
# ✅ Filled row 633 on tab 1 with product: Aniline Ramin Antraciet 1,4 Cm
# ✅ Filled row 634 on tab 1 with product: Aniline Ramin Antraciet 2,3 Cm
# ✅ Filled row 635 on tab 1 with product: Aniline Ramin Donkerblauw 2,3Cm
# ✅ Filled row 636 on tab 1 with product: Aniline Ramin Donkergroen 1,4 Cm
# ✅ Filled row 637 on tab 1 with product: Aniline Ramin Donkergroen 2,3 Cm
# ✅ Filled row 638 on tab 1 with product: Aniline Ramin Donkerrood 1,4 Cm
# ✅ Filled row 639 on tab 1 with product: Aniline Ramin Donkerrood 2,3 Cm
# ✅ Filled row 640 on tab 1 with product: Aniline Ramin Groen/Blauw 1,4Cm
# ✅ Filled row 641 on tab 1 with product: Aniline Ramin Groen/Blauw 2,3 Cm
# ✅ Filled row 642 on tab 1 with product: Aniline Ramin Hoogblauw 1,4 Cm
# ✅ Filled row 643 on tab 1 with product: Aniline Ramin Lichtbruin 1,4 Cm
# ✅ Filled row 644 on tab 1 with product: Aniline Ramin Lichtbruin 2,3 Cm
# ✅ Filled row 645 on tab 1 with product: Aniline Ramin Lichtgeel 2,3 Cm
# ✅ Filled row 646 on tab 1 with product: Aniline Ramin Mahonie 1,4 Cm
# ✅ Filled row 647 on tab 1 with product: Aniline Ramin Mahonie 2,3 Cm
# ✅ Filled row 648 on tab 1 with product: Aniline Ramin Natuurkleur Vernist 1,4 Cm
# ✅ Filled row 649 on tab 1 with product: Aniline Ramin Natuurkleur Vernist 2,3 Cm
# ✅ Filled row 650 on tab 1 with product: Antiek Goud Plat 2,5 Cm
# ✅ Filled row 651 on tab 1 with product: Antiek Goud Plat 8 Cm
# ✅ Filled row 652 on tab 1 with product: Antiek Goud/Zw.Ondergrond
# ✅ Filled row 653 on tab 1 with product: Antiek Zilver 4 Cm
# ✅ Filled row 654 on tab 1 with product: Antiek Zilver Plat 8 Cm
# ✅ Filled row 655 on tab 1 with product: Antique White
# ✅ Filled row 656 on tab 1 with product: Antique White - Oversize
# ✅ Filled row 657 on tab 1 with product: Antraciet 0,4Cm
# ✅ Filled row 658 on tab 1 with product: Antraciet 0,7 Cm
# ✅ Filled row 659 on tab 1 with product: Antraciet 5,5Mm K1108
# ✅ Filled row 660 on tab 1 with product: Antraciet Mat 0,6 Cm
# ✅ Filled row 661 on tab 1 with product: Antraciet Mat 1 Cm
# ✅ Filled row 662 on tab 1 with product: Antraciet Mat 1,5 Cm
# ✅ Filled row 663 on tab 1 with product: Aqua Blauw 14x15
# ✅ Filled row 664 on tab 1 with product: Aqua Geel 14x15
# ✅ Filled row 665 on tab 1 with product: Aqua Green
# ✅ Filled row 666 on tab 1 with product: Aqua Groen 14x15
# ✅ Filled row 667 on tab 1 with product: Aqua Rood 14x15
# ✅ Filled row 668 on tab 1 with product: Aqua Rood 2,1 Cm
# ✅ Filled row 669 on tab 1 with product: Aqua Wit 14x15
# ✅ Filled row 670 on tab 1 with product: Aqua Zwart 14x15
# ✅ Filled row 671 on tab 1 with product: Arctic White
# ✅ Filled row 672 on tab 1 with product: Arctic White
# ✅ Filled row 673 on tab 1 with product: Arctic White
# ✅ Filled row 674 on tab 1 with product: Arctic White
# ✅ Filled row 675 on tab 1 with product: Art Deco Green
# ✅ Filled row 676 on tab 1 with product: Artglass AR70
# ✅ Filled row 677 on tab 1 with product: Artglass AR92
# ✅ Filled row 678 on tab 1 with product: Artglass AR99
# ✅ Filled row 679 on tab 1 with product: Ash - Suede
# ✅ Filled row 680 on tab 1 with product: Astral White
# ✅ Filled row 681 on tab 1 with product: Astral White 3.3mm
# ✅ Filled row 682 on tab 1 with product: Athentica Loft Dkr Grijs Met Spacer B:2Cm H:3,3Cm
# ✅ Filled row 683 on tab 1 with product: Authentic Grijs Gekleurd 20/20
# ✅ Filled row 684 on tab 1 with product: Authentic Grijs Gekleurd 24/38
# ✅ Filled row 685 on tab 1 with product: Authentic Turtledove Gekleurd 24/38
# ✅ Filled row 686 on tab 1 with product: Authentic Tutledove 20/20
# ✅ Filled row 687 on tab 1 with product: Authentic Wit Gekleurd 20/20
# ✅ Filled row 688 on tab 1 with product: Authentic Wit Gekleurd 24/38
# ✅ Filled row 689 on tab 1 with product: Authentic Zwart Gekleurd 20/20
# ✅ Filled row 690 on tab 1 with product: Authentic Zwart Gekleurd 24/38
# ✅ Filled row 691 on tab 1 with product: Authentica  Wit 4 Cm
# ✅ Filled row 692 on tab 1 with product: Authentica Beige 4 Cm
# ✅ Filled row 693 on tab 1 with product: Authentica Beige Handingekleurd 2,1 Cm
# ✅ Filled row 694 on tab 1 with product: Authentica Beige Handingekleurd 3 Cm
# ✅ Filled row 695 on tab 1 with product: Authentica Beige Handingekleurd 4 Cm
# ✅ Filled row 696 on tab 1 with product: Authentica Blok Creme 4 Cm
# ✅ Filled row 697 on tab 1 with product: Authentica Blok Lichtgrijs 4 Cm
# ✅ Filled row 698 on tab 1 with product: Authentica Blok Taupe 4 Cm
# ✅ Filled row 699 on tab 1 with product: Authentica Blok Wenge 4 Cm
# ✅ Filled row 700 on tab 1 with product: Authentica Blok Wit 4 Cm
# ✅ Filled row 701 on tab 1 with product: Authentica Blok Zwart 4 Cm
# ✅ Filled row 702 on tab 1 with product: Authentica Bruin Geborsteld Handingekleurd 3 Cm
# ✅ Filled row 703 on tab 1 with product: Authentica Combi 53015/3715 Wit 9 Cm
# ✅ Filled row 704 on tab 1 with product: Authentica Creme B 4 Cm/ H 3,7 Cm
# ✅ Filled row 705 on tab 1 with product: Authentica Creme Ingekleurd 1,5 Cm
# ✅ Filled row 706 on tab 1 with product: Authentica Creme Ingekleurd 2,5 Cm
# ✅ Filled row 707 on tab 1 with product: Authentica D.Grijs Ingekleurd 4 Cm
# ✅ Filled row 708 on tab 1 with product: Authentica Dkr Grijs B 4 Cm / H 3,7 Cm
# ✅ Filled row 709 on tab 1 with product: Authentica Donker Grijs Ingekleurd 1,5 Cm
# ✅ Filled row 710 on tab 1 with product: Authentica Donker Grijs Ingekleurd 2,5 Cm
# ✅ Filled row 711 on tab 1 with product: Authentica Donkergrijs Ingekleurd 3 Cm
# ✅ Filled row 712 on tab 1 with product: Authentica Grijs 4 Cm
# ✅ Filled row 713 on tab 1 with product: Authentica Grijs Handingekleurd 2,1 Cm
# ✅ Filled row 714 on tab 1 with product: Authentica Grijs Handingekleurd 3 Cm
# ✅ Filled row 715 on tab 1 with product: Authentica Grijs Handingekleurd 4 Cm
# ✅ Filled row 716 on tab 1 with product: Authentica Kaslijst Zwart  20x50
# ✅ Filled row 717 on tab 1 with product: Authentica Lichtgrijs Handingekleurd 2,1 Cm
# ✅ Filled row 718 on tab 1 with product: Authentica Lichtgrijs Ingekleurd 1,5 Cm
# ✅ Filled row 719 on tab 1 with product: Authentica Lichtgrijs Ingekleurd 2,5 Cm
# ✅ Filled row 720 on tab 1 with product: Authentica Lichtgrijs Ingekleurd 3 Cm
# ✅ Filled row 721 on tab 1 with product: Authentica Lichtgrijs Ingekleurd 4 Cm
# ✅ Filled row 722 on tab 1 with product: Authentica Loft Dkr Grijs B 2 Cm / H 3,3 Cm
# ✅ Filled row 723 on tab 1 with product: Authentica Loft Taupe B 2 Cm / H 3,3 Cm
# ✅ Filled row 724 on tab 1 with product: Authentica Loft Taupe Met Witte Spacer B:2 Cm H:3,3 Cm
# ✅ Filled row 725 on tab 1 with product: Authentica Loft Wit B 2 Cm / H 3,3 Cm
# ✅ Filled row 726 on tab 1 with product: Authentica Loft Wit Met Witte Spacer B:2Cm H:3,3Cm
# ✅ Filled row 727 on tab 1 with product: Authentica Taupe 4 Cm
# ✅ Filled row 728 on tab 1 with product: Authentica Taupe Handingekleurd 2,1 Cm
# ✅ Filled row 729 on tab 1 with product: Authentica Taupe Ingekleurd 1,5 Cm
# ✅ Filled row 730 on tab 1 with product: Authentica Taupe Ingekleurd 2,5 Cm
# ✅ Filled row 731 on tab 1 with product: Authentica Taupe Ingekleurd 3 Cm
# ✅ Filled row 732 on tab 1 with product: Authentica Taupe Ingekleurd 4 Cm
# ...
# ✅ Filled row 57 on tab 3 with service: [7, 'Assembleren kader']
# ✅ Filled row 58 on tab 3 with service: [7, 'Assembleren kader']
# ✅ Filled row 59 on tab 3 with service: [7, 'Assembleren kader']
# ✅ Filled row 60 on tab 3 with service: [7, 'Assembleren kader']
# ✅ Filled row 61 on tab 3 with service: [7, 'Assembleren kader']
# ✅ Filled row 62 on tab 3 with service: [8, 'Inlijsten']
# ✅ Filled row 63 on tab 3 with service: [8, 'Inlijsten']
# ✅ Filled row 64 on tab 3 with service: [8, 'Inlijsten']
# ✅ Filled row 65 on tab 3 with service: [8, 'Inlijsten']
# ✅ Filled row 66 on tab 3 with service: [8, 'Inlijsten']
# ✅ Filled row 67 on tab 3 with service: [8, 'Inlijsten']
# ✅ Filled row 68 on tab 3 with service: [8, 'Inlijsten']
# ✅ Filled row 69 on tab 3 with service: [8, 'Inlijsten']
# ✅ Filled row 70 on tab 3 with service: [9, 'Passe partout']
# ✅ Filled row 71 on tab 3 with service: [10, 'Losse producten inpakken']
# ✅ Filled row 72 on tab 3 with service: [10, 'Losse producten inpakken']
# ✅ Filled row 73 on tab 3 with service: [11, 'PP snijden']
# ✅ Filled row 74 on tab 3 with service: [11, 'PP snijden']
# ✅ Filled row 75 on tab 3 with service: [11, 'PP snijden']
# ✅ Filled row 76 on tab 3 with service: [11, 'PP snijden']
# ✅ Filled row 77 on tab 3 with service: [12, 'Shrinken']
# ✅ Filled row 78 on tab 3 with service: [12, 'Shrinken']
# ✅ Filled row 79 on tab 3 with service: [12, 'Shrinken']
# ✅ Filled row 80 on tab 3 with service: [12, 'Shrinken']
# ✅ Filled row 81 on tab 3 with service: [12, 'Shrinken']
# ✅ Filled row 82 on tab 3 with service: [12, 'Shrinken']
# ✅ Filled row 83 on tab 3 with service: [12, 'Shrinken']
# ✅ Filled row 84 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 85 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 86 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 87 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 88 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 89 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 90 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 91 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 92 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 93 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 94 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 95 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 96 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 97 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 98 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 99 on tab 3 with service: [13, 'Spieraam opspannen']
# ✅ Filled row 100 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 101 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 102 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 103 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 104 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 105 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 106 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 107 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 108 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 109 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 110 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 111 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 112 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 113 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 114 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 115 on tab 3 with service: [14, 'Spierraam assembleren']
# ✅ Filled row 116 on tab 3 with service: [15, 'Vellen snijden verpakking']
# ✅ Filled row 117 on tab 3 with service: [15, 'Vellen snijden verpakking']
# ✅ Filled row 118 on tab 3 with service: [15, 'Vellen snijden verpakking']
# ✅ Filled row 119 on tab 3 with service: [16, 'MDF Zagen']
# ✅ Filled row 120 on tab 3 with service: [16, 'MDF Zagen']
# ✅ Filled row 121 on tab 3 with service: [16, 'MDF Zagen']
# ✅ Filled row 122 on tab 3 with service: [16, 'MDF Zagen']
# ✅ Filled row 123 on tab 3 with service: [17, 'Vellen snijden (PVC/KARTON)']
# ✅ Filled row 124 on tab 3 with service: [17, 'Vellen snijden (PVC/KARTON)']
# ✅ Filled row 125 on tab 3 with service: [17, 'Vellen snijden (PVC/KARTON)']
# ✅ Filled row 126 on tab 3 with service: [17, 'Vellen snijden (PVC/KARTON)']
# ✅ Filled row 127 on tab 3 with service: [17, 'Vellen snijden (PVC/KARTON)']
# ✅ Filled row 128 on tab 3 with service: [17, 'Vellen snijden (PVC/KARTON)']
# ✅ Filled row 129 on tab 3 with service: [17, 'Vellen snijden (PVC/KARTON)']
# ✅ Filled row 130 on tab 3 with service: [17, 'Vellen snijden (PVC/KARTON)']
# ✅ Filled row 131 on tab 3 with service: [17, 'Vellen snijden (PVC/KARTON)']
# ✅ Filled row 132 on tab 3 with service: [17, 'Vellen snijden (PVC/KARTON)']
# ✅ Filled row 133 on tab 3 with service: [18, 'MONTEREN HINGES']
# ✅ Filled row 134 on tab 3 with service: [18, 'MONTEREN HINGES']
# ✅ Filled row 135 on tab 3 with service: [18, 'MONTEREN HINGES']
# ✅ Filled row 136 on tab 3 with service: [18, 'MONTEREN HINGES']
# ✅ Filled row 137 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 138 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 139 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 140 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 141 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 142 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 143 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 144 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 145 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 146 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 147 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 148 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 149 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 150 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 151 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 152 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 153 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 154 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 155 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 156 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 157 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 158 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 159 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 160 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 161 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 162 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 163 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 164 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 165 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 166 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 167 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 168 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 169 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 170 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 171 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 172 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 173 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 174 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 175 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 176 on tab 3 with service: [19, 'Kleven dibond 2mm koud']
# ✅ Filled row 177 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 178 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 179 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 180 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 181 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 182 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 183 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 184 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 185 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 186 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 187 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 188 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 189 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 190 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 191 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 192 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 193 on tab 3 with service: [20, 'Printen Barytte']
# ✅ Filled row 194 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 195 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 196 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 197 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 198 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 199 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 200 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 201 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 202 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 203 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 204 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 205 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 206 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 207 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 208 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 209 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 210 on tab 3 with service: [21, 'Printen ETCH/RAG']
# ✅ Filled row 211 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 212 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 213 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 214 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 215 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 216 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 217 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 218 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 219 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 220 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 221 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 222 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 223 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 224 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 225 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 226 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 227 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 228 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 229 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 230 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 231 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 232 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 233 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 234 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 235 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 236 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 237 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 238 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 239 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 240 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 241 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 242 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 243 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 244 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 245 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 246 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 247 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 248 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 249 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 250 on tab 3 with service: [22, 'Kleven op dibond 3mm']
# ✅ Filled row 251 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 252 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 253 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 254 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 255 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 256 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 257 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 258 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 259 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 260 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 261 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 262 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 263 on tab 3 with service: [23, 'Koud kleven']
# ✅ Filled row 264 on tab 3 with service: [24, 'AR99 Glas snijden']
# ✅ Filled row 265 on tab 3 with service: [24, 'AR99 Glas snijden']
# ✅ Filled row 266 on tab 3 with service: [24, 'AR99 Glas snijden']
# ✅ Filled row 267 on tab 3 with service: [24, 'AR99 Glas snijden']
# ✅ Filled row 268 on tab 3 with service: [24, 'AR99 Glas snijden']
# ✅ Filled row 269 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 270 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 271 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 272 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 273 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 274 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 275 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 276 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 277 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 278 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 279 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 280 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 281 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 282 on tab 3 with service: [25, 'Warm kleven']
# ✅ Filled row 283 on tab 3 with service: [26, 'AR92 Glas snijden']
# ✅ Filled row 284 on tab 3 with service: [26, 'AR92 Glas snijden']
# ✅ Filled row 285 on tab 3 with service: [26, 'AR92 Glas snijden']
# ✅ Filled row 286 on tab 3 with service: [26, 'AR92 Glas snijden']
# ✅ Filled row 287 on tab 3 with service: [26, 'AR92 Glas snijden']
# ✅ Filled row 288 on tab 3 with service: [27, 'Printen Fine Art Paper']
# ✅ Filled row 289 on tab 3 with service: [27, 'Printen Fine Art Paper']
# ✅ Filled row 290 on tab 3 with service: [28, 'Spacer uit passe-partout']
# ✅ Filled row 291 on tab 3 with service: [28, 'Spacer uit passe-partout']
# ✅ Filled row 292 on tab 3 with service: [28, 'Spacer uit passe-partout']
# ✅ Filled row 293 on tab 3 with service: [29, 'Monteren Crate']
# ✅ Filled row 294 on tab 3 with service: [29, 'Monteren Crate']
# ✅ Filled row 295 on tab 3 with service: [29, 'Monteren Crate']
# ✅ Filled row 296 on tab 3 with service: [29, 'Monteren Crate']
#
# ✅ Successfully filled 294 service duration rules into tab 3
#
# ✅ Done!

# %%
#CREATE PRODUCT PRICE EXCEL

import pandas as pd
import openpyxl
from datetime import datetime
import re

# Load the Excel file
excel_file = "justframeit_pricelist_20251113_184919.xlsx"
print(f"📂 Loading Excel file: {excel_file}")
wb = openpyxl.load_workbook(excel_file, data_only=True)  # data_only=True to get calculated values
print(f"✅ Excel file loaded successfully")

# Access the first tab
ws = wb.worksheets[0]
print(f"📄 Accessing first worksheet: {ws.title}")

# Headers are in row 6
header_row = 6
start_row = 7  # Data starts from row 7

# Find the last row with data in column A (starting from row 7)
last_row = start_row

print(f"🔍 Finding last row with data...")
# Find where column A becomes 0 or empty
for row in range(start_row, ws.max_row + 1):
    if row % 100 == 0:  # Log progress every 100 rows
        print(f"   Checking row {row}...")
    cell_value = ws[f'A{row}'].value
    if cell_value == 0 or cell_value is None or cell_value == '':
        break
    last_row = row

print(f"📊 Extracting data from row {start_row} to row {last_row}")

# Get headers from row 6, but check row 5 for dimension indicators
print(f"📋 Reading headers from row {header_row}...")
headers = []
found_first_dimension = False
last_dimension_col = 0
for col in range(1, ws.max_column + 1):
    if col % 50 == 0:  # Log progress every 50 columns
        print(f"   Processing column {col}...")
    # Check row 5 for dimension indicator (e.g., "10.0 x 20.0")
    dimension_cell = ws.cell(row=5, column=col)
    dimension_value = dimension_cell.value
    
    # Get the header from row 6
    header_cell = ws.cell(row=header_row, column=col)
    header_value = header_cell.value
    
    # Stricter check: dimension must contain 'x' AND at least one number
    is_dimension = False
    if dimension_value and isinstance(dimension_value, str):
        # Check if it contains 'x' and at least one digit
        if 'x' in dimension_value.lower() and re.search(r'\d', dimension_value):
            is_dimension = True
            found_first_dimension = True
            last_dimension_col = col
    
    # If we found dimensions before but now stopped finding them, stop processing columns
    if found_first_dimension and not is_dimension and not header_value:
        print(f"🛑 Stopping at column {col} - no more dimension headers found")
        break
    
    # If row 5 contains a valid dimension indicator, use it
    if is_dimension:
        headers.append(dimension_value)
    elif header_value:
        headers.append(header_value)
    else:
        headers.append(f'Column_{col}')

print(f"✅ Found {len(headers)} columns (last dimension column: {last_dimension_col})")

# Extract data from row 7 onwards to the last valid row
print(f"📥 Extracting data from {last_row - start_row + 1} rows...")
data = []
for row in range(start_row, last_row + 1):
    if (row - start_row) % 50 == 0:  # Log progress every 50 rows
        print(f"   Processing row {row} ({row - start_row + 1}/{last_row - start_row + 1})...")
    row_data = []
    for col in range(1, len(headers) + 1):
        cell = ws.cell(row=row, column=col)
        # Get the actual value, not the formula
        cell_value = cell.value
        
        # Handle special cases
        if cell_value is None:
            row_data.append(None)
        elif isinstance(cell_value, str) and cell_value.startswith('!REF'):
            # Handle reference errors
            row_data.append(None)
        else:
            row_data.append(cell_value)
    data.append(row_data)

# Create DataFrame
print(f"🔄 Creating DataFrame...")
df = pd.DataFrame(data, columns=headers)
print(f"✅ DataFrame created with {len(df)} rows and {len(df.columns)} columns")

# Create a new CSV filename (don't overwrite the Excel file)
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_file = f"justframeit_pricelist_filtered_{timestamp}.csv"
print(f"💾 Saving to CSV file: {csv_file}")
df.to_csv(csv_file, index=False)

print(f"\n✅ Successfully created CSV file: {csv_file}")
print(f"📝 Extracted {len(df)} rows from the Excel file")
print(f"📁 Original Excel file remains unchanged: {excel_file}")
print(f"📋 Column headers: {headers[:5]}...")  # Show first 5 headers

# %%
#CREATE PRODUCT PRICE CSV (To be sent to Craft)

import pandas as pd
import openpyxl
from datetime import datetime
import re
import xlwings as xw

# Load the Excel file with xlwings to force calculation
excel_file = "price_export_generated_20251114_131558.xlsx"
print(f"📂 Loading Excel file with xlwings: {excel_file}")

# Open with xlwings to force calculation
app = xw.App(visible=False)
wb_xlwings = app.books.open(excel_file)
ws_xlwings = wb_xlwings.sheets[0]

# Force calculation
print(f"🔄 Forcing Excel calculation...")
wb_xlwings.app.calculate()

# Save the calculated workbook
temp_file = f"temp_calculated_{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx"
wb_xlwings.save(temp_file)
wb_xlwings.close()
app.quit()

print(f"✅ Calculated workbook saved as: {temp_file}")

# Now load with openpyxl
print(f"📂 Loading calculated Excel file with openpyxl: {temp_file}")
wb = openpyxl.load_workbook(temp_file, data_only=True)
ws = wb.worksheets[0]
print(f"✅ Excel file loaded successfully")

# Access the first tab
print(f"📄 Accessing first worksheet: {ws.title}")

# Test reading cells K7 and L7 to verify values
print(f"\n🔍 Testing calculated values for cells K7 and L7:")
k7_cell = ws['K7']
l7_cell = ws['L7']
print(f"   K7 calculated value: {k7_cell.value}")
print(f"   K7 data_type: {k7_cell.data_type}")
print(f"   L7 calculated value: {l7_cell.value}")
print(f"   L7 data_type: {l7_cell.data_type}")

# Headers are in row 6
header_row = 6
start_row = 7  # Data starts from row 7

# Find the last row with data in column A (starting from row 7)
last_row = start_row

print(f"\n🔍 Finding last row with data...")
# Find where column A becomes 0 or empty
for row in range(start_row, ws.max_row + 1):
    if row % 100 == 0:  # Log progress every 100 rows
        print(f"   Checking row {row}...")
    cell_value = ws[f'A{row}'].value
    if cell_value == 0 or cell_value is None or cell_value == '':
        break
    last_row = row

print(f"📊 Extracting data from row {start_row} to row {last_row}")

# Get headers from row 6, but check row 5 for dimension indicators
print(f"📋 Reading headers from row {header_row}...")
headers = []
valid_columns = []  # Track which columns to include
dimension_columns = []  # Track which columns are dimensions
found_first_dimension = False
last_dimension_col = 0
for col in range(1, ws.max_column + 1):
    if col % 50 == 0:  # Log progress every 50 columns
        print(f"   Processing column {col}...")
    # Check row 5 for dimension indicator (e.g., "10.0 x 20.0")
    dimension_cell = ws.cell(row=5, column=col)
    dimension_value = dimension_cell.value
    
    # Get the header from row 6
    header_cell = ws.cell(row=header_row, column=col)
    header_value = header_cell.value
    
    # Stricter check: dimension must contain 'x' AND at least one number
    is_dimension = False
    if dimension_value and isinstance(dimension_value, str):
        # Check if it contains 'x' and at least one digit
        if 'x' in dimension_value.lower() and re.search(r'\d', dimension_value):
            is_dimension = True
            found_first_dimension = True
            last_dimension_col = col
    
    # If we found dimensions before but now stopped finding them, stop processing columns
    if found_first_dimension and not is_dimension:
        print(f"🛑 Stopping at column {col} - no more dimension headers found")
        break
    
    # If row 5 contains a valid dimension indicator, use it
    if is_dimension:
        headers.append(dimension_value)
        valid_columns.append(col)
        dimension_columns.append(len(headers) - 1)  # Track the index of this dimension column
    elif header_value and not found_first_dimension:
        # Only include non-dimension columns if we haven't found dimensions yet
        headers.append(header_value)
        valid_columns.append(col)
    elif not found_first_dimension:
        headers.append(f'Column_{col}')
        valid_columns.append(col)

print(f"✅ Found {len(headers)} columns (last dimension column: {last_dimension_col})")

# Extract data from row 7 onwards to the last valid row
print(f"📥 Extracting data from {last_row - start_row + 1} rows...")
data = []
for row in range(start_row, last_row + 1):
    if (row - start_row) % 50 == 0:  # Log progress every 50 rows
        print(f"   Processing row {row} ({row - start_row + 1}/{last_row - start_row + 1})...")
    row_data = []
    for idx, col in enumerate(valid_columns):  # Only extract data from valid columns
        cell = ws.cell(row=row, column=col)
        # Get the actual value, not the formula
        cell_value = cell.value
        
        # Log K7 and L7 specifically
        if row == 7 and col in [11, 12]:  # K=11, L=12
            col_letter = openpyxl.utils.get_column_letter(col)
            print(f"   📌 Cell {col_letter}{row}: value={cell_value}, type={type(cell_value)}")
        
        # Check if this is a dimension column
        is_dimension_col = idx in dimension_columns
        
        # Handle special cases
        if cell_value is None:
            row_data.append(None)
        elif isinstance(cell_value, str) and cell_value.startswith('!REF'):
            # Handle reference errors
            row_data.append(None)
        elif isinstance(cell_value, (int, float)):
            # Round all numeric values to 2 decimal places
            row_data.append(round(float(cell_value), 2))
        else:
            row_data.append(cell_value)
    data.append(row_data)

# Create DataFrame
print(f"🔄 Creating DataFrame...")
df = pd.DataFrame(data, columns=headers)
print(f"✅ DataFrame created with {len(df)} rows and {len(df.columns)} columns")

# Create a new CSV filename (don't overwrite the Excel file)
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_file = f"justframeit_pricelist_filtered_{timestamp}.csv"
print(f"💾 Saving to CSV file: {csv_file}")
df.to_csv(csv_file, index=False)

print(f"\n✅ Successfully created CSV file: {csv_file}")
print(f"📝 Extracted {len(df)} rows from the Excel file")
print(f"📁 Original Excel file remains unchanged: {excel_file}")
print(f"📋 Column headers: {headers[:5]}...")  # Show first 5 headers

# Clean up temporary file
import os
try:
    os.remove(temp_file)
    print(f"🗑️ Cleaned up temporary file: {temp_file}")
except Exception as e:
    print(f"⚠️ Could not remove temporary file: {e}")
# Out:
# 📂 Loading Excel file with xlwings: price_export_generated_20251114_131558.xlsx
# 🔄 Forcing Excel calculation...
# ✅ Calculated workbook saved as: temp_calculated_20251114_135613.xlsx
# 📂 Loading calculated Excel file with openpyxl: temp_calculated_20251114_135613.xlsx
# ✅ Excel file loaded successfully
# 📄 Accessing first worksheet: Products Prices
#
# 🔍 Testing calculated values for cells K7 and L7:
#    K7 calculated value: 0.1
#    K7 data_type: n
#    L7 calculated value: 1.203888888888889
#    L7 data_type: n
#
# 🔍 Finding last row with data...
#    Checking row 100...
#    Checking row 200...
#    Checking row 300...
#    Checking row 400...
#    Checking row 500...
#    Checking row 600...
#    Checking row 700...
#    Checking row 800...
#    Checking row 900...
#    Checking row 1000...
#    Checking row 1100...
#    Checking row 1200...
#    Checking row 1300...
#    Checking row 1400...
#    Checking row 1500...
#    Checking row 1600...
#    Checking row 1700...
#    Checking row 1800...
#    Checking row 1900...
# 📊 Extracting data from row 7 to row 1899
# 📋 Reading headers from row 6...
#    Processing column 50...
#    Processing column 100...
#    Processing column 150...
# 🛑 Stopping at column 157 - no more dimension headers found
# ✅ Found 156 columns (last dimension column: 156)
# 📥 Extracting data from 1893 rows...
#    Processing row 7 (1/1893)...
#    📌 Cell K7: value=0.1, type=<class 'float'>
#    📌 Cell L7: value=1.203888888888889, type=<class 'float'>
#    Processing row 57 (51/1893)...
#    Processing row 107 (101/1893)...
#    Processing row 157 (151/1893)...
#    Processing row 207 (201/1893)...
#    Processing row 257 (251/1893)...
#    Processing row 307 (301/1893)...
#    Processing row 357 (351/1893)...
#    Processing row 407 (401/1893)...
#    Processing row 457 (451/1893)...
#    Processing row 507 (501/1893)...
#    Processing row 557 (551/1893)...
#    Processing row 607 (601/1893)...
#    Processing row 657 (651/1893)...
#    Processing row 707 (701/1893)...
#    Processing row 757 (751/1893)...
#    Processing row 807 (801/1893)...
#    Processing row 857 (851/1893)...
#    Processing row 907 (901/1893)...
#    Processing row 957 (951/1893)...
#    Processing row 1007 (1001/1893)...
#    Processing row 1057 (1051/1893)...
#    Processing row 1107 (1101/1893)...
#    Processing row 1157 (1151/1893)...
#    Processing row 1207 (1201/1893)...
#    Processing row 1257 (1251/1893)...
#    Processing row 1307 (1301/1893)...
#    Processing row 1357 (1351/1893)...
#    Processing row 1407 (1401/1893)...
#    Processing row 1457 (1451/1893)...
#    Processing row 1507 (1501/1893)...
#    Processing row 1557 (1551/1893)...
#    Processing row 1607 (1601/1893)...
#    Processing row 1657 (1651/1893)...
#    Processing row 1707 (1701/1893)...
#    Processing row 1757 (1751/1893)...
#    Processing row 1807 (1801/1893)...
#    Processing row 1857 (1851/1893)...
# 🔄 Creating DataFrame...
# ✅ DataFrame created with 1893 rows and 156 columns
# 💾 Saving to CSV file: justframeit_pricelist_filtered_20251114_135630.csv
#
# ✅ Successfully created CSV file: justframeit_pricelist_filtered_20251114_135630.csv
# 📝 Extracted 1893 rows from the Excel file
# 📁 Original Excel file remains unchanged: price_export_generated_20251114_131558.xlsx
# 📋 Column headers: ['Name', 'ID', 'Product Code', 'Location Code', 'eCommerce Description']...
# 🗑️ Cleaned up temporary file: temp_calculated_20251114_135613.xlsx

# %%
#TEST READING K7 AND L7 - 5 DIFFERENT APPROACHES

import pandas as pd
import openpyxl
from openpyxl import load_workbook

# Load the Excel file
excel_file = "price_export_generated_20251114_131558.xlsx"
print(f"📂 Testing file: {excel_file}\n")

# ============================================================================
# APPROACH 1: Load with data_only=True (calculated values only)
# ============================================================================
print("=" * 80)
print("APPROACH 1: Load with data_only=True (calculated values only)")
print("=" * 80)
try:
    wb1 = load_workbook(excel_file, data_only=True)
    ws1 = wb1.worksheets[0]
    k7_val = ws1['K7'].value
    l7_val = ws1['L7'].value
    print(f"✅ K7 value: {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value: {l7_val} (type: {type(l7_val)})")
    wb1.close()
except Exception as e:
    print(f"❌ Error: {e}")
print()

# ============================================================================
# APPROACH 2: Load with data_only=False (formulas, not calculated values)
# ============================================================================
print("=" * 80)
print("APPROACH 2: Load with data_only=False (formulas, not calculated values)")
print("=" * 80)
try:
    wb2 = load_workbook(excel_file, data_only=False)
    ws2 = wb2.worksheets[0]
    k7_cell = ws2['K7']
    l7_cell = ws2['L7']
    print(f"✅ K7 value: {k7_cell.value} (type: {type(k7_cell.value)})")
    print(f"   K7 data_type: {k7_cell.data_type}")
    print(f"✅ L7 value: {l7_cell.value} (type: {type(l7_cell.value)})")
    print(f"   L7 data_type: {l7_cell.data_type}")
    wb2.close()
except Exception as e:
    print(f"❌ Error: {e}")
print()

# ============================================================================
# APPROACH 3: Use pandas read_excel with openpyxl engine
# ============================================================================
print("=" * 80)
print("APPROACH 3: Use pandas read_excel with openpyxl engine")
print("=" * 80)
try:
    # Read starting from row 6 (0-indexed row 5) to get headers from row 6
    df3 = pd.read_excel(excel_file, sheet_name=0, header=5, engine='openpyxl')
    # K7 would be row 0 (first data row after header), column K (index 10)
    # L7 would be row 0, column L (index 11)
    print(f"✅ Column names: {list(df3.columns[:15])}")
    if len(df3) > 0:
        k7_val = df3.iloc[0, 10] if len(df3.columns) > 10 else "N/A"
        l7_val = df3.iloc[0, 11] if len(df3.columns) > 11 else "N/A"
        print(f"✅ K7 value (row 0, col 10): {k7_val} (type: {type(k7_val)})")
        print(f"✅ L7 value (row 0, col 11): {l7_val} (type: {type(l7_val)})")
except Exception as e:
    print(f"❌ Error: {e}")
print()

# ============================================================================
# APPROACH 4: Access by cell coordinates (row, column)
# ============================================================================
print("=" * 80)
print("APPROACH 4: Access by cell coordinates (row=7, column=11 and 12)")
print("=" * 80)
try:
    wb4 = load_workbook(excel_file, data_only=True)
    ws4 = wb4.worksheets[0]
    k7_cell = ws4.cell(row=7, column=11)  # K=11
    l7_cell = ws4.cell(row=7, column=12)  # L=12
    print(f"✅ K7 (row=7, col=11) value: {k7_cell.value} (type: {type(k7_cell.value)})")
    print(f"   K7 data_type: {k7_cell.data_type}")
    print(f"✅ L7 (row=7, col=12) value: {l7_cell.value} (type: {type(l7_cell.value)})")
    print(f"   L7 data_type: {l7_cell.data_type}")
    wb4.close()
except Exception as e:
    print(f"❌ Error: {e}")
print()

# ============================================================================
# APPROACH 5: Save and reload to force calculation
# ============================================================================
print("=" * 80)
print("APPROACH 5: Save and reload to force calculation")
print("=" * 80)
try:
    # First load without data_only
    wb5a = load_workbook(excel_file, data_only=False)
    temp_file = excel_file.replace('.xlsx', '_temp_calculated.xlsx')
    wb5a.save(temp_file)
    wb5a.close()
    print(f"✅ Saved temporary file: {temp_file}")
    
    # Now reload with data_only=True
    wb5b = load_workbook(temp_file, data_only=True)
    ws5b = wb5b.worksheets[0]
    k7_val = ws5b['K7'].value
    l7_val = ws5b['L7'].value
    print(f"✅ K7 value: {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value: {l7_val} (type: {type(l7_val)})")
    wb5b.close()
    
    # Clean up temp file
    import os
    os.remove(temp_file)
    print(f"✅ Cleaned up temporary file")
except Exception as e:
    print(f"❌ Error: {e}")
print()

print("=" * 80)
print("TESTING COMPLETE")
print("=" * 80)
# Out:
# 📂 Testing file: price_export_generated_20251114_131558.xlsx
#
# ================================================================================
# APPROACH 1: Load with data_only=True (calculated values only)
# ================================================================================
# ✅ K7 value: None (type: <class 'NoneType'>)
# ✅ L7 value: None (type: <class 'NoneType'>)
#
# ================================================================================
# APPROACH 2: Load with data_only=False (formulas, not calculated values)
# ================================================================================
# ✅ K7 value: =(Pricelists!$D$3*(-1)/100) (type: <class 'str'>)
#    K7 data_type: f
# ✅ L7 value: <openpyxl.worksheet.formula.ArrayFormula object at 0x0000023301BC8190> (type: <class 'openpyxl.worksheet.formula.ArrayFormula'>)
#    L7 data_type: f
#
# ================================================================================
# APPROACH 3: Use pandas read_excel with openpyxl engine
# ================================================================================
# ✅ Column names: ['Name', 'ID', 'Product Code', 'Location Code', 'eCommerce Description', 'Price computation', 'Material Cost per uni', 'Associated Service', 'Associated Work Center', 'Associated Cost per Employee per Hour', 'Margin', 'Column1', 'Column2', 'Column3', 'Column4']
# ✅ K7 value (row 0, col 10): nan (type: <class 'numpy.float64'>)
# ✅ L7 value (row 0, col 11): nan (type: <class 'numpy.float64'>)
#
# ================================================================================
# APPROACH 4: Access by cell coordinates (row=7, column=11 and 12)
# ================================================================================
# ✅ K7 (row=7, col=11) value: None (type: <class 'NoneType'>)
#    K7 data_type: n
# ✅ L7 (row=7, col=12) value: None (type: <class 'NoneType'>)
#    L7 data_type: n
#
# ================================================================================
# APPROACH 5: Save and reload to force calculation
# ================================================================================
# ✅ Saved temporary file: price_export_generated_20251114_131558_temp_calculated.xlsx
# ✅ K7 value: None (type: <class 'NoneType'>)
# ✅ L7 value: None (type: <class 'NoneType'>)
# ✅ Cleaned up temporary file
#
# ================================================================================
# TESTING COMPLETE
# ================================================================================

# %%
#TEST READING K7 AND L7 - APPROACHES 6-10 WITH PROPER LOADING TIME

import pandas as pd
import openpyxl
from openpyxl import load_workbook
import time
import os

# Load the Excel file
excel_file = "price_export_generated_20251114_131558.xlsx"
print(f"📂 Testing file: {excel_file}\n")

# ============================================================================
# APPROACH 6: Load with data_only=True and wait for file to fully load
# ============================================================================
print("=" * 80)
print("APPROACH 6: Load with data_only=True and wait for file to fully load")
print("=" * 80)
try:
    print("⏳ Loading workbook...")
    wb6 = load_workbook(excel_file, data_only=True)
    time.sleep(2)  # Wait 2 seconds for file to fully load
    print("✅ Workbook loaded, accessing worksheet...")
    ws6 = wb6.worksheets[0]
    time.sleep(1)  # Wait 1 second
    print("✅ Worksheet accessed, reading cells...")
    k7_val = ws6['K7'].value
    l7_val = ws6['L7'].value
    print(f"✅ K7 value: {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value: {l7_val} (type: {type(l7_val)})")
    wb6.close()
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 7: Load with data_only=False, wait, then access formulas
# ============================================================================
print("=" * 80)
print("APPROACH 7: Load with data_only=False, wait, then access formulas")
print("=" * 80)
try:
    print("⏳ Loading workbook with formulas...")
    wb7 = load_workbook(excel_file, data_only=False)
    time.sleep(2)  # Wait 2 seconds
    print("✅ Workbook loaded, accessing worksheet...")
    ws7 = wb7.worksheets[0]
    time.sleep(1)  # Wait 1 second
    print("✅ Worksheet accessed, reading cells...")
    k7_cell = ws7['K7']
    l7_cell = ws7['L7']
    print(f"✅ K7 value: {k7_cell.value} (type: {type(k7_cell.value)})")
    print(f"   K7 data_type: {k7_cell.data_type}")
    print(f"✅ L7 value: {l7_cell.value} (type: {type(l7_cell.value)})")
    print(f"   L7 data_type: {l7_cell.data_type}")
    wb7.close()
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 8: Use pandas with wait time
# ============================================================================
print("=" * 80)
print("APPROACH 8: Use pandas read_excel with wait time")
print("=" * 80)
try:
    print("⏳ Reading Excel file with pandas...")
    time.sleep(1)  # Wait before reading
    df8 = pd.read_excel(excel_file, sheet_name=0, header=5, engine='openpyxl')
    time.sleep(2)  # Wait after reading
    print("✅ DataFrame loaded")
    print(f"✅ DataFrame shape: {df8.shape}")
    print(f"✅ Column names (first 15): {list(df8.columns[:15])}")
    if len(df8) > 0 and len(df8.columns) > 11:
        k7_val = df8.iloc[0, 10]
        l7_val = df8.iloc[0, 11]
        print(f"✅ K7 value (row 0, col 10): {k7_val} (type: {type(k7_val)})")
        print(f"✅ L7 value (row 0, col 11): {l7_val} (type: {type(l7_val)})")
    else:
        print("⚠️ DataFrame doesn't have enough rows or columns")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 9: Access by cell coordinates with extended wait
# ============================================================================
print("=" * 80)
print("APPROACH 9: Access by cell coordinates with extended wait")
print("=" * 80)
try:
    print("⏳ Loading workbook...")
    wb9 = load_workbook(excel_file, data_only=True)
    time.sleep(3)  # Wait 3 seconds
    print("✅ Workbook loaded, accessing worksheet...")
    ws9 = wb9.worksheets[0]
    time.sleep(2)  # Wait 2 seconds
    print("✅ Worksheet accessed, reading cells by coordinates...")
    k7_cell = ws9.cell(row=7, column=11)  # K=11
    l7_cell = ws9.cell(row=7, column=12)  # L=12
    time.sleep(1)  # Wait 1 second
    print(f"✅ K7 (row=7, col=11) value: {k7_cell.value} (type: {type(k7_cell.value)})")
    print(f"   K7 data_type: {k7_cell.data_type}")
    print(f"✅ L7 (row=7, col=12) value: {l7_cell.value} (type: {type(l7_cell.value)})")
    print(f"   L7 data_type: {l7_cell.data_type}")
    wb9.close()
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 10: Save, wait, reload with extended delays
# ============================================================================
print("=" * 80)
print("APPROACH 10: Save, wait, reload with extended delays")
print("=" * 80)
try:
    print("⏳ Loading workbook without data_only...")
    wb10a = load_workbook(excel_file, data_only=False)
    time.sleep(2)  # Wait 2 seconds
    temp_file = excel_file.replace('.xlsx', '_temp_calculated.xlsx')
    print(f"⏳ Saving temporary file: {temp_file}")
    wb10a.save(temp_file)
    wb10a.close()
    time.sleep(3)  # Wait 3 seconds after saving
    print(f"✅ Saved and closed, waiting before reload...")
    
    print("⏳ Reloading with data_only=True...")
    wb10b = load_workbook(temp_file, data_only=True)
    time.sleep(3)  # Wait 3 seconds
    print("✅ Workbook reloaded, accessing worksheet...")
    ws10b = wb10b.worksheets[0]
    time.sleep(2)  # Wait 2 seconds
    print("✅ Worksheet accessed, reading cells...")
    k7_val = ws10b['K7'].value
    l7_val = ws10b['L7'].value
    print(f"✅ K7 value: {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value: {l7_val} (type: {type(l7_val)})")
    wb10b.close()
    
    # Clean up temp file
    time.sleep(1)
    if os.path.exists(temp_file):
        os.remove(temp_file)
        print(f"✅ Cleaned up temporary file")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

print("=" * 80)
print("TESTING COMPLETE (APPROACHES 6-10)")
print("=" * 80)
# Out:
# 📂 Testing file: price_export_generated_20251114_131558.xlsx
#
# ================================================================================
# APPROACH 6: Load with data_only=True and wait for file to fully load
# ================================================================================
# ⏳ Loading workbook...
# ✅ Workbook loaded, accessing worksheet...
# ✅ Worksheet accessed, reading cells...
# ✅ K7 value: None (type: <class 'NoneType'>)
# ✅ L7 value: None (type: <class 'NoneType'>)
#
# ================================================================================
# APPROACH 7: Load with data_only=False, wait, then access formulas
# ================================================================================
# ⏳ Loading workbook with formulas...
# ✅ Workbook loaded, accessing worksheet...
# ✅ Worksheet accessed, reading cells...
# ✅ K7 value: =(Pricelists!$D$3*(-1)/100) (type: <class 'str'>)
#    K7 data_type: f
# ✅ L7 value: <openpyxl.worksheet.formula.ArrayFormula object at 0x000002337CE3A5D0> (type: <class 'openpyxl.worksheet.formula.ArrayFormula'>)
#    L7 data_type: f
#
# ================================================================================
# APPROACH 8: Use pandas read_excel with wait time
# ================================================================================
# ⏳ Reading Excel file with pandas...
# ✅ DataFrame loaded
# ✅ DataFrame shape: (1893, 182)
# ✅ Column names (first 15): ['Name', 'ID', 'Product Code', 'Location Code', 'eCommerce Description', 'Price computation', 'Material Cost per uni', 'Associated Service', 'Associated Work Center', 'Associated Cost per Employee per Hour', 'Margin', 'Column1', 'Column2', 'Column3', 'Column4']
# ✅ K7 value (row 0, col 10): nan (type: <class 'numpy.float64'>)
# ✅ L7 value (row 0, col 11): nan (type: <class 'numpy.float64'>)
#
# ================================================================================
# APPROACH 9: Access by cell coordinates with extended wait
# ================================================================================
# ⏳ Loading workbook...
# ✅ Workbook loaded, accessing worksheet...
# ✅ Worksheet accessed, reading cells by coordinates...
# ✅ K7 (row=7, col=11) value: None (type: <class 'NoneType'>)
#    K7 data_type: n
# ✅ L7 (row=7, col=12) value: None (type: <class 'NoneType'>)
#    L7 data_type: n
#
# ================================================================================
# APPROACH 10: Save, wait, reload with extended delays
# ================================================================================
# ⏳ Loading workbook without data_only...
# ⏳ Saving temporary file: price_export_generated_20251114_131558_temp_calculated.xlsx
# ✅ Saved and closed, waiting before reload...
# ⏳ Reloading with data_only=True...
# ✅ Workbook reloaded, accessing worksheet...
# ✅ Worksheet accessed, reading cells...
# ✅ K7 value: None (type: <class 'NoneType'>)
# ✅ L7 value: None (type: <class 'NoneType'>)
# ✅ Cleaned up temporary file
#
# ================================================================================
# TESTING COMPLETE (APPROACHES 6-10)
# ================================================================================

# %%
# TEST READING K7 AND L7 - APPROACHES 11-15 (Copy/Paste Values)

import pandas as pd
import openpyxl
from openpyxl import load_workbook
from openpyxl.utils import get_column_letter
import os
import time
from copy import copy

# Load the Excel file
excel_file = "price_export_generated_20251114_131558.xlsx"
print(f"📂 Testing file: {excel_file}\n")

# ============================================================================
# APPROACH 11: Copy values only to new workbook
# ============================================================================
print("=" * 80)
print("APPROACH 11: Copy values only to new workbook")
print("=" * 80)
try:
    print("⏳ Loading workbook with data_only=True...")
    wb11a = load_workbook(excel_file, data_only=True)
    ws11a = wb11a.worksheets[0]
    
    print("⏳ Creating new workbook and copying values...")
    from openpyxl import Workbook
    wb11b = Workbook()
    ws11b = wb11b.active
    
    # Copy only values from the original sheet
    for row in ws11a.iter_rows():
        for cell in row:
            ws11b[cell.coordinate].value = cell.value
    
    temp_file = excel_file.replace('.xlsx', '_temp_values_only.xlsx')
    print(f"⏳ Saving values-only file: {temp_file}")
    wb11b.save(temp_file)
    wb11a.close()
    wb11b.close()
    
    print("⏳ Reloading values-only file...")
    wb11c = load_workbook(temp_file, data_only=True)
    ws11c = wb11c.worksheets[0]
    k7_val = ws11c['K7'].value
    l7_val = ws11c['L7'].value
    print(f"✅ K7 value: {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value: {l7_val} (type: {type(l7_val)})")
    wb11c.close()
    
    # Clean up
    if os.path.exists(temp_file):
        os.remove(temp_file)
        print(f"✅ Cleaned up temporary file")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 12: Use xlwings to force calculation (if available)
# ============================================================================
print("=" * 80)
print("APPROACH 12: Use xlwings to force calculation")
print("=" * 80)
try:
    import xlwings as xw
    print("⏳ Opening workbook with xlwings...")
    app = xw.App(visible=False)
    wb12 = xw.Book(excel_file)
    ws12 = wb12.sheets[0]
    
    print("⏳ Reading K7 and L7 values...")
    k7_val = ws12.range('K7').value
    l7_val = ws12.range('L7').value
    print(f"✅ K7 value: {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value: {l7_val} (type: {type(l7_val)})")
    
    wb12.close()
    app.quit()
except ImportError:
    print("⚠️ xlwings not installed - skipping this approach")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 13: Read raw XML from Excel file
# ============================================================================
print("=" * 80)
print("APPROACH 13: Read raw XML from Excel file")
print("=" * 80)
try:
    import zipfile
    import xml.etree.ElementTree as ET
    
    print("⏳ Opening Excel file as ZIP...")
    with zipfile.ZipFile(excel_file, 'r') as zip_ref:
        # Read the worksheet XML
        sheet_xml = zip_ref.read('xl/worksheets/sheet1.xml')
        root = ET.fromstring(sheet_xml)
        
        # Define namespace
        ns = {'main': 'http://schemas.openxmlformats.org/spreadsheetml/2006/main'}
        
        print("⏳ Searching for K7 and L7 cells in XML...")
        for cell in root.findall('.//main:c', ns):
            ref = cell.get('r')
            if ref in ['K7', 'L7']:
                value_elem = cell.find('main:v', ns)
                value = value_elem.text if value_elem is not None else None
                print(f"✅ {ref} raw XML value: {value}")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 14: Copy entire sheet to new workbook with paste special values
# ============================================================================
print("=" * 80)
print("APPROACH 14: Copy entire sheet with manual value extraction")
print("=" * 80)
try:
    print("⏳ Loading workbook...")
    wb14a = load_workbook(excel_file, data_only=True)
    ws14a = wb14a.worksheets[0]
    
    print("⏳ Creating new workbook...")
    from openpyxl import Workbook
    wb14b = Workbook()
    ws14b = wb14b.active
    
    print("⏳ Copying all cell values (this may take a moment)...")
    for row_idx, row in enumerate(ws14a.iter_rows(min_row=1, max_row=ws14a.max_row), 1):
        if row_idx % 100 == 0:
            print(f"   Processing row {row_idx}...")
        for col_idx, cell in enumerate(row, 1):
            # Only copy the value, not formulas or formatting
            new_cell = ws14b.cell(row=row_idx, column=col_idx)
            new_cell.value = cell.value
    
    temp_file = excel_file.replace('.xlsx', '_temp_manual_copy.xlsx')
    print(f"⏳ Saving copied workbook: {temp_file}")
    wb14b.save(temp_file)
    wb14a.close()
    wb14b.close()
    
    print("⏳ Reloading copied workbook...")
    wb14c = load_workbook(temp_file, data_only=True)
    ws14c = wb14c.worksheets[0]
    k7_val = ws14c['K7'].value
    l7_val = ws14c['L7'].value
    print(f"✅ K7 value: {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value: {l7_val} (type: {type(l7_val)})")
    wb14c.close()
    
    # Clean up
    if os.path.exists(temp_file):
        os.remove(temp_file)
        print(f"✅ Cleaned up temporary file")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 15: Use pandas to read and write back as values
# ============================================================================
print("=" * 80)
print("APPROACH 15: Use pandas to read and write back as values")
print("=" * 80)
try:
    print("⏳ Reading Excel file with pandas...")
    # Read the entire sheet
    df15 = pd.read_excel(excel_file, sheet_name=0, header=None, engine='openpyxl')
    
    print(f"✅ DataFrame shape: {df15.shape}")
    print("⏳ Accessing K7 and L7 (row 6, columns 10 and 11)...")
    # K7 is row 6 (0-indexed), column 10 (K is the 11th column, 0-indexed = 10)
    # L7 is row 6 (0-indexed), column 11 (L is the 12th column, 0-indexed = 11)
    k7_val = df15.iloc[6, 10] if df15.shape[0] > 6 and df15.shape[1] > 10 else None
    l7_val = df15.iloc[6, 11] if df15.shape[0] > 6 and df15.shape[1] > 11 else None
    print(f"✅ K7 value (row 6, col 10): {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value (row 6, col 11): {l7_val} (type: {type(l7_val)})")
    
    # Write back to new file
    temp_file = excel_file.replace('.xlsx', '_temp_pandas.xlsx')
    print(f"⏳ Writing to temporary file: {temp_file}")
    df15.to_excel(temp_file, index=False, header=False, engine='openpyxl')
    
    print("⏳ Reloading with openpyxl...")
    wb15 = load_workbook(temp_file, data_only=True)
    ws15 = wb15.worksheets[0]
    k7_val_reload = ws15['K7'].value
    l7_val_reload = ws15['L7'].value
    print(f"✅ K7 value (reloaded): {k7_val_reload} (type: {type(k7_val_reload)})")
    print(f"✅ L7 value (reloaded): {l7_val_reload} (type: {type(l7_val_reload)})")
    wb15.close()
    
    # Clean up
    if os.path.exists(temp_file):
        os.remove(temp_file)
        print(f"✅ Cleaned up temporary file")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

print("=" * 80)
print("TESTING COMPLETE (APPROACHES 11-15)")
print("=" * 80)
# Out:
# 📂 Testing file: price_export_generated_20251114_131558.xlsx
#
# ================================================================================
# APPROACH 11: Copy values only to new workbook
# ================================================================================
# ⏳ Loading workbook with data_only=True...
# ⏳ Creating new workbook and copying values...
# ⏳ Saving values-only file: price_export_generated_20251114_131558_temp_values_only.xlsx
# ⏳ Reloading values-only file...
# ✅ K7 value: None (type: <class 'NoneType'>)
# ✅ L7 value: None (type: <class 'NoneType'>)
# ✅ Cleaned up temporary file
#
# ================================================================================
# APPROACH 12: Use xlwings to force calculation
# ================================================================================
# ⏳ Opening workbook with xlwings...
# ⏳ Reading K7 and L7 values...
# ✅ K7 value: 0.1 (type: <class 'float'>)
# ✅ L7 value: 1.203888888888889 (type: <class 'float'>)
#
# ================================================================================
# APPROACH 13: Read raw XML from Excel file
# ================================================================================
# ⏳ Opening Excel file as ZIP...
# ⏳ Searching for K7 and L7 cells in XML...
# ✅ K7 raw XML value: None
# ✅ L7 raw XML value: None
#
# ================================================================================
# APPROACH 14: Copy entire sheet with manual value extraction
# ================================================================================
# ⏳ Loading workbook...
# ⏳ Creating new workbook...
# ⏳ Copying all cell values (this may take a moment)...
#    Processing row 100...
#    Processing row 200...
#    Processing row 300...
#    Processing row 400...
#    Processing row 500...
#    Processing row 600...
#    Processing row 700...
#    Processing row 800...
#    Processing row 900...
#    Processing row 1000...
#    Processing row 1100...
#    Processing row 1200...
#    Processing row 1300...
#    Processing row 1400...
#    Processing row 1500...
#    Processing row 1600...
#    Processing row 1700...
#    Processing row 1800...
#    Processing row 1900...
#    Processing row 2000...
# ⏳ Saving copied workbook: price_export_generated_20251114_131558_temp_manual_copy.xlsx
# ⏳ Reloading copied workbook...
# ✅ K7 (row=7, col=11) value: None (type: <class 'NoneType'>)
#    K7 data_type: n
# ✅ L7 (row=7, col=12) value: None (type: <class 'NoneType'>)
#    L7 data_type: n
#
# ================================================================================
# APPROACH 5: Save and reload to force calculation
# ================================================================================
# ✅ Saved temporary file: price_export_generated_20251114_131558_temp_calculated.xlsx
# ✅ K7 value: None (type: <class 'NoneType'>)
# ✅ L7 value: None (type: <class 'NoneType'>)
# ✅ Cleaned up temporary file
#
# ================================================================================
# TESTING COMPLETE
# ================================================================================

# %%
# TEST READING K7 AND L7 - APPROACHES 11-15 (Copy/Paste Values)

import pandas as pd
import openpyxl
from openpyxl import load_workbook
from openpyxl.utils import get_column_letter
import os
import time
from copy import copy

# Load the Excel file
excel_file = "price_export_generated_20251114_153059.xlsx"
print(f"📂 Testing file: {excel_file}\n")

# ============================================================================
# APPROACH 11: Copy values only to new workbook
# ============================================================================
print("=" * 80)
print("APPROACH 11: Copy values only to new workbook")
print("=" * 80)
try:
    print("⏳ Loading workbook with data_only=True...")
    wb11a = load_workbook(excel_file, data_only=True)
    ws11a = wb11a.worksheets[0]
    
    print("⏳ Creating new workbook and copying values...")
    from openpyxl import Workbook
    wb11b = Workbook()
    ws11b = wb11b.active
    
    # Copy only values from the original sheet
    for row in ws11a.iter_rows():
        for cell in row:
            ws11b[cell.coordinate].value = cell.value
    
    temp_file = excel_file.replace('.xlsx', '_temp_values_only.xlsx')
    print(f"⏳ Saving values-only file: {temp_file}")
    wb11b.save(temp_file)
    wb11a.close()
    wb11b.close()
    
    print("⏳ Reloading values-only file...")
    wb11c = load_workbook(temp_file, data_only=True)
    ws11c = wb11c.worksheets[0]
    k7_val = ws11c['K7'].value
    l7_val = ws11c['L7'].value
    print(f"✅ K7 value: {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value: {l7_val} (type: {type(l7_val)})")
    wb11c.close()
    
    # Clean up
    if os.path.exists(temp_file):
        os.remove(temp_file)
        print(f"✅ Cleaned up temporary file")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 12: Use xlwings to force calculation (if available)
# ============================================================================
print("=" * 80)
print("APPROACH 12: Use xlwings to force calculation")
print("=" * 80)
try:
    import xlwings as xw
    print("⏳ Opening workbook with xlwings...")
    app = xw.App(visible=False)
    wb12 = xw.Book(excel_file)
    ws12 = wb12.sheets[0]
    
    print("⏳ Reading K7 and L7 values...")
    k7_val = ws12.range('K7').value
    l7_val = ws12.range('L7').value
    print(f"✅ K7 value: {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value: {l7_val} (type: {type(l7_val)})")
    
    wb12.close()
    app.quit()
except ImportError:
    print("⚠️ xlwings not installed - skipping this approach")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 13: Read raw XML from Excel file
# ============================================================================
print("=" * 80)
print("APPROACH 13: Read raw XML from Excel file")
print("=" * 80)
try:
    import zipfile
    import xml.etree.ElementTree as ET
    
    print("⏳ Opening Excel file as ZIP...")
    with zipfile.ZipFile(excel_file, 'r') as zip_ref:
        # Read the worksheet XML
        sheet_xml = zip_ref.read('xl/worksheets/sheet1.xml')
        root = ET.fromstring(sheet_xml)
        
        # Define namespace
        ns = {'main': 'http://schemas.openxmlformats.org/spreadsheetml/2006/main'}
        
        print("⏳ Searching for K7 and L7 cells in XML...")
        for cell in root.findall('.//main:c', ns):
            ref = cell.get('r')
            if ref in ['K7', 'L7']:
                value_elem = cell.find('main:v', ns)
                value = value_elem.text if value_elem is not None else None
                print(f"✅ {ref} raw XML value: {value}")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 14: Copy entire sheet to new workbook with paste special values
# ============================================================================
print("=" * 80)
print("APPROACH 14: Copy entire sheet with manual value extraction")
print("=" * 80)
try:
    print("⏳ Loading workbook...")
    wb14a = load_workbook(excel_file, data_only=True)
    ws14a = wb14a.worksheets[0]
    
    print("⏳ Creating new workbook...")
    from openpyxl import Workbook
    wb14b = Workbook()
    ws14b = wb14b.active
    
    print("⏳ Copying all cell values (this may take a moment)...")
    for row_idx, row in enumerate(ws14a.iter_rows(min_row=1, max_row=ws14a.max_row), 1):
        if row_idx % 100 == 0:
            print(f"   Processing row {row_idx}...")
        for col_idx, cell in enumerate(row, 1):
            # Only copy the value, not formulas or formatting
            new_cell = ws14b.cell(row=row_idx, column=col_idx)
            new_cell.value = cell.value
    
    temp_file = excel_file.replace('.xlsx', '_temp_manual_copy.xlsx')
    print(f"⏳ Saving copied workbook: {temp_file}")
    wb14b.save(temp_file)
    wb14a.close()
    wb14b.close()
    
    print("⏳ Reloading copied workbook...")
    wb14c = load_workbook(temp_file, data_only=True)
    ws14c = wb14c.worksheets[0]
    k7_val = ws14c['K7'].value
    l7_val = ws14c['L7'].value
    print(f"✅ K7 value: {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value: {l7_val} (type: {type(l7_val)})")
    wb14c.close()
    
    # Clean up
    if os.path.exists(temp_file):
        os.remove(temp_file)
        print(f"✅ Cleaned up temporary file")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

# ============================================================================
# APPROACH 15: Use pandas to read and write back as values
# ============================================================================
print("=" * 80)
print("APPROACH 15: Use pandas to read and write back as values")
print("=" * 80)
try:
    print("⏳ Reading Excel file with pandas...")
    # Read the entire sheet
    df15 = pd.read_excel(excel_file, sheet_name=0, header=None, engine='openpyxl')
    
    print(f"✅ DataFrame shape: {df15.shape}")
    print("⏳ Accessing K7 and L7 (row 6, columns 10 and 11)...")
    # K7 is row 6 (0-indexed), column 10 (K is the 11th column, 0-indexed = 10)
    # L7 is row 6 (0-indexed), column 11 (L is the 12th column, 0-indexed = 11)
    k7_val = df15.iloc[6, 10] if df15.shape[0] > 6 and df15.shape[1] > 10 else None
    l7_val = df15.iloc[6, 11] if df15.shape[0] > 6 and df15.shape[1] > 11 else None
    print(f"✅ K7 value (row 6, col 10): {k7_val} (type: {type(k7_val)})")
    print(f"✅ L7 value (row 6, col 11): {l7_val} (type: {type(l7_val)})")
    
    # Write back to new file
    temp_file = excel_file.replace('.xlsx', '_temp_pandas.xlsx')
    print(f"⏳ Writing to temporary file: {temp_file}")
    df15.to_excel(temp_file, index=False, header=False, engine='openpyxl')
    
    print("⏳ Reloading with openpyxl...")
    wb15 = load_workbook(temp_file, data_only=True)
    ws15 = wb15.worksheets[0]
    k7_val_reload = ws15['K7'].value
    l7_val_reload = ws15['L7'].value
    print(f"✅ K7 value (reloaded): {k7_val_reload} (type: {type(k7_val_reload)})")
    print(f"✅ L7 value (reloaded): {l7_val_reload} (type: {type(l7_val_reload)})")
    wb15.close()
    
    # Clean up
    if os.path.exists(temp_file):
        os.remove(temp_file)
        print(f"✅ Cleaned up temporary file")
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
print()

print("=" * 80)
print("TESTING COMPLETE (APPROACHES 11-15)")
print("=" * 80)
# Out:
# 📂 Testing file: price_export_generated_20251114_153059.xlsx
#
# ================================================================================
# APPROACH 11: Copy values only to new workbook
# ================================================================================
# ⏳ Loading workbook with data_only=True...
# ⏳ Creating new workbook and copying values...
# ⏳ Saving values-only file: price_export_generated_20251114_153059_temp_values_only.xlsx
# ⏳ Reloading values-only file...
# ✅ K7 value: None (type: <class 'NoneType'>)
# ✅ L7 value: None (type: <class 'NoneType'>)
# ✅ Cleaned up temporary file
#
# ================================================================================
# APPROACH 12: Use xlwings to force calculation
# ================================================================================
# ⏳ Opening workbook with xlwings...
# ⏳ Reading K7 and L7 values...
# ✅ K7 value: 0.1 (type: <class 'float'>)
# ✅ L7 value: 1.203888888888889 (type: <class 'float'>)
#
# ================================================================================
# APPROACH 13: Read raw XML from Excel file
# ================================================================================
# ⏳ Opening Excel file as ZIP...
# ⏳ Searching for K7 and L7 cells in XML...
# ✅ K7 raw XML value: None
# ✅ L7 raw XML value: None
#
# ================================================================================
# APPROACH 14: Copy entire sheet with manual value extraction
# ================================================================================
# ⏳ Loading workbook...
# ⏳ Creating new workbook...
# ⏳ Copying all cell values (this may take a moment)...
#    Processing row 100...
#    Processing row 200...
#    Processing row 300...
#    Processing row 400...
#    Processing row 500...
#    Processing row 600...
#    Processing row 700...
#    Processing row 800...
#    Processing row 900...
#    Processing row 1000...
#    Processing row 1100...
#    Processing row 1200...
#    Processing row 1300...
#    Processing row 1400...
#    Processing row 1500...
#    Processing row 1600...
#    Processing row 1700...
#    Processing row 1800...
#    Processing row 1900...
#    Processing row 2000...
# ⏳ Saving copied workbook: price_export_generated_20251114_153059_temp_manual_copy.xlsx
# ⏳ Reloading copied workbook...
# ✅ K7 value: None (type: <class 'NoneType'>)
# ✅ L7 value: None (type: <class 'NoneType'>)
# ✅ Cleaned up temporary file
#
# ================================================================================
# APPROACH 15: Use pandas to read and write back as values
# ================================================================================
# ⏳ Reading Excel file with pandas...
# ✅ DataFrame shape: (1899, 182)
# ⏳ Accessing K7 and L7 (row 6, columns 10 and 11)...
# ✅ K7 value (row 6, col 10): nan (type: <class 'float'>)
# ✅ L7 value (row 6, col 11): nan (type: <class 'float'>)
# ⏳ Writing to temporary file: price_export_generated_20251114_153059_temp_pandas.xlsx
# ⏳ Reloading with openpyxl...
# ✅ K7 value (reloaded): None (type: <class 'NoneType'>)
# ✅ L7 value (reloaded): None (type: <class 'NoneType'>)
# ✅ Cleaned up temporary file
#
# ================================================================================
# TESTING COMPLETE (APPROACHES 11-15)
# ================================================================================

# %%
excel_file = "price_export_generated_20251114_153059.xlsx"

# Save the Excel file as CSV
print("=" * 80)
print("SAVING EXCEL FILE AS CSV (WITH FORMULA EVALUATION)")
print("=" * 80)
try:
    print(f"⏳ Reading Excel file: {excel_file}")
    
    import pandas as pd
    import openpyxl
    import time
    
    csv_file = excel_file.replace('.xlsx', '.csv')
    
    print("⏳ Converting Excel to CSV using openpyxl and pandas...")
    
    # Load workbook with data_only=True to get calculated values instead of formulas
    print("⏳ Loading workbook (this may take a moment)...")
    wb = openpyxl.load_workbook(excel_file, data_only=True)
    ws = wb.active
    
    print(f"✅ Workbook loaded. Active sheet: {ws.title}")
    print(f"📊 Sheet dimensions: {ws.max_row} rows x {ws.max_column} columns")
    
    # Wait 10 seconds to ensure formulas are fully calculated
    print("⏳ Waiting 10 seconds to ensure all formulas are fully loaded and calculated...")
    time.sleep(30)
    print("✅ Wait complete. Proceeding with data extraction...")
    
    # Extract all data as values
    print("⏳ Extracting data from cells...")
    data = []
    for idx, row in enumerate(ws.iter_rows(values_only=True), 1):
        data.append(row)
        if idx % 100 == 0:
            print(f"   Processed {idx} rows...")
    
    print(f"✅ Extracted {len(data)} rows of data")
    
    wb.close()
    
    # Create DataFrame from the extracted values
    print("⏳ Creating DataFrame...")
    df = pd.DataFrame(data)
    
    # Print sample values to verify data extraction
    print("\n📋 Sample values from DataFrame:")
    print(f"   Shape: {df.shape}")
    if df.shape[0] > 6 and df.shape[1] > 11:
        print(f"   K7 (row 6, col 10): {df.iloc[6, 10]}")
        print(f"   L7 (row 6, col 11): {df.iloc[6, 11]}")
    
    # Save to CSV
    print(f"\n⏳ Saving to CSV: {csv_file}")
    df.to_csv(csv_file, index=False, header=False)
    
    print(f"✅ Successfully saved to {csv_file}")
    
    # Read the CSV to get row/column count
    df_check = pd.read_csv(csv_file, header=None)
    print(f"📊 CSV contains {len(df_check)} rows and {len(df_check.columns)} columns")
    
except Exception as e:
    print(f"❌ Error saving to CSV: {e}")
    import traceback
    traceback.print_exc()
print()
# Out:
# ================================================================================
# SAVING EXCEL FILE AS CSV (WITH FORMULA EVALUATION)
# ================================================================================
# ⏳ Reading Excel file: price_export_generated_20251114_153059.xlsx
# ⏳ Converting Excel to CSV using openpyxl and pandas...
# ⏳ Loading workbook (this may take a moment)...
# ✅ Workbook loaded. Active sheet: Products Prices
# 📊 Sheet dimensions: 2001 rows x 182 columns
# ⏳ Waiting 10 seconds to ensure all formulas are fully loaded and calculated...
# ✅ Wait complete. Proceeding with data extraction...
# ⏳ Extracting data from cells...
#    Processed 100 rows...
#    Processed 200 rows...
#    Processed 300 rows...
#    Processed 400 rows...
#    Processed 500 rows...
#    Processed 600 rows...
#    Processed 700 rows...
#    Processed 800 rows...
#    Processed 900 rows...
#    Processed 1000 rows...
#    Processed 1100 rows...
#    Processed 1200 rows...
#    Processed 1300 rows...
#    Processed 1400 rows...
#    Processed 1500 rows...
#    Processed 1600 rows...
#    Processed 1700 rows...
#    Processed 1800 rows...
#    Processed 1900 rows...
#    Processed 2000 rows...
# ✅ Extracted 2001 rows of data
# ⏳ Creating DataFrame...
#
# 📋 Sample values from DataFrame:
#    Shape: (2001, 182)
#    K7 (row 6, col 10): None
#    L7 (row 6, col 11): None
#
# ⏳ Saving to CSV: price_export_generated_20251114_153059.csv
# ✅ Successfully saved to price_export_generated_20251114_153059.csv
# 📊 CSV contains 2001 rows and 182 columns

# %%
excel_file = "price_export_generated_20251114_153059.xlsx"

# Save the Excel file as CSV
print("=" * 80)
print("SAVING EXCEL FILE AS CSV (WITH FORMULA EVALUATION)")
print("=" * 80)
try:
    print(f"⏳ Reading Excel file: {excel_file}")
    
    from xlsx2csv import Xlsx2csv
    from io import StringIO
    
    csv_file = excel_file.replace('.xlsx', '.csv')
    
    print("⏳ Converting Excel to CSV using xlsx2csv...")
    
    # Use xlsx2csv to convert Excel to CSV
    # This library reads calculated values from Excel files
    print("⏳ Processing Excel file...")
    Xlsx2csv(excel_file, outputencoding="utf-8").convert(csv_file)
    
    print(f"✅ Successfully saved to {csv_file}")
    
    # Read the CSV to get row/column count and verify
    import pandas as pd
    df_check = pd.read_csv(csv_file, header=None)
    print(f"📊 CSV contains {len(df_check)} rows and {len(df_check.columns)} columns")
    
    # Print sample values to verify data extraction
    print("\n📋 Sample values from CSV:")
    print(f"   Shape: {df_check.shape}")
    if df_check.shape[0] > 6 and df_check.shape[1] > 11:
        print(f"   K7 (row 6, col 10): {df_check.iloc[6, 10]}")
        print(f"   L7 (row 6, col 11): {df_check.iloc[6, 11]}")
    
except Exception as e:
    print(f"❌ Error saving to CSV: {e}")
    import traceback
    traceback.print_exc()
print()
# Out:
# ================================================================================
# SAVING EXCEL FILE AS CSV (WITH FORMULA EVALUATION)
# ================================================================================
# ⏳ Reading Excel file: price_export_generated_20251114_153059.xlsx
# ⏳ Converting Excel to CSV using xlsx2csv...
# ⏳ Processing Excel file...
# ✅ Successfully saved to price_export_generated_20251114_153059.csv
# 📊 CSV contains 2001 rows and 182 columns
#
# 📋 Sample values from CSV:
#    Shape: (2001, 182)
#    K7 (row 6, col 10): nan
#    L7 (row 6, col 11): nan

# %%
# CLEAN CHATTER FROM x_configuration RECORD ID 1
# CAUTION !!! Are you sure you want to delete this ? 

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo with allow_none=True to handle None values
common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)

# Configuration record ID
config_id = 1

print(f"🧹 Cleaning chatter from x_configuration record ID {config_id}...")

# Search for all messages related to this record
message_ids = models.execute_kw(
    JUSTFRAMEIT_ODOO_DB,
    uid,
    JUSTFRAMEIT_ODOO_API_KEY,
    'mail.message',
    'search',
    [[
        ('model', '=', 'x_configuration'),
        ('res_id', '=', config_id)
    ]]
)

print(f"📧 Found {len(message_ids)} messages in chatter")

if message_ids:
    # Delete all messages
    models.execute_kw(
        JUSTFRAMEIT_ODOO_DB,
        uid,
        JUSTFRAMEIT_ODOO_API_KEY,
        'mail.message',
        'unlink',
        [message_ids]
    )
    print(f"✅ Successfully deleted {len(message_ids)} messages from chatter")
else:
    print("ℹ️ No messages found in chatter")
# Out:
# 🧹 Cleaning chatter from x_configuration record ID 1...
# 📧 Found 3 messages in chatter
# ✅ Successfully deleted 3 messages from chatter

# %%
# FETCH ALL ROUTE INFORMATION FOR PRODUCT.TEMPLATE ID 14918

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo with allow_none=True to handle None values
common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)

product_id = 14918

print(f"🔍 Fetching route_ids information for product.template ID {product_id}...")

# Read the product template with route_ids field
product_data = models.execute_kw(
    JUSTFRAMEIT_ODOO_DB,
    uid,
    JUSTFRAMEIT_ODOO_API_KEY,
    'product.template',
    'read',
    [[product_id]],
    {'fields': ['name', 'route_ids']}
)

if product_data:
    product = product_data[0]
    print(f"\n📦 Product: {product.get('name')}")
    print(f"🛣️ Route IDs: {product.get('route_ids')}")
    
    route_ids = product.get('route_ids', [])
    
    if route_ids:
        print(f"\n📋 Found {len(route_ids)} route(s). Fetching details...\n")
        
        # Fetch all route details
        routes = models.execute_kw(
            JUSTFRAMEIT_ODOO_DB,
            uid,
            JUSTFRAMEIT_ODOO_API_KEY,
            'stock.route',
            'read',
            [route_ids]
        )
        
        for route in routes:
            print(f"{'='*80}")
            print(f"Route ID: {route.get('id')}")
            print(f"Name: {route.get('name')}")
            print(f"\nAll fields:")
            for key, value in sorted(route.items()):
                print(f"  {key}: {value}")
            print()
    else:
        print("\nℹ️ No routes assigned to this product")
else:
    print(f"❌ Product with ID {product_id} not found")
# Out:
# 🔍 Fetching route_ids information for product.template ID 14918...
#
# 📦 Product: Finished Product 20251202_160336
# 🛣️ Route IDs: [1, 6, 4]
#
# 📋 Found 3 route(s). Fetching details...
#
# ================================================================================
# Route ID: 1
# Name: Replenish on Order (MTO)
#
# All fields:
#   active: True
#   categ_ids: []
#   company_id: False
#   create_date: 2025-08-27 17:32:28
#   create_uid: [1, 'OdooBot']
#   display_name: Replenish on Order (MTO)
#   id: 1
#   name: Replenish on Order (MTO)
#   package_type_selectable: False
#   product_categ_selectable: True
#   product_ids: [14912, 14918]
#   product_selectable: True
#   rule_ids: [3, 5]
#   sale_selectable: True
#   sequence: 5
#   shipping_selectable: False
#   supplied_wh_id: False
#   supplier_wh_id: False
#   warehouse_domain_ids: [1]
#   warehouse_ids: []
#   warehouse_selectable: False
#   write_date: 2025-11-28 11:50:31
#   write_uid: [2, 'louisdresse@gmail.com']
#
# ================================================================================
# Route ID: 6
# Name: Buy
#
# All fields:
#   active: True
#   categ_ids: []
#   company_id: False
#   create_date: 2025-09-01 09:44:15
#   create_uid: [1, 'OdooBot']
#   display_name: Buy
#   id: 6
#   name: Buy
#   package_type_selectable: False
#   product_categ_selectable: False
#   product_ids: [9896, 9897, 9898, 9899, 9900, 9901, 9902, 9903, 9904, 9905, 9906, 9907, 9908, 9909, 9910, 9911, 9912, 9913, 9914, 9915, 9916, 9917, 9918, 9919, 9920, 9921, 9922, 9923, 9924, 9925, 9926, 9927, 9928, 9929, 9930, 9931, 9932, 9933, 9934, 9935, 9936, 9937, 9938, 9939, 9940, 9941, 9942, 9943, 9944, 9945, 9946, 9947, 9948, 9949, 9950, 9951, 9952, 9953, 9954, 9955, 9956, 9957, 9958, 9959, 9960, 9961, 9962, 9963, 9964, 9965, 9966, 9967, 9968, 9969, 9970, 9971, 9972, 9973, 9974, 9975, 9976, 9977, 9978, 9979, 9980, 9981, 9982, 9983, 9984, 9985, 9986, 9987, 9988, 9989, 9990, 9991, 9992, 9993, 9994, 9995, 9996, 9997, 9998, 9999, 10000, 10001, 10002, 10003, 10005, 10004, 10006, 10007, 10008, 10009, 10010, 10011, 10012, 10013, 10014, 10015, 10016, 10017, 10018, 10019, 10020, 10021, 10022, 10023, 10024, 10025, 10026, 10027, 10028, 10029, 10030, 10031, 10032, 10033, 10034, 10035, 10036, 10037, 10038, 10039, 10040, 10041, 10042, 10043, 10044, 10045, 10046, 10047, 10048, 10049, 10050, 10051, 10052, 10053, 10054, 10055, 10056, 10057, 10058, 10059, 10060, 10061, 10062, 10063, 10064, 10065, 10066, 10067, 10068, 10069, 10070, 10071, 10072, 10073, 10074, 10075, 10076, 10077, 10078, 10079, 10080, 10081, 10082, 10083, 10084, 10085, 10086, 10087, 10088, 10089, 10090, 10091, 10092, 10093, 10094, 10095, 10096, 10097, 10098, 10099, 10100, 10101, 10102, 10103, 10104, 10106, 10105, 10107, 10108, 10109, 10110, 10111, 10112, 10113, 10114, 10115, 10116, 10117, 10118, 10119, 10120, 10121, 10122, 10123, 10124, 10125, 10126, 10127, 10128, 10129, 10130, 10131, 10132, 10133, 10134, 10135, 10136, 10137, 10138, 10139, 10140, 10141, 10142, 10143, 10144, 10145, 10146, 10147, 10148, 10149, 10150, 10151, 10152, 10153, 10154, 10155, 10156, 10157, 10158, 10159, 10160, 10161, 10162, 10163, 10164, 10165, 10166, 10167, 10168, 10169, 10170, 10171, 10172, 10173, 10174, 10175, 10176, 10177, 10178, 10179, 10180, 10181, 10182, 10183, 10184, 10185, 10186, 10187, 10188, 10189, 10190, 10191, 10192, 10193, 10194, 10195, 10196, 10197, 10198, 10199, 10200, 10201, 10202, 10203, 10204, 10205, 10206, 10207, 10208, 10209, 10210, 10211, 10212, 10213, 10214, 10215, 10216, 10217, 10218, 10219, 10220, 10221, 10222, 10223, 10224, 10225, 10226, 10227, 10228, 10229, 10230, 10231, 10232, 10233, 10234, 10235, 10236, 10237, 10238, 10239, 10240, 10241, 10242, 10243, 10244, 10245, 10246, 10247, 10248, 10249, 10250, 10251, 10252, 10253, 10254, 10255, 10256, 10257, 10258, 10259, 10260, 10261, 10262, 10263, 10264, 10265, 10266, 10267, 10268, 10269, 10270, 10271, 10272, 10273, 10274, 10275, 10276, 10277, 10278, 10279, 10280, 10281, 10282, 10283, 10284, 10285, 10286, 10287, 10288, 10289, 10290, 10291, 10292, 10293, 10294, 10295, 10296, 10297, 10298, 10299, 10300, 10301, 10302, 10303, 10304, 10305, 10306, 10307, 10308, 10309, 10310, 10311, 10312, 10313, 10314, 10315, 10316, 10317, 10318, 10319, 10320, 10321, 10322, 10323, 10324, 10325, 10326, 10327, 10328, 10330, 10329, 10331, 10332, 10333, 10334, 10335, 10336, 10337, 10338, 10339, 10340, 10341, 10342, 10343, 10344, 10345, 10346, 10347, 10348, 10350, 10349, 10351, 10352, 10353, 10354, 10355, 10356, 10357, 10358, 10359, 10360, 10361, 10362, 10363, 10364, 10365, 10368, 10367, 10366, 10369, 10371, 10370, 10372, 10373, 10377, 10374, 10375, 10376, 10380, 10378, 10379, 10381, 10384, 10382, 10383, 10385, 10386, 10387, 10388, 10389, 10390, 10391, 10392, 10393, 10394, 10395, 10396, 10397, 10398, 10399, 10401, 10400, 10402, 10403, 10404, 10405, 10406, 10407, 10408, 10409, 10410, 10411, 10412, 10413, 10414, 10415, 10416, 10417, 10418, 10419, 10420, 10421, 10422, 10423, 10424, 10425, 13250, 10426, 10427, 10428, 10429, 10430, 10431, 10432, 10433, 10434, 10435, 10436, 10437, 10438, 10439, 10440, 10441, 10442, 10443, 10444, 10445, 10447, 10446, 10448, 10449, 10450, 10451, 10452, 10453, 10454, 10455, 10456, 10457, 10458, 10459, 10460, 10461, 10462, 10463, 10464, 10465, 10466, 10467, 10468, 10469, 10470, 10471, 10472, 10473, 10474, 10475, 10476, 10477, 10478,  ...
#   product_selectable: True
#   rule_ids: [7]
#   sale_selectable: False
#   sequence: 5
#   shipping_selectable: False
#   supplied_wh_id: False
#   supplier_wh_id: False
#   warehouse_domain_ids: [1]
#   warehouse_ids: []
#   warehouse_selectable: False
#   write_date: 2025-09-01 09:44:15
#   write_uid: [1, 'OdooBot']
#
# ================================================================================
# Route ID: 4
# Name: Manufacture
#
# All fields:
#   active: True
#   categ_ids: []
#   company_id: False
#   create_date: 2025-08-27 17:32:28
#   create_uid: [1, 'OdooBot']
#   display_name: Manufacture
#   id: 4
#   name: Manufacture
#   package_type_selectable: False
#   product_categ_selectable: False
#   product_ids: [14912, 14918]
#   product_selectable: True
#   rule_ids: [4]
#   sale_selectable: False
#   sequence: 10
#   shipping_selectable: False
#   supplied_wh_id: False
#   supplier_wh_id: False
#   warehouse_domain_ids: [1]
#   warehouse_ids: []
#   warehouse_selectable: False
#   write_date: 2025-08-27 17:32:28
#   write_uid: [1, 'OdooBot']

# %%
import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo with allow_none=True to handle None values
common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)

# %%
import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo with allow_none=True to handle None values
common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)

# Fetch all order lines for sale orders 211 and 212
sale_order_ids = [211, 212]

for sale_order_id in sale_order_ids:
    # Get the sale order to retrieve order line IDs
    sale_order = models.execute_kw(
        JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'sale.order', 'read',
        [sale_order_id],
        {'fields': ['order_line']}
    )

    if sale_order:
        order_line_ids = sale_order[0].get('order_line', [])
        print(f"📋 Sale Order {sale_order_id} has {len(order_line_ids)} order line(s)")
        print(f"Order Line IDs: {order_line_ids}\n")
        
        if order_line_ids:
            # Fetch all order lines with all their fields
            order_lines = models.execute_kw(
                JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
                'sale.order.line', 'read',
                [order_line_ids]
            )
            
            # Display each order line
            for idx, line in enumerate(order_lines, 1):
                print(f"{'='*80}")
                print(f"📦 Order Line {idx} (ID: {line.get('id')})")
                print(f"{'='*80}")
                print(f"\nAll fields:")
                for key, value in sorted(line.items()):
                    print(f"  {key}: {value}")
                print()
        else:
            print("ℹ️ No order lines found for this sale order")
        
        print(f"\n{'#'*80}\n")
    else:
        print(f"❌ Sale Order with ID {sale_order_id} not found\n")
# Out:
# 📋 Sale Order 211 has 1 order line(s)
# Order Line IDs: [242]
#
# ================================================================================
# 📦 Order Line 1 (ID: 242)
# ================================================================================
#
# All fields:
#   allowed_uom_ids: [1]
#   amount_invoiced: 0.0
#   amount_to_invoice: 0.0
#   analytic_distribution: False
#   analytic_line_ids: []
#   analytic_precision: 2
#   available_product_document_ids: []
#   calendar_booking_ids: []
#   calendar_event_id: False
#   combo_item_id: False
#   company_id: [1, 'The Frame Company']
#   company_price_include: tax_excluded
#   create_date: 2025-12-18 09:36:16
#   create_uid: [2, 'louisdresse@gmail.com']
#   currency_id: [125, 'EUR']
#   customer_lead: 7.0
#   discount: 0.0
#   display_name: S00211 - Kader op maat (Mat glas) (Louis Test)
#   display_qty_widget: False
#   display_type: False
#   distribution_analytic_account_ids: []
#   extra_tax_data: False
#   forecast_expected_date: False
#   free_qty_today: 0.0
#   id: 242
#   invoice_lines: []
#   invoice_status: to invoice
#   is_configurable_product: True
#   is_delivery: False
#   is_downpayment: False
#   is_expense: False
#   is_mto: False
#   is_product_archived: False
#   is_service: False
#   is_storable: False
#   linked_line_id: False
#   linked_line_ids: []
#   linked_virtual_id: False
#   move_ids: [58]
#   name: Kader op maat (Mat glas)
#   name_short: Kader op maat (Mat glas)
#   order_id: [211, 'S00211']
#   order_partner_id: [8, 'Louis Test']
#   planning_hours_planned: 0.0
#   planning_hours_to_plan: 1.0
#   planning_slot_ids: []
#   price_reduce_taxexcl: 0.0
#   price_reduce_taxinc: 0.0
#   price_subtotal: 0.0
#   price_tax: 0.0
#   price_total: 0.0
#   price_unit: 0.0
#   pricelist_item_id: [5, 'All Products']
#   product_add_mode: configurator
#   product_custom_attribute_value_ids: []
#   product_document_ids: []
#   product_id: [15062, 'Kader op maat (Mat glas)']
#   product_no_variant_attribute_value_ids: []
#   product_qty: 1.0
#   product_template_attribute_value_ids: [42]
#   product_template_id: [12060, 'Kader op maat']
#   product_type: consu
#   product_uom_id: [1, 'Units']
#   product_uom_qty: 1.0
#   product_uom_readonly: True
#   product_updatable: False
#   project_id: False
#   purchase_line_count: 0
#   purchase_line_ids: []
#   qty_available_today: 0.0
#   qty_delivered: 0.0
#   qty_delivered_method: stock_move
#   qty_invoiced: 0.0
#   qty_invoiced_posted: 0.0
#   qty_to_deliver: 1.0
#   qty_to_invoice: 1.0
#   reached_milestones_ids: []
#   recompute_delivery_price: False
#   route_ids: []
#   sale_line_warn_msg:
#   sale_order_option_ids: []
#   salesman_id: [2, 'louisdresse@gmail.com']
#   scheduled_date: False
#   selected_combo_items: False
#   sequence: 10
#   service_tracking: no
#   shop_warning: False
#   state: sale
#   task_id: False
#   tax_calculation_rounding_method: round_per_line
#   tax_country_id: [20, 'Belgium']
#   tax_ids: [5]
#   technical_price_unit: 0.0
#   translated_product_name: Kader op maat (Mat glas)
#   untaxed_amount_invoiced: 0.0
#   untaxed_amount_to_invoice: 0.0
#   virtual_available_at_date: 0.0
#   virtual_id: False
#   warehouse_id: [1, 'JUSTFRAMEIT']
#   write_date: 2025-12-18 09:36:16
#   write_uid: [2, 'louisdresse@gmail.com']
#   x_studio_height: 60.0
#   x_studio_width: 40.0
#
#
# ################################################################################
#
# 📋 Sale Order 212 has 1 order line(s)
# Order Line IDs: [243]
#
# ================================================================================
# 📦 Order Line 1 (ID: 243)
# ================================================================================
#
# All fields:
#   allowed_uom_ids: [1]
#   amount_invoiced: 0.0
#   amount_to_invoice: 0.0
#   analytic_distribution: False
#   analytic_line_ids: []
#   analytic_precision: 2
#   available_product_document_ids: []
#   calendar_booking_ids: []
#   calendar_event_id: False
#   combo_item_id: False
#   company_id: [1, 'The Frame Company']
#   company_price_include: tax_excluded
#   create_date: 2025-12-18 11:20:51
#   create_uid: [2, 'louisdresse@gmail.com']
#   currency_id: [125, 'EUR']
#   customer_lead: 0.0
#   discount: 0.0
#   display_name: S00212 - Template A (Louis Test)
#   display_qty_widget: True
#   display_type: False
#   distribution_analytic_account_ids: []
#   extra_tax_data: False
#   forecast_expected_date: False
#   free_qty_today: 0.0
#   id: 243
#   invoice_lines: []
#   invoice_status: no
#   is_configurable_product: False
#   is_delivery: False
#   is_downpayment: False
#   is_expense: False
#   is_mto: False
#   is_product_archived: False
#   is_service: False
#   is_storable: True
#   linked_line_id: False
#   linked_line_ids: []
#   linked_virtual_id: False
#   move_ids: []
#   name: Template A
#   name_short: Template A
#   order_id: [212, 'S00212']
#   order_partner_id: [8, 'Louis Test']
#   planning_hours_planned: 0.0
#   planning_hours_to_plan: 0.0
#   planning_slot_ids: []
#   price_reduce_taxexcl: 0.0
#   price_reduce_taxinc: 0.0
#   price_subtotal: 0.0
#   price_tax: 0.0
#   price_total: 0.0
#   price_unit: 0.0
#   pricelist_item_id: [5, 'All Products']
#   product_add_mode: configurator
#   product_custom_attribute_value_ids: []
#   product_document_ids: []
#   product_id: [44, 'Template A']
#   product_no_variant_attribute_value_ids: []
#   product_qty: 1.0
#   product_template_attribute_value_ids: []
#   product_template_id: [44, 'Template A']
#   product_type: consu
#   product_uom_id: [1, 'Units']
#   product_uom_qty: 1.0
#   product_uom_readonly: False
#   product_updatable: True
#   project_id: False
#   purchase_line_count: 0
#   purchase_line_ids: []
#   qty_available_today: 0.0
#   qty_delivered: 0.0
#   qty_delivered_method: stock_move
#   qty_invoiced: 0.0
#   qty_invoiced_posted: 0.0
#   qty_to_deliver: 1.0
#   qty_to_invoice: 0.0
#   reached_milestones_ids: []
#   recompute_delivery_price: False
#   route_ids: []
#   sale_line_warn_msg:
#   sale_order_option_ids: []
#   salesman_id: [2, 'louisdresse@gmail.com']
#   scheduled_date: 2025-12-18 11:21:41
#   selected_combo_items: False
#   sequence: 10
#   service_tracking: no
#   shop_warning: False
#   state: draft
#   task_id: False
#   tax_calculation_rounding_method: round_per_line
#   tax_country_id: [20, 'Belgium']
#   tax_ids: [5]
#   technical_price_unit: 0.0
#   translated_product_name: Template A
#   untaxed_amount_invoiced: 0.0
#   untaxed_amount_to_invoice: 0.0
#   virtual_available_at_date: -1.0
#   virtual_id: False
#   warehouse_id: [1, 'JUSTFRAMEIT']
#   write_date: 2025-12-18 11:20:51
#   write_uid: [2, 'louisdresse@gmail.com']
#   x_studio_height: 100.0
#   x_studio_width: 100.0
#
#
# ################################################################################

# %%
import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Connect to Odoo with allow_none=True to handle None values
common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
uid = common.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})

if not uid:
    raise Exception("❌ Failed to authenticate to Odoo. Please check credentials.")

models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)

# Fetch all BOMs for product 12060
product_id = 12060
print(f"🔍 Searching for BOMs for product ID: {product_id}\n")

# Search for BOMs associated with this product
bom_ids = models.execute_kw(
    JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
    'mrp.bom', 'search',
    [[['product_tmpl_id', '=', product_id]]]
)

if bom_ids:
    print(f"📋 Found {len(bom_ids)} BOM(s) for product {product_id}")
    print(f"BOM IDs: {bom_ids}\n")
    
    # Fetch the 'code' field for all found BOMs
    bom_data = models.execute_kw(
        JUSTFRAMEIT_ODOO_DB, uid, JUSTFRAMEIT_ODOO_API_KEY,
        'mrp.bom', 'read',
        [bom_ids],
        {'fields': ['code']}
    )
    
    # Display the code values
    for bom in bom_data:
        print(f"{'='*80}")
        print(f"📦 BOM ID: {bom.get('id')}")
        print(f"{'='*80}")
        print(f"Code: {bom.get('code')}")
        print()
else:
    print(f"❌ No BOMs found for product ID {product_id}")
# Out:
# 🔍 Searching for BOMs for product ID: 12060
#
# 📋 Found 8 BOM(s) for product 12060
# BOM IDs: [585, 586, 587, 588, 589, 590, 591, 592]
#
# ================================================================================
# 📦 BOM ID: 585
# ================================================================================
# Code: Kader op maat (Blinkend glas)
#
# ================================================================================
# 📦 BOM ID: 586
# ================================================================================
# Code: Kader op maat (Geen glas)
#
# ================================================================================
# 📦 BOM ID: 587
# ================================================================================
# Code: Kader op maat (Blinkend plexi glas)
#
# ================================================================================
# 📦 BOM ID: 588
# ================================================================================
# Code: Kader op maat (Artglass AR99)
#
# ================================================================================
# 📦 BOM ID: 589
# ================================================================================
# Code: Kader op maat (Mat plexi glas)
#
# ================================================================================
# 📦 BOM ID: 590
# ================================================================================
# Code: Kader op maat (Artglass AR70)
#
# ================================================================================
# 📦 BOM ID: 591
# ================================================================================
# Code: Kader op maat (Artglass AR92)
#
# ================================================================================
# 📦 BOM ID: 592
# ================================================================================
# Code: Kader op maat (Mat glas)
