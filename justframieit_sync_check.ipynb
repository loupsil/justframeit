# %%
# Fetch all product categories ID, display name, and number of products for each

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables
JUSTFRAMEIT_ODOO_V14_URL = os.getenv('JUSTFRAMEIT_ODOO_V14_URL')
JUSTFRAMEIT_ODOO_V14_DB = os.getenv('JUSTFRAMEIT_ODOO_V14_DB')
JUSTFRAMEIT_ODOO_V14_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_V14_USERNAME')
JUSTFRAMEIT_ODOO_V14_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_V14_API_KEY')

print("=" * 80)
print("Fetching Product Categories from Odoo V14")
print("=" * 80)

try:
    # Authenticate
    common = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/common", allow_none=True)
    uid = common.authenticate(JUSTFRAMEIT_ODOO_V14_DB, JUSTFRAMEIT_ODOO_V14_USERNAME, JUSTFRAMEIT_ODOO_V14_API_KEY, {})
    print(f"✅ Authenticated! UID: {uid}\n")
    
    # Create models proxy
    models = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/object", allow_none=True)
    
    # Fetch all product categories
    category_ids = models.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.category', 'search', [[]])
    
    # Read category details
    categories = models.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.category', 'read', [category_ids], {'fields': ['id', 'display_name']})
    
    print(f"Found {len(categories)} product categories:\n")
    
    # For each category, count the number of products
    for category in categories:
        # Count products in this category
        product_count = models.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid, JUSTFRAMEIT_ODOO_V14_API_KEY,
            'product.template', 'search_count', [[['categ_id', '=', category['id']]]])
        
        print(f"ID: {category['id']:4d} | Name: {category['display_name']:50s} | Products: {product_count:4d}")
    
except Exception as e:
    print(f"❌ Failed: {e}")

print("\n" + "=" * 80)
print("Category fetch complete!")
print("=" * 80)
# Out:
# ================================================================================
# Fetching Product Categories from Odoo V14
# ================================================================================
# ✅ Authenticated! UID: 28
#
# Found 54 product categories:
#
# ID:   62 | Name: 0. Custom                                          | Products:    0
# ID:    1 | Name: 0. Presets                                         | Products: 1972
# ID:    4 | Name: 0. Presets / 1. Presets zonder PP                  | Products:   13
# ID:    8 | Name: 0. Presets / 2. Presets met PP                     | Products:    6
# ID:   10 | Name: 0. Presets / 3. Losse verkopen                     | Products:    7
# ID:   34 | Name: 0. Presets / 4. Diensten                           | Products:    0
# ID:   57 | Name: 0. Presets / 4. Losse PP                           | Products:    1
# ID:   78 | Name: 0. Presets / Expenses                              | Products:    0
# ID:   82 | Name: 0. Presets / Fixed margin                          | Products:    1
# ID:   77 | Name: 0. Presets / Saleable                              | Products:    0
# ID:   76 | Name: 0. Presets Craft PP                                | Products:    0
# ID:   36 | Name: 04. Askaders                                       | Products:   10
# ID:   37 | Name: 1. Lijsten                                         | Products: 1683
# ID:   38 | Name: 2. Glas                                            | Products:   10
# ID:   39 | Name: 3. Passe-partout                                   | Products:  167
# ID:   40 | Name: 4. Ruggen                                          | Products:    2
# ID:   41 | Name: 41. Standaardruggen                                | Products:   11
# ID:   42 | Name: 5. Prefab kaders                                   | Products: 1247
# ID:   43 | Name: 6. Diensten                                        | Products:    1
# ID:   44 | Name: 7. Printen                                         | Products:   12
# ID:   45 | Name: 8. Kleven                                          | Products:    0
# ID:   79 | Name: 8. Spiegels                                        | Products:    0
# ID:   80 | Name: 89. Crate m2                                       | Products:    2
# ID:   81 | Name: 89. Crate omtrek                                   | Products:    1
# ID:   83 | Name: 89. Crate opstart                                  | Products:    1
# ID:   46 | Name: 9. Verzending                                      | Products:    1
# ID:   47 | Name: 91. Verpakking                                     | Products:    3
# ID:   63 | Name: 91A. Verpakkingsdozen                              | Products:   15
# ID:   48 | Name: 92. Interne productie diensten                     | Products:    7
# ID:   49 | Name: 93. Andere producten                               | Products:    6
# ID:   50 | Name: 94. Ophangsystemen                                 | Products:    3
# ID:   51 | Name: 95. Inlijstmaterialen                              | Products:    0
# ID:   52 | Name: 96. Asbuisjes                                      | Products:    1
# ID:   53 | Name: 97. Spieraam lijsten                               | Products:   12
# ID:   60 | Name: 98. Fome boarden                                   | Products:    4
# ID:   61 | Name: 99. Platen                                         | Products:   19
# ID:   71 | Name: Cadeaubon                                          | Products:    5
# ID:   84 | Name: Fotobox                                            | Products:    4
# ID:   73 | Name: Intern kleven                                      | Products:    2
# ID:   54 | Name: Interne productie posten                           | Products:    7
# ID:   59 | Name: Kaders op maat                                     | Products:    0
# ID:   72 | Name: Kleven                                             | Products:    2
# ID:   55 | Name: NTB                                                | Products:    8
# ID:   75 | Name: TestPRESET element                                 | Products:    0
# ID:   64 | Name: Toebehoren                                         | Products:    0
# ID:   70 | Name: Toebehoren / Econospacers                          | Products:    3
# ID:   66 | Name: Toebehoren / Handgereedschap klein materiaal       | Products:   17
# ID:   67 | Name: Toebehoren / LINECO                                | Products:    4
# ID:   65 | Name: Toebehoren / Ophangingen aan de lijst              | Products:   15
# ID:   68 | Name: Toebehoren / TESA                                  | Products:   17
# ID:   69 | Name: Toebehoren / Verpakken en beschermen               | Products:    3
# ID:   58 | Name: Vaste prijs producten                              | Products:   12
# ID:   56 | Name: X. Archived products                               | Products:    1
# ID:   74 | Name: print                                              | Products:    0
#
# ================================================================================
# Category fetch complete!
# ================================================================================

# %%
# Compare BOMs between Odoo V14 and V18 to find mismatches

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables for V14
JUSTFRAMEIT_ODOO_V14_URL = os.getenv('JUSTFRAMEIT_ODOO_V14_URL')
JUSTFRAMEIT_ODOO_V14_DB = os.getenv('JUSTFRAMEIT_ODOO_V14_DB')
JUSTFRAMEIT_ODOO_V14_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_V14_USERNAME')
JUSTFRAMEIT_ODOO_V14_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_V14_API_KEY')

# Get environment variables for V18
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

print("=" * 80)
print("Comparing BOMs between Odoo V14 and V18")
print("=" * 80)

try:
    # Authenticate to V14
    print("\n[V14] Authenticating...")
    common_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/common", allow_none=True)
    uid_v14 = common_v14.authenticate(JUSTFRAMEIT_ODOO_V14_DB, JUSTFRAMEIT_ODOO_V14_USERNAME, JUSTFRAMEIT_ODOO_V14_API_KEY, {})
    print(f"✅ V14 Authenticated! UID: {uid_v14}")
    
    # Authenticate to V18
    print("\n[V18] Authenticating...")
    common_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
    uid_v18 = common_v18.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
    print(f"✅ V18 Authenticated! UID: {uid_v18}\n")
    
    # Create models proxies
    models_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/object", allow_none=True)
    models_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)
    
    # Define specific category IDs to check
    target_category_ids = [4, 8, 10, 57, 82]
    #target_category_ids = [10] #for testing
    
    print(f"Checking specific categories: {target_category_ids}\n")
    
    # Get category details from V14 (single call)
    categories = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.category', 'read',
        [target_category_ids],
        {'fields': ['display_name']})
    
    print("Categories to check:")
    for cat in categories:
        print(f"  - Category ID {cat['id']}: {cat['display_name']}")
    print()
    
    # Get all product templates in these categories from V14 (single call)
    print("[V14] Fetching product templates in these categories...")
    product_template_ids = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'search',
        [[['categ_id', 'in', target_category_ids]]])
    
    print(f"Found {len(product_template_ids)} product templates\n")
    
    # Search for BOMs with is_custom_made = False in V14 (single call)
    print("[V14] Searching for BOMs with is_custom_made = False...")
    print("=" * 80)
    
    bom_ids_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'mrp.bom', 'search',
        [[['product_tmpl_id', 'in', product_template_ids], ['is_custom_made', '=', False]]])
    
    print(f"\n[V14] Found {len(bom_ids_v14)} BOMs with is_custom_made = False\n")
    
    if not bom_ids_v14:
        print("No BOMs found with is_custom_made = False in V14")
    else:
        # Get ALL BOM details from V14 in a single call
        boms_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
            'mrp.bom', 'read',
            [bom_ids_v14],
            {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'is_custom_made', 'bom_line_ids']})
        
        # Get ALL BOM lines from V14 in a single call
        all_bom_line_ids_v14 = []
        for bom in boms_v14:
            if bom['bom_line_ids']:
                all_bom_line_ids_v14.extend(bom['bom_line_ids'])
        
        bom_lines_v14_dict = {}
        if all_bom_line_ids_v14:
            all_bom_lines_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'mrp.bom.line', 'read',
                [all_bom_line_ids_v14],
                {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
            
            # Get all product IDs from BOM lines to fetch product codes
            product_ids_v14 = [line['product_id'][0] for line in all_bom_lines_v14 if line['product_id']]
            
            # Fetch product codes for all products in V14
            products_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.product', 'read',
                [product_ids_v14],
                {'fields': ['id', 'product_code']})
            
            # Create a mapping of product_id to product_code
            product_code_map_v14 = {p['id']: p['product_code'] for p in products_v14}
            
            # Organize by bom_id for easy lookup
            for line in all_bom_lines_v14:
                bom_id = line['bom_id'][0] if line['bom_id'] else None
                if bom_id not in bom_lines_v14_dict:
                    bom_lines_v14_dict[bom_id] = []
                # Add product_code to the line data
                product_id = line['product_id'][0] if line['product_id'] else None
                line['product_code'] = product_code_map_v14.get(product_id, 'N/A')
                bom_lines_v14_dict[bom_id].append(line)
        
        # Collect all BOM codes to search in V18
        bom_codes_v14 = [bom['code'] for bom in boms_v14 if bom['code']]
        
        # Search for ALL corresponding BOMs in V18 in a single call
        bom_ids_v18 = []
        if bom_codes_v14:
            bom_ids_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'search',
                [[['code', 'in', bom_codes_v14]]])
        
        # Get ALL BOM details from V18 in a single call
        boms_v18_dict = {}
        if bom_ids_v18:
            boms_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'read',
                [bom_ids_v18],
                {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'bom_line_ids']})
            
            # Organize by code for easy lookup
            for bom in boms_v18:
                if bom['code']:
                    boms_v18_dict[bom['code']] = bom
            
            # Get ALL BOM lines from V18 in a single call
            all_bom_line_ids_v18 = []
            for bom in boms_v18:
                if bom['bom_line_ids']:
                    all_bom_line_ids_v18.extend(bom['bom_line_ids'])
            
            bom_lines_v18_dict = {}
            if all_bom_line_ids_v18:
                all_bom_lines_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'mrp.bom.line', 'read',
                    [all_bom_line_ids_v18],
                    {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
                
                # Get all product IDs from BOM lines to fetch product codes
                product_ids_v18 = [line['product_id'][0] for line in all_bom_lines_v18 if line['product_id']]
                
                # Fetch product codes for all products in V18
                products_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'product.product', 'read',
                    [product_ids_v18],
                    {'fields': ['id', 'x_studio_product_code']})
                
                # Create a mapping of product_id to x_studio_product_code
                product_code_map_v18 = {p['id']: p['x_studio_product_code'] for p in products_v18}
                
                # Organize by bom_id for easy lookup
                for line in all_bom_lines_v18:
                    bom_id = line['bom_id'][0] if line['bom_id'] else None
                    if bom_id not in bom_lines_v18_dict:
                        bom_lines_v18_dict[bom_id] = []
                    # Add product_code to the line data
                    product_id = line['product_id'][0] if line['product_id'] else None
                    line['product_code'] = product_code_map_v18.get(product_id, 'N/A')
                    bom_lines_v18_dict[bom_id].append(line)
        
        print("Comparing BOMs between V14 and V18:")
        print("-" * 80)
        
        mismatches_found = 0
        
        for bom_v14 in boms_v14:
            product_tmpl_name = bom_v14['product_tmpl_id'][1] if bom_v14['product_tmpl_id'] else 'N/A'
            product_variant_name = bom_v14['product_id'][1] if bom_v14['product_id'] else 'N/A (Template BOM)'
            bom_reference = bom_v14['code'] if bom_v14['code'] else 'No reference'
            bom_display_name = bom_v14['display_name'] if bom_v14['display_name'] else 'No display name'
            
            print(f"\n{'=' * 80}")
            print(f"BOM ID (V14): {bom_v14['id']}")
            print(f"  Reference: {bom_reference}")
            print(f"  Display Name: {bom_display_name}")
            print(f"  Product Template: {product_tmpl_name}")
            print(f"  Product Variant: {product_variant_name}")
            print(f"  is_custom_made (V14): {bom_v14['is_custom_made']}")
            
            # Get BOM line components from V14 (from pre-fetched data)
            components_v14 = {}
            bom_lines = bom_lines_v14_dict.get(bom_v14['id'], [])
            
            if bom_lines:
                print(f"\n  [V14] Components ({len(bom_lines)} items):")
                for line in bom_lines:
                    component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                    component_code = line['product_code']
                    component_qty = line['product_qty']
                    components_v14[component_code] = {'name': component_name, 'qty': component_qty}
                    print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
            else:
                print(f"\n  [V14] Components: None")
            
            # Find corresponding BOM in V18 (from pre-fetched data)
            print(f"\n  [V18] Searching for corresponding BOM by matching BOM reference (code)...")
            
            if not bom_reference or bom_reference == 'No reference':
                print(f"  ❌ NO BOM REFERENCE (CODE) IN V14 - CANNOT MATCH!")
                mismatches_found += 1
                continue
            
            print(f"     BOM reference (V14): {bom_reference}")
            
            bom_v18 = boms_v18_dict.get(bom_reference)
            
            if not bom_v18:
                print(f"  ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: '{bom_reference}')!")
                mismatches_found += 1
                continue
            
            print(f"  ✅ Found corresponding BOM in V18 (ID: {bom_v18['id']}, Code: '{bom_v18['code']}')")
            
            # Get BOM line components from V18 (from pre-fetched data)
            components_v18 = {}
            bom_lines_v18 = bom_lines_v18_dict.get(bom_v18['id'], [])
            
            if bom_lines_v18:
                print(f"\n  [V18] Components ({len(bom_lines_v18)} items):")
                for line in bom_lines_v18:
                    component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                    component_code = line['product_code']
                    component_qty = line['product_qty']
                    components_v18[component_code] = {'name': component_name, 'qty': component_qty}
                    print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
            else:
                print(f"\n  [V18] Components: None")
            
            # Compare components
            print(f"\n  🔍 COMPARISON RESULTS:")
            has_mismatch = False
            
            # Check for missing components in V18
            for component_code, component_data in components_v14.items():
                if component_code not in components_v18:
                    print(f"    ❌ MISSING IN V18: {component_data['name']} (Code: {component_code}, Qty in V14: {component_data['qty']})")
                    has_mismatch = True
                elif components_v18[component_code]['qty'] != component_data['qty']:
                    print(f"    ⚠️  QUANTITY MISMATCH: {component_data['name']} (Code: {component_code})")
                    print(f"       V14 Qty: {component_data['qty']}")
                    print(f"       V18 Qty: {components_v18[component_code]['qty']}")
                    has_mismatch = True
            
            # Check for extra components in V18
            for component_code, component_data in components_v18.items():
                if component_code not in components_v14:
                    print(f"    ➕ EXTRA IN V18: {component_data['name']} (Code: {component_code}, Qty: {component_data['qty']})")
                    has_mismatch = True
            
            if not has_mismatch:
                print(f"    ✅ All components match!")
            else:
                mismatches_found += 1
    
    print("\n" + "=" * 80)
    print(f"BOM comparison complete!")
    print(f"Total BOMs checked: {len(bom_ids_v14) if bom_ids_v14 else 0}")
    print(f"BOMs with mismatches: {mismatches_found}")
    print("=" * 80)
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ================================================================================
# Comparing BOMs between Odoo V14 and V18
# ================================================================================
#
# [V14] Authenticating...
# ✅ V14 Authenticated! UID: 28
#
# [V18] Authenticating...
# ✅ V18 Authenticated! UID: 2
#
# Checking specific categories: [4, 8, 10, 57, 82]
#
# Categories to check:
#   - Category ID 4: 0. Presets / 1. Presets zonder PP
#   - Category ID 8: 0. Presets / 2. Presets met PP
#   - Category ID 10: 0. Presets / 3. Losse verkopen
#   - Category ID 57: 0. Presets / 4. Losse PP
#   - Category ID 82: 0. Presets / Fixed margin
#
# [V14] Fetching product templates in these categories...
# Found 28 product templates
#
# [V14] Searching for BOMs with is_custom_made = False...
# ================================================================================
#
# [V14] Found 249 BOMs with is_custom_made = False
#
# Comparing BOMs between V14 and V18:
# --------------------------------------------------------------------------------
#
# ================================================================================
# BOM ID (V14): 53
#   Reference: Los glas (Blinked plexi glas 2mm)
#   Display Name: Los glas (Blinked plexi glas 2mm): Los glas
#   Product Template: Los glas
#   Product Variant: Los glas (Blinked plexi glas 2mm)
#   is_custom_made (V14): False
#
#   [V14] Components (4 items):
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Los glas (Blinked plexi glas 2mm)
#   ✅ Found corresponding BOM in V18 (ID: 746, Code: 'Los glas (Blinked plexi glas 2mm)')
#
#   [V18] Components (3 items):
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT Verpakking (Code: MDF3MM, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT Verpakking (Code: MDF3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#
# ================================================================================
# BOM ID (V14): 39
#   Reference: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, A)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)')!
#
# ================================================================================
# BOM ID (V14): 62
#   Reference: Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat))
#   Display Name: Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat)): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat))
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat))
#   ✅ Found corresponding BOM in V18 (ID: 721, Code: 'Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat))')
#
#   [V18] Components (6 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 4106
#   Reference: Puzzel + Kader custom (XXL)
#   Display Name: Puzzel + Kader custom (XXL): Puzzel + Kader custom
#   Product Template: Puzzel + Kader custom
#   Product Variant: Puzzel + Kader custom (XXL)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond3mm.x] Dibond 2mm (kopie) (Code: Dibond3mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Puzzel + Kader custom (XXL)
#   ✅ Found corresponding BOM in V18 (ID: 593, Code: 'Puzzel + Kader custom (XXL)')
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [Dibond3mmx] Dibond 2mm (kopie) (Code: Dibond3mm, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 124
#   Reference: Kader + Print (Mat glas, Etch (Fine Art Mat))
#   Display Name: Kader + Print (Mat glas, Etch (Fine Art Mat)): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, Etch (Fine Art Mat))
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print (Mat glas, Etch (Fine Art Mat))
#   ✅ Found corresponding BOM in V18 (ID: 667, Code: 'Kader + Print (Mat glas, Etch (Fine Art Mat))')
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [BARYTTE.PRINT] Barytte (Fine Art) (Code: BARYTTE, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MG.GLAS] Mat glas (Code: MG., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     ➕ EXTRA IN V18: [BARYTTE.PRINT] Barytte (Fine Art) (Code: BARYTTE, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6565
#   Reference: Kader + FM + Print (Mat glas, 3mm)
#   Display Name: Kader + FM + Print (Mat glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Print (Mat glas, 3mm)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + FM + Print (Mat glas, 3mm)')!
#
# ================================================================================
# BOM ID (V14): 6541
#   Reference: Kader + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print + Inlijsting (Mat glas, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + Print + Inlijsting (Mat glas, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6547
#   Reference: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat pl, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6549
#   Reference: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR70, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6552
#   Reference: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Mat glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6560
#   Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   ✅ Found corresponding BOM in V18 (ID: 227, Code: 'Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)')
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6545
#   Reference: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6548
#   Reference: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend plexi glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6550
#   Reference: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR92, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6553
#   Reference: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6556
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Artglass AR70, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6561
#   Reference: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR70, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   ✅ Found corresponding BOM in V18 (ID: 228, Code: 'Kader + FM + Inlijsting (Artglass AR70, 3mm)')
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6566
#   Reference: Kader + FM + Print (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Blinkend glas, 3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Print (Blinkend glas, 3mm)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + FM + Print (Blinkend glas, 3mm)')!
#
# ================================================================================
# BOM ID (V14): 6551
#   Reference: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR99, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6554
#   Reference: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Mat pl, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6559
#   Reference: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   ✅ Found corresponding BOM in V18 (ID: 213, Code: 'Kader + FM + Inlijsting (Blinkend glas, 3mm)')
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6563
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   ✅ Found corresponding BOM in V18 (ID: 214, Code: 'Kader + FM + Inlijsting (Artglass AR99, 3mm)')
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6568
#   Reference: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend plexi glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Print (Blinkend plexi glas, 3mm)
#   ✅ Found corresponding BOM in V18 (ID: 544, Code: 'Kader + FM + Print (Blinkend plexi glas, 3mm)')
#
#   [V18] Components (7 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 2.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6555
#   Reference: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6562
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   ✅ Found corresponding BOM in V18 (ID: 215, Code: 'Kader + FM + Inlijsting (Artglass AR92, 3mm)')
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6564
#   Reference: Kader + FM + Inlijsting (Geen glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Geen glas, 3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Inlijsting (Geen glas, 3mm)
#   ✅ Found corresponding BOM in V18 (ID: 216, Code: 'Kader + FM + Inlijsting (Geen glas, 3mm)')
#
#   [V18] Components (4 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6569
#   Reference: Kader + FM + Print (Artglass AR70, 3mm)
#   Display Name: Kader + FM + Print (Artglass AR70, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Artglass AR70, 3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Print (Artglass AR70, 3mm)
#   ✅ Found corresponding BOM in V18 (ID: 545, Code: 'Kader + FM + Print (Artglass AR70, 3mm)')
#
#   [V18] Components (7 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 2.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6557
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Artglass AR92, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre)')!
#
# ================================================================================
# BOM ID (V14): 6570
#   Reference: Kader + FM + Print (Artglass AR92, 3mm)
#   Display Name: Kader + FM + Print (Artglass AR92, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Artglass AR92, 3mm)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Print (Artglass AR92, 3mm)
#   ✅ Found corresponding BOM in V18 (ID: 546, Code: 'Kader + FM + Print (Artglass AR92, 3mm)')
#
#   [V18] Components (7 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 2.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6558
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR99, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Artglass AR99, Matt Fibre)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
# ...
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print (Mat plexi glas, Barytte (Fine Art))
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + Print (Mat plexi glas, Barytte (Fine Art))')!
#
# ================================================================================
# BOM ID (V14): 242
#   Reference: Los Dozen (40x40)
#   Display Name: Los Dozen (40x40): Los Dozen
#   Product Template: Los Dozen
#   Product Variant: [LD.X] Los Dozen (40x40)
#   is_custom_made (V14): False
#
#   [V14] Components (2 items):
#     - [DOOS4040.BOX] DOOS 40X40 CM (Code: DOOS4040, Qty: 1.0)
#     - [PK4040.BOX] Plooikost doos 40x40 (Code: PK4040, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Los Dozen (40x40)
#   ✅ Found corresponding BOM in V18 (ID: 734, Code: 'Los Dozen (40x40)')
#
#   [V18] Components (1 items):
#     - [DOOS4040.BOX] DOOS 40X40 CM (Code: DOOS4040, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [PK4040.BOX] Plooikost doos 40x40 (Code: PK4040, Qty in V14: 1.0)
#
# ================================================================================
# BOM ID (V14): 6140
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   ✅ Found corresponding BOM in V18 (ID: 230, Code: 'Kader + FM + Inlijsting (Artglass AR99, 2mm)')
#
#   [V18] Components (6 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2Econospacer Transparant 3,2mm] Econospacer Transparant (Code: ECOST2, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 146
#   Reference: Kader + PP (Artglass AR70)
#   Display Name: Kader + PP (Artglass AR70): Kader op maat + PP
#   Product Template: Kader op maat + PP
#   Product Variant: Kader op maat + PP (Artglass AR70)
#   is_custom_made (V14): False
#
#   [V14] Components (5 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [GSRM918.C7] Very White              (Code: GSRM918, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + PP (Artglass AR70)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + PP (Artglass AR70)')!
#
# ================================================================================
# BOM ID (V14): 121
#   Reference: Kader + Print (Mat glas, Semi Matte Epson)
#   Display Name: Kader + Print (Mat glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, A)
#   is_custom_made (V14): False
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print (Mat glas, Semi Matte Epson)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + Print (Mat glas, Semi Matte Epson)')!
#
# ================================================================================
# BOM ID (V14): 4105
#   Reference: Puzzel + Kader custom (Normaal)
#   Display Name: Puzzel + Kader custom (Normaal): Puzzel + Kader custom
#   Product Template: Puzzel + Kader custom
#   Product Variant: [P109P] Puzzel + Kader custom (Normaal)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond2mm.X] Forex Wit 10mm (kopie) (Code: Dibond2mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Puzzel + Kader custom (Normaal)
#   ✅ Found corresponding BOM in V18 (ID: 594, Code: 'Puzzel + Kader custom (Normaal)')
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [Dibond2mm.X] Forex Wit 10mm (kopie) (Code: Dibond2mm, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6139
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   ✅ Found corresponding BOM in V18 (ID: 236, Code: 'Kader + FM + Inlijsting (Artglass AR92, 2mm)')
#
#   [V18] Components (6 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2Econospacer Transparant 3,2mm] Econospacer Transparant (Code: ECOST2, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 199
#   Reference: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   Display Name: [KOF5MM.diensten] Kleven op Fomeboard (5mm): Kleven op Fomeboard
#   Product Template: Kleven op Fomeboard
#   Product Variant: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   is_custom_made (V14): False
#
#   [V14] Components (2 items):
#     - [SK5MM.X] Schuimkarton 5mm (Code: SK5MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: '[KOF5MM.diensten] Kleven op Fomeboard (5mm)')!
#
# ================================================================================
# BOM ID (V14): 6138
#   Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 2mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend plexi glas, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend plexi glas, 2mm)
#   is_custom_made (V14): False
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Inlijsting (Blinkend plexi glas, 2mm)
#   ✅ Found corresponding BOM in V18 (ID: 229, Code: 'Kader + FM + Inlijsting (Blinkend plexi glas, 2mm)')
#
#   [V18] Components (6 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2Econospacer Transparant 3,2mm] Econospacer Transparant (Code: ECOST2, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 157
#   Reference: Kader + Print (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Kader + Print (Blinkend plexi glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend plexi glas, A)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + Print (Blinkend plexi glas, Semi Matte Epson)
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: 'Kader + Print (Blinkend plexi glas, Semi Matte Epson)')!
#
# ================================================================================
# BOM ID (V14): 6141
#   Reference: Kader + FM + Inlijsting (Geen glas, 2mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Geen glas, 2mm)
#   is_custom_made (V14): False
#
#   [V14] Components (9 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM by matching BOM reference (code)...
#      BOM reference (V14): Kader + FM + Inlijsting (Geen glas, 2mm)
#   ✅ Found corresponding BOM in V18 (ID: 231, Code: 'Kader + FM + Inlijsting (Geen glas, 2mm)')
#
#   [V18] Components (5 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2Econospacer Transparant 3,2mm] Econospacer Transparant (Code: ECOST2, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM comparison complete!
# Total BOMs checked: 249
# BOMs with mismatches: 243
# ================================================================================

# %%
# Compare material_cost (V14) vs x_studio_computed_cost (V18) for product templates

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables for V14
JUSTFRAMEIT_ODOO_V14_URL = os.getenv('JUSTFRAMEIT_ODOO_V14_URL')
JUSTFRAMEIT_ODOO_V14_DB = os.getenv('JUSTFRAMEIT_ODOO_V14_DB')
JUSTFRAMEIT_ODOO_V14_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_V14_USERNAME')
JUSTFRAMEIT_ODOO_V14_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_V14_API_KEY')

# Get environment variables for V18
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

print("=" * 80)
print("Comparing material_cost (V14) vs x_studio_computed_cost (V18) for Product Templates")
print("=" * 80)

try:
    # Authenticate to V14
    print("\n[V14] Authenticating...")
    common_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/common", allow_none=True)
    uid_v14 = common_v14.authenticate(JUSTFRAMEIT_ODOO_V14_DB, JUSTFRAMEIT_ODOO_V14_USERNAME, JUSTFRAMEIT_ODOO_V14_API_KEY, {})
    print(f"✅ V14 Authenticated! UID: {uid_v14}")
    
    # Authenticate to V18
    print("\n[V18] Authenticating...")
    common_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
    uid_v18 = common_v18.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
    print(f"✅ V18 Authenticated! UID: {uid_v18}\n")
    
    # Create models proxies
    models_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/object", allow_none=True)
    models_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)
    
    # Define category IDs to EXCLUDE
    excluded_category_ids = [1, 4, 8, 10, 57, 82]
    
    print(f"Excluding categories: {excluded_category_ids}\n")
    
    # Get category details from V14
    categories = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.category', 'read',
        [excluded_category_ids],
        {'fields': ['display_name']})
    
    print("Categories to exclude:")
    for cat in categories:
        print(f"  - Category ID {cat['id']}: {cat['display_name']}")
    print()
    
    # Get all product templates from V14 excluding the specified categories
    print("[V14] Fetching product templates (excluding specified categories)...")
    template_ids_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'search',
        [[['categ_id', 'not in', excluded_category_ids]]])
    
    print(f"Found {len(template_ids_v14)} product templates in V14\n")
    
    # Get product template details from V14
    print("[V14] Reading product template details (id, product_code, material_cost, categ_id)...")
    templates_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'read',
        [template_ids_v14],
        {'fields': ['id', 'default_code', 'product_code', 'name', 'material_cost', 'categ_id']})
    
    print(f"Retrieved details for {len(templates_v14)} product templates\n")
    
    # Get all product codes from V14 (excluding None values)
    product_codes_v14 = [t['product_code'] for t in templates_v14 if t.get('product_code')]
    
    print(f"Found {len(product_codes_v14)} product templates with product_code in V14\n")
    
    # Fetch ALL matching product templates from V18 in ONE API call using product codes
    print("[V18] Fetching all matching product templates by x_studio_product_code in one call...")
    template_ids_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
        'product.template', 'search',
        [[['x_studio_product_code', 'in', product_codes_v14]]])
    
    print(f"Found {len(template_ids_v18)} matching product templates in V18\n")
    
    # Get all V18 product template details in ONE API call
    print("[V18] Reading all product template details in one call...")
    templates_v18_list = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
        'product.template', 'read',
        [template_ids_v18],
        {'fields': ['id', 'default_code', 'x_studio_product_code', 'name', 'x_studio_computed_cost']})
    
    # Create a dictionary for quick lookup by x_studio_product_code
    templates_v18_dict = {t['x_studio_product_code']: t for t in templates_v18_list if t.get('x_studio_product_code')}
    
    print(f"Retrieved details for {len(templates_v18_list)} product templates from V18\n")
    
    print("Comparing costs between V14 and V18:")
    print("-" * 80)
    
    mismatches_found = 0
    matches_found = 0
    templates_checked = 0
    templates_not_found_in_v18 = 0
    templates_without_product_code = 0
    
    for template_v14 in templates_v14:
        template_id = template_v14['id']
        template_code = template_v14['default_code']
        product_code_v14 = template_v14.get('product_code')
        template_name = template_v14['name']
        material_cost_v14 = template_v14['material_cost'] if template_v14['material_cost'] else 0.0
        category_name = template_v14['categ_id'][1] if template_v14['categ_id'] else 'N/A'
        
        # Skip if no product_code in V14
        if not product_code_v14:
            templates_without_product_code += 1
            continue
        
        templates_checked += 1
        
        # Look up product template in V18 dictionary by product_code
        template_v18 = templates_v18_dict.get(product_code_v14)
        
        if not template_v18:
            print(f"\n❌ Product Template NOT FOUND in V18:")
            print(f"   ID (V14): {template_id}")
            print(f"   Code: {template_code}")
            print(f"   product_code (V14): {product_code_v14}")
            print(f"   Name: {template_name}")
            print(f"   Category: {category_name}")
            print(f"   material_cost (V14): €{material_cost_v14:.2f}")
            templates_not_found_in_v18 += 1
            continue
        
        computed_cost_v18 = template_v18['x_studio_computed_cost'] if template_v18['x_studio_computed_cost'] else 0.0
        
        # Compare costs (with small tolerance for floating point comparison)
        tolerance = 0.01
        if abs(material_cost_v14 - computed_cost_v18) > tolerance:
            print(f"\n⚠️  COST MISMATCH:")
            print(f"   ID (V14): {template_id}")
            print(f"   ID (V18): {template_v18['id']}")
            print(f"   Code: {template_code}")
            print(f"   product_code (V14): {product_code_v14}")
            print(f"   x_studio_product_code (V18): {template_v18['x_studio_product_code']}")
            print(f"   Name (V14): {template_name}")
            print(f"   Name (V18): {template_v18['name']}")
            print(f"   Category: {category_name}")
            print(f"   material_cost (V14): €{material_cost_v14:.2f}")
            print(f"   x_studio_computed_cost (V18): €{computed_cost_v18:.2f}")
            print(f"   Difference: €{abs(material_cost_v14 - computed_cost_v18):.2f}")
            mismatches_found += 1
        else:
            matches_found += 1
    
    print("\n" + "=" * 80)
    print(f"Cost comparison complete!")
    print(f"Total product templates in V14 (excluding categories): {len(templates_v14)}")
    print(f"Product templates without product_code (skipped): {templates_without_product_code}")
    print(f"Product templates checked: {templates_checked}")
    print(f"Product templates not found in V18: {templates_not_found_in_v18}")
    print(f"Product templates with cost matches: {matches_found}")
    print(f"Product templates with cost mismatches: {mismatches_found}")
    print("=" * 80)
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ================================================================================
# Comparing material_cost (V14) vs x_studio_computed_cost (V18) for Product Templates
# ================================================================================
#
# [V14] Authenticating...
# ✅ V14 Authenticated! UID: 28
#
# [V18] Authenticating...
# ✅ V18 Authenticated! UID: 2
#
# Excluding categories: [1, 4, 8, 10, 57, 82]
#
# Categories to exclude:
#   - Category ID 1: 0. Presets
#   - Category ID 4: 0. Presets / 1. Presets zonder PP
#   - Category ID 8: 0. Presets / 2. Presets met PP
#   - Category ID 10: 0. Presets / 3. Losse verkopen
#   - Category ID 57: 0. Presets / 4. Losse PP
#   - Category ID 82: 0. Presets / Fixed margin
#
# [V14] Fetching product templates (excluding specified categories)...
# Found 3318 product templates in V14
#
# [V14] Reading product template details (id, product_code, material_cost, categ_id)...
# Retrieved details for 3318 product templates
#
# Found 3292 product templates with product_code in V14
#
# [V18] Fetching all matching product templates by x_studio_product_code in one call...
# Found 3234 matching product templates in V18
#
# [V18] Reading all product template details in one call...
# Retrieved details for 3234 product templates from V18
#
# Comparing costs between V14 and V18:
# --------------------------------------------------------------------------------
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4278
#    ID (V18): 9942
#    Code: 74980.X
#    product_code (V14): 74980
#    x_studio_product_code (V18): 74980
#    Name (V14): "Charles V" Spaanse Barok Goud
#    Name (V18): "Charles V" Spaanse Barok Goud
#    Category: 1. Lijsten
#    material_cost (V14): €38.16
#    x_studio_computed_cost (V18): €81.45
#    Difference: €43.29
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4507
#    ID (V18): 9944
#    Code: 81045.F20
#    product_code (V14): 81045
#    x_studio_product_code (V18): 81045
#    Name (V14): "Chique" Barok Grijs Geborsteld 5Cm
#    Name (V18): "Chique" Barok Grijs Geborsteld 5Cm
#    Category: 1. Lijsten
#    material_cost (V14): €28.42
#    x_studio_computed_cost (V18): €17.80
#    Difference: €10.62
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4506
#    ID (V18): 9945
#    Code: 81030.F20
#    product_code (V14): 81030
#    x_studio_product_code (V18): 81030
#    Name (V14): "Chique" Barok Groen Geborsteld 5Cm
#    Name (V18): "Chique" Barok Groen Geborsteld 5Cm
#    Category: 1. Lijsten
#    material_cost (V14): €28.42
#    x_studio_computed_cost (V18): €17.80
#    Difference: €10.62
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4503
#    ID (V18): 9946
#    Code: 80917.F19
#    product_code (V14): 80917
#    x_studio_product_code (V18): 80917
#    Name (V14): "Chique" Barok Ivoor Geborsteld 2,5Cm
#    Name (V18): "Chique" Barok Ivoor Geborsteld 2,5Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €6.67
#    Difference: €17.69
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4505
#    ID (V18): 9947
#    Code: 81017.F20
#    product_code (V14): 81017
#    x_studio_product_code (V18): 81017
#    Name (V14): "Chique" Barok Ivoor Geborsteld 5Cm
#    Name (V18): "Chique" Barok Ivoor Geborsteld 5Cm
#    Category: 1. Lijsten
#    material_cost (V14): €28.42
#    x_studio_computed_cost (V18): €17.80
#    Difference: €10.62
#
# ⚠️  COST MISMATCH:
#    ID (V14): 3806
#    ID (V18): 9950
#    Code: 80910.F19
#    product_code (V14): 80910
#    x_studio_product_code (V18): 80910
#    Name (V14): "Chique" Barok Zwart Geborsteld 2,5Cm
#    Name (V18): "Chique" Barok Zwart Geborsteld 2,5Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €6.67
#    Difference: €17.69
#
# ⚠️  COST MISMATCH:
#    ID (V14): 17023
#    ID (V18): 10011
#    Code: 71510.C17
#    product_code (V14): 71510
#    x_studio_product_code (V18): 71510
#    Name (V14): "GLOSS" BAKLIJST LAK WIT 50x40 (kopie)
#    Name (V18): "Gloss" Baklijst Lak Zwart K1155
#    Category: 1. Lijsten
#    material_cost (V14): €14.13
#    x_studio_computed_cost (V18): €13.25
#    Difference: €0.88
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16155
#    ID (V18): 11277
#    Code: 79810.X
#    product_code (V14): 79810
#    x_studio_product_code (V18): 79810
#    Name (V14): "LIME" BAKLIJST LINDE BLANK MET GOUDEN TOP 30x30 (kopie)
#    Name (V18): 79810.C1 Baklijst Noir30x30
#    Category: 1. Lijsten
#    material_cost (V14): €9.64
#    x_studio_computed_cost (V18): €17.05
#    Difference: €7.41
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4446
#    ID (V18): 10036
#    Code: 85275.E23
#    product_code (V14): 85275
#    x_studio_product_code (V18): 85275
#    Name (V14): "Minimal" Eik
#    Name (V18): "Minimal" Eik
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €4.78
#    Difference: €18.77
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4447
#    ID (V18): 10037
#    Code: 85278.E23
#    product_code (V14): 85278
#    x_studio_product_code (V18): 85278
#    Name (V14): "Minimal" Kers
#    Name (V18): "Minimal" Kers
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €4.78
#    Difference: €18.77
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4443
#    ID (V18): 10038
#    Code: 85236.E23
#    product_code (V14): 85236
#    x_studio_product_code (V18): 85236
#    Name (V14): "Minimal" Noten
#    Name (V18): "Minimal" Noten
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €4.78
#    Difference: €18.77
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4040
#    ID (V18): 10041
#    Code: 85203.E23
#    product_code (V14): 85203
#    x_studio_product_code (V18): 85203
#    Name (V14): "Minimal" Wit
#    Name (V18): "Minimal" Wit
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €4.78
#    Difference: €18.77
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4834
#    ID (V18): 10062
#    Code: 68217.N23
#    product_code (V14): 68217
#    x_studio_product_code (V18): 68217
#    Name (V14): "Pinus" Grenen Creme 2,5 Cm
#    Name (V18): "Pinus" Grenen Creme 2,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €2.85
#    Difference: €21.51
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4835
#    ID (V18): 10064
#    Code: 68247.N23
#    product_code (V14): 68247
#    x_studio_product_code (V18): 68247
#    Name (V14): "Pinus" Grenen Lichtgrijs 2,5 Cm
#    Name (V18): "Pinus" Grenen Lichtgrijs 2,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €2.85
#    Difference: €21.51
#
# ⚠️  COST MISMATCH:
#    ID (V14): 5207
#    ID (V18): 10083
#    Code: 73220.X
#    product_code (V14): 73220
#    x_studio_product_code (V18): 73220
#    Name (V14): "Riviera" Schelp Pastelblauw
#    Name (V18): "Riviera" Schelp Pastelblauw
#    Category: 1. Lijsten
#    material_cost (V14): €24.20
#    x_studio_computed_cost (V18): €4.29
#    Difference: €19.91
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4187
#    ID (V18): 10084
#    Code: 73215.X
#    product_code (V14): 73215
#    x_studio_product_code (V18): 73215
#    Name (V14): "Riviera" Schelp Wit
#    Name (V18): "Riviera" Schelp Wit
#    Category: 1. Lijsten
#    material_cost (V14): €24.20
#    x_studio_computed_cost (V18): €4.01
#    Difference: €20.19
#
# ⚠️  COST MISMATCH:
#    ID (V14): 3796
#    ID (V18): 10085
#    Code: 73210.E09
#    product_code (V14): 73210
#    x_studio_product_code (V18): 73210
#    Name (V14): "Riviera" Schelp Zwart
#    Name (V18): "Riviera" Schelp Zwart
#    Category: 1. Lijsten
#    material_cost (V14): €24.20
#    x_studio_computed_cost (V18): €3.97
#    Difference: €20.23
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4666
#    ID (V18): 12445
#    Code: 68867.X
#    product_code (V14): 68867
#    x_studio_product_code (V18): 68867
#    Name (V14): "Solid Wood" Amerikaanse Baklijst Eik K1090
#    Name (V18): Solid Wood Baklijst Eik 50x40
#    Category: 1. Lijsten
#    material_cost (V14): €26.68
#    x_studio_computed_cost (V18): €27.87
#    Difference: €1.19
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4914
#    ID (V18): 13545
#    Code: 53224.R16
#    product_code (V14): 53224
#    x_studio_product_code (V18): 53224
#    Name (V14): ''Lino,, Gestreept Bruin 2 Cm
#    Name (V18): accent by nielsen aluminum picture frame Accent, 13x18 cm, Frosted Silver
#    Category: 1. Lijsten
#    material_cost (V14): €3.57
#    x_studio_computed_cost (V18): €0.00
#    Difference: €3.57
#
# ⚠️  COST MISMATCH:
#    ID (V14): 3911
#    ID (V18): 13547
#    Code: 53221.R14
#    product_code (V14): 53221
#    x_studio_product_code (V18): 53221
#    Name (V14): ''Lino,, Gestreept Zwart 2 Cm
#    Name (V18): accent by nielsen aluminum picture frame Accent, 13x18 cm, Gold
#    Category: 1. Lijsten
#    material_cost (V14): €3.57
#    x_studio_computed_cost (V18): €0.00
#    Difference: €3.57
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17516
#    Code: 401.83.103.C39
#    product_code (V14): 401.83.103
#    Name: 'Mid Stairs' Ayous naturel 39x30 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €3.51
#
# ⚠️  COST MISMATCH:
#    ID (V14): 15651
#    ID (V18): 12653
#    Code: 12-004.X
#    product_code (V14): 12-004
#    x_studio_product_code (V18): 12-004
#    Name (V14): 12-250 Alpha Aluminium zwart + spacer (kopie)
#    Name (V18): Zilver aluminium + spacer 7 x 40
#    Category: 1. Lijsten
#    material_cost (V14): €16.91
#    x_studio_computed_cost (V18): €9.07
#    Difference: €7.84
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14158
#    ID (V18): 10467
#    Code: 1596.X
#    product_code (V14): 1596
#    x_studio_product_code (V18): 1596
#    Name (V14): 1596
#    Name (V18): 1596
#    Category: 1. Lijsten
#    material_cost (V14): €23.39
#    x_studio_computed_cost (V18): €2.27
#    Difference: €21.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14132
#    ID (V18): 10912
#    Code: 56567.X
#    product_code (V14): 56567
#    x_studio_product_code (V18): 56567
#    Name (V14): 56567
#    Name (V18): 56567
#    Category: 1. Lijsten
#    material_cost (V14): €28.42
#    x_studio_computed_cost (V18): €16.56
#    Difference: €11.86
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14206
#    ID (V18): 11067
#    Code: 65430.I02+I03
#    product_code (V14): 65430
#    x_studio_product_code (V18): 65430
#    Name (V14): 65430
#    Name (V18): 65430
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €1.55
#    Difference: €22.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14130
#    ID (V18): 12562
#    Code: 66202.X
#    product_code (V14): 66202
#    x_studio_product_code (V18): 66202
#    Name (V14): 66202
#    Name (V18): Verstevigingsprofiel Brut Ayous groot
#    Category: 1. Lijsten
#    material_cost (V14): €4.22
#    x_studio_computed_cost (V18): €0.00
#    Difference: €4.22
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14191
#    ID (V18): 11209
#    Code: 74346.X
#    product_code (V14): 74346
#    x_studio_product_code (V18): 74346
#    Name (V14): 74346
#    Name (V18): 74346
#    Category: 1. Lijsten
#    material_cost (V14): €29.07
#    x_studio_computed_cost (V18): €16.36
#    Difference: €12.71
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14214
#    ID (V18): 11275
#    Code: 79211.X
#    product_code (V14): 79211
#    x_studio_product_code (V18): 79211
#    Name (V14): 79211
#    Name (V18): 79211
#    Category: 1. Lijsten
#    material_cost (V14): €15.19
#    x_studio_computed_cost (V18): €0.00
#    Difference: €15.19
#
# ⚠️  COST MISMATCH:
#    ID (V14): 15840
#    ID (V18): 11278
#    Code: 79815.C1
#    product_code (V14): 79815
#    x_studio_product_code (V18): 79815
#    Name (V14): 79810.C1 Baklijst Zwart 30x30 (kopie)
#    Name (V18): 79815.C1 Baklijst Wit 30x30
#    Category: 1. Lijsten
#    material_cost (V14): €10.57
#    x_studio_computed_cost (V18): €17.05
#    Difference: €6.47
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14172
#    ID (V18): 11324
#    Code: 81936.E30
#    product_code (V14): 81936
#    x_studio_product_code (V18): 81936
#    Name (V14): 81936
#    Name (V18): 81936
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €13.39
#    Difference: €10.16
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4318
#    ID (V18): 11521
#    Code: 96080.X
#    product_code (V14): 96080
#    x_studio_product_code (V18): 96080
#    Name (V14): Afgerond Profiel Goud 70X20
#    Name (V18): Afgerond Profiel Goud 70X20
#    Category: 1. Lijsten
#    material_cost (V14): €31.67
#    x_studio_computed_cost (V18): €26.87
#    Difference: €4.80
#
# ⚠️  COST MISMATCH:
#    ID (V14): 3989
#    ID (V18): 11524
#    Code: 39910.F29
#    product_code (V14): 39910
#    x_studio_product_code (V18): 39910
#    Name (V14): Afstandshouder Zwart 5X15 Mm
#    Name (V18): Afstandshouder Zwart 5X15 Mm
#    Category: 1. Lijsten
#    material_cost (V14): €21.92
#    x_studio_computed_cost (V18): €1.44
#    Difference: €20.48
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17539
#    Code: 015-003.O18
#    product_code (V14): 015-003
#    Name: Aluminium Zilver mat 9x26 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €9.14
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17487
#    Code: AR70XXL.GLAS
#    product_code (V14): AR70XXL
#    Name: Artglass AR70 (kopie)
#    Category: 2. Glas
#    material_cost (V14): €123.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 43
#    Code: AB.0
#    product_code (V14): AB.
#    Name: Asbuisje
#    Category: 96. Asbuisjes
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17592
#    Code: IN.AS
#    product_code (V14): IN
#    Name: Askader Esdoorn, 10,5 x 10,5cm (kopie)
#    Category: 04. Askaders
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 701
#    Code: False
#    product_code (V14): AK.
#    Name: Assembleren kader
#    Category: 92. Interne productie diensten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 702
#    Code: A.DIENST
#    product_code (V14): A
#    Name: Assembleren prijs per uur
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 703
#    Code: AS.DIENST
#    product_code (V14): AS.
#    Name: Assembleren spieraam
#    Category: 92. Interne productie diensten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4744
#    ID (V18): 11620
#    Code: 53017.M14
#    product_code (V14): 53017
#    x_studio_product_code (V18): 53017
#    Name (V14): Authentica Blok Creme 4 Cm
#    Name (V18): Authentica Blok Creme 4 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €26.80
#    x_studio_computed_cost (V18): €8.68
#    Difference: €18.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4746
#    ID (V18): 11621
#    Code: 53045.M14
#    product_code (V14): 53045
#    x_studio_product_code (V18): 53045
#    Name (V14): Authentica Blok Lichtgrijs 4 Cm
#    Name (V18): Authentica Blok Lichtgrijs 4 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €26.80
#    x_studio_computed_cost (V18): €8.68
#    Difference: €18.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4749
#    ID (V18): 11622
#    Code: 53047.M15
#    product_code (V14): 53047
#    x_studio_product_code (V18): 53047
#    Name (V14): Authentica Blok Taupe 4 Cm
#    Name (V18): Authentica Blok Taupe 4 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €26.80
#    x_studio_computed_cost (V18): €8.68
#    Difference: €18.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4741
#    ID (V18): 11644
#    Code: 52945.M08
#    product_code (V14): 52945
#    x_studio_product_code (V18): 52945
#    Name (V14): Authentica Lichtgrijs Ingekleurd 3 Cm
#    Name (V18): Authentica Lichtgrijs Ingekleurd 3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €25.17
#    x_studio_computed_cost (V18): €4.99
#    Difference: €20.18
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4743
#    ID (V18): 11655
#    Code: 52947.M11
#    product_code (V14): 52947
#    x_studio_product_code (V18): 52947
#    Name (V14): Authentica Taupe Ingekleurd 3 Cm
#    Name (V18): Authentica Taupe Ingekleurd 3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €25.17
#    x_studio_computed_cost (V18): €4.99
#    Difference: €20.18
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4330
#    ID (V18): 11658
#    Code: 53847.X
#    product_code (V14): 53847
#    x_studio_product_code (V18): 53847
#    Name (V14): Authentica Vlak Taupe 6 Cm
#    Name (V18): Authentica Vlak Taupe 6 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €29.88
#    x_studio_computed_cost (V18): €7.62
#    Difference: €22.27
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17549
#    Code: 28300B.G34
#    product_code (V14): 28300B
#    Name: Baklijst authentica Zwart 15x44 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €9.25
#
# ⚠️  COST MISMATCH:
#    ID (V14): 6932
#    ID (V18): 13299
#    Code: 4089.A7
#    product_code (V14): 4089
#    x_studio_product_code (V18): 4089
#    Name (V14): Black
#    Name (V18): Black (kopie)
#    Category: 3. Passe-partout
#    material_cost (V14): €7.80
#    x_studio_computed_cost (V18): €13.20
#    Difference: €5.40
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16615
#    ID (V18): 13301
#    Code: 5089.C6
#    product_code (V14): 5089
#    x_studio_product_code (V18): 5089
#    Name (V14): Black - Black Core - Oversize (kopie)
#    Name (V18): Black - Black Core - Oversize
#    Category: 3. Passe-partout
#    material_cost (V14): €7.80
#    x_studio_computed_cost (V18): €13.20
#    Difference: €5.40
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4691
#    ID (V18): 11765
#    Code: 16920.L03
#    product_code (V14): 16920
#    x_studio_product_code (V18): 16920
#    Name (V14): Blauw Geborsteld 2,3 Cm
#    Name (V18): Blauw Geborsteld 2,3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.04
#    x_studio_computed_cost (V18): €2.75
#    Difference: €21.29
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16617
#    ID (V18): 13314
#    Code: 4071.X
#    product_code (V14): 4071
#    x_studio_product_code (V18): 4071
#    Name (V14): Brilliant White - Oversize (kopie)
#    Name (V18): Brilliant White - Oversize
#    Category: 3. Passe-partout
#    material_cost (V14): €7.80
#    x_studio_computed_cost (V18): €13.20
#    Difference: €5.40
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4692
#    ID (V18): 11910
#    Code: 16931.L03
#    product_code (V14): 16931
#    x_studio_product_code (V18): 16931
#    Name (V14): Donkergroen Geborsteld 2,3 Cm
#    Name (V18): Donkergroen Geborsteld 2,3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.04
#    x_studio_computed_cost (V18): €2.75
#    Difference: €21.29
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 41
#    Code: DP.X
#    product_code (V14): DP
#    Name: Down payment
#    Category: X. Archived products
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 15844
#    Code: 55442.A08+A11
#    product_code (V14): 55442
#    Name: Dummy Lijst (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €10.90
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4869
#    ID (V18): 11925
#    Code: 034-514.O15
#    product_code (V14): 034-514
#    x_studio_product_code (V18): 034-514
#    Name (V14): Eik 0,5 Cm K1117
#    Name (V18): Eik 0,5 Cm K1117
#    Category: 1. Lijsten
#    material_cost (V14): €12.05
#    x_studio_computed_cost (V18): €9.62
#    Difference: €2.43
#
# ⚠️  COST MISMATCH:
#    ID (V14): 5024
#    ID (V18): 11941
#    Code: 034-511.O20
#    product_code (V14): 034-511
#    x_studio_product_code (V18): 034-511
#    Name (V14): Esdoorn 0,5 Cm K1120
#    Name (V18): Esdoorn 0,5 Cm K1120
#    Category: 1. Lijsten
#    material_cost (V14): €12.05
#    x_studio_computed_cost (V18): €9.62
#    Difference: €2.43
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17444
#    Code: ForexW13.X
#    product_code (V14): ForexW13
#    Name: Forex Wit 10mm (kopie)
#    Category: 99. Platen
#    material_cost (V14): €52.61
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17437
#    Code: FTBX_Z.X
#    product_code (V14): FTBX_Z
#    Name: Fotobox (kopie)
#    Category: Fotobox
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17439
#    Code: FTBX_T.X
#    product_code (V14): FTBX_T
#    Name: Fotobox wit (kopie)
#    Category: Fotobox
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17438
#    Code: FTBX_W.X
#    product_code (V14): FTBX_W
#    Name: Fotobox zwart (kopie)
#    Category: Fotobox
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 1
#    Code: Afhaling.X
#    product_code (V14): Afhaling
#    Name: Free delivery charges
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 40
#    Code: GS.DIENST
#    product_code (V14): GS
#    Name: Glas snijden
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 3883
#    ID (V18): 12000
#    Code: 6071.N28
#    product_code (V14): 6071
#    x_studio_product_code (V18): 6071
#    Name (V14): Gouden Barok Zwarte Lijn
#    Name (V18): Gouden Barok Zwarte Lijn
#    Category: 1. Lijsten
#    material_cost (V14): €31.83
#    x_studio_computed_cost (V18): €19.04
#    Difference: €12.79
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17627
#    Code: 3424.N30
#    product_code (V14): 3424
#    Name: Gouden Baroklijst Middenornament K1146 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €64.11
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 4632
#    Code: 4540-571.F32
#    product_code (V14): 4540-571
#    Name: Grijs 4.5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €5.80
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17594
#    Code: Satin.PRINT
#    product_code (V14): Satin
#    Name: Hahnemühle Photo Rag ®️ Ultra Smooth 350gr (kopie)
#    Category: 7. Printen
#    material_cost (V14): €34.42
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4313
#    ID (V18): 12015
#    Code: 16536.X
#    product_code (V14): 16536
#    x_studio_product_code (V18): 16536
#    Name (V14): Halfrond Goud-Bruin
#    Name (V18): Halfrond Goud-Bruin
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €6.26
#    Difference: €18.10
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4312
#    ID (V18): 12016
#    Code: 16531.X
#    product_code (V14): 16531
#    x_studio_product_code (V18): 16531
#    Name (V14): Halfrond Goud-Groen
#    Name (V18): Halfrond Goud-Groen
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €6.26
#    Difference: €18.10
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4182
#    ID (V18): 12018
#    Code: 16515.X
#    product_code (V14): 16515
#    x_studio_product_code (V18): 16515
#    Name (V14): Halfrond Goud/Wit
#    Name (V18): Halfrond Goud/Wit
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €5.11
#    Difference: €19.25
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 15065
#    Code: SI.DIENST
#    product_code (V14): SI
#    Name: Junior inlijster (kopie)
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4498
#    ID (V18): 12066
#    Code: 73317.F17
#    product_code (V14): 73317
#    x_studio_product_code (V18): 73317
#    Name (V14): Kaslijst Beige Lage Uitsnijding 1,5 Cm
#    Name (V18): Kaslijst Beige Lage Uitsnijding 1,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €22.74
#    x_studio_computed_cost (V18): €4.63
#    Difference: €18.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4501
#    ID (V18): 12073
#    Code: 73346.F16
#    product_code (V14): 73346
#    x_studio_product_code (V18): 73346
#    Name (V14): Kaslijst Grijs Lage Uitsnijding 1,5 Cm
#    Name (V18): Kaslijst Grijs Lage Uitsnijding 1,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €22.74
#    x_studio_computed_cost (V18): €4.63
#    Difference: €18.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4500
#    ID (V18): 12074
#    Code: 73345.F16
#    product_code (V14): 73345
#    x_studio_product_code (V18): 73345
#    Name (V14): Kaslijst Grijs/Groen Lage Uitsnijding 1,5 Cm
#    Name (V18): Kaslijst Grijs/Groen Lage Uitsnijding 1,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €22.74
#    x_studio_computed_cost (V18): €4.63
#    Difference: €18.11
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17490
#    Code: 4110.X
#    product_code (V14): 4110
#    Name: Kaslijst Lichtbruin 2cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €3.43
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 3887
#    Code: 48310.A03+A04+A05+O03
#    product_code (V14): 48310
#    Name: Kaslijst Zwart 2 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €2.97
#
# ⚠️  COST MISMATCH:
#    ID (V14): 13454
#    ID (V18): 11913
#    Code: DummylijstDummy Lijst
#    product_code (V14): Dummylijst
#    x_studio_product_code (V18): Dummylijst
#    Name (V14): Kaslijst Zwart 2 cm (kopie)
#    Name (V18): Dummy Lijst
#    Category: 1. Lijsten
#    material_cost (V14): €24357.56
#    x_studio_computed_cost (V18): €0.00
#    Difference: €24357.56
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4032
#    ID (V18): 12165
#    Code: 4747.D14
#    product_code (V14): 4747
#    x_studio_product_code (V18): 4747
#    Name (V14): Lichtbruin Loodwit
#    Name (V18): Lichtbruin Loodwit
#    Category: 1. Lijsten
#    material_cost (V14): €25.33
#    x_studio_computed_cost (V18): €4.56
#    Difference: €20.77
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4695
#    ID (V18): 12169
#    Code: 16945.L03
#    product_code (V14): 16945
#    x_studio_product_code (V18): 16945
#    Name (V14): Lichtgrijs Geborsteld 2,3 Cm
#    Name (V18): Lichtgrijs Geborsteld 2,3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.04
#    x_studio_computed_cost (V18): €2.75
#    Difference: €21.29
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 717
#    Code: LS.DIENST
#    product_code (V14): LS.
#    Name: Lijst snijden
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 15064
#    Code: JI.DIENST
#    product_code (V14): JI
#    Name: Lijst snijden (kopie)
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 4479
#    Code: 41516.F06
#    product_code (V14): 41516
#    Name: Loft Wenge + Spacer 20X35
#    Category: 1. Lijsten
#    material_cost (V14): €7.67
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16584
#    ID (V18): 12199
#    Code: 40516.F06
#    product_code (V14): 40516
#    x_studio_product_code (V18): 40516
#    Name (V14): Loft Wenge + Spacer 20X35 (kopie)
#    Name (V18): Loft Wenge 20X35
#    Category: 1. Lijsten
#    material_cost (V14): €13.23
#    x_studio_computed_cost (V18): €6.39
#    Difference: €6.84
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 722
#    Code: False
#    product_code (V14): MDF3MM.
#    Name: MDF 3MM BRUT
#    Category: 4. Ruggen
#    material_cost (V14): €3.14
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4521
#    ID (V18): 12224
#    Code: 1372.X
#    product_code (V14): 1372
#    x_studio_product_code (V18): 1372
#    Name (V14): Marquetterie Olm 2Cm
#    Name (V18): Marquetterie Olm 2Cm
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €8.05
#    Difference: €15.50
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 723
#    Code: MG.GLAS
#    product_code (V14): MG.
#    Name: Mat glas
#    Category: 2. Glas
#    material_cost (V14): €20.10
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4607
#    ID (V18): 12254
#    Code: 57797.I15
#    product_code (V14): 57797
#    x_studio_product_code (V18): 57797
#    Name (V14): Metropoli Brons 5 Cm
#    Name (V18): Metropoli Brons 5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €28.42
#    x_studio_computed_cost (V18): €14.50
#    Difference: €13.92
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4271
#    ID (V18): 12296
#    Code: 1796.O34
#    product_code (V14): 1796
#    x_studio_product_code (V18): 1796
#    Name (V14): Noten Ant.Goud.Bies 7,5 Cm
#    Name (V18): Noten Ant.Goud.Bies 7,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €32.48
#    x_studio_computed_cost (V18): €12.14
#    Difference: €20.34
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17441
#    Code: 401.43.103.C39
#    product_code (V14): 401.43.103
#    Name: ORNAMENT ZWART GESATINEERD MET STRUCTUUR 79x49 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €4.86
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 729
#    Code: OIW.X
#    product_code (V14): OIW
#    Name: Ophalen in Wondelgem
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 13474
#    Code: Gratisverzending.X
#    product_code (V14): Gratisverzending
#    Name: Ophalen in Wondelgem (kopie)
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 16184
#    Code: OIA.X
#    product_code (V14): OIA
#    Name: Ophalen in Wondelgem (kopie)
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 730
#    Code: OS.DIENST
#    product_code (V14): OS.
#    Name: Opspannen spieraam
#    Category: 92. Interne productie diensten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4118
#    ID (V18): 12314
#    Code: 10715.N29
#    product_code (V14): 10715
#    x_studio_product_code (V18): 10715
#    Name (V14): Ornament Antiek Wit 1,4 Cm K1075
#    Name (V18): Ornament Antiek Wit 1,4 Cm K1075
#    Category: 1. Lijsten
#    material_cost (V14): €22.57
#    x_studio_computed_cost (V18): €6.75
#    Difference: €15.83
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4031
#    ID (V18): 12348
#    Code: 4743.X
#    product_code (V14): 4743
#    x_studio_product_code (V18): 4743
#    Name (V14): Perzik Loodwit 3 Cm
#    Name (V18): Perzik Loodwit 3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €25.33
#    x_studio_computed_cost (V18): €4.56
#    Difference: €20.77
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 12796
#    Code: PK4040.BOX
#    product_code (V14): PK4040
#    Name: Plooikost doos 40x40
#    Category: 91A. Verpakkingsdozen
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 12797
#    Code: PK4565.BOX
#    product_code (V14): PK4565
#    Name: Plooikost doos 40x40 (kopie)
#    Category: 91A. Verpakkingsdozen
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 12798
#    Code: PK6070.BOX
#    product_code (V14): PK6070
#    Name: Plooikost doos 45x65 (kopie)
#    Category: 91A. Verpakkingsdozen
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 12799
#    Code: PK70100.BOX
#    product_code (V14): PK70100
#    Name: Plooikost doos 60x70 (kopie)
#    Category: 91A. Verpakkingsdozen
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 12800
#    Code: PK75115.BOX
#    product_code (V14): PK75115
#    Name: Plooikost doos 70x100 (kopie)
#    Category: 91A. Verpakkingsdozen
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 6935
#    ID (V18): 13424
#    Code: 4754.A12
#    product_code (V14): 4754
#    x_studio_product_code (V18): 4754
#    Name (V14): Porcelain
#    Name (V18): Porcelain (kopie)
#    Category: 3. Passe-partout
#    material_cost (V14): €7.80
#    x_studio_computed_cost (V18): €13.20
#    Difference: €5.40
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 9936
#    Code: Printen.INT
#    product_code (V14): Printen
#    Name: Printen
#    Category: 92. Interne productie diensten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 735
#    ID (V18): 13436
#    Code: ZR.0
#    product_code (V14): ZR
#    x_studio_product_code (V18): ZR
#    Name (V14): Rugwand met voet
#    Name (V18): Rugwand met voet
#    Category: 41. Standaardruggen
#    material_cost (V14): €0.00
#    x_studio_computed_cost (V18): €5.75
#    Difference: €5.75
#
# ⚠️  COST MISMATCH:
#    ID (V14): 9927
#    ID (V18): 13265
#    Code: 974017.SP
#    product_code (V14): 974017
#    x_studio_product_code (V18): 974017
#    Name (V14): Si - frame Hoekverbinder (kopie)
#    Name (V18): Allsize Hoekverbinding
#    Category: 93. Andere producten
#    material_cost (V14): €0.00
#    x_studio_computed_cost (V18): €0.24
#    Difference: €0.24
#
# ⚠️  COST MISMATCH:
#    ID (V14): 9923
#    ID (V18): 13456
#    Code: 00210-05-I.SP
#    product_code (V14): 00210-05-I
#    x_studio_product_code (V18): 00210-05-I
#    Name (V14): Si - frame Kruislatverbinder (kopie)
#    Name (V18): Si - frame Hoekverbinder
#    Category: 93. Andere producten
#    material_cost (V14): €0.00
#    x_studio_computed_cost (V18): €2.28
#    Difference: €2.28
#
# ⚠️  COST MISMATCH:
#    ID (V14): 9922
#    ID (V18): 13458
#    Code: 00210-05-J.SP
#    product_code (V14): 00210-05-J
#    x_studio_product_code (V18): 00210-05-J
#    Name (V14): Si - frame Kruislatverbinder (kopie)
#    Name (V18): Si - frame Tussenlatverbinder
#    Category: 93. Andere producten
#    material_cost (V14): €0.00
#    x_studio_computed_cost (V18): €2.18
#    Difference: €2.18
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17494
#    Code: 40546.X
#    product_code (V14): 40546
#    Name: Spacer Mat Zwart 6 X 21 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €2.07
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17491
#    Code: 40554.X
#    product_code (V14): 40554
#    Name: Spacer Mat Zwart 6 X 30 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €3.76
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17483
#    Code: 40015C.X
#    product_code (V14): 40015C
#    Name: Spacer Wit 5X10 mm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €2.84
#
# ⚠️  COST MISMATCH:
#    ID (V14): 17593
#    ID (V18): 11524
#    Code: 39910.X
#    product_code (V14): 39910
#    x_studio_product_code (V18): 39910
#    Name (V14): Spacer Wit 5X15 mm (kopie)
#    Name (V18): Afstandshouder Zwart 5X15 Mm
#    Category: 1. Lijsten
#    material_cost (V14): €2.29
#    x_studio_computed_cost (V18): €1.44
#    Difference: €0.85
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17486
#    Code: 40115C.X
#    product_code (V14): 40115C
#    Name: Spacer Wit Op Compo 5X20 mm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €4.34
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17484
#    Code: 14323003.X
#    product_code (V14): 14323003
#    Name: Spacer Wit op compo 5X10 mm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €1.39
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17482
#    Code: 395815.X
#    product_code (V14): 395815
#    Name: Spacer Zwart 5X10 mm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €1.39
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17485
#    Code: 40110C.X
#    product_code (V14): 40110C
#    Name: Spacer Zwart Op Compo 5X20mm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €4.34
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 6984
#    Code: STO.INL
#    product_code (V14): STO
#    Name: Stomen + opspelden Tshirt
#    Category: Vaste prijs producten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4696
#    ID (V18): 12527
#    Code: 17936.L04
#    product_code (V14): 17936
#    x_studio_product_code (V18): 17936
#    Name (V14): Terra Roestbruin Geborsteld 3,8 Cm
#    Name (V18): Terra Roestbruin Geborsteld 3,8 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €26.47
#    x_studio_computed_cost (V18): €6.07
#    Difference: €20.41
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17440
#    Code: G-0063/4035.X
#    product_code (V14): G-0063/4035
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €17.56
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17461
#    Code: 2902.P21
#    product_code (V14): 2902
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €2.69
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17690
#    Code: 3009.X
#    product_code (V14): 3009
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €12.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 15649
#    ID (V18): 12694
#    Code: 12-250.X
#    product_code (V14): 12-250
#    x_studio_product_code (V18): 12-250
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): Zwart aluminium + spacer 7 x 40
#    Category: 1. Lijsten
#    material_cost (V14): €16.91
#    x_studio_computed_cost (V18): €9.07
#    Difference: €7.84
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17629
#    Code: 83080.X
#    product_code (V14): 83080
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €8.81
#
# ⚠️  COST MISMATCH:
#    ID (V14): 17015
#    ID (V18): 10010
#    Code: 71515.C17
#    product_code (V14): 71515
#    x_studio_product_code (V18): 71515
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): "Gloss" Baklijst Lak Wit 5Cm K1162
#    Category: 1. Lijsten
#    material_cost (V14): €14.13
#    x_studio_computed_cost (V18): €13.35
#    Difference: €0.78
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17743
#    Code: R-801.20.895./
#    product_code (V14): R-801.20.895
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €14.40
#
# ⚠️  COST MISMATCH:
#    ID (V14): 15621
#    ID (V18): 11950
#    Code: 77163.N31
#    product_code (V14): 77163
#    x_studio_product_code (V18): 77163
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): FINEER ITALIAANSE NOTEN 15/25
#    Category: 1. Lijsten
#    material_cost (V14): €3.18
#    x_studio_computed_cost (V18): €3.13
#    Difference: €0.05
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17578
#    Code: R801.20.894.X
#    product_code (V14): R801.20.894
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €8.48
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17575
#    Code: 1291.X
#    product_code (V14): 1291
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €11.64
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17479
#    Code: 102485.X
#    product_code (V14): 102485
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €7.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17489
#    Code: 4120.X
#    product_code (V14): 4120
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €4.04
#
# ⚠️  COST MISMATCH:
#    ID (V14): 15639
#    ID (V18): 12163
#    Code: 63110.M29
#    product_code (V14): 63110
#    x_studio_product_code (V18): 63110
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): Lak Zwart 6,8 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €16.56
#    x_studio_computed_cost (V18): €16.48
#    Difference: €0.09
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17495
#    Code: 94810.X
#    product_code (V14): 94810
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €10.83
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16730
#    ID (V18): 12682
#    Code: 214-021.X
#    product_code (V14): 214-021
#    x_studio_product_code (V18): 214-021
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): Zwart Mat 1,3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €11.53
#    x_studio_computed_cost (V18): €7.61
#    Difference: €3.92
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17517
#    Code: 3382.O39
#    product_code (V14): 3382
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €3.46
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16866
#    ID (V18): 11908
#    Code: 78046.x
#    product_code (V14): 78046
#    x_studio_product_code (V18): 78046
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): Donkergrijs
#    Category: 1. Lijsten
#    material_cost (V14): €4.58
#    x_studio_computed_cost (V18): €10.44
#    Difference: €5.86
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17548
#    Code: S-999-15W.X
#    product_code (V14): S-999-15W
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €12.04
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 745
#    Code: VS.X
#    product_code (V14): VS
#    Name: Vellen snijden
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 856
#    Code: VLP.X
#    product_code (V14): VLP
#    Name: Verpakken losse producten
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 746
#    Code: VD.X
#    product_code (V14): VD
#    Name: Verpakking dienst
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 15865
#    Code: OPHAALSERVICE.X
#    product_code (V14): OPHAALSERVICE
#    Name: Verpakkingsrol (kopie)
#    Category: Vaste prijs producten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 13465
#    Code: VERPDOOS.X
#    product_code (V14): VERPDOOS.
#    Name: Verpakkingsrol (kopie)
#    Category: Vaste prijs producten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 17492
#    ID (V18): 12561
#    Code: 66102.X
#    product_code (V14): 66102
#    x_studio_product_code (V18): 66102
#    Name (V14): Verstevigingsprofiel Brut Ayous Groot 50x10 (kopie)
#    Name (V18): Verstevigingsprofiel Brut Ayous 40x10 66102
#    Category: 1. Lijsten
#    material_cost (V14): €3.09
#    x_studio_computed_cost (V18): €0.00
#    Difference: €3.09
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 747
#    Code: Interntransport.X
#    product_code (V14): Interntransport
#    Name: Vervoerskosten
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 748
#    Code: VZB.X
#    product_code (V14): VZB
#    Name: Verzenden via Bpost
#    Category: NTB
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4868
#    ID (V18): 12575
#    Code: 034-516.O12
#    product_code (V14): 034-516
#    x_studio_product_code (V18): 034-516
#    Name (V14): Wenge Donker 0,5 Cm K1122
#    Name (V18): Wenge Donker 0,5 Cm K1122
#    Category: 1. Lijsten
#    material_cost (V14): €12.05
#    x_studio_computed_cost (V18): €9.62
#    Difference: €2.43
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4871
#    ID (V18): 12576
#    Code: 034-515.O14
#    product_code (V14): 034-515
#    x_studio_product_code (V18): 034-515
#    Name (V14): Wenge Licht 0,5 Cm K1118
#    Name (V18): Wenge Licht 0,5 Cm K1118
#    Category: 1. Lijsten
#    material_cost (V14): €12.05
#    x_studio_computed_cost (V18): €9.62
#    Difference: €2.43
#
# ⚠️  COST MISMATCH:
#    ID (V14): 17048
#    ID (V18): 13504
#    Code: BR844987.PP
#    product_code (V14): BR844987
#    x_studio_product_code (V18): BR844987
#    Name (V14): White -Red Core  (kopie)
#    Name (V18): White -Yellow Core
#    Category: 3. Passe-partout
#    material_cost (V14): €20.34
#    x_studio_computed_cost (V18): €0.00
#    Difference: €20.34
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4087
#    ID (V18): 12586
#    Code: 16915.L03
#    product_code (V14): 16915
#    x_studio_product_code (V18): 16915
#    Name (V14): Wit Geborsteld 2,3 Cm
#    Name (V18): Wit Geborsteld 2,3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.04
#    x_studio_computed_cost (V18): €2.61
#    Difference: €21.43
#
# ================================================================================
# Cost comparison complete!
# Total product templates in V14 (excluding categories): 3318
# Product templates without product_code (skipped): 26
# Product templates checked: 3292
# Product templates not found in V18: 66
# Product templates with cost matches: 3148
# Product templates with cost mismatches: 78
# ================================================================================

# %%
# Sync seller_ids from V14 to V18 for ALL products that have more than 1 seller
# This will process all products with multiple sellers in V14

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables for V14
JUSTFRAMEIT_ODOO_V14_URL = os.getenv('JUSTFRAMEIT_ODOO_V14_URL')
JUSTFRAMEIT_ODOO_V14_DB = os.getenv('JUSTFRAMEIT_ODOO_V14_DB')
JUSTFRAMEIT_ODOO_V14_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_V14_USERNAME')
JUSTFRAMEIT_ODOO_V14_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_V14_API_KEY')

# Get environment variables for V18
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

print("=" * 80)
print(f"Syncing seller_ids from V14 to V18 for ALL products with more than 1 seller")
print("=" * 80)

try:
    # Authenticate to V14
    print("\n[V14] Authenticating...")
    common_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/common", allow_none=True)
    uid_v14 = common_v14.authenticate(JUSTFRAMEIT_ODOO_V14_DB, JUSTFRAMEIT_ODOO_V14_USERNAME, JUSTFRAMEIT_ODOO_V14_API_KEY, {})
    print(f"✅ V14 Authenticated! UID: {uid_v14}\n")
    
    # Create models proxy for V14
    models_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/object", allow_none=True)
    
    # Get all product templates with seller_ids field from V14
    print(f"[V14] Fetching all product.template records with seller_ids...")
    all_product_ids = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'search',
        [[]])
    
    print(f"[V14] Found {len(all_product_ids)} total product templates")
    print(f"[V14] Reading seller_ids for all products...")
    
    all_products = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'read',
        [all_product_ids],
        {'fields': ['id', 'name', 'default_code', 'product_code', 'seller_ids']})
    
    # Filter products with more than 1 seller
    products_with_multiple_sellers = []
    for product in all_products:
        if product['seller_ids'] and len(product['seller_ids']) > 1:
            products_with_multiple_sellers.append(product)
    
    print(f"\n✅ Found {len(products_with_multiple_sellers)} products with more than 1 seller\n")
    
    if not products_with_multiple_sellers:
        print("⚠️  No products with multiple sellers found. Nothing to sync.")
        raise Exception("No products to sync")
    
    # Now authenticate to V18
    print("=" * 80)
    print("[V18] Authenticating...")
    common_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
    uid_v18 = common_v18.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
    print(f"✅ V18 Authenticated! UID: {uid_v18}\n")
    
    # Create models proxy for V18
    models_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)
    
    # Process each product
    print("=" * 80)
    print("Starting sync process...")
    print("=" * 80)
    
    total_products = len(products_with_multiple_sellers)
    synced_count = 0
    skipped_count = 0
    error_count = 0
    
    for product_index, template_v14 in enumerate(products_with_multiple_sellers, 1):
        print(f"\n{'=' * 80}")
        print(f"Processing product {product_index}/{total_products}")
        print(f"{'=' * 80}")
        
        product_code_v14 = template_v14.get('product_code')
        
        print(f"\n✅ Product Template (V14):")
        print(f"   ID: {template_v14['id']}")
        print(f"   Name: {template_v14['name']}")
        print(f"   Default Code: {template_v14['default_code']}")
        print(f"   Product Code: {product_code_v14}")
        print(f"   Number of Sellers: {len(template_v14['seller_ids'])}")
        
        if not product_code_v14:
            print("\n⚠️  No product_code found for this product template in V14. Skipping.")
            skipped_count += 1
            continue
        
        try:
            # Fetch seller details from V14
            print(f"\n[V14] Fetching details for {len(template_v14['seller_ids'])} seller records...")
            seller_info_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.supplierinfo', 'read',
                [template_v14['seller_ids']],
                {'fields': ['id', 'name', 'price', 'is_preferred_supplier', 'sequence', 'product_code']})
            
            print(f"\nSeller Information V14:")
            for idx, seller in enumerate(seller_info_v14, 1):
                print(f"   Seller #{idx}: {seller['name'][1]} (Price: {seller['price']}, Preferred: {seller['is_preferred_supplier']})")
            
            # Find matching product in V18 using x_studio_product_code
            print(f"\n[V18] Searching for product with x_studio_product_code = {product_code_v14}...")
            product_ids_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'product.template', 'search',
                [[['x_studio_product_code', '=', product_code_v14]]])
            
            if not product_ids_v18:
                print(f"⚠️  No product found in V18 with x_studio_product_code = {product_code_v14}. Skipping.")
                skipped_count += 1
                continue
            
            product_id_v18 = product_ids_v18[0]
            print(f"✅ Found matching product in V18: ID {product_id_v18}")
            
            # Get product template from V18
            product_template_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'product.template', 'read',
                [product_id_v18],
                {'fields': ['id', 'name', 'default_code', 'x_studio_product_code', 'seller_ids']})
            
            template_v18 = product_template_v18[0]
            print(f"\n✅ Product Template (V18):")
            print(f"   ID: {template_v18['id']}")
            print(f"   Name: {template_v18['name']}")
            print(f"   Current Seller IDs: {template_v18['seller_ids']}")
            
            # Get existing sellers in V18
            existing_sellers_v18 = []
            if template_v18['seller_ids']:
                existing_sellers_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'product.supplierinfo', 'read',
                    [template_v18['seller_ids']],
                    {'fields': ['id', 'partner_id', 'price', 'sequence']})
                
                print(f"\nExisting sellers in V18:")
                for seller in existing_sellers_v18:
                    print(f"   - {seller['partner_id'][1]} (Price: {seller['price']}, Sequence: {seller['sequence']})")
            
            # Process each seller from V14
            print(f"\nSyncing sellers...")
            
            # Sort sellers: preferred first, then by original sequence
            sorted_sellers_v14 = sorted(seller_info_v14, 
                                       key=lambda x: (not x['is_preferred_supplier'], x['sequence']))
            
            # Assign new sequences starting from 1
            for new_sequence, seller_v14 in enumerate(sorted_sellers_v14, start=1):
                supplier_name_v14 = seller_v14['name'][1]  # name is [id, name]
                supplier_id_v14 = seller_v14['name'][0]
                price_v14 = seller_v14['price']
                is_preferred_v14 = seller_v14['is_preferred_supplier']
                
                print(f"   Processing: {supplier_name_v14} (Price: {price_v14}, Sequence: {new_sequence}, Preferred: {is_preferred_v14})")
                
                # Search for partner in V18 by name
                partner_ids_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'res.partner', 'search',
                    [[['name', '=', supplier_name_v14]]])
                
                if not partner_ids_v18:
                    print(f"      Creating partner '{supplier_name_v14}' in V18...")
                    partner_id_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                        'res.partner', 'create',
                        [{'name': supplier_name_v14, 'supplier_rank': 1}])
                    print(f"      ✅ Created partner with ID: {partner_id_v18}")
                else:
                    partner_id_v18 = partner_ids_v18[0]
                
                # Check if this supplier already exists for this product in V18
                existing_seller = None
                for seller in existing_sellers_v18:
                    if seller['partner_id'][0] == partner_id_v18:
                        existing_seller = seller
                        break
                
                if existing_seller:
                    # Update existing seller
                    models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                        'product.supplierinfo', 'write',
                        [[existing_seller['id']], {
                            'price': price_v14,
                            'sequence': new_sequence
                        }])
                    print(f"      ✅ Updated existing seller (ID: {existing_seller['id']})")
                else:
                    # Create new seller
                    new_seller_id = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                        'product.supplierinfo', 'create',
                        [{
                            'partner_id': partner_id_v18,
                            'product_tmpl_id': product_id_v18,
                            'price': price_v14,
                            'sequence': new_sequence
                        }])
                    print(f"      ✅ Created new seller (ID: {new_seller_id})")
            
            synced_count += 1
            print(f"\n✅ Successfully synced product {template_v14['name']}")
            
        except Exception as e:
            error_count += 1
            print(f"\n❌ Error processing product {template_v14['name']}: {e}")
            import traceback
            traceback.print_exc()
            continue
    
    print("\n" + "=" * 80)
    print("Sync complete!")
    print("=" * 80)
    print(f"\nSummary:")
    print(f"   Total products with multiple sellers: {total_products}")
    print(f"   Successfully synced: {synced_count}")
    print(f"   Skipped: {skipped_count}")
    print(f"   Errors: {error_count}")
    print("=" * 80)
    
except Exception as e:
    print(f"\n❌ Fatal Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ================================================================================
# Syncing seller_ids from V14 to V18 for ALL products with more than 1 seller
# ================================================================================
#
# [V14] Authenticating...
# ✅ V14 Authenticated! UID: 28
#
# [V14] Fetching all product.template records with seller_ids...
# [V14] Found 5320 total product templates
# [V14] Reading seller_ids for all products...
#
# ✅ Found 152 products with more than 1 seller
#
# ================================================================================
# [V18] Authenticating...
# ✅ V18 Authenticated! UID: 2
#
# ================================================================================
# Starting sync process...
# ================================================================================
#
# ================================================================================
# Processing product 1/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 5237
#    Name: "Altis" Baklijst Eik Fineer 38X25
#    Default Code: 100767.D08+D10
#    Product Code: 100767
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.7, Preferred: True)
#    Seller #2: Molgra (Price: 5.6, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = 100767...
# ✅ Found matching product in V18: ID 9897
#
# ✅ Product Template (V18):
#    ID: 9897
#    Name: "Altis" Baklijst Eik Fineer 38X25
#    Current Seller IDs: [5349, 7121]
#
# Existing sellers in V18:
#    - Eurolijsten (Price: 7.7, Sequence: 1)
#    - Molgra (Price: 5.6, Sequence: 2)
#
# Syncing sellers...
#    Processing: Eurolijsten (Price: 7.7, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 5349)
#    Processing: Molgra (Price: 5.6, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7121)
#
# ✅ Successfully synced product "Altis" Baklijst Eik Fineer 38X25
#
# ================================================================================
# Processing product 2/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 4398
#    Name: "Aniline" Ramin Natuurkleur Vernist 23/13
#    Default Code: 70803.E03
#    Product Code: 70803
#    Number of Sellers: 3
#
# [V14] Fetching details for 3 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 3.1, Preferred: False)
#    Seller #2: Nmc (Price: 1.2, Preferred: False)
#    Seller #3: The Frame Company (Price: 2.8, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 70803...
# ✅ Found matching product in V18: ID 9913
#
# ✅ Product Template (V18):
#    ID: 9913
#    Name: "Aniline" Ramin Natuurkleur Vernist 23/13
#    Current Seller IDs: [7124, 7122, 7123]
#
# Existing sellers in V18:
#    - The Frame Company (Price: 2.8, Sequence: 1)
#    - Eurolijsten (Price: 3.1, Sequence: 1)
#    - Nmc (Price: 1.2, Sequence: 2)
#
# Syncing sellers...
#    Processing: The Frame Company (Price: 2.8, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 7124)
#    Processing: Eurolijsten (Price: 3.1, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7122)
#    Processing: Nmc (Price: 1.2, Sequence: 3, Preferred: False)
#       ✅ Updated existing seller (ID: 7123)
#
# ✅ Successfully synced product "Aniline" Ramin Natuurkleur Vernist 23/13
#
# ================================================================================
# Processing product 3/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 4857
#    Name: "Solid Wood" Eik 1,5Cm K1124
#    Default Code: 60567.N03+N10
#    Product Code: 60567
#    Number of Sellers: 4
#
# [V14] Fetching details for 4 seller records...
#
# Seller Information V14:
#    Seller #1: Intermol (Price: 3.6, Preferred: False)
#    Seller #2: Nmc (Price: 1.69, Preferred: False)
#    Seller #3: The Frame Company (Price: 4.5, Preferred: True)
#    Seller #4: Eurolijsten (Price: 6.45, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = 60567...
# ✅ Found matching product in V18: ID 10092
#
# ✅ Product Template (V18):
#    ID: 10092
#    Name: "Solid Wood" Eik 1,5Cm K1124
#    Current Seller IDs: [7125, 7127, 7126, 7128]
#
# Existing sellers in V18:
#    - Intermol (Price: 3.6, Sequence: 1)
#    - The Frame Company (Price: 4.5, Sequence: 1)
#    - Nmc (Price: 1.69, Sequence: 2)
#    - Eurolijsten (Price: 6.45, Sequence: 4)
#
# Syncing sellers...
#    Processing: The Frame Company (Price: 4.5, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 7127)
#    Processing: Intermol (Price: 3.6, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7125)
#    Processing: Nmc (Price: 1.69, Sequence: 3, Preferred: False)
#       ✅ Updated existing seller (ID: 7126)
#    Processing: Eurolijsten (Price: 6.45, Sequence: 4, Preferred: False)
#       ✅ Updated existing seller (ID: 7128)
#
# ✅ Successfully synced product "Solid Wood" Eik 1,5Cm K1124
#
# ================================================================================
# Processing product 4/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 4638
#    Name: "Solid Wood" Spacer Eik 5X15Mm
#    Default Code: 15003.J33
#    Product Code: 15003
#    Number of Sellers: 3
#
# [V14] Fetching details for 3 seller records...
#
# Seller Information V14:
#    Seller #1: Intermol (Price: 1.5, Preferred: False)
#    Seller #2: Eurolijsten (Price: 2.75, Preferred: False)
#    Seller #3: Tfc (Price: 1.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 15003...
# ✅ Found matching product in V18: ID 10104
#
# ✅ Product Template (V18):
#    ID: 10104
#    Name: "Solid Wood" Spacer Eik 5X15Mm
#    Current Seller IDs: [7129, 7131, 7130]
#
# Existing sellers in V18:
#    - Intermol (Price: 1.5, Sequence: 1)
#    - Tfc (Price: 1.5, Sequence: 1)
#    - Eurolijsten (Price: 2.75, Sequence: 2)
#
# Syncing sellers...
#    Processing: Tfc (Price: 1.5, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 7131)
#    Processing: Intermol (Price: 1.5, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7129)
#    Processing: Eurolijsten (Price: 2.75, Sequence: 3, Preferred: False)
#       ✅ Updated existing seller (ID: 7130)
#
# ✅ Successfully synced product "Solid Wood" Spacer Eik 5X15Mm
#
# ================================================================================
# Processing product 5/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 14226
#    Name: 100867
#    Default Code: 100867.A10+A23+C20+C21
#    Product Code: 100867
#    Number of Sellers: 3
#
# [V14] Fetching details for 3 seller records...
#
# Seller Information V14:
#    Seller #1: Tfc (Price: 9.62, Preferred: True)
#    Seller #2: Eurolijsten (Price: 10.85, Preferred: False)
#    Seller #3: Molgra (Price: 8.62, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = 100867...
# ✅ Found matching product in V18: ID 11527
#
# ✅ Product Template (V18):
#    ID: 11527
#    Name: Altis Baklijst Eik 55x45
#    Current Seller IDs: [5898, 7132, 7133]
#
# Existing sellers in V18:
#    - Tfc (Price: 9.62, Sequence: 1)
#    - Eurolijsten (Price: 10.85, Sequence: 1)
#    - Molgra (Price: 8.62, Sequence: 2)
#
# Syncing sellers...
#    Processing: Tfc (Price: 9.62, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 5898)
#    Processing: Eurolijsten (Price: 10.85, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7132)
#    Processing: Molgra (Price: 8.62, Sequence: 3, Preferred: False)
#       ✅ Updated existing seller (ID: 7133)
#
# ✅ Successfully synced product 100867
#
# ================================================================================
# Processing product 6/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 14255
#    Name: 6204/06
#    Default Code: 6204/06.O27
#    Product Code: 6204/06
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Cami Belgium Bvba (Price: 0.0, Preferred: False)
#    Seller #2: Eurolijsten (Price: 10.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 6204/06...
# ✅ Found matching product in V18: ID 11035
#
# ✅ Product Template (V18):
#    ID: 11035
#    Name: 6204/06
#    Current Seller IDs: [7134, 7135]
#
# Existing sellers in V18:
#    - Cami Belgium Bvba (Price: 0.0, Sequence: 1)
#    - Eurolijsten (Price: 10.5, Sequence: 1)
#
# Syncing sellers...
#    Processing: Eurolijsten (Price: 10.5, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 7135)
#    Processing: Cami Belgium Bvba (Price: 0.0, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7134)
#
# ✅ Successfully synced product 6204/06
#
# ================================================================================
# Processing product 7/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 14148
#    Name: 74215
#    Default Code: 74215.X
#    Product Code: 74215
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 8.0, Preferred: True)
#    Seller #2: Eurolijsten (Price: 8.0, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = 74215...
# ✅ Found matching product in V18: ID 11201
#
# ✅ Product Template (V18):
#    ID: 11201
#    Name: 74215
#    Current Seller IDs: [5822]
#
# Existing sellers in V18:
#    - Eurolijsten (Price: 8.0, Sequence: 1)
#
# Syncing sellers...
#    Processing: Eurolijsten (Price: 8.0, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 5822)
#    Processing: Eurolijsten (Price: 8.0, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 5822)
#
# ✅ Successfully synced product 74215
#
# ================================================================================
# Processing product 8/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 4015
#    Name: Afstandshouder Zwart Op Compo 5X10 Mm
#    Default Code: 39810C.F27
#    Product Code: 39810C
#    Number of Sellers: 3
#
# [V14] Fetching details for 3 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 1.9, Preferred: False)
#    Seller #2: Nmc (Price: 1.55, Preferred: False)
#    Seller #3: The Frame Company (Price: 1.9, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 39810C...
# ✅ Found matching product in V18: ID 11525
#
# ✅ Product Template (V18):
#    ID: 11525
#    Name: Afstandshouder Zwart Op Compo 5X10 Mm
#    Current Seller IDs: [7136, 7138, 7137]
#
# Existing sellers in V18:
#    - Eurolijsten (Price: 1.9, Sequence: 1)
#    - The Frame Company (Price: 1.9, Sequence: 1)
#    - Nmc (Price: 1.55, Sequence: 2)
#
# Syncing sellers...
#    Processing: The Frame Company (Price: 1.9, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 7138)
#    Processing: Eurolijsten (Price: 1.9, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7136)
#    Processing: Nmc (Price: 1.55, Sequence: 3, Preferred: False)
#       ✅ Updated existing seller (ID: 7137)
#
# ✅ Successfully synced product Afstandshouder Zwart Op Compo 5X10 Mm
#
# ================================================================================
# Processing product 9/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16487
#    Name: Alabaster
#    Default Code: GSRM3300.PP
#    Product Code: GSRM3300
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 5.5, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = GSRM3300...
# ✅ Found matching product in V18: ID 13262
#
# ✅ Product Template (V18):
#    ID: 13262
#    Name: Alabaster
#    Current Seller IDs: [7139, 7140]
#
# Existing sellers in V18:
#    - Eurolijsten (Price: 5.5, Sequence: 1)
#    - Tfc (Price: 6.5, Sequence: 2)
#
# Syncing sellers...
#    Processing: Eurolijsten (Price: 5.5, Sequence: 1, Preferred: False)
#       ✅ Updated existing seller (ID: 7139)
#    Processing: Tfc (Price: 6.5, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7140)
#
# ✅ Successfully synced product Alabaster
#
# ================================================================================
# Processing product 10/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16549
#    Name: Alabaster
#    Default Code: BLACK CORE 63300.PP
#    Product Code: BLACK CORE 63300
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 8.89, Preferred: False)
#    Seller #2: Tfc (Price: 10.0, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = BLACK CORE 63300...
# ✅ Found matching product in V18: ID 13263
#
# ✅ Product Template (V18):
#    ID: 13263
#    Name: Alabaster - Black Core
#    Current Seller IDs: [7141, 7142]
#
# Existing sellers in V18:
#    - Eurolijsten (Price: 8.89, Sequence: 1)
#    - Tfc (Price: 10.0, Sequence: 1)
#
# Syncing sellers...
#    Processing: Tfc (Price: 10.0, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 7142)
#    Processing: Eurolijsten (Price: 8.89, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7141)
#
# ✅ Successfully synced product Alabaster
#
# ================================================================================
# Processing product 11/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6944
#    Name: Alabaster
#    Default Code: 4825.C2
#    Product Code: 4825
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 5.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 4825...
# ✅ Found matching product in V18: ID 13261
#
# ✅ Product Template (V18):
#    ID: 13261
#    Name: Alabaster
#    Current Seller IDs: [7143, 7144]
#
# Existing sellers in V18:
#    - Nielsen Design (Price: 5.3, Sequence: 1)
#    - Tfc (Price: 6.5, Sequence: 1)
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 7144)
#    Processing: Nielsen Design (Price: 5.3, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7143)
#
# ✅ Successfully synced product Alabaster
#
# ================================================================================
# Processing product 12/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 13453
#    Name: Alabaster (kopie)
#    Default Code: SRM986.X
#    Product Code: SRM986
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 5.71, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = SRM986...
# ✅ Found matching product in V18: ID 13474
#
# ✅ Product Template (V18):
#    ID: 13474
#    Name: TAMPICO BROWN
#    Current Seller IDs: [7145, 7146]
#
# Existing sellers in V18:
#    - Eurolijsten (Price: 5.71, Sequence: 1)
#    - Tfc (Price: 6.5, Sequence: 1)
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 7146)
#    Processing: Eurolijsten (Price: 5.71, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7145)
#
# ✅ Successfully synced product Alabaster (kopie)
#
# ================================================================================
# Processing product 13/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 5238
#    Name: Altis" Baklijst Eik Fineer
#    Default Code: 100967.D12+D13
#    Product Code: 100967
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 12.05, Preferred: True)
#    Seller #2: Molgra (Price: 10.2, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = 100967...
# ✅ Found matching product in V18: ID 11530
#
# ✅ Product Template (V18):
#    ID: 11530
#    Name: Altis" Baklijst Eik Fineer
#    Current Seller IDs: [5900, 7147]
#
# Existing sellers in V18:
#    - Eurolijsten (Price: 12.05, Sequence: 1)
#    - Molgra (Price: 10.2, Sequence: 2)
#
# Syncing sellers...
#    Processing: Eurolijsten (Price: 12.05, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 5900)
#    Processing: Molgra (Price: 10.2, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7147)
#
# ✅ Successfully synced product Altis" Baklijst Eik Fineer
#
# ================================================================================
# Processing product 14/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 17074
#    Name: Aluminium Baklijst 2mm Zwart (kopie)
#    Default Code: 433-24.O41
#    Product Code: 433-24
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Molgra (Price: 6.99, Preferred: True)
#    Seller #2: Tfc (Price: 12.0, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = 433-24...
# ✅ Found matching product in V18: ID 11537
#
# ✅ Product Template (V18):
#    ID: 11537
#    Name: Aluminium Baklijst  Zwart 2 x 48mm
#    Current Seller IDs: [5907, 7148]
#
# Existing sellers in V18:
#    - Molgra (Price: 6.99, Sequence: 1)
#    - Tfc (Price: 12.0, Sequence: 1)
#
# Syncing sellers...
#    Processing: Molgra (Price: 6.99, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 5907)
#    Processing: Tfc (Price: 12.0, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7148)
#
# ✅ Successfully synced product Aluminium Baklijst 2mm Zwart (kopie)
#
# ================================================================================
# Processing product 15/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 13446
#    Name: Amerikaanse Lijst Blank 65/60 K1160 (kopie)
#    Default Code: 015-108.O18
#    Product Code: 015-108
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 9.0, Preferred: False)
#    Seller #2: Nielsen Design (Price: 6.3, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 015-108...
# ✅ Found matching product in V18: ID 11907
#
# ✅ Product Template (V18):
#    ID: 11907
#    Name: Donkerblauw met lichte bol K1100
#    Current Seller IDs: [7150, 7149]
#
# Existing sellers in V18:
#    - Nielsen Design (Price: 6.3, Sequence: 1)
#    - Eurolijsten (Price: 9.0, Sequence: 1)
#
# Syncing sellers...
#    Processing: Nielsen Design (Price: 6.3, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 7150)
#    Processing: Eurolijsten (Price: 9.0, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 7149)
#
# ✅ Successfully synced product Amerikaanse Lijst Blank 65/60 K1160 (kopie)
#
# ================================================================================
# Processing product 16/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6966
#    Name: Antique White
#    Default Code: GSRM3293.D8
#    Product Code: GSRM3293
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 5.5, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = GSRM3293...
# ✅ Found matching product in V18: ID 13268
#
# ✅ Product Template (V18):
#    ID: 13268
#    Name: Antique White
#    Current Seller IDs: [7151]
#
# Existing sellers in V18:
#    - Eurolijsten (Price: 5.5, Sequence: 1)
#
# Syncing sellers...
#    Processing: Eurolijsten (Price: 5.5, Sequence: 1, Preferred: False)
#       ✅ Updated existing seller (ID: 7151)
#    Processing: Tfc (Price: 6.5, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7152)
#
# ✅ Successfully synced product Antique White
#
# ================================================================================
# Processing product 17/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16541
#    Name: Arctic White
#    Default Code: BLACK CORE 63297.PP
#    Product Code: BLACK CORE 63297
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 12.42, Preferred: False)
#    Seller #2: Tfc (Price: 10.0, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = BLACK CORE 63297...
# ✅ Found matching product in V18: ID 13272
#
# ✅ Product Template (V18):
#    ID: 13272
#    Name: Arctic White
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 10.0, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7153)
#    Processing: Eurolijsten (Price: 12.42, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7154)
#
# ✅ Successfully synced product Arctic White
#
# ================================================================================
# Processing product 18/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16506
#    Name: Arctic White
#    Default Code: GSRM3297.PP
#    Product Code: GSRM3297
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 6.74, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM3297...
# ✅ Found matching product in V18: ID 13273
#
# ✅ Product Template (V18):
#    ID: 13273
#    Name: Arctic White
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7155)
#    Processing: Eurolijsten (Price: 6.74, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7156)
#
# ✅ Successfully synced product Arctic White
#
# ================================================================================
# Processing product 19/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16502
#    Name: Art Deco Green
#    Default Code: GSRM3328.D9
#    Product Code: GSRM3328
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.63, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM3328...
# ✅ Found matching product in V18: ID 13275
#
# ✅ Product Template (V18):
#    ID: 13275
#    Name: Art Deco Green
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7157)
#    Processing: Eurolijsten (Price: 7.63, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7158)
#
# ✅ Successfully synced product Art Deco Green
#
# ================================================================================
# Processing product 20/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 37
#    Name: Artglass AR70
#    Default Code: False
#    Product Code: AR70
#    Number of Sellers: 3
#
# [V14] Fetching details for 3 seller records...
#
# Seller Information V14:
#    Seller #1: The Frame Company (Price: 60.0, Preferred: False)
#    Seller #2: Wybenga (Price: 42.0, Preferred: True)
#    Seller #3: Eurolijsten (Price: 52.0, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = AR70...
# ✅ Found matching product in V18: ID 11600
#
# ✅ Product Template (V18):
#    ID: 11600
#    Name: Artglass AR70
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Wybenga (Price: 42.0, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7159)
#    Processing: The Frame Company (Price: 60.0, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7160)
#    Processing: Eurolijsten (Price: 52.0, Sequence: 3, Preferred: False)
#       ✅ Created new seller (ID: 7161)
#
# ✅ Successfully synced product Artglass AR70
#
# ================================================================================
# Processing product 21/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16521
#    Name: Astral White
#    Default Code: GSRM945.PP
#    Product Code: GSRM945
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 6.73, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM945...
# ✅ Found matching product in V18: ID 13287
#
# ✅ Product Template (V18):
#    ID: 13287
#    Name: Astral White
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7162)
#    Processing: Eurolijsten (Price: 6.73, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7163)
#
# ✅ Successfully synced product Astral White
#
# ================================================================================
# Processing product 22/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16509
#    Name: Autumn Mist
#    Default Code: GSRM916.PP
#    Product Code: GSRM916
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM916...
# ✅ Found matching product in V18: ID 13289
#
# ✅ Product Template (V18):
#    ID: 13289
#    Name: Autumn Mist
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7164)
#    Processing: Eurolijsten (Price: 7.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7165)
#
# ✅ Successfully synced product Autumn Mist
#
# ================================================================================
# Processing product 23/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16484
#    Name: Baltic Blue
#    Default Code: GSRM1054.PP
#    Product Code: GSRM1054
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.35, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM1054...
# ✅ Found matching product in V18: ID 13290
#
# ✅ Product Template (V18):
#    ID: 13290
#    Name: Baltic Blue
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7166)
#    Processing: Eurolijsten (Price: 7.35, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7167)
#
# ✅ Successfully synced product Baltic Blue
#
# ================================================================================
# Processing product 24/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16519
#    Name: Bar Harbor Gray
#    Default Code: GSRM976.PP
#    Product Code: GSRM976
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM976...
# ✅ Found matching product in V18: ID 13291
#
# ✅ Product Template (V18):
#    ID: 13291
#    Name: Bar Harbor Gray
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7168)
#    Processing: Eurolijsten (Price: 7.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7169)
#
# ✅ Successfully synced product Bar Harbor Gray
#
# ================================================================================
# Processing product 25/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 704
#    Name: Barytte (Fine Art)
#    Default Code: BARYTTE.PRINT
#    Product Code: BARYTTE
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Bvba Gotech (Price: 103.3, Preferred: False)
#    Seller #2: The Frame Company (Price: 24.02, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = BARYTTE...
# ✅ Found matching product in V18: ID 13292
#
# ✅ Product Template (V18):
#    ID: 13292
#    Name: Barytte (Fine Art)
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: The Frame Company (Price: 24.02, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7170)
#    Processing: Bvba Gotech (Price: 103.3, Sequence: 2, Preferred: False)
#       Creating partner 'Bvba Gotech' in V18...
#       ✅ Created partner with ID: 178
#       ✅ Created new seller (ID: 7171)
#
# ✅ Successfully synced product Barytte (Fine Art)
#
# ================================================================================
# Processing product 26/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16477
#    Name: Bimini Blue
#    Default Code: GSRM1080.PP
#    Product Code: GSRM1080
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.62, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM1080...
# ✅ Found matching product in V18: ID 13294
#
# ✅ Product Template (V18):
#    ID: 13294
#    Name: Bimini Blue
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7172)
#    Processing: Eurolijsten (Price: 7.62, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7173)
#
# ✅ Successfully synced product Bimini Blue
#
# ================================================================================
# Processing product 27/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16538
#    Name: Biscay Blue
#    Default Code: BLACK CORE 61073.PP
#    Product Code: BLACK CORE 61073
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 10.47, Preferred: False)
#    Seller #2: Tfc (Price: 10.0, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = BLACK CORE 61073...
# ✅ Found matching product in V18: ID 13295
#
# ✅ Product Template (V18):
#    ID: 13295
#    Name: Biscay Blue
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 10.0, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7174)
#    Processing: Eurolijsten (Price: 10.47, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7175)
#
# ✅ Successfully synced product Biscay Blue
#
# ================================================================================
# Processing product 28/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16482
#    Name: Biscay Blue
#    Default Code: GSRM1073.PP
#    Product Code: GSRM1073
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.35, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM1073...
# ✅ Found matching product in V18: ID 13296
#
# ✅ Product Template (V18):
#    ID: 13296
#    Name: Biscay Blue
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7176)
#    Processing: Eurolijsten (Price: 7.35, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7177)
#
# ✅ Successfully synced product Biscay Blue
#
# ================================================================================
# Processing product 29/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6940
#    Name: Bisque
#    Default Code: 4772.B7
#    Product Code: 4772
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 5.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 4772...
# ✅ Found matching product in V18: ID 13297
#
# ✅ Product Template (V18):
#    ID: 13297
#    Name: Bisque
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7178)
#    Processing: Nielsen Design (Price: 5.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7179)
#
# ✅ Successfully synced product Bisque
#
# ================================================================================
# Processing product 30/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6932
#    Name: Black
#    Default Code: 4089.A7
#    Product Code: 4089
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 5.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 4089...
# ✅ Found matching product in V18: ID 13298
#
# ✅ Product Template (V18):
#    ID: 13298
#    Name: Black
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7180)
#    Processing: Nielsen Design (Price: 5.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7181)
#
# ✅ Successfully synced product Black
#
# ================================================================================
# Processing product 31/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16615
#    Name: Black - Black Core - Oversize (kopie)
#    Default Code: 5089.C6
#    Product Code: 5089
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 5.5, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 5089...
# ✅ Found matching product in V18: ID 13300
#
# ✅ Product Template (V18):
#    ID: 13300
#    Name: Black - Black Core
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7182)
#    Processing: Nielsen Design (Price: 5.5, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7183)
#
# ✅ Successfully synced product Black - Black Core - Oversize (kopie)
#
# ================================================================================
# Processing product 32/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16476
#    Name: Black Walnut
#    Default Code: GSRM3349.PP
#    Product Code: GSRM3349
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 10.47, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM3349...
# ✅ Found matching product in V18: ID 13310
#
# ✅ Product Template (V18):
#    ID: 13310
#    Name: Black Walnut
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7184)
#    Processing: Eurolijsten (Price: 10.47, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7185)
#
# ✅ Successfully synced product Black Walnut
#
# ================================================================================
# Processing product 33/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16531
#    Name: Blaze
#    Default Code: CS5504.PP
#    Product Code: CS5504
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 17.55, Preferred: False)
#    Seller #2: Tfc (Price: 22.94, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = CS5504...
# ✅ Found matching product in V18: ID 13312
#
# ✅ Product Template (V18):
#    ID: 13312
#    Name: Blaze
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 22.94, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7186)
#    Processing: Eurolijsten (Price: 17.55, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7187)
#
# ✅ Successfully synced product Blaze
#
# ================================================================================
# Processing product 34/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16617
#    Name: Brilliant White - Oversize (kopie)
#    Default Code: 4071.X
#    Product Code: 4071
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen (Price: 5.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 4071...
# ✅ Found matching product in V18: ID 13313
#
# ✅ Product Template (V18):
#    ID: 13313
#    Name: Brilliant White
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7188)
#    Processing: Nielsen (Price: 5.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7189)
#
# ✅ Successfully synced product Brilliant White - Oversize (kopie)
#
# ================================================================================
# Processing product 35/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6936
#    Name: Candlewick
#    Default Code: 4756.A13
#    Product Code: 4756
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 5.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 4756...
# ✅ Found matching product in V18: ID 13316
#
# ✅ Product Template (V18):
#    ID: 13316
#    Name: Candlewick
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7190)
#    Processing: Nielsen Design (Price: 5.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7191)
#
# ✅ Successfully synced product Candlewick
#
# ================================================================================
# Processing product 36/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6947
#    Name: Canvas
#    Default Code: GSRM500.C13
#    Product Code: GSRM500
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM500...
# ✅ Found matching product in V18: ID 13317
#
# ✅ Product Template (V18):
#    ID: 13317
#    Name: Canvas
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7192)
#    Processing: Eurolijsten (Price: 7.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7193)
#
# ✅ Successfully synced product Canvas
#
# ================================================================================
# Processing product 37/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6943
#    Name: Chantilly
#    Default Code: 4824.B14
#    Product Code: 4824
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 5.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 4824...
# ✅ Found matching product in V18: ID 13318
#
# ✅ Product Template (V18):
#    ID: 13318
#    Name: Chantilly
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7194)
#    Processing: Nielsen Design (Price: 5.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7195)
#
# ✅ Successfully synced product Chantilly
#
# ================================================================================
# Processing product 38/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6927
#    Name: Charcoal
#    Default Code: 4041.A2
#    Product Code: 4041
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 5.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 4041...
# ✅ Found matching product in V18: ID 13319
#
# ✅ Product Template (V18):
#    ID: 13319
#    Name: Charcoal
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7196)
#    Processing: Nielsen Design (Price: 5.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7197)
#
# ✅ Successfully synced product Charcoal
#
# ================================================================================
# Processing product 39/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16494
#    Name: China Blue
#    Default Code: GSRM3360.B6
#    Product Code: GSRM3360
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.62, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM3360...
# ✅ Found matching product in V18: ID 13320
#
# ✅ Product Template (V18):
#    ID: 13320
#    Name: China Blue
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7198)
#    Processing: Eurolijsten (Price: 7.62, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7199)
#
# ✅ Successfully synced product China Blue
#
# ================================================================================
# Processing product 40/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16536
#    Name: Classic Beige
#    Default Code: CL5520.PP
#    Product Code: CL5520
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 22.03, Preferred: False)
#    Seller #2: Tfc (Price: 22.94, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = CL5520...
# ✅ Found matching product in V18: ID 13322
#
# ✅ Product Template (V18):
#    ID: 13322
#    Name: Classic Beige
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 22.94, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7200)
#    Processing: Eurolijsten (Price: 22.03, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7201)
#
# ✅ Successfully synced product Classic Beige
#
# ================================================================================
# Processing product 41/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 12787
#    Name: Clickrail wit 200cm (kopie)
#    Default Code: 9.23150.X
#    Product Code: 9.23150
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 17.5, Preferred: True)
#    Seller #2: Eurolijsten (Price: 85.0, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = 9.23150...
# ✅ Found matching product in V18: ID 11603
#
# ✅ Product Template (V18):
#    ID: 11603
#    Name: Artiteq Twister Met Perlon Ophangdraad 2 Mm 150 Cm
#    Current Seller IDs: [5976]
#
# Existing sellers in V18:
#    - Eurolijsten (Price: 17.5, Sequence: 1)
#
# Syncing sellers...
#    Processing: Eurolijsten (Price: 17.5, Sequence: 1, Preferred: True)
#       ✅ Updated existing seller (ID: 5976)
#    Processing: Eurolijsten (Price: 85.0, Sequence: 2, Preferred: False)
#       ✅ Updated existing seller (ID: 5976)
#
# ✅ Successfully synced product Clickrail wit 200cm (kopie)
#
# ================================================================================
# Processing product 42/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6938
#    Name: Cognac
#    Default Code: 4766.B3
#    Product Code: 4766
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 5.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 4766...
# ✅ Found matching product in V18: ID 13323
#
# ✅ Product Template (V18):
#    ID: 13323
#    Name: Cognac
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7202)
#    Processing: Nielsen Design (Price: 5.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7203)
#
# ✅ Successfully synced product Cognac
#
# ================================================================================
# Processing product 43/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6933
#    Name: Cream
#    Default Code: 4203.A8
#    Product Code: 4203
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 5.3, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 4203...
# ✅ Found matching product in V18: ID 13324
#
# ✅ Product Template (V18):
#    ID: 13324
#    Name: Cream
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7204)
#    Processing: Nielsen Design (Price: 5.3, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7205)
#
# ✅ Successfully synced product Cream
#
# ================================================================================
# Processing product 44/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6954
#    Name: Cream
#    Default Code: GSRM961.C9
#    Product Code: GSRM961
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 5.7, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM961...
# ✅ Found matching product in V18: ID 13325
#
# ✅ Product Template (V18):
#    ID: 13325
#    Name: Cream
#    Current Seller IDs: []
#
# ...
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7394)
#    Processing: Eurolijsten (Price: 6.84, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7395)
#
# ✅ Successfully synced product Very White
#
# ================================================================================
# Processing product 138/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16499
#    Name: Volcano Blue
#    Default Code: GSRM1081.PP
#    Product Code: GSRM1081
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.34, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM1081...
# ✅ Found matching product in V18: ID 13491
#
# ✅ Product Template (V18):
#    ID: 13491
#    Name: Volcano Blue
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7396)
#    Processing: Eurolijsten (Price: 7.34, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7397)
#
# ✅ Successfully synced product Volcano Blue
#
# ================================================================================
# Processing product 139/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16524
#    Name: Warm White
#    Default Code: GSRM1450.PP
#    Product Code: GSRM1450
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 6.74, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM1450...
# ✅ Found matching product in V18: ID 13492
#
# ✅ Product Template (V18):
#    ID: 13492
#    Name: Warm White
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7398)
#    Processing: Eurolijsten (Price: 6.74, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7399)
#
# ✅ Successfully synced product Warm White
#
# ================================================================================
# Processing product 140/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16556
#    Name: Wheat
#    Default Code: BLACK CORE 61029.PP
#    Product Code: BLACK CORE 61029
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 10.47, Preferred: False)
#    Seller #2: Tfc (Price: 10.0, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = BLACK CORE 61029...
# ✅ Found matching product in V18: ID 13493
#
# ✅ Product Template (V18):
#    ID: 13493
#    Name: Wheat
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 10.0, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7400)
#    Processing: Eurolijsten (Price: 10.47, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7401)
#
# ✅ Successfully synced product Wheat
#
# ================================================================================
# Processing product 141/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16474
#    Name: Wheat
#    Default Code: GSRM1029.PP
#    Product Code: GSRM1029
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.35, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM1029...
# ✅ Found matching product in V18: ID 13494
#
# ✅ Product Template (V18):
#    ID: 13494
#    Name: Wheat
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7402)
#    Processing: Eurolijsten (Price: 7.35, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7403)
#
# ✅ Successfully synced product Wheat
#
# ================================================================================
# Processing product 142/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6953
#    Name: White
#    Default Code: GSRM960.C10
#    Product Code: GSRM960
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 6.29, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM960...
# ✅ Found matching product in V18: ID 13495
#
# ✅ Product Template (V18):
#    ID: 13495
#    Name: White
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7404)
#    Processing: Eurolijsten (Price: 6.29, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7405)
#
# ✅ Successfully synced product White
#
# ================================================================================
# Processing product 143/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6946
#    Name: White & Cream
#    Default Code: GSRM33.C12
#    Product Code: GSRM33
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 6.74, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM33...
# ✅ Found matching product in V18: ID 13496
#
# ✅ Product Template (V18):
#    ID: 13496
#    Name: White & Cream
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7406)
#    Processing: Eurolijsten (Price: 6.74, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7407)
#
# ✅ Successfully synced product White & Cream
#
# ================================================================================
# Processing product 144/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6977
#    Name: White/Cream
#    Default Code: 9031.A1
#    Product Code: 9031
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 8.69, Preferred: False)
#    Seller #2: Tfc (Price: 10.0, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 9031...
# ✅ Found matching product in V18: ID 13505
#
# ✅ Product Template (V18):
#    ID: 13505
#    Name: White/Cream
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 10.0, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7408)
#    Processing: Nielsen Design (Price: 8.69, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7409)
#
# ✅ Successfully synced product White/Cream
#
# ================================================================================
# Processing product 145/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16483
#    Name: Williamsburg Blue
#    Default Code: GSRM1047.PP
#    Product Code: GSRM1047
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.62, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM1047...
# ✅ Found matching product in V18: ID 13506
#
# ✅ Product Template (V18):
#    ID: 13506
#    Name: Williamsburg Blue
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7410)
#    Processing: Eurolijsten (Price: 7.62, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7411)
#
# ✅ Successfully synced product Williamsburg Blue
#
# ================================================================================
# Processing product 146/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16545
#    Name: Williamsburg Green
#    Default Code: BLACK CORE 6988.PP
#    Product Code: BLACK CORE 6988
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 10.41, Preferred: False)
#    Seller #2: Tfc (Price: 10.0, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = BLACK CORE 6988...
# ✅ Found matching product in V18: ID 13508
#
# ✅ Product Template (V18):
#    ID: 13508
#    Name: Williamsburg Green - Black Core
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 10.0, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7412)
#    Processing: Eurolijsten (Price: 10.41, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7413)
#
# ✅ Successfully synced product Williamsburg Green
#
# ================================================================================
# Processing product 147/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6956
#    Name: Williamsburg Green
#    Default Code: GSRM988.C14
#    Product Code: GSRM988
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 8.59, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM988...
# ✅ Found matching product in V18: ID 13507
#
# ✅ Product Template (V18):
#    ID: 13507
#    Name: Williamsburg Green
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7414)
#    Processing: Eurolijsten (Price: 8.59, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7415)
#
# ✅ Successfully synced product Williamsburg Green
#
# ================================================================================
# Processing product 148/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 16493
#    Name: Williamsburg Red
#    Default Code: GSRM1042.PP
#    Product Code: GSRM1042
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 7.62, Preferred: False)
#    Seller #2: Tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM1042...
# ✅ Found matching product in V18: ID 13510
#
# ✅ Product Template (V18):
#    ID: 13510
#    Name: Williamsburg Red
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7416)
#    Processing: Eurolijsten (Price: 7.62, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7417)
#
# ✅ Successfully synced product Williamsburg Red
#
# ================================================================================
# Processing product 149/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 6948
#    Name: Yellow
#    Default Code: GSRM902.D8
#    Product Code: GSRM902
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Eurolijsten (Price: 5.71, Preferred: False)
#    Seller #2: tfc (Price: 6.5, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = GSRM902...
# ✅ Found matching product in V18: ID 13535
#
# ✅ Product Template (V18):
#    ID: 13535
#    Name: Yellow
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: tfc (Price: 6.5, Sequence: 1, Preferred: True)
#       Creating partner 'tfc' in V18...
#       ✅ Created partner with ID: 181
#       ✅ Created new seller (ID: 7418)
#    Processing: Eurolijsten (Price: 5.71, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7419)
#
# ✅ Successfully synced product Yellow
#
# ================================================================================
# Processing product 150/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 4943
#    Name: Zilver Blinkend 0,6 Cm
#    Default Code: 004-003.X
#    Product Code: 004-003
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 2.7, Preferred: False)
#    Seller #2: Nielsen Design (Price: 2.7, Preferred: True)
#
# [V18] Searching for product with x_studio_product_code = 004-003...
# ✅ Found matching product in V18: ID 12623
#
# ✅ Product Template (V18):
#    ID: 12623
#    Name: Zilver Blinkend 0,6 Cm
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Nielsen Design (Price: 2.7, Sequence: 1, Preferred: True)
#       ✅ Created new seller (ID: 7420)
#    Processing: Nielsen Design (Price: 2.7, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7421)
#
# ✅ Successfully synced product Zilver Blinkend 0,6 Cm
#
# ================================================================================
# Processing product 151/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 11376
#    Name: accent by nielsen aluminum picture frame Accent, 10x15 cm, Gold
#    Default Code: 51221.NIEL
#    Product Code: 51221
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 3.17, Preferred: False)
#    Seller #2: Nielsen Design (Price: 3.17, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = 51221...
# ✅ Found matching product in V18: ID 13540
#
# ✅ Product Template (V18):
#    ID: 13540
#    Name: accent by nielsen aluminum picture frame Accent, 10x15 cm, Gold
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Nielsen Design (Price: 3.17, Sequence: 1, Preferred: False)
#       ✅ Created new seller (ID: 7422)
#    Processing: Nielsen Design (Price: 3.17, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7423)
#
# ✅ Successfully synced product accent by nielsen aluminum picture frame Accent, 10x15 cm, Gold
#
# ================================================================================
# Processing product 152/152
# ================================================================================
#
# ✅ Product Template (V14):
#    ID: 726
#    Name: nielsen aluminium picture frame Classic, 13x18 cm, Gold
#    Default Code: 33201.NIEL
#    Product Code: 33201
#    Number of Sellers: 2
#
# [V14] Fetching details for 2 seller records...
#
# Seller Information V14:
#    Seller #1: Nielsen Design (Price: 5.94, Preferred: False)
#    Seller #2: Nielsen (Price: 16.95, Preferred: False)
#
# [V18] Searching for product with x_studio_product_code = 33201...
# ✅ Found matching product in V18: ID 14306
#
# ✅ Product Template (V18):
#    ID: 14306
#    Name: nielsen aluminium picture frame Classic, 13x18 cm, Gold
#    Current Seller IDs: []
#
# Syncing sellers...
#    Processing: Nielsen Design (Price: 5.94, Sequence: 1, Preferred: False)
#       ✅ Created new seller (ID: 7424)
#    Processing: Nielsen (Price: 16.95, Sequence: 2, Preferred: False)
#       ✅ Created new seller (ID: 7425)
#
# ✅ Successfully synced product nielsen aluminium picture frame Classic, 13x18 cm, Gold
#
# ================================================================================
# Sync complete!
# ================================================================================
#
# Summary:
#    Total products with multiple sellers: 152
#    Successfully synced: 147
#    Skipped: 5
#    Errors: 0
# ================================================================================

# %%
# Update seller_ids sequence for products with specific x_studio_variable_a_label values in V18
# This temporarily changes the sequence to trigger automated actions

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables for V18
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

# Define the target variable_a_label values
TARGET_VALUES = ['aankoopprijs', 'aankoopprijs_m2', 'leveranciersprijs', 'materiaalkost', 'price', 'prijs_papier']

print("=" * 80)
print(f"Updating seller_ids sequence for products with specific x_studio_variable_a_label values in V18")
print("=" * 80)
print(f"Target values: {', '.join(TARGET_VALUES)}")
print("=" * 80)

try:
    # Authenticate to V18
    print("\n[V18] Authenticating...")
    common_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
    uid_v18 = common_v18.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
    print(f"✅ V18 Authenticated! UID: {uid_v18}\n")
    
    # Create models proxy for V18
    models_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)
    
    # Get all product templates with matching x_studio_variable_a_label values
    print(f"[V18] Fetching product.template records with matching x_studio_variable_a_label values...")
    product_templates = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
        'product.template', 'search_read',
        [[['x_studio_variable_a_label', 'in', TARGET_VALUES]]],
        {'fields': ['id', 'name', 'default_code', 'x_studio_variable_a_label', 'seller_ids']})
    
    print(f"✅ Found {len(product_templates)} product templates matching criteria\n")
    
    if not product_templates:
        print(f"❌ No products found with the specified x_studio_variable_a_label values!")
    else:
        processed_count = 0
        updated_count = 0
        skipped_count = 0
        error_count = 0
        
        for product in product_templates:
            try:
                processed_count += 1
                print(f"\n[{processed_count}/{len(product_templates)}] Processing product:")
                print(f"   ID: {product['id']}")
                print(f"   Name: {product['name']}")
                print(f"   Code: {product['default_code']}")
                print(f"   Variable A Label: {product['x_studio_variable_a_label']}")
                print(f"   Seller IDs: {product['seller_ids']}")
                
                if not product['seller_ids']:
                    print(f"   ⚠️  No seller_ids found - skipping")
                    skipped_count += 1
                    continue
                
                # Get detailed seller information
                sellers = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'product.supplierinfo', 'search_read',
                    [[['id', 'in', product['seller_ids']]]],
                    {'fields': ['id', 'partner_id', 'price', 'sequence']})
                
                print(f"   Current sellers ({len(sellers)}):")
                for seller in sellers:
                    print(f"      - ID: {seller['id']}, Partner: {seller['partner_id'][1]}, Price: {seller['price']}, Sequence: {seller['sequence']}")
                
                # Find the first seller with sequence 1
                seller_with_seq_1 = next((s for s in sellers if s['sequence'] == 1), None)
                
                if seller_with_seq_1:
                    print(f"   Found seller with sequence 1: ID {seller_with_seq_1['id']}")
                    
                    # Step 1: Change sequence from 1 to 2
                    print(f"      Step 1: Changing sequence from 1 to 2...")
                    models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                        'product.supplierinfo', 'write',
                        [[seller_with_seq_1['id']], {'sequence': 2}])
                    print(f"      ✅ Changed sequence to 2")
                    
                    # Step 2: Change sequence back from 2 to 1
                    print(f"      Step 2: Changing sequence back from 2 to 1...")
                    models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                        'product.supplierinfo', 'write',
                        [[seller_with_seq_1['id']], {'sequence': 1}])
                    print(f"      ✅ Changed sequence back to 1")
                    
                    updated_count += 1
                    print(f"   ✅ Successfully triggered automated action for product {product['id']}")
                else:
                    print(f"   ⚠️  No seller with sequence 1 found - skipping")
                    skipped_count += 1
                
            except Exception as e:
                error_count += 1
                print(f"   ❌ Error processing product {product['id']}: {e}")
                import traceback
                traceback.print_exc()
                continue
        
        print(f"\n{'=' * 80}")
        print(f"Update complete!")
        print(f"{'=' * 80}")
        print(f"Summary:")
        print(f"   Total products found: {len(product_templates)}")
        print(f"   Successfully updated: {updated_count}")
        print(f"   Skipped (no sellers or no sequence 1): {skipped_count}")
        print(f"   Errors: {error_count}")
        print("=" * 80)
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ================================================================================
# Updating seller_ids sequence for products with specific x_studio_variable_a_label values in V18
# ================================================================================
# Target values: aankoopprijs, aankoopprijs_m2, leveranciersprijs, materiaalkost, price, prijs_papier
# ================================================================================
#
# [V18] Authenticating...
# ✅ V18 Authenticated! UID: 2
#
# [V18] Fetching product.template records with matching x_studio_variable_a_label values...
# ✅ Found 227 product templates matching criteria
#
#
# [1/227] Processing product:
#    ID: 13261
#    Name: Alabaster
#    Code: 4825.C2
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7144, 7143]
#    Current sellers (2):
#       - ID: 7144, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7143, Partner: Nielsen Design, Price: 5.3, Sequence: 2
#    Found seller with sequence 1: ID 7144
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13261
#
# [2/227] Processing product:
#    ID: 13262
#    Name: Alabaster
#    Code: GSRM3300.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7139, 7140]
#    Current sellers (2):
#       - ID: 7139, Partner: Eurolijsten, Price: 5.5, Sequence: 1
#       - ID: 7140, Partner: Tfc, Price: 6.5, Sequence: 2
#    Found seller with sequence 1: ID 7139
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13262
#
# [3/227] Processing product:
#    ID: 13264
#    Name: Alabaster - Black Core
#    Code: BR74987.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [5893]
#    Current sellers (1):
#       - ID: 5893, Partner: Eurolijsten, Price: 17.95, Sequence: 1
#    Found seller with sequence 1: ID 5893
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13264
#
# [4/227] Processing product:
#    ID: 13263
#    Name: Alabaster - Black Core
#    Code: BLACK CORE 63300.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7142, 7141]
#    Current sellers (2):
#       - ID: 7142, Partner: Tfc, Price: 10.0, Sequence: 1
#       - ID: 7141, Partner: Eurolijsten, Price: 8.89, Sequence: 2
#    Found seller with sequence 1: ID 7142
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13263
#
# [5/227] Processing product:
#    ID: 13265
#    Name: Allsize Hoekverbinding
#    Code: 974017.SP
#    Variable A Label: aankoopprijs
#    Seller IDs: [5894]
#    Current sellers (1):
#       - ID: 5894, Partner: Eurolijsten, Price: 0.21, Sequence: 1
#    Found seller with sequence 1: ID 5894
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13265
#
# [6/227] Processing product:
#    ID: 13266
#    Name: Allsize Spielat 20mm
#    Code: 70402.SP
#    Variable A Label: aankoopprijs
#    Seller IDs: [5895]
#    Current sellers (1):
#       - ID: 5895, Partner: Eurolijsten, Price: 3.6, Sequence: 1
#    Found seller with sequence 1: ID 5895
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13266
#
# [7/227] Processing product:
#    ID: 13267
#    Name: Allsize Spielat 40mm
#    Code: 70502.SP
#    Variable A Label: aankoopprijs
#    Seller IDs: [5896]
#    Current sellers (1):
#       - ID: 5896, Partner: Eurolijsten, Price: 6.7, Sequence: 1
#    Found seller with sequence 1: ID 5896
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13267
#
# [8/227] Processing product:
#    ID: 11526
#    Name: Allsize tussen-en kruislat
#    Code: 70602.SP
#    Variable A Label: aankoopprijs
#    Seller IDs: [5897]
#    Current sellers (1):
#       - ID: 5897, Partner: Eurolijsten, Price: 2.85, Sequence: 1
#    Found seller with sequence 1: ID 5897
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 11526
#
# [9/227] Processing product:
#    ID: 13268
#    Name: Antique White
#    Code: GSRM3293.D8
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7151, 7152]
#    Current sellers (2):
#       - ID: 7151, Partner: Eurolijsten, Price: 5.5, Sequence: 1
#       - ID: 7152, Partner: Tfc, Price: 6.5, Sequence: 2
#    Found seller with sequence 1: ID 7151
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13268
#
# [10/227] Processing product:
#    ID: 13269
#    Name: Antique White - Oversize
#    Code: OSRM83293.pp
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [5957]
#    Current sellers (1):
#       - ID: 5957, Partner: Eurolijsten, Price: 11.0, Sequence: 1
#    Found seller with sequence 1: ID 5957
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13269
#
# [11/227] Processing product:
#    ID: 13270
#    Name: Aqua Green
#    Code: GSRM3357.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [5966]
#    Current sellers (1):
#       - ID: 5966, Partner: Eurolijsten, Price: 5.5, Sequence: 1
#    Found seller with sequence 1: ID 5966
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13270
#
# [12/227] Processing product:
#    ID: 13274
#    Name: Arctic White
#    Code: CJ 863297.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [5973]
#    Current sellers (1):
#       - ID: 5973, Partner: Eurolijsten, Price: 17.25, Sequence: 1
#    Found seller with sequence 1: ID 5973
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13274
#
# [13/227] Processing product:
#    ID: 13272
#    Name: Arctic White
#    Code: BLACK CORE 63297.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7153, 7154]
#    Current sellers (2):
#       - ID: 7153, Partner: Tfc, Price: 10.0, Sequence: 1
#       - ID: 7154, Partner: Eurolijsten, Price: 12.42, Sequence: 2
#    Found seller with sequence 1: ID 7153
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13272
#
# [14/227] Processing product:
#    ID: 13273
#    Name: Arctic White
#    Code: GSRM3297.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7155, 7156]
#    Current sellers (2):
#       - ID: 7155, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7156, Partner: Eurolijsten, Price: 6.74, Sequence: 2
#    Found seller with sequence 1: ID 7155
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13273
#
# [15/227] Processing product:
#    ID: 13271
#    Name: Arctic White
#    Code: BLACK CORE 2.2 623297.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [5972]
#    Current sellers (1):
#       - ID: 5972, Partner: Eurolijsten, Price: 17.25, Sequence: 1
#    Found seller with sequence 1: ID 5972
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13271
#
# [16/227] Processing product:
#    ID: 13275
#    Name: Art Deco Green
#    Code: GSRM3328.D9
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7157, 7158]
#    Current sellers (2):
#       - ID: 7157, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7158, Partner: Eurolijsten, Price: 7.63, Sequence: 2
#    Found seller with sequence 1: ID 7157
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13275
#
# [17/227] Processing product:
#    ID: 13278
#    Name: Ash - Suede
#    Code: CS5518.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [5979]
#    Current sellers (1):
#       - ID: 5979, Partner: Eurolijsten, Price: 22.94, Sequence: 1
#    Found seller with sequence 1: ID 5979
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13278
#
# [18/227] Processing product:
#    ID: 13287
#    Name: Astral White
#    Code: GSRM945.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7162, 7163]
#    Current sellers (2):
#       - ID: 7162, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7163, Partner: Eurolijsten, Price: 6.73, Sequence: 2
#    Found seller with sequence 1: ID 7162
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13287
#
# [19/227] Processing product:
#    ID: 13288
#    Name: Astral White 3.3mm
#    Code: 3045.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [5980]
#    Current sellers (1):
#       - ID: 5980, Partner: Eurolijsten, Price: 14.23, Sequence: 1
#    Found seller with sequence 1: ID 5980
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13288
#
# [20/227] Processing product:
#    ID: 13289
#    Name: Autumn Mist
#    Code: GSRM916.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7164, 7165]
#    Current sellers (2):
#       - ID: 7164, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7165, Partner: Eurolijsten, Price: 7.3, Sequence: 2
#    Found seller with sequence 1: ID 7164
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13289
#
# [21/227] Processing product:
#    ID: 13290
#    Name: Baltic Blue
#    Code: GSRM1054.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7166, 7167]
#    Current sellers (2):
#       - ID: 7166, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7167, Partner: Eurolijsten, Price: 7.35, Sequence: 2
#    Found seller with sequence 1: ID 7166
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13290
#
# [22/227] Processing product:
#    ID: 13291
#    Name: Bar Harbor Gray
#    Code: GSRM976.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7168, 7169]
#    Current sellers (2):
#       - ID: 7168, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7169, Partner: Eurolijsten, Price: 7.3, Sequence: 2
#    Found seller with sequence 1: ID 7168
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13291
#
# [23/227] Processing product:
#    ID: 13292
#    Name: Barytte (Fine Art)
#    Code: BARYTTE.PRINT
#    Variable A Label: prijs_papier
#    Seller IDs: [7170, 7171]
#    Current sellers (2):
#       - ID: 7170, Partner: The Frame Company, Price: 24.02, Sequence: 1
#       - ID: 7171, Partner: Bvba Gotech, Price: 103.3, Sequence: 2
#    Found seller with sequence 1: ID 7170
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13292
#
# [24/227] Processing product:
#    ID: 13293
#    Name: Berry - Suede
#    Code: CS5503.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6129]
#    Current sellers (1):
#       - ID: 6129, Partner: Eurolijsten, Price: 22.94, Sequence: 1
#    Found seller with sequence 1: ID 6129
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13293
#
# [25/227] Processing product:
#    ID: 13294
#    Name: Bimini Blue
#    Code: GSRM1080.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7172, 7173]
#    Current sellers (2):
#       - ID: 7172, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7173, Partner: Eurolijsten, Price: 7.62, Sequence: 2
#    Found seller with sequence 1: ID 7172
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13294
#
# [26/227] Processing product:
#    ID: 13295
#    Name: Biscay Blue
#    Code: BLACK CORE 61073.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7174, 7175]
#    Current sellers (2):
#       - ID: 7174, Partner: Tfc, Price: 10.0, Sequence: 1
#       - ID: 7175, Partner: Eurolijsten, Price: 10.47, Sequence: 2
#    Found seller with sequence 1: ID 7174
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13295
#
# [27/227] Processing product:
#    ID: 13296
#    Name: Biscay Blue
#    Code: GSRM1073.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7176, 7177]
#    Current sellers (2):
#       - ID: 7176, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7177, Partner: Eurolijsten, Price: 7.35, Sequence: 2
#    Found seller with sequence 1: ID 7176
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13296
#
# [28/227] Processing product:
#    ID: 13297
#    Name: Bisque
#    Code: 4772.B7
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7178, 7179]
#    Current sellers (2):
#       - ID: 7178, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7179, Partner: Nielsen Design, Price: 5.3, Sequence: 2
#    Found seller with sequence 1: ID 7178
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13297
#
# [29/227] Processing product:
#    ID: 13298
#    Name: Black
#    Code: 4089.A7
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7180, 7181]
#    Current sellers (2):
#       - ID: 7180, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7181, Partner: Nielsen Design, Price: 5.3, Sequence: 2
#    Found seller with sequence 1: ID 7180
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13298
#
# [30/227] Processing product:
#    ID: 13299
#    Name: Black (kopie)
#    Code: 4089.X
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6136]
#    Current sellers (1):
#       - ID: 6136, Partner: Nielsen Design, Price: 11.0, Sequence: 1
#    Found seller with sequence 1: ID 6136
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13299
#
# [31/227] Processing product:
#    ID: 13300
#    Name: Black - Black Core
#    Code: 5089.X
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7182, 7183]
#    Current sellers (2):
#       - ID: 7182, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7183, Partner: Nielsen Design, Price: 5.5, Sequence: 2
#    Found seller with sequence 1: ID 7182
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13300
#
# [32/227] Processing product:
#    ID: 13301
#    Name: Black - Black Core - Oversize
#    Code: 5089.C5
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6137]
#    Current sellers (1):
#       - ID: 6137, Partner: Nielsen Design, Price: 11.0, Sequence: 1
#    Found seller with sequence 1: ID 6137
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13301
#
# [33/227] Processing product:
#    ID: 13302
#    Name: Black - Blue Core
#    Code: C BR14921.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6138]
#    Current sellers (1):
#       - ID: 6138, Partner: Eurolijsten, Price: 16.75, Sequence: 1
#    Found seller with sequence 1: ID 6138
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13302
#
# [34/227] Processing product:
#    ID: 13303
#    Name: Black - Green Core
#    Code: BR24921.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6139]
#    Current sellers (1):
#       - ID: 6139, Partner: Eurolijsten, Price: 16.9, Sequence: 1
#    Found seller with sequence 1: ID 6139
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13303
#
# [35/227] Processing product:
#    ID: 13304
#    Name: Black - Pink Core
#    Code: C BR74921.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6140]
#    Current sellers (1):
#       - ID: 6140, Partner: Eurolijsten, Price: 17.95, Sequence: 1
#    Found seller with sequence 1: ID 6140
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13304
#
# [36/227] Processing product:
#    ID: 13305
#    Name: Black -Aqua Core
#    Code: BR84921.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6141]
#    Current sellers (1):
#       - ID: 6141, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6141
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13305
#
# [37/227] Processing product:
#    ID: 13306
#    Name: Black -Orange Core
#    Code: BR54921.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6142]
#    Current sellers (1):
#       - ID: 6142, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6142
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13306
#
# [38/227] Processing product:
#    ID: 13307
#    Name: Black -Purple Core
#    Code: BR64921.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6143]
#    Current sellers (1):
#       - ID: 6143, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6143
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13307
#
# [39/227] Processing product:
#    ID: 13308
#    Name: Black -Red Core
#    Code: BR34921.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6144]
#    Current sellers (1):
#       - ID: 6144, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6144
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13308
#
# [40/227] Processing product:
#    ID: 13309
#    Name: Black -Yellow Core
#    Code: BR44921.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6145]
#    Current sellers (1):
#       - ID: 6145, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6145
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13309
#
# [41/227] Processing product:
#    ID: 13310
#    Name: Black Walnut
#    Code: GSRM3349.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7184, 7185]
#    Current sellers (2):
#       - ID: 7184, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7185, Partner: Eurolijsten, Price: 10.47, Sequence: 2
#    Found seller with sequence 1: ID 7184
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13310
#
# [42/227] Processing product:
#    ID: 13311
#    Name: Black Walnut - Black Core
#    Code: BLACK CORE 63349.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6146]
#    Current sellers (1):
#       - ID: 6146, Partner: Eurolijsten, Price: 7.85, Sequence: 1
#    Found seller with sequence 1: ID 6146
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13311
#
# [43/227] Processing product:
#    ID: 13312
#    Name: Blaze
#    Code: CS5504.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7186, 7187]
#    Current sellers (2):
#       - ID: 7186, Partner: Tfc, Price: 22.94, Sequence: 1
#       - ID: 7187, Partner: Eurolijsten, Price: 17.55, Sequence: 2
#    Found seller with sequence 1: ID 7186
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13312
#
# [44/227] Processing product:
#    ID: 13313
#    Name: Brilliant White
#    Code: 4071.X
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7188, 7189]
#    Current sellers (2):
#       - ID: 7188, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7189, Partner: Nielsen, Price: 5.3, Sequence: 2
#    Found seller with sequence 1: ID 7188
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13313
#
# [45/227] Processing product:
#    ID: 13314
#    Name: Brilliant White - Oversize
#    Code: 4071.A5
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6168]
#    Current sellers (1):
#       - ID: 6168, Partner: Nielsen Design, Price: 11.0, Sequence: 1
#    Found seller with sequence 1: ID 6168
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13314
#
# [46/227] Processing product:
#    ID: 13315
#    Name: Brook
#    Code: CS5501.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6174]
#    Current sellers (1):
#       - ID: 6174, Partner: Eurolijsten, Price: 22.94, Sequence: 1
#    Found seller with sequence 1: ID 6174
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13315
#
# [47/227] Processing product:
#    ID: 11812
#    Name: Bubbelfolie 100cm (80My - 100m)
#    Code: BF.X
#    Variable A Label: leveranciersprijs
#    Seller IDs: [6199]
#    Current sellers (1):
#       - ID: 6199, Partner: Bovo Verpakking, Price: 25.19, Sequence: 1
#    Found seller with sequence 1: ID 6199
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 11812
#
# [48/227] Processing product:
#    ID: 11813
#    Name: Bubbelfolie 100cm (80My - 100m) (kopie)
#    Code: FK.VERPAKKING
#    Variable A Label: leveranciersprijs
#    Seller IDs: [6200]
#    Current sellers (1):
#       - ID: 6200, Partner: Eurolijsten, Price: 6.0, Sequence: 1
#    Found seller with sequence 1: ID 6200
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 11813
#
# [49/227] Processing product:
#    ID: 11815
#    Name: CLS-SLS 38x90mm
#    Code: CLS-SLS.X
#    Variable A Label: materiaalkost
#    Seller IDs: [6202]
#    Current sellers (1):
#       - ID: 6202, Partner: Rodegros - The Frame Company BV, Price: 2.5, Sequence: 1
#    Found seller with sequence 1: ID 6202
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 11815
#
# [50/227] Processing product:
#    ID: 13316
#    Name: Candlewick
#    Code: 4756.A13
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7190, 7191]
#    Current sellers (2):
#       - ID: 7190, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7191, Partner: Nielsen Design, Price: 5.3, Sequence: 2
#    Found seller with sequence 1: ID 7190
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13316
#
# [51/227] Processing product:
#    ID: 13317
#    Name: Canvas
#    Code: GSRM500.C13
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7192, 7193]
#    Current sellers (2):
#       - ID: 7192, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7193, Partner: Eurolijsten, Price: 7.3, Sequence: 2
#    Found seller with sequence 1: ID 7192
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13317
#
# [52/227] Processing product:
#    ID: 13318
#    Name: Chantilly
#    Code: 4824.B14
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7194, 7195]
#    Current sellers (2):
#       - ID: 7194, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7195, Partner: Nielsen Design, Price: 5.3, Sequence: 2
#    Found seller with sequence 1: ID 7194
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13318
#
# [53/227] Processing product:
#    ID: 13319
#    Name: Charcoal
#    Code: 4041.A2
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7196, 7197]
#    Current sellers (2):
#       - ID: 7196, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7197, Partner: Nielsen Design, Price: 5.3, Sequence: 2
#    Found seller with sequence 1: ID 7196
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13319
#
# [54/227] Processing product:
#    ID: 13320
#    Name: China Blue
#    Code: GSRM3360.B6
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7198, 7199]
#    Current sellers (2):
#       - ID: 7198, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7199, Partner: Eurolijsten, Price: 7.62, Sequence: 2
#    Found seller with sequence 1: ID 7198
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13320
#
# [55/227] Processing product:
#    ID: 13321
#    Name: Chinese Red
#    Code: GSRM3214.D9
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6212]
#    Current sellers (1):
#       - ID: 6212, Partner: Eurolijsten, Price: 5.5, Sequence: 1
#    Found seller with sequence 1: ID 6212
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13321
#
# [56/227] Processing product:
#    ID: 13322
#    Name: Classic Beige
#    Code: CL5520.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7200, 7201]
#    Current sellers (2):
#       - ID: 7200, Partner: Tfc, Price: 22.94, Sequence: 1
#       - ID: 7201, Partner: Eurolijsten, Price: 22.03, Sequence: 2
#    Found seller with sequence 1: ID 7200
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13322
#
# [57/227] Processing product:
#    ID: 13323
#    Name: Cognac
#    Code: 4766.B3
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7202, 7203]
#    Current sellers (2):
#       - ID: 7202, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7203, Partner: Nielsen Design, Price: 5.3, Sequence: 2
#    Found seller with sequence 1: ID 7202
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13323
#
# [58/227] Processing product:
#    ID: 13324
#    Name: Cream
#    Code: 4203.A8
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7204, 7205]
#    Current sellers (2):
#       - ID: 7204, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7205, Partner: Nielsen Design, Price: 5.3, Sequence: 2
#    Found seller with sequence 1: ID 7204
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13324
#
# [59/227] Processing product:
#    ID: 13325
#    Name: Cream
#    Code: GSRM961.C9
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7206, 7207]
#    Current sellers (2):
#       - ID: 7206, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7207, Partner: Eurolijsten, Price: 5.7, Sequence: 2
#    Found seller with sequence 1: ID 7206
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13325
#
# [60/227] Processing product:
#    ID: 13326
#    Name: Crimson
#    Code: GSRM1023.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7208, 7209]
#    Current sellers (2):
#       - ID: 7208, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7209, Partner: Eurolijsten, Price: 7.25, Sequence: 2
#    Found seller with sequence 1: ID 7208
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13326
#
# [61/227] Processing product:
#    ID: 13327
#    Name: Crimson - Black Core
#    Code: BLACK CORE 61023.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7210, 7211]
#    Current sellers (2):
#       - ID: 7210, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7211, Partner: Eurolijsten, Price: 7.25, Sequence: 2
#    Found seller with sequence 1: ID 7210
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13327
#
# [62/227] Processing product:
#    ID: 13335
#    Name: DOOS 75X114 CM
#    Code: DOOS75115b.BOX
#    Variable A Label: aankoopprijs
#    Seller IDs: [6286]
#    Current sellers (1):
#       - ID: 6286, Partner: Kartonnage Lefevere Beel Nv, Price: 2.36, Sequence: 1
#    Found seller with sequence 1: ID 6286
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13335
#
# [63/227] Processing product:
#    ID: 13336
#    Name: DOOS 75X115,5 CM Bovenstuk (kopie)
#    Code: DOOS75115o.BOX
#    Variable A Label: aankoopprijs
#    Seller IDs: []
#    ⚠️  No seller_ids found - skipping
#
# [64/227] Processing product:
#    ID: 13337
#    Name: DOOS 75X115,5 CM Onderstuk (kopie)
#    Code: DOOS75115v.BOX
#    Variable A Label: aankoopprijs
#    Seller IDs: []
#    ⚠️  No seller_ids found - skipping
#
# [65/227] Processing product:
#    ID: 13339
#    Name: Dark Ash
#    Code: BLACK CORE 61033.D13
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7212, 7213]
#    Current sellers (2):
#       - ID: 7212, Partner: Tfc, Price: 10.0, Sequence: 1
#       - ID: 7213, Partner: Eurolijsten, Price: 10.47, Sequence: 2
#    Found seller with sequence 1: ID 7212
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13339
#
# [66/227] Processing product:
#    ID: 13338
#    Name: Dark Ash
#    Code: GSRM1033.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6287]
#    Current sellers (1):
#       - ID: 6287, Partner: Eurolijsten, Price: 6.5, Sequence: 1
#    Found seller with sequence 1: ID 6287
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13338
#
# [67/227] Processing product:
#    ID: 13340
#    Name: Dark Green
#    Code: GSRM939.D6
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6288]
#    Current sellers (1):
#       - ID: 6288, Partner: Eurolijsten, Price: 5.5, Sequence: 1
#    Found seller with sequence 1: ID 6288
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13340
#
# [68/227] Processing product:
#    ID: 13341
#    Name: Dark Grey
#    Code: GSRM924.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7214, 7215]
#    Current sellers (2):
#       - ID: 7214, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7215, Partner: Eurolijsten, Price: 6.73, Sequence: 2
#    Found seller with sequence 1: ID 7214
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13341
#
# [69/227] Processing product:
#    ID: 13342
#    Name: Dark Olive
#    Code: GSRM1032.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7218, 7219]
#    Current sellers (2):
#       - ID: 7218, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7219, Partner: Eurolijsten, Price: 6.73, Sequence: 2
#    Found seller with sequence 1: ID 7218
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13342
#
# [70/227] Processing product:
#    ID: 13343
#    Name: Dark Olive
#    Code: BLACK CORE 61032.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7216, 7217]
#    Current sellers (2):
#       - ID: 7216, Partner: Tfc, Price: 10.0, Sequence: 1
#       - ID: 7217, Partner: Eurolijsten, Price: 10.47, Sequence: 2
#    Found seller with sequence 1: ID 7216
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13343
#
# [71/227] Processing product:
#    ID: 13344
#    Name: Dawn Gray
#    Code: GSRM974.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7220, 7221]
#    Current sellers (2):
#       - ID: 7220, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7221, Partner: Eurolijsten, Price: 7.63, Sequence: 2
#    Found seller with sequence 1: ID 7220
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13344
#
# [72/227] Processing product:
#    ID: 13345
#    Name: Delft Blue
#    Code: 4885.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6289]
#    Current sellers (1):
#       - ID: 6289, Partner: Nielsen, Price: 8.4, Sequence: 1
#    Found seller with sequence 1: ID 6289
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13345
#
# [73/227] Processing product:
#    ID: 13346
#    Name: Dibond 2mm (kopie)
#    Code: Dibond3mmx
#    Variable A Label: aankoopprijs
#    Seller IDs: [6297]
#    Current sellers (1):
#       - ID: 6297, Partner: Thyssenkrupp, Price: 29.56, Sequence: 1
#    Found seller with sequence 1: ID 6297
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13346
#
# [74/227] Processing product:
#    ID: 13347
#    Name: Dibond 3mm (kopie)
#    Code: ZKF.X
#    Variable A Label: aankoopprijs
#    Seller IDs: [6298]
#    Current sellers (1):
#       - ID: 6298, Partner: Thyssenkrupp, Price: 4.9, Sequence: 1
#    Found seller with sequence 1: ID 6298
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13347
#
# [75/227] Processing product:
#    ID: 13348
#    Name: Dilite 2mm
#    Code: Dilite2mm.X
#    Variable A Label: aankoopprijs
#    Seller IDs: [6299]
#    Current sellers (1):
#       - ID: 6299, Partner: Thyssenkrupp, Price: 20.34, Sequence: 1
#    Found seller with sequence 1: ID 6299
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13348
#
# [76/227] Processing product:
#    ID: 13349
#    Name: Dilite 3mm
#    Code: Dilite3mm.X
#    Variable A Label: aankoopprijs
#    Seller IDs: [6300]
#    Current sellers (1):
#       - ID: 6300, Partner: Thyssenkrupp, Price: 2217.0, Sequence: 1
#    Found seller with sequence 1: ID 6300
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13349
#
# [77/227] Processing product:
#    ID: 13350
#    Name: Dusty Blue
#    Code: GSRM1024.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7222, 7223]
#    Current sellers (2):
#       - ID: 7222, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7223, Partner: Eurolijsten, Price: 7.63, Sequence: 2
#    Found seller with sequence 1: ID 7222
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13350
#
# [78/227] Processing product:
#    ID: 13351
#    Name: Easter Egg
#    Code: 9560.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7273, 7274]
#    Current sellers (2):
#       - ID: 7273, Partner: Tfc, Price: 10.0, Sequence: 1
#       - ID: 7274, Partner: Eurolijsten, Price: 8.65, Sequence: 2
#    Found seller with sequence 1: ID 7273
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13351
#
# [79/227] Processing product:
#    ID: 13352
#    Name: Epson Premium semigloss Photo Paper
#    Code: EPSPP.X
#    Variable A Label: prijs_papier
#    Seller IDs: [6332]
#    Current sellers (1):
#       - ID: 6332, Partner: Lab 9 Pro, Price: 8.99, Sequence: 1
#    Found seller with sequence 1: ID 6332
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13352
#
# [80/227] Processing product:
#    ID: 13353
#    Name: Etch (Fine Art Mat)
#    Code: ETCH.PRINT
#    Variable A Label: prijs_papier
#    Seller IDs: [7224, 7225]
#    Current sellers (2):
#       - ID: 7224, Partner: The Frame Company, Price: 28.14, Sequence: 1
#       - ID: 7225, Partner: Bvba Gotech, Price: 119.83, Sequence: 2
#    Found seller with sequence 1: ID 7224
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13353
#
# [81/227] Processing product:
#    ID: 13354
#    Name: Fabric White
#    Code: 4065.A4
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7226, 7227]
#    Current sellers (2):
#       - ID: 7226, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7227, Partner: Nielsen Design, Price: 5.3, Sequence: 2
#    Found seller with sequence 1: ID 7226
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13354
#
# [82/227] Processing product:
#    ID: 13355
#    Name: Foamboard 3mm
#    Code: Foam3.X
#    Variable A Label: aankoopprijs
#    Seller IDs: [6357]
#    Current sellers (1):
#       - ID: 6357, Partner: Eurolijsten, Price: 7.8, Sequence: 1
#    Found seller with sequence 1: ID 6357
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13355
#
# [83/227] Processing product:
#    ID: 13357
#    Name: Foamboard 5mm
#    Code: Foam10.X
#    Variable A Label: aankoopprijs
#    Seller IDs: [6358]
#    Current sellers (1):
#       - ID: 6358, Partner: Eurolijsten, Price: 24.65, Sequence: 1
#    Found seller with sequence 1: ID 6358
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13357
#
# [84/227] Processing product:
#    ID: 13356
#    Name: Foamboard 5mm
#    Code: Foam5.X
#    Variable A Label: aankoopprijs
#    Seller IDs: [6359]
#    Current sellers (1):
#       - ID: 6359, Partner: Eurolijsten, Price: 10.0, Sequence: 1
#    Found seller with sequence 1: ID 6359
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13356
#
# [85/227] Processing product:
#    ID: 13358
#    Name: Fog
#    Code: GSRM915.D2
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6360]
#    Current sellers (1):
#       - ID: 6360, Partner: Eurolijsten, Price: 5.5, Sequence: 1
#    Found seller with sequence 1: ID 6360
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13358
#
# [86/227] Processing product:
#    ID: 13359
#    Name: Fog - Black Core
#    Code: BLACK CORE 6915.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7228, 7229]
#    Current sellers (2):
#       - ID: 7228, Partner: Tfc, Price: 10.0, Sequence: 1
#       - ID: 7229, Partner: Eurolijsten, Price: 10.41, Sequence: 2
#    Found seller with sequence 1: ID 7228
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13359
#
# [87/227] Processing product:
#    ID: 13360
#    Name: Forex Wit 10mm
#    Code: ForexW10.X
#    Variable A Label: aankoopprijs
#    Seller IDs: [6362]
#    Current sellers (1):
#       - ID: 6362, Partner: Thyssenkrupp, Price: 40.03, Sequence: 1
#    Found seller with sequence 1: ID 6362
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13360
#
# [88/227] Processing product:
#    ID: 13361
#    Name: Forex Wit 10mm (kopie)
#    Code: ForexW19.X
#    Variable A Label: aankoopprijs
#    Seller IDs: [6365]
#    Current sellers (1):
#       - ID: 6365, Partner: Thyssenkrupp, Price: 68.85, Sequence: 1
#    Found seller with sequence 1: ID 6365
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13361
#
# [89/227] Processing product:
#    ID: 13362
#    Name: Forex Wit 10mm (kopie)
#    Code: Dibond2mm.X
#    Variable A Label: aankoopprijs
#    Seller IDs: [6364]
#    Current sellers (1):
#       - ID: 6364, Partner: Thyssenkrupp, Price: 27.66, Sequence: 1
#    Found seller with sequence 1: ID 6364
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13362
#
# [90/227] Processing product:
#    ID: 13363
#    Name: Forex Wit 10mm (kopie)
#    Code: ForexW5.X
#    Variable A Label: aankoopprijs
#    Seller IDs: [6363]
#    Current sellers (1):
#       - ID: 6363, Partner: Thyssenkrupp, Price: 21.15, Sequence: 1
#    Found seller with sequence 1: ID 6363
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
# ...
#       - ID: 6931, Partner: Eurolijsten, Price: 22.94, Sequence: 1
#    Found seller with sequence 1: ID 6931
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13481
#
# [199/227] Processing product:
#    ID: 13482
#    Name: Treeline
#    Code: CS5500.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6935]
#    Current sellers (1):
#       - ID: 6935, Partner: Eurolijsten, Price: 22.94, Sequence: 1
#    Found seller with sequence 1: ID 6935
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13482
#
# [200/227] Processing product:
#    ID: 13484
#    Name: Verhoging kruisen 4,5 cm
#    Code: VK45.SPIE
#    Variable A Label: aankoopprijs
#    Seller IDs: [6947]
#    Current sellers (1):
#       - ID: 6947, Partner: Claessens Canvas, Price: 2.5, Sequence: 1
#    Found seller with sequence 1: ID 6947
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13484
#
# [201/227] Processing product:
#    ID: 13486
#    Name: Verhoging kruisen 4,5 cm 3D
#    Code: VK3D45.SPIE
#    Variable A Label: aankoopprijs
#    Seller IDs: [6948]
#    Current sellers (1):
#       - ID: 6948, Partner: Claessens Canvas, Price: 5.48, Sequence: 1
#    Found seller with sequence 1: ID 6948
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13486
#
# [202/227] Processing product:
#    ID: 13485
#    Name: Verhoging kruisen 5,5 cm
#    Code: VK55.SPIE
#    Variable A Label: aankoopprijs
#    Seller IDs: [6946]
#    Current sellers (1):
#       - ID: 6946, Partner: Claessens Canvas, Price: 6.7, Sequence: 1
#    Found seller with sequence 1: ID 6946
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13485
#
# [203/227] Processing product:
#    ID: 13489
#    Name: Very White
#    Code: GSRM918.C7
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7394, 7395]
#    Current sellers (2):
#       - ID: 7394, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7395, Partner: Eurolijsten, Price: 6.84, Sequence: 2
#    Found seller with sequence 1: ID 7394
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13489
#
# [204/227] Processing product:
#    ID: 13490
#    Name: Very White Oversize
#    Code: OSRM8918.pp
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6949]
#    Current sellers (1):
#       - ID: 6949, Partner: Eurolijsten, Price: 11.0, Sequence: 1
#    Found seller with sequence 1: ID 6949
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13490
#
# [205/227] Processing product:
#    ID: 13491
#    Name: Volcano Blue
#    Code: GSRM1081.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7396, 7397]
#    Current sellers (2):
#       - ID: 7396, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7397, Partner: Eurolijsten, Price: 7.34, Sequence: 2
#    Found seller with sequence 1: ID 7396
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13491
#
# [206/227] Processing product:
#    ID: 12568
#    Name: W.P.B. Elliotti Pine (multiplex)
#    Code: WPB.X
#    Variable A Label: materiaalkost
#    Seller IDs: [6955]
#    Current sellers (1):
#       - ID: 6955, Partner: Rodegros - The Frame Company BV, Price: 18.01, Sequence: 1
#    Found seller with sequence 1: ID 6955
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 12568
#
# [207/227] Processing product:
#    ID: 13492
#    Name: Warm White
#    Code: GSRM1450.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7398, 7399]
#    Current sellers (2):
#       - ID: 7398, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7399, Partner: Eurolijsten, Price: 6.74, Sequence: 2
#    Found seller with sequence 1: ID 7398
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13492
#
# [208/227] Processing product:
#    ID: 13493
#    Name: Wheat
#    Code: BLACK CORE 61029.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7400, 7401]
#    Current sellers (2):
#       - ID: 7400, Partner: Tfc, Price: 10.0, Sequence: 1
#       - ID: 7401, Partner: Eurolijsten, Price: 10.47, Sequence: 2
#    Found seller with sequence 1: ID 7400
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13493
#
# [209/227] Processing product:
#    ID: 13494
#    Name: Wheat
#    Code: GSRM1029.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7402, 7403]
#    Current sellers (2):
#       - ID: 7402, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7403, Partner: Eurolijsten, Price: 7.35, Sequence: 2
#    Found seller with sequence 1: ID 7402
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13494
#
# [210/227] Processing product:
#    ID: 13495
#    Name: White
#    Code: GSRM960.C10
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7404, 7405]
#    Current sellers (2):
#       - ID: 7404, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7405, Partner: Eurolijsten, Price: 6.29, Sequence: 2
#    Found seller with sequence 1: ID 7404
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13495
#
# [211/227] Processing product:
#    ID: 13496
#    Name: White & Cream
#    Code: GSRM33.C12
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7406, 7407]
#    Current sellers (2):
#       - ID: 7406, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7407, Partner: Eurolijsten, Price: 6.74, Sequence: 2
#    Found seller with sequence 1: ID 7406
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13496
#
# [212/227] Processing product:
#    ID: 13497
#    Name: White & Cream (kopie)
#    Code: GSRM3033.X
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6970]
#    Current sellers (1):
#       - ID: 6970, Partner: Eurolijsten, Price: 14.23, Sequence: 1
#    Found seller with sequence 1: ID 6970
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13497
#
# [213/227] Processing product:
#    ID: 13498
#    Name: White - Aqua Core
#    Code: BR84987.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6971]
#    Current sellers (1):
#       - ID: 6971, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6971
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13498
#
# [214/227] Processing product:
#    ID: 13499
#    Name: White - Blue Core
#    Code: BR14987.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6972]
#    Current sellers (1):
#       - ID: 6972, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6972
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13499
#
# [215/227] Processing product:
#    ID: 13500
#    Name: White - Green Core
#    Code: BR24987.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6973]
#    Current sellers (1):
#       - ID: 6973, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6973
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13500
#
# [216/227] Processing product:
#    ID: 13501
#    Name: White - Orange Core
#    Code: BR54987.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6974]
#    Current sellers (1):
#       - ID: 6974, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6974
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13501
#
# [217/227] Processing product:
#    ID: 13502
#    Name: White - Purple Core
#    Code: BR64987.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6975]
#    Current sellers (1):
#       - ID: 6975, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6975
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13502
#
# [218/227] Processing product:
#    ID: 13503
#    Name: White -Red Core
#    Code: BR34987.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6976]
#    Current sellers (1):
#       - ID: 6976, Partner: Eurolijsten, Price: 16.95, Sequence: 1
#    Found seller with sequence 1: ID 6976
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13503
#
# [219/227] Processing product:
#    ID: 13504
#    Name: White -Yellow Core
#    Code: BR844987.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: []
#    ⚠️  No seller_ids found - skipping
#
# [220/227] Processing product:
#    ID: 13505
#    Name: White/Cream
#    Code: 9031.A1
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7408, 7409]
#    Current sellers (2):
#       - ID: 7408, Partner: Tfc, Price: 10.0, Sequence: 1
#       - ID: 7409, Partner: Nielsen Design, Price: 8.69, Sequence: 2
#    Found seller with sequence 1: ID 7408
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13505
#
# [221/227] Processing product:
#    ID: 13506
#    Name: Williamsburg Blue
#    Code: GSRM1047.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7410, 7411]
#    Current sellers (2):
#       - ID: 7410, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7411, Partner: Eurolijsten, Price: 7.62, Sequence: 2
#    Found seller with sequence 1: ID 7410
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13506
#
# [222/227] Processing product:
#    ID: 13507
#    Name: Williamsburg Green
#    Code: GSRM988.C14
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7414, 7415]
#    Current sellers (2):
#       - ID: 7414, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7415, Partner: Eurolijsten, Price: 8.59, Sequence: 2
#    Found seller with sequence 1: ID 7414
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13507
#
# [223/227] Processing product:
#    ID: 13508
#    Name: Williamsburg Green - Black Core
#    Code: BLACK CORE 6988.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7412, 7413]
#    Current sellers (2):
#       - ID: 7412, Partner: Tfc, Price: 10.0, Sequence: 1
#       - ID: 7413, Partner: Eurolijsten, Price: 10.41, Sequence: 2
#    Found seller with sequence 1: ID 7412
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13508
#
# [224/227] Processing product:
#    ID: 13509
#    Name: Williamsburg Green - Oversize
#    Code: OSRM8988.pp
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6977]
#    Current sellers (1):
#       - ID: 6977, Partner: Eurolijsten, Price: 11.0, Sequence: 1
#    Found seller with sequence 1: ID 6977
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13509
#
# [225/227] Processing product:
#    ID: 13510
#    Name: Williamsburg Red
#    Code: GSRM1042.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7416, 7417]
#    Current sellers (2):
#       - ID: 7416, Partner: Tfc, Price: 6.5, Sequence: 1
#       - ID: 7417, Partner: Eurolijsten, Price: 7.62, Sequence: 2
#    Found seller with sequence 1: ID 7416
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13510
#
# [226/227] Processing product:
#    ID: 13511
#    Name: Winter White
#    Code: GSRM3354.PP
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [6978]
#    Current sellers (1):
#       - ID: 6978, Partner: Eurolijsten, Price: 5.5, Sequence: 1
#    Found seller with sequence 1: ID 6978
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13511
#
# [227/227] Processing product:
#    ID: 13535
#    Name: Yellow
#    Code: GSRM902.D8
#    Variable A Label: aankoopprijs_m2
#    Seller IDs: [7418, 7419]
#    Current sellers (2):
#       - ID: 7418, Partner: tfc, Price: 6.5, Sequence: 1
#       - ID: 7419, Partner: Eurolijsten, Price: 5.71, Sequence: 2
#    Found seller with sequence 1: ID 7418
#       Step 1: Changing sequence from 1 to 2...
#       ✅ Changed sequence to 2
#       Step 2: Changing sequence back from 2 to 1...
#       ✅ Changed sequence back to 1
#    ✅ Successfully triggered automated action for product 13535
#
# ================================================================================
# Update complete!
# ================================================================================
# Summary:
#    Total products found: 227
#    Successfully updated: 219
#    Skipped (no sellers or no sequence 1): 8
#    Errors: 0
# ================================================================================
