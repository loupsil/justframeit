# %%
# Compare BOMs between Odoo V14 and V18 to find mismatches

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables for V14
JUSTFRAMEIT_ODOO_V14_URL = os.getenv('JUSTFRAMEIT_ODOO_V14_URL')
JUSTFRAMEIT_ODOO_V14_DB = os.getenv('JUSTFRAMEIT_ODOO_V14_DB')
JUSTFRAMEIT_ODOO_V14_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_V14_USERNAME')
JUSTFRAMEIT_ODOO_V14_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_V14_API_KEY')

# Get environment variables for V18
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

print("=" * 80)
print("Comparing BOMs between Odoo V14 and V18")
print("=" * 80)

# Helper function to normalize product codes for comparison
def normalize_code(code):
    """Remove dots from product code for comparison"""
    if code:
        return str(code).replace('.', '')
    return ''

try:
    # Authenticate to V14
    print("\n[V14] Authenticating...")
    common_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/common", allow_none=True)
    uid_v14 = common_v14.authenticate(JUSTFRAMEIT_ODOO_V14_DB, JUSTFRAMEIT_ODOO_V14_USERNAME, JUSTFRAMEIT_ODOO_V14_API_KEY, {})
    print(f"✅ V14 Authenticated! UID: {uid_v14}")
    
    # Authenticate to V18
    print("\n[V18] Authenticating...")
    common_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
    uid_v18 = common_v18.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
    print(f"✅ V18 Authenticated! UID: {uid_v18}\n")
    
    # Create models proxies
    models_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/object", allow_none=True)
    models_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)
    
    # Define specific category IDs to check
    target_category_ids = [4, 8, 10, 57, 82]
    #target_category_ids = [10] #for testing
    
    print(f"Checking specific categories: {target_category_ids}\n")
    
    # Get category details from V14 (single call)
    categories = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.category', 'read',
        [target_category_ids],
        {'fields': ['display_name']})
    
    print("Categories to check:")
    for cat in categories:
        print(f"  - Category ID {cat['id']}: {cat['display_name']}")
    print()
    
    # Get all product templates in these categories from V14 (single call)
    print("[V14] Fetching product templates in these categories...")
    product_template_ids = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'search',
        [[['categ_id', 'in', target_category_ids]]])
    
    print(f"Found {len(product_template_ids)} product templates\n")
    
    # Search for BOMs with is_custom_made = False in V14 (single call)
    print("[V14] Searching for BOMs with is_custom_made = False...")
    print("=" * 80)
    
    bom_ids_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'mrp.bom', 'search',
        [[['product_tmpl_id', 'in', product_template_ids], ['is_custom_made', '=', False]]])
    
    print(f"\n[V14] Found {len(bom_ids_v14)} BOMs with is_custom_made = False\n")
    
    if not bom_ids_v14:
        print("No BOMs found with is_custom_made = False in V14")
    else:
        # Get ALL BOM details from V14 in a single call
        boms_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
            'mrp.bom', 'read',
            [bom_ids_v14],
            {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'is_custom_made', 'bom_line_ids']})
        
        # Get ALL BOM lines from V14 in a single call
        all_bom_line_ids_v14 = []
        for bom in boms_v14:
            if bom['bom_line_ids']:
                all_bom_line_ids_v14.extend(bom['bom_line_ids'])
        
        bom_lines_v14_dict = {}
        if all_bom_line_ids_v14:
            all_bom_lines_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'mrp.bom.line', 'read',
                [all_bom_line_ids_v14],
                {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
            
            # Get all product IDs from BOM lines to fetch product codes
            product_ids_v14 = [line['product_id'][0] for line in all_bom_lines_v14 if line['product_id']]
            
            # Fetch product codes for all products in V14
            products_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.product', 'read',
                [product_ids_v14],
                {'fields': ['id', 'product_code']})
            
            # Create a mapping of product_id to product_code
            product_code_map_v14 = {p['id']: p['product_code'] for p in products_v14}
            
            # Organize by bom_id for easy lookup
            for line in all_bom_lines_v14:
                bom_id = line['bom_id'][0] if line['bom_id'] else None
                if bom_id not in bom_lines_v14_dict:
                    bom_lines_v14_dict[bom_id] = []
                # Add product_code to the line data
                product_id = line['product_id'][0] if line['product_id'] else None
                line['product_code'] = product_code_map_v14.get(product_id, 'N/A')
                bom_lines_v14_dict[bom_id].append(line)
        
        # Collect all BOM IDs from V14 to search in V18 by code (reference)
        bom_ids_v14_as_strings = [str(bom['id']) for bom in boms_v14]
        
        # Search for ALL corresponding BOMs in V18 in a single call (matching V14 ID to V18 code)
        bom_ids_v18 = []
        if bom_ids_v14_as_strings:
            bom_ids_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'search',
                [[['code', 'in', bom_ids_v14_as_strings]]])
        
        # Get ALL BOM details from V18 in a single call
        boms_v18_dict = {}
        if bom_ids_v18:
            boms_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'read',
                [bom_ids_v18],
                {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'bom_line_ids']})
            
            # Organize by code for easy lookup
            for bom in boms_v18:
                if bom['code']:
                    boms_v18_dict[bom['code']] = bom
            
            # Get ALL BOM lines from V18 in a single call
            all_bom_line_ids_v18 = []
            for bom in boms_v18:
                if bom['bom_line_ids']:
                    all_bom_line_ids_v18.extend(bom['bom_line_ids'])
            
            bom_lines_v18_dict = {}
            if all_bom_line_ids_v18:
                all_bom_lines_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'mrp.bom.line', 'read',
                    [all_bom_line_ids_v18],
                    {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
                
                # Get all product IDs from BOM lines to fetch product codes
                product_ids_v18 = [line['product_id'][0] for line in all_bom_lines_v18 if line['product_id']]
                
                # Fetch product codes for all products in V18
                products_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'product.product', 'read',
                    [product_ids_v18],
                    {'fields': ['id', 'x_studio_product_code']})
                
                # Create a mapping of product_id to x_studio_product_code
                product_code_map_v18 = {p['id']: p['x_studio_product_code'] for p in products_v18}
                
                # Organize by bom_id for easy lookup
                for line in all_bom_lines_v18:
                    bom_id = line['bom_id'][0] if line['bom_id'] else None
                    if bom_id not in bom_lines_v18_dict:
                        bom_lines_v18_dict[bom_id] = []
                    # Add product_code to the line data
                    product_id = line['product_id'][0] if line['product_id'] else None
                    line['product_code'] = product_code_map_v18.get(product_id, 'N/A')
                    bom_lines_v18_dict[bom_id].append(line)
        
        # Collect mismatches and matches
        mismatches = []
        matches = []
        
        for bom_v14 in boms_v14:
            product_tmpl_name = bom_v14['product_tmpl_id'][1] if bom_v14['product_tmpl_id'] else 'N/A'
            product_variant_name = bom_v14['product_id'][1] if bom_v14['product_id'] else 'N/A (Template BOM)'
            bom_reference = bom_v14['code'] if bom_v14['code'] else 'No reference'
            bom_display_name = bom_v14['display_name'] if bom_v14['display_name'] else 'No display name'
            bom_id_v14 = str(bom_v14['id'])
            
            # Get BOM line components from V14 (from pre-fetched data)
            components_v14 = {}
            bom_lines = bom_lines_v14_dict.get(bom_v14['id'], [])
            
            for line in bom_lines:
                component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                component_code = line['product_code']
                component_qty = line['product_qty']
                # Use normalized code as key for comparison
                normalized_code = normalize_code(component_code)
                components_v14[normalized_code] = {
                    'name': component_name, 
                    'qty': component_qty,
                    'original_code': component_code
                }
            
            # Find corresponding BOM in V18 by matching V14 ID to V18 code (reference)
            bom_v18 = boms_v18_dict.get(bom_id_v14)
            
            if not bom_v18:
                mismatches.append({
                    'type': 'missing_v18',
                    'bom_v14': bom_v14,
                    'bom_id_v14': bom_id_v14,
                    'bom_reference': bom_reference,
                    'bom_display_name': bom_display_name,
                    'product_tmpl_name': product_tmpl_name,
                    'product_variant_name': product_variant_name,
                    'bom_lines': bom_lines
                })
                continue
            
            # Get BOM line components from V18 (from pre-fetched data)
            components_v18 = {}
            bom_lines_v18 = bom_lines_v18_dict.get(bom_v18['id'], [])
            
            for line in bom_lines_v18:
                component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                component_code = line['product_code']
                component_qty = line['product_qty']
                # Use normalized code as key for comparison
                normalized_code = normalize_code(component_code)
                components_v18[normalized_code] = {
                    'name': component_name, 
                    'qty': component_qty,
                    'original_code': component_code
                }
            
            # Compare components
            has_mismatch = False
            mismatch_details = []
            
            # Check for missing components in V18
            for normalized_code, component_data in components_v14.items():
                if normalized_code not in components_v18:
                    mismatch_details.append(f"    ❌ MISSING IN V18: {component_data['name']} (Code: {component_data['original_code']}, Qty in V14: {component_data['qty']})")
                    has_mismatch = True
                elif components_v18[normalized_code]['qty'] != component_data['qty']:
                    mismatch_details.append(f"    ⚠️  QUANTITY MISMATCH: {component_data['name']} (Code: {component_data['original_code']})")
                    mismatch_details.append(f"       V14 Qty: {component_data['qty']}")
                    mismatch_details.append(f"       V18 Qty: {components_v18[normalized_code]['qty']}")
                    has_mismatch = True
            
            # Check for extra components in V18
            for normalized_code, component_data in components_v18.items():
                if normalized_code not in components_v14:
                    mismatch_details.append(f"    ➕ EXTRA IN V18: {component_data['name']} (Code: {component_data['original_code']}, Qty: {component_data['qty']})")
                    has_mismatch = True
            
            if has_mismatch:
                mismatches.append({
                    'type': 'component_mismatch',
                    'bom_v14': bom_v14,
                    'bom_v18': bom_v18,
                    'bom_id_v14': bom_id_v14,
                    'bom_reference': bom_reference,
                    'bom_display_name': bom_display_name,
                    'product_tmpl_name': product_tmpl_name,
                    'product_variant_name': product_variant_name,
                    'bom_lines': bom_lines,
                    'bom_lines_v18': bom_lines_v18,
                    'mismatch_details': mismatch_details
                })
            else:
                matches.append({
                    'bom_v14': bom_v14,
                    'bom_v18': bom_v18,
                    'bom_id_v14': bom_id_v14,
                    'bom_reference': bom_reference,
                    'bom_display_name': bom_display_name,
                    'product_tmpl_name': product_tmpl_name,
                    'product_variant_name': product_variant_name,
                    'bom_lines': bom_lines,
                    'bom_lines_v18': bom_lines_v18
                })
        
        # Print mismatches first
        if mismatches:
            print("\n" + "=" * 80)
            print("MISMATCHES FOUND:")
            print("=" * 80)
            
            for mismatch in mismatches:
                print(f"\n{'=' * 80}")
                print(f"BOM ID (V14): {mismatch['bom_v14']['id']}")
                print(f"  Reference: {mismatch['bom_reference']}")
                print(f"  Display Name: {mismatch['bom_display_name']}")
                print(f"  Product Template: {mismatch['product_tmpl_name']}")
                print(f"  Product Variant: {mismatch['product_variant_name']}")
                print(f"  is_custom_made (V14): {mismatch['bom_v14']['is_custom_made']}")
                
                if mismatch['type'] == 'missing_v18':
                    print(f"\n  ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: '{mismatch['bom_id_v14']}')!")
                else:
                    print(f"\n  ✅ Found corresponding BOM in V18 (ID: {mismatch['bom_v18']['id']}, Code: '{mismatch['bom_v18']['code']}')")
                    
                    if mismatch['bom_lines']:
                        print(f"\n  [V14] Components ({len(mismatch['bom_lines'])} items):")
                        for line in mismatch['bom_lines']:
                            component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                            component_code = line['product_code']
                            component_qty = line['product_qty']
                            print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
                    else:
                        print(f"\n  [V14] Components: None")
                    
                    if mismatch['bom_lines_v18']:
                        print(f"\n  [V18] Components ({len(mismatch['bom_lines_v18'])} items):")
                        for line in mismatch['bom_lines_v18']:
                            component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                            component_code = line['product_code']
                            component_qty = line['product_qty']
                            print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
                    else:
                        print(f"\n  [V18] Components: None")
                    
                    print(f"\n  🔍 COMPARISON RESULTS:")
                    for detail in mismatch['mismatch_details']:
                        print(detail)
        
        # Print matches
        if matches:
            print("\n" + "=" * 80)
            print("MATCHES FOUND:")
            print("=" * 80)
            
            for match in matches:
                print(f"\n{'=' * 80}")
                print(f"BOM ID (V14): {match['bom_v14']['id']}")
                print(f"  Reference: {match['bom_reference']}")
                print(f"  Display Name: {match['bom_display_name']}")
                print(f"  Product Template: {match['product_tmpl_name']}")
                print(f"  Product Variant: {match['product_variant_name']}")
                print(f"  is_custom_made (V14): {match['bom_v14']['is_custom_made']}")
                print(f"\n  ✅ Found corresponding BOM in V18 (ID: {match['bom_v18']['id']}, Code: '{match['bom_v18']['code']}')")
                
                if match['bom_lines']:
                    print(f"\n  [V14] Components ({len(match['bom_lines'])} items):")
                    for line in match['bom_lines']:
                        component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                        component_code = line['product_code']
                        component_qty = line['product_qty']
                        print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
                else:
                    print(f"\n  [V14] Components: None")
                
                if match['bom_lines_v18']:
                    print(f"\n  [V18] Components ({len(match['bom_lines_v18'])} items):")
                    for line in match['bom_lines_v18']:
                        component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                        component_code = line['product_code']
                        component_qty = line['product_qty']
                        print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
                else:
                    print(f"\n  [V18] Components: None")
                
                print(f"\n  ✅ All components match perfectly!")
    
    print("\n" + "=" * 80)
    print(f"BOM comparison complete!")
    print(f"Total BOMs checked: {len(bom_ids_v14) if bom_ids_v14 else 0}")
    print(f"BOMs with mismatches: {len(mismatches) if 'mismatches' in locals() else 0}")
    print(f"BOMs with perfect matches: {len(matches) if 'matches' in locals() else 0}")
    print("=" * 80)
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ================================================================================
# Comparing BOMs between Odoo V14 and V18
# ================================================================================
#
# [V14] Authenticating...
# ✅ V14 Authenticated! UID: 28
#
# [V18] Authenticating...
# ✅ V18 Authenticated! UID: 2
#
# Checking specific categories: [4, 8, 10, 57, 82]
#
# Categories to check:
#   - Category ID 4: 0. Presets / 1. Presets zonder PP
#   - Category ID 8: 0. Presets / 2. Presets met PP
#   - Category ID 10: 0. Presets / 3. Losse verkopen
#   - Category ID 57: 0. Presets / 4. Losse PP
#   - Category ID 82: 0. Presets / Fixed margin
#
# [V14] Fetching product templates in these categories...
# Found 28 product templates
#
# [V14] Searching for BOMs with is_custom_made = False...
# ================================================================================
#
# [V14] Found 249 BOMs with is_custom_made = False
#
#
# ================================================================================
# MISMATCHES FOUND:
# ================================================================================
#
# ================================================================================
# BOM ID (V14): 92
#   Reference: Aluminium Spieraam met opspannen (25mm, Met tussenlat)
#   Display Name: Aluminium Spieraam met opspannen (25mm, Met tussenlat): Spieraam met opspannen
#   Product Template: Spieraam met opspannen
#   Product Variant: Spieraam met opspannen (25mm, Met tussenlat)
#   is_custom_made (V14): False
#
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: '92')!
#
# ================================================================================
# BOM ID (V14): 43
#   Reference: Askaders (Eik)
#   Display Name: Askaders (Eik): Askaders
#   Product Template: Askaders
#   Product Variant: Askaders (Eik)
#   is_custom_made (V14): False
#
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: '43')!
#
# ================================================================================
# BOM ID (V14): 3557
#   Reference: Los glas (Artglass AR92)
#   Display Name: Los glas (Artglass AR92): Los glas
#   Product Template: Los glas
#   Product Variant: Los glas (Artglass AR92)
#   is_custom_made (V14): False
#
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: '3557')!
#
# ================================================================================
# BOM ID (V14): 3556
#   Reference: Los glas (Artglass AR70)
#   Display Name: Los glas (Artglass AR70): Los glas
#   Product Template: Los glas
#   Product Variant: Los glas (Artglass AR70)
#   is_custom_made (V14): False
#
#   ❌ NO CORRESPONDING BOM FOUND IN V18 (searched by code: '3556')!
#
# ================================================================================
# MATCHES FOUND:
# ================================================================================
#
# ================================================================================
# BOM ID (V14): 53
#   Reference: Los glas (Blinked plexi glas 2mm)
#   Display Name: Los glas (Blinked plexi glas 2mm): Los glas
#   Product Template: Los glas
#   Product Variant: Los glas (Blinked plexi glas 2mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 746, Code: '53')
#
#   [V14] Components (4 items):
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   [V18] Components (4 items):
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT Verpakking (Code: MDF3MM, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT Verpakking (Code: MDF3MM, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 39
#   Reference: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, A)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 723, Code: '39')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 62
#   Reference: Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat))
#   Display Name: Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat)): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat))
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 721, Code: '62')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 4106
#   Reference: Puzzel + Kader custom (XXL)
#   Display Name: Puzzel + Kader custom (XXL): Puzzel + Kader custom
#   Product Template: Puzzel + Kader custom
#   Product Variant: Puzzel + Kader custom (XXL)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 593, Code: '4106')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond3mm.x] Dibond 2mm (kopie) (Code: Dibond3mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [Dibond3mmx] Dibond 2mm (kopie) (Code: Dibond3mm, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 124
#   Reference: Kader + Print (Mat glas, Etch (Fine Art Mat))
#   Display Name: Kader + Print (Mat glas, Etch (Fine Art Mat)): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, Etch (Fine Art Mat))
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 667, Code: '124')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6565
#   Reference: Kader + FM + Print (Mat glas, 3mm)
#   Display Name: Kader + FM + Print (Mat glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (3mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 845, Code: '6565')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6541
#   Reference: Kader + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 679, Code: '6541')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6547
#   Reference: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat pl, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 680, Code: '6547')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Mat plexiglas (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6549
#   Reference: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR70, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 674, Code: '6549')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6552
#   Reference: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Mat glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 714, Code: '6552')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6560
#   Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 227, Code: '6560')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6545
#   Reference: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 677, Code: '6545')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6548
#   Reference: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend plexi glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 678, Code: '6548')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6550
#   Reference: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR92, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 675, Code: '6550')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6553
#   Reference: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 712, Code: '6553')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6556
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Artglass AR70, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 709, Code: '6556')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6561
#   Reference: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR70, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 228, Code: '6561')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6566
#   Reference: Kader + FM + Print (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Blinkend glas, 3mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 910, Code: '6566')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6551
#   Reference: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR99, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 676, Code: '6551')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6554
#   Reference: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Mat pl, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 715, Code: '6554')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Mat plexiglas (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6559
#   Reference: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 213, Code: '6559')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6563
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 214, Code: '6563')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6568
#   Reference: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend plexi glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 544, Code: '6568')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 2.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6555
#   Reference: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 713, Code: '6555')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6562
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 215, Code: '6562')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6564
#   Reference: Kader + FM + Inlijsting (Geen glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Geen glas, 3mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 216, Code: '6564')
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (8 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6569
#   Reference: Kader + FM + Print (Artglass AR70, 3mm)
#   Display Name: Kader + FM + Print (Artglass AR70, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Artglass AR70, 3mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 545, Code: '6569')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 2.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6557
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Artglass AR92, Matt Fibre)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 710, Code: '6557')
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
# ...
#     - [PK75115.BOX] Plooikost doos 70x100 (Code: PK75115, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 153
#   Reference: Kader + Print (Mat plexi glas, Barytte (Fine Art))
#   Display Name: Kader + Print (Mat plexi glas, Barytte (Fine Art)): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat pl, B)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 670, Code: '153')
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [BARYTTE.PRINT] Barytte (Fine Art) (Code: BARYTTE, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Components (8 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Mat plexiglas (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [BARYTTE.PRINT] Barytte (Fine Art) (Code: BARYTTE, Qty: 1.0)
#     - [P16.K] Kleven op PVC (Code: P16, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 242
#   Reference: Los Dozen (40x40)
#   Display Name: Los Dozen (40x40): Los Dozen
#   Product Template: Los Dozen
#   Product Variant: [LD.X] Los Dozen (40x40)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 734, Code: '242')
#
#   [V14] Components (2 items):
#     - [DOOS4040.BOX] DOOS 40X40 CM (Code: DOOS4040, Qty: 1.0)
#     - [PK4040.BOX] Plooikost doos 40x40 (Code: PK4040, Qty: 1.0)
#
#   [V18] Components (2 items):
#     - [DOOS4040.BOX] DOOS 40X40 CM (Code: DOOS4040, Qty: 1.0)
#     - [PK4040.BOX] Plooikost doos 40x40 (Code: PK4040, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6140
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 230, Code: '6140')
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2.X] Econospacer Transparant (Code: ECOST2., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 146
#   Reference: Kader + PP (Artglass AR70)
#   Display Name: Kader + PP (Artglass AR70): Kader op maat + PP
#   Product Template: Kader op maat + PP
#   Product Variant: Kader op maat + PP (Artglass AR70)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 687, Code: '146')
#
#   [V14] Components (5 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [GSRM918.C7] Very White              (Code: GSRM918, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [GSRM918.C7] Very White              (Code: GSRM918, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 121
#   Reference: Kader + Print (Mat glas, Semi Matte Epson)
#   Display Name: Kader + Print (Mat glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, A)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 669, Code: '121')
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Components (8 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [P16.K] Kleven op PVC (Code: P16, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 4105
#   Reference: Puzzel + Kader custom (Normaal)
#   Display Name: Puzzel + Kader custom (Normaal): Puzzel + Kader custom
#   Product Template: Puzzel + Kader custom
#   Product Variant: [P109P] Puzzel + Kader custom (Normaal)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 594, Code: '4105')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond2mm.X] Forex Wit 10mm (kopie) (Code: Dibond2mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [Dibond2mm.X] Forex Wit 10mm (kopie) (Code: Dibond2mm, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6139
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 236, Code: '6139')
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2.X] Econospacer Transparant (Code: ECOST2., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 199
#   Reference: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   Display Name: [KOF5MM.diensten] Kleven op Fomeboard (5mm): Kleven op Fomeboard
#   Product Template: Kleven op Fomeboard
#   Product Variant: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 733, Code: '199')
#
#   [V14] Components (2 items):
#     - [SK5MM.X] Schuimkarton 5mm (Code: SK5MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Components (2 items):
#     - [SK5MM.X] Schuimkarton 5mm (Code: SK5MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6138
#   Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 2mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend plexi glas, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend plexi glas, 2mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 229, Code: '6138')
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2.X] Econospacer Transparant (Code: ECOST2., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 157
#   Reference: Kader + Print (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Kader + Print (Blinkend plexi glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend plexi glas, A)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 665, Code: '157')
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [P16.K] Kleven op PVC (Code: P16, Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM ID (V14): 6141
#   Reference: Kader + FM + Inlijsting (Geen glas, 2mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Geen glas, 2mm)
#   is_custom_made (V14): False
#
#   ✅ Found corresponding BOM in V18 (ID: 231, Code: '6141')
#
#   [V14] Components (9 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Components (9 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2.X] Econospacer Transparant (Code: ECOST2., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK., Qty: 1.0)
#
#   ✅ All components match perfectly!
#
# ================================================================================
# BOM comparison complete!
# Total BOMs checked: 249
# BOMs with mismatches: 4
# BOMs with perfect matches: 245
# ================================================================================

# %%
# Compare material_cost (V14) vs x_studio_computed_cost (V18) for product templates

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables for V14
JUSTFRAMEIT_ODOO_V14_URL = os.getenv('JUSTFRAMEIT_ODOO_V14_URL')
JUSTFRAMEIT_ODOO_V14_DB = os.getenv('JUSTFRAMEIT_ODOO_V14_DB')
JUSTFRAMEIT_ODOO_V14_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_V14_USERNAME')
JUSTFRAMEIT_ODOO_V14_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_V14_API_KEY')

# Get environment variables for V18
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

print("=" * 80)
print("Comparing material_cost (V14) vs x_studio_computed_cost (V18) for Product Templates")
print("=" * 80)

try:
    # Authenticate to V14
    print("\n[V14] Authenticating...")
    common_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/common", allow_none=True)
    uid_v14 = common_v14.authenticate(JUSTFRAMEIT_ODOO_V14_DB, JUSTFRAMEIT_ODOO_V14_USERNAME, JUSTFRAMEIT_ODOO_V14_API_KEY, {})
    print(f"✅ V14 Authenticated! UID: {uid_v14}")
    
    # Authenticate to V18
    print("\n[V18] Authenticating...")
    common_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
    uid_v18 = common_v18.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
    print(f"✅ V18 Authenticated! UID: {uid_v18}\n")
    
    # Create models proxies
    models_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/object", allow_none=True)
    models_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)
    
    # Define category IDs to EXCLUDE
    excluded_category_ids = [1, 4, 8, 10, 57, 82]
    
    print(f"Excluding categories: {excluded_category_ids}\n")
    
    # Get category details from V14
    categories = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.category', 'read',
        [excluded_category_ids],
        {'fields': ['display_name']})
    
    print("Categories to exclude:")
    for cat in categories:
        print(f"  - Category ID {cat['id']}: {cat['display_name']}")
    print()
    
    # Get all product templates from V14 excluding the specified categories
    print("[V14] Fetching product templates (excluding specified categories)...")
    template_ids_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'search',
        [[['categ_id', 'not in', excluded_category_ids]]])
    
    print(f"Found {len(template_ids_v14)} product templates in V14\n")
    
    # Get product template details from V14
    print("[V14] Reading product template details (id, product_code, material_cost, categ_id)...")
    templates_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'read',
        [template_ids_v14],
        {'fields': ['id', 'default_code', 'product_code', 'name', 'material_cost', 'categ_id']})
    
    print(f"Retrieved details for {len(templates_v14)} product templates\n")
    
    # Get all product codes from V14 (excluding None values)
    product_codes_v14 = [t['product_code'] for t in templates_v14 if t.get('product_code')]
    
    print(f"Found {len(product_codes_v14)} product templates with product_code in V14\n")
    
    # Fetch ALL matching product templates from V18 in ONE API call using product codes
    print("[V18] Fetching all matching product templates by x_studio_product_code in one call...")
    template_ids_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
        'product.template', 'search',
        [[['x_studio_product_code', 'in', product_codes_v14]]])
    
    print(f"Found {len(template_ids_v18)} matching product templates in V18\n")
    
    # Get all V18 product template details in ONE API call
    print("[V18] Reading all product template details in one call...")
    templates_v18_list = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
        'product.template', 'read',
        [template_ids_v18],
        {'fields': ['id', 'default_code', 'x_studio_product_code', 'name', 'x_studio_computed_cost']})
    
    # Create a dictionary for quick lookup by x_studio_product_code
    templates_v18_dict = {t['x_studio_product_code']: t for t in templates_v18_list if t.get('x_studio_product_code')}
    
    print(f"Retrieved details for {len(templates_v18_list)} product templates from V18\n")
    
    print("Comparing costs between V14 and V18:")
    print("-" * 80)
    
    mismatches_found = 0
    matches_found = 0
    templates_checked = 0
    templates_not_found_in_v18 = 0
    templates_without_product_code = 0
    
    for template_v14 in templates_v14:
        template_id = template_v14['id']
        template_code = template_v14['default_code']
        product_code_v14 = template_v14.get('product_code')
        template_name = template_v14['name']
        material_cost_v14 = template_v14['material_cost'] if template_v14['material_cost'] else 0.0
        category_name = template_v14['categ_id'][1] if template_v14['categ_id'] else 'N/A'
        
        # Skip if no product_code in V14
        if not product_code_v14:
            templates_without_product_code += 1
            continue
        
        templates_checked += 1
        
        # Look up product template in V18 dictionary by product_code
        template_v18 = templates_v18_dict.get(product_code_v14)
        
        if not template_v18:
            print(f"\n❌ Product Template NOT FOUND in V18:")
            print(f"   ID (V14): {template_id}")
            print(f"   Code: {template_code}")
            print(f"   product_code (V14): {product_code_v14}")
            print(f"   Name: {template_name}")
            print(f"   Category: {category_name}")
            print(f"   material_cost (V14): €{material_cost_v14:.2f}")
            templates_not_found_in_v18 += 1
            continue
        
        computed_cost_v18 = template_v18['x_studio_computed_cost'] if template_v18['x_studio_computed_cost'] else 0.0
        
        # Compare costs (with small tolerance for floating point comparison)
        tolerance = 0.01
        if abs(material_cost_v14 - computed_cost_v18) > tolerance:
            print(f"\n⚠️  COST MISMATCH:")
            print(f"   ID (V14): {template_id}")
            print(f"   ID (V18): {template_v18['id']}")
            print(f"   Code: {template_code}")
            print(f"   product_code (V14): {product_code_v14}")
            print(f"   x_studio_product_code (V18): {template_v18['x_studio_product_code']}")
            print(f"   Name (V14): {template_name}")
            print(f"   Name (V18): {template_v18['name']}")
            print(f"   Category: {category_name}")
            print(f"   material_cost (V14): €{material_cost_v14:.2f}")
            print(f"   x_studio_computed_cost (V18): €{computed_cost_v18:.2f}")
            print(f"   Difference: €{abs(material_cost_v14 - computed_cost_v18):.2f}")
            mismatches_found += 1
        else:
            matches_found += 1
    
    print("\n" + "=" * 80)
    print(f"Cost comparison complete!")
    print(f"Total product templates in V14 (excluding categories): {len(templates_v14)}")
    print(f"Product templates without product_code (skipped): {templates_without_product_code}")
    print(f"Product templates checked: {templates_checked}")
    print(f"Product templates not found in V18: {templates_not_found_in_v18}")
    print(f"Product templates with cost matches: {matches_found}")
    print(f"Product templates with cost mismatches: {mismatches_found}")
    print("=" * 80)
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ================================================================================
# Comparing material_cost (V14) vs x_studio_computed_cost (V18) for Product Templates
# ================================================================================
#
# [V14] Authenticating...
# ✅ V14 Authenticated! UID: 28
#
# [V18] Authenticating...
# ✅ V18 Authenticated! UID: 2
#
# Excluding categories: [1, 4, 8, 10, 57, 82]
#
# Categories to exclude:
#   - Category ID 1: 0. Presets
#   - Category ID 4: 0. Presets / 1. Presets zonder PP
#   - Category ID 8: 0. Presets / 2. Presets met PP
#   - Category ID 10: 0. Presets / 3. Losse verkopen
#   - Category ID 57: 0. Presets / 4. Losse PP
#   - Category ID 82: 0. Presets / Fixed margin
#
# [V14] Fetching product templates (excluding specified categories)...
# Found 3318 product templates in V14
#
# [V14] Reading product template details (id, product_code, material_cost, categ_id)...
# Retrieved details for 3318 product templates
#
# Found 3292 product templates with product_code in V14
#
# [V18] Fetching all matching product templates by x_studio_product_code in one call...
# Found 3234 matching product templates in V18
#
# [V18] Reading all product template details in one call...
# Retrieved details for 3234 product templates from V18
#
# Comparing costs between V14 and V18:
# --------------------------------------------------------------------------------
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4278
#    ID (V18): 9942
#    Code: 74980.X
#    product_code (V14): 74980
#    x_studio_product_code (V18): 74980
#    Name (V14): "Charles V" Spaanse Barok Goud
#    Name (V18): "Charles V" Spaanse Barok Goud
#    Category: 1. Lijsten
#    material_cost (V14): €38.16
#    x_studio_computed_cost (V18): €81.45
#    Difference: €43.29
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4507
#    ID (V18): 9944
#    Code: 81045.F20
#    product_code (V14): 81045
#    x_studio_product_code (V18): 81045
#    Name (V14): "Chique" Barok Grijs Geborsteld 5Cm
#    Name (V18): "Chique" Barok Grijs Geborsteld 5Cm
#    Category: 1. Lijsten
#    material_cost (V14): €28.42
#    x_studio_computed_cost (V18): €17.80
#    Difference: €10.62
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4506
#    ID (V18): 9945
#    Code: 81030.F20
#    product_code (V14): 81030
#    x_studio_product_code (V18): 81030
#    Name (V14): "Chique" Barok Groen Geborsteld 5Cm
#    Name (V18): "Chique" Barok Groen Geborsteld 5Cm
#    Category: 1. Lijsten
#    material_cost (V14): €28.42
#    x_studio_computed_cost (V18): €17.80
#    Difference: €10.62
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4503
#    ID (V18): 9946
#    Code: 80917.F19
#    product_code (V14): 80917
#    x_studio_product_code (V18): 80917
#    Name (V14): "Chique" Barok Ivoor Geborsteld 2,5Cm
#    Name (V18): "Chique" Barok Ivoor Geborsteld 2,5Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €6.67
#    Difference: €17.69
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4505
#    ID (V18): 9947
#    Code: 81017.F20
#    product_code (V14): 81017
#    x_studio_product_code (V18): 81017
#    Name (V14): "Chique" Barok Ivoor Geborsteld 5Cm
#    Name (V18): "Chique" Barok Ivoor Geborsteld 5Cm
#    Category: 1. Lijsten
#    material_cost (V14): €28.42
#    x_studio_computed_cost (V18): €17.80
#    Difference: €10.62
#
# ⚠️  COST MISMATCH:
#    ID (V14): 3806
#    ID (V18): 9950
#    Code: 80910.F19
#    product_code (V14): 80910
#    x_studio_product_code (V18): 80910
#    Name (V14): "Chique" Barok Zwart Geborsteld 2,5Cm
#    Name (V18): "Chique" Barok Zwart Geborsteld 2,5Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €6.67
#    Difference: €17.69
#
# ⚠️  COST MISMATCH:
#    ID (V14): 17023
#    ID (V18): 10011
#    Code: 71510.C17
#    product_code (V14): 71510
#    x_studio_product_code (V18): 71510
#    Name (V14): "GLOSS" BAKLIJST LAK WIT 50x40 (kopie)
#    Name (V18): "Gloss" Baklijst Lak Zwart K1155
#    Category: 1. Lijsten
#    material_cost (V14): €14.13
#    x_studio_computed_cost (V18): €13.25
#    Difference: €0.88
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16155
#    ID (V18): 11277
#    Code: 79810.X
#    product_code (V14): 79810
#    x_studio_product_code (V18): 79810
#    Name (V14): "LIME" BAKLIJST LINDE BLANK MET GOUDEN TOP 30x30 (kopie)
#    Name (V18): 79810.C1 Baklijst Noir30x30
#    Category: 1. Lijsten
#    material_cost (V14): €9.64
#    x_studio_computed_cost (V18): €17.05
#    Difference: €7.41
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4446
#    ID (V18): 10036
#    Code: 85275.E23
#    product_code (V14): 85275
#    x_studio_product_code (V18): 85275
#    Name (V14): "Minimal" Eik
#    Name (V18): "Minimal" Eik
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €4.78
#    Difference: €18.77
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4447
#    ID (V18): 10037
#    Code: 85278.E23
#    product_code (V14): 85278
#    x_studio_product_code (V18): 85278
#    Name (V14): "Minimal" Kers
#    Name (V18): "Minimal" Kers
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €4.78
#    Difference: €18.77
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4443
#    ID (V18): 10038
#    Code: 85236.E23
#    product_code (V14): 85236
#    x_studio_product_code (V18): 85236
#    Name (V14): "Minimal" Noten
#    Name (V18): "Minimal" Noten
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €4.78
#    Difference: €18.77
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4040
#    ID (V18): 10041
#    Code: 85203.E23
#    product_code (V14): 85203
#    x_studio_product_code (V18): 85203
#    Name (V14): "Minimal" Wit
#    Name (V18): "Minimal" Wit
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €4.78
#    Difference: €18.77
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4834
#    ID (V18): 10062
#    Code: 68217.N23
#    product_code (V14): 68217
#    x_studio_product_code (V18): 68217
#    Name (V14): "Pinus" Grenen Creme 2,5 Cm
#    Name (V18): "Pinus" Grenen Creme 2,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €2.85
#    Difference: €21.51
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4835
#    ID (V18): 10064
#    Code: 68247.N23
#    product_code (V14): 68247
#    x_studio_product_code (V18): 68247
#    Name (V14): "Pinus" Grenen Lichtgrijs 2,5 Cm
#    Name (V18): "Pinus" Grenen Lichtgrijs 2,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €2.85
#    Difference: €21.51
#
# ⚠️  COST MISMATCH:
#    ID (V14): 5207
#    ID (V18): 10083
#    Code: 73220.X
#    product_code (V14): 73220
#    x_studio_product_code (V18): 73220
#    Name (V14): "Riviera" Schelp Pastelblauw
#    Name (V18): "Riviera" Schelp Pastelblauw
#    Category: 1. Lijsten
#    material_cost (V14): €24.20
#    x_studio_computed_cost (V18): €4.29
#    Difference: €19.91
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4187
#    ID (V18): 10084
#    Code: 73215.X
#    product_code (V14): 73215
#    x_studio_product_code (V18): 73215
#    Name (V14): "Riviera" Schelp Wit
#    Name (V18): "Riviera" Schelp Wit
#    Category: 1. Lijsten
#    material_cost (V14): €24.20
#    x_studio_computed_cost (V18): €4.01
#    Difference: €20.19
#
# ⚠️  COST MISMATCH:
#    ID (V14): 3796
#    ID (V18): 10085
#    Code: 73210.E09
#    product_code (V14): 73210
#    x_studio_product_code (V18): 73210
#    Name (V14): "Riviera" Schelp Zwart
#    Name (V18): "Riviera" Schelp Zwart
#    Category: 1. Lijsten
#    material_cost (V14): €24.20
#    x_studio_computed_cost (V18): €3.97
#    Difference: €20.23
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4666
#    ID (V18): 12445
#    Code: 68867.X
#    product_code (V14): 68867
#    x_studio_product_code (V18): 68867
#    Name (V14): "Solid Wood" Amerikaanse Baklijst Eik K1090
#    Name (V18): Solid Wood Baklijst Eik 50x40
#    Category: 1. Lijsten
#    material_cost (V14): €26.68
#    x_studio_computed_cost (V18): €27.87
#    Difference: €1.19
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4914
#    ID (V18): 13545
#    Code: 53224.R16
#    product_code (V14): 53224
#    x_studio_product_code (V18): 53224
#    Name (V14): ''Lino,, Gestreept Bruin 2 Cm
#    Name (V18): accent by nielsen aluminum picture frame Accent, 13x18 cm, Frosted Silver
#    Category: 1. Lijsten
#    material_cost (V14): €3.57
#    x_studio_computed_cost (V18): €0.00
#    Difference: €3.57
#
# ⚠️  COST MISMATCH:
#    ID (V14): 3911
#    ID (V18): 13547
#    Code: 53221.R14
#    product_code (V14): 53221
#    x_studio_product_code (V18): 53221
#    Name (V14): ''Lino,, Gestreept Zwart 2 Cm
#    Name (V18): accent by nielsen aluminum picture frame Accent, 13x18 cm, Gold
#    Category: 1. Lijsten
#    material_cost (V14): €3.57
#    x_studio_computed_cost (V18): €0.00
#    Difference: €3.57
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17516
#    Code: 401.83.103.C39
#    product_code (V14): 401.83.103
#    Name: 'Mid Stairs' Ayous naturel 39x30 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €3.51
#
# ⚠️  COST MISMATCH:
#    ID (V14): 15651
#    ID (V18): 12653
#    Code: 12-004.X
#    product_code (V14): 12-004
#    x_studio_product_code (V18): 12-004
#    Name (V14): 12-250 Alpha Aluminium zwart + spacer (kopie)
#    Name (V18): Zilver aluminium + spacer 7 x 40
#    Category: 1. Lijsten
#    material_cost (V14): €16.91
#    x_studio_computed_cost (V18): €9.07
#    Difference: €7.84
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14158
#    ID (V18): 10467
#    Code: 1596.X
#    product_code (V14): 1596
#    x_studio_product_code (V18): 1596
#    Name (V14): 1596
#    Name (V18): 1596
#    Category: 1. Lijsten
#    material_cost (V14): €23.39
#    x_studio_computed_cost (V18): €2.27
#    Difference: €21.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14132
#    ID (V18): 10912
#    Code: 56567.X
#    product_code (V14): 56567
#    x_studio_product_code (V18): 56567
#    Name (V14): 56567
#    Name (V18): 56567
#    Category: 1. Lijsten
#    material_cost (V14): €28.42
#    x_studio_computed_cost (V18): €16.56
#    Difference: €11.86
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14206
#    ID (V18): 11067
#    Code: 65430.I02+I03
#    product_code (V14): 65430
#    x_studio_product_code (V18): 65430
#    Name (V14): 65430
#    Name (V18): 65430
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €1.55
#    Difference: €22.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14130
#    ID (V18): 12562
#    Code: 66202.X
#    product_code (V14): 66202
#    x_studio_product_code (V18): 66202
#    Name (V14): 66202
#    Name (V18): Verstevigingsprofiel Brut Ayous groot
#    Category: 1. Lijsten
#    material_cost (V14): €4.22
#    x_studio_computed_cost (V18): €0.00
#    Difference: €4.22
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14191
#    ID (V18): 11209
#    Code: 74346.X
#    product_code (V14): 74346
#    x_studio_product_code (V18): 74346
#    Name (V14): 74346
#    Name (V18): 74346
#    Category: 1. Lijsten
#    material_cost (V14): €29.07
#    x_studio_computed_cost (V18): €16.36
#    Difference: €12.71
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14214
#    ID (V18): 11275
#    Code: 79211.X
#    product_code (V14): 79211
#    x_studio_product_code (V18): 79211
#    Name (V14): 79211
#    Name (V18): 79211
#    Category: 1. Lijsten
#    material_cost (V14): €15.19
#    x_studio_computed_cost (V18): €0.00
#    Difference: €15.19
#
# ⚠️  COST MISMATCH:
#    ID (V14): 15840
#    ID (V18): 11278
#    Code: 79815.C1
#    product_code (V14): 79815
#    x_studio_product_code (V18): 79815
#    Name (V14): 79810.C1 Baklijst Zwart 30x30 (kopie)
#    Name (V18): 79815.C1 Baklijst Wit 30x30
#    Category: 1. Lijsten
#    material_cost (V14): €10.57
#    x_studio_computed_cost (V18): €17.05
#    Difference: €6.47
#
# ⚠️  COST MISMATCH:
#    ID (V14): 14172
#    ID (V18): 11324
#    Code: 81936.E30
#    product_code (V14): 81936
#    x_studio_product_code (V18): 81936
#    Name (V14): 81936
#    Name (V18): 81936
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €13.39
#    Difference: €10.16
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4318
#    ID (V18): 11521
#    Code: 96080.X
#    product_code (V14): 96080
#    x_studio_product_code (V18): 96080
#    Name (V14): Afgerond Profiel Goud 70X20
#    Name (V18): Afgerond Profiel Goud 70X20
#    Category: 1. Lijsten
#    material_cost (V14): €31.67
#    x_studio_computed_cost (V18): €26.87
#    Difference: €4.80
#
# ⚠️  COST MISMATCH:
#    ID (V14): 3989
#    ID (V18): 11524
#    Code: 39910.F29
#    product_code (V14): 39910
#    x_studio_product_code (V18): 39910
#    Name (V14): Afstandshouder Zwart 5X15 Mm
#    Name (V18): Afstandshouder Zwart 5X15 Mm
#    Category: 1. Lijsten
#    material_cost (V14): €21.92
#    x_studio_computed_cost (V18): €1.44
#    Difference: €20.48
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17539
#    Code: 015-003.O18
#    product_code (V14): 015-003
#    Name: Aluminium Zilver mat 9x26 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €9.14
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17487
#    Code: AR70XXL.GLAS
#    product_code (V14): AR70XXL
#    Name: Artglass AR70 (kopie)
#    Category: 2. Glas
#    material_cost (V14): €123.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 43
#    Code: AB.0
#    product_code (V14): AB.
#    Name: Asbuisje
#    Category: 96. Asbuisjes
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17592
#    Code: IN.AS
#    product_code (V14): IN
#    Name: Askader Esdoorn, 10,5 x 10,5cm (kopie)
#    Category: 04. Askaders
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 701
#    Code: False
#    product_code (V14): AK.
#    Name: Assembleren kader
#    Category: 92. Interne productie diensten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 702
#    Code: A.DIENST
#    product_code (V14): A
#    Name: Assembleren prijs per uur
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 703
#    Code: AS.DIENST
#    product_code (V14): AS.
#    Name: Assembleren spieraam
#    Category: 92. Interne productie diensten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4744
#    ID (V18): 11620
#    Code: 53017.M14
#    product_code (V14): 53017
#    x_studio_product_code (V18): 53017
#    Name (V14): Authentica Blok Creme 4 Cm
#    Name (V18): Authentica Blok Creme 4 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €26.80
#    x_studio_computed_cost (V18): €8.68
#    Difference: €18.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4746
#    ID (V18): 11621
#    Code: 53045.M14
#    product_code (V14): 53045
#    x_studio_product_code (V18): 53045
#    Name (V14): Authentica Blok Lichtgrijs 4 Cm
#    Name (V18): Authentica Blok Lichtgrijs 4 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €26.80
#    x_studio_computed_cost (V18): €8.68
#    Difference: €18.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4749
#    ID (V18): 11622
#    Code: 53047.M15
#    product_code (V14): 53047
#    x_studio_product_code (V18): 53047
#    Name (V14): Authentica Blok Taupe 4 Cm
#    Name (V18): Authentica Blok Taupe 4 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €26.80
#    x_studio_computed_cost (V18): €8.68
#    Difference: €18.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4741
#    ID (V18): 11644
#    Code: 52945.M08
#    product_code (V14): 52945
#    x_studio_product_code (V18): 52945
#    Name (V14): Authentica Lichtgrijs Ingekleurd 3 Cm
#    Name (V18): Authentica Lichtgrijs Ingekleurd 3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €25.17
#    x_studio_computed_cost (V18): €4.99
#    Difference: €20.18
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4743
#    ID (V18): 11655
#    Code: 52947.M11
#    product_code (V14): 52947
#    x_studio_product_code (V18): 52947
#    Name (V14): Authentica Taupe Ingekleurd 3 Cm
#    Name (V18): Authentica Taupe Ingekleurd 3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €25.17
#    x_studio_computed_cost (V18): €4.99
#    Difference: €20.18
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4330
#    ID (V18): 11658
#    Code: 53847.X
#    product_code (V14): 53847
#    x_studio_product_code (V18): 53847
#    Name (V14): Authentica Vlak Taupe 6 Cm
#    Name (V18): Authentica Vlak Taupe 6 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €29.88
#    x_studio_computed_cost (V18): €7.62
#    Difference: €22.27
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17549
#    Code: 28300B.G34
#    product_code (V14): 28300B
#    Name: Baklijst authentica Zwart 15x44 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €9.25
#
# ⚠️  COST MISMATCH:
#    ID (V14): 6932
#    ID (V18): 13299
#    Code: 4089.A7
#    product_code (V14): 4089
#    x_studio_product_code (V18): 4089
#    Name (V14): Black
#    Name (V18): Black (kopie)
#    Category: 3. Passe-partout
#    material_cost (V14): €7.80
#    x_studio_computed_cost (V18): €13.20
#    Difference: €5.40
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16615
#    ID (V18): 13301
#    Code: 5089.C6
#    product_code (V14): 5089
#    x_studio_product_code (V18): 5089
#    Name (V14): Black - Black Core - Oversize (kopie)
#    Name (V18): Black - Black Core - Oversize
#    Category: 3. Passe-partout
#    material_cost (V14): €7.80
#    x_studio_computed_cost (V18): €13.20
#    Difference: €5.40
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4691
#    ID (V18): 11765
#    Code: 16920.L03
#    product_code (V14): 16920
#    x_studio_product_code (V18): 16920
#    Name (V14): Blauw Geborsteld 2,3 Cm
#    Name (V18): Blauw Geborsteld 2,3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.04
#    x_studio_computed_cost (V18): €2.75
#    Difference: €21.29
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16617
#    ID (V18): 13314
#    Code: 4071.X
#    product_code (V14): 4071
#    x_studio_product_code (V18): 4071
#    Name (V14): Brilliant White - Oversize (kopie)
#    Name (V18): Brilliant White - Oversize
#    Category: 3. Passe-partout
#    material_cost (V14): €7.80
#    x_studio_computed_cost (V18): €13.20
#    Difference: €5.40
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4692
#    ID (V18): 11910
#    Code: 16931.L03
#    product_code (V14): 16931
#    x_studio_product_code (V18): 16931
#    Name (V14): Donkergroen Geborsteld 2,3 Cm
#    Name (V18): Donkergroen Geborsteld 2,3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.04
#    x_studio_computed_cost (V18): €2.75
#    Difference: €21.29
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 41
#    Code: DP.X
#    product_code (V14): DP
#    Name: Down payment
#    Category: X. Archived products
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 15844
#    Code: 55442.A08+A11
#    product_code (V14): 55442
#    Name: Dummy Lijst (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €10.90
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4869
#    ID (V18): 11925
#    Code: 034-514.O15
#    product_code (V14): 034-514
#    x_studio_product_code (V18): 034-514
#    Name (V14): Eik 0,5 Cm K1117
#    Name (V18): Eik 0,5 Cm K1117
#    Category: 1. Lijsten
#    material_cost (V14): €12.05
#    x_studio_computed_cost (V18): €9.62
#    Difference: €2.43
#
# ⚠️  COST MISMATCH:
#    ID (V14): 5024
#    ID (V18): 11941
#    Code: 034-511.O20
#    product_code (V14): 034-511
#    x_studio_product_code (V18): 034-511
#    Name (V14): Esdoorn 0,5 Cm K1120
#    Name (V18): Esdoorn 0,5 Cm K1120
#    Category: 1. Lijsten
#    material_cost (V14): €12.05
#    x_studio_computed_cost (V18): €9.62
#    Difference: €2.43
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17444
#    Code: ForexW13.X
#    product_code (V14): ForexW13
#    Name: Forex Wit 10mm (kopie)
#    Category: 99. Platen
#    material_cost (V14): €52.61
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17437
#    Code: FTBX_Z.X
#    product_code (V14): FTBX_Z
#    Name: Fotobox (kopie)
#    Category: Fotobox
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17439
#    Code: FTBX_T.X
#    product_code (V14): FTBX_T
#    Name: Fotobox wit (kopie)
#    Category: Fotobox
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17438
#    Code: FTBX_W.X
#    product_code (V14): FTBX_W
#    Name: Fotobox zwart (kopie)
#    Category: Fotobox
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 1
#    Code: Afhaling.X
#    product_code (V14): Afhaling
#    Name: Free delivery charges
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 40
#    Code: GS.DIENST
#    product_code (V14): GS
#    Name: Glas snijden
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 3883
#    ID (V18): 12000
#    Code: 6071.N28
#    product_code (V14): 6071
#    x_studio_product_code (V18): 6071
#    Name (V14): Gouden Barok Zwarte Lijn
#    Name (V18): Gouden Barok Zwarte Lijn
#    Category: 1. Lijsten
#    material_cost (V14): €31.83
#    x_studio_computed_cost (V18): €19.04
#    Difference: €12.79
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17627
#    Code: 3424.N30
#    product_code (V14): 3424
#    Name: Gouden Baroklijst Middenornament K1146 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €64.11
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 4632
#    Code: 4540-571.F32
#    product_code (V14): 4540-571
#    Name: Grijs 4.5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €5.80
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17594
#    Code: Satin.PRINT
#    product_code (V14): Satin
#    Name: Hahnemühle Photo Rag ®️ Ultra Smooth 350gr (kopie)
#    Category: 7. Printen
#    material_cost (V14): €34.42
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4313
#    ID (V18): 12015
#    Code: 16536.X
#    product_code (V14): 16536
#    x_studio_product_code (V18): 16536
#    Name (V14): Halfrond Goud-Bruin
#    Name (V18): Halfrond Goud-Bruin
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €6.26
#    Difference: €18.10
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4312
#    ID (V18): 12016
#    Code: 16531.X
#    product_code (V14): 16531
#    x_studio_product_code (V18): 16531
#    Name (V14): Halfrond Goud-Groen
#    Name (V18): Halfrond Goud-Groen
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €6.26
#    Difference: €18.10
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4182
#    ID (V18): 12018
#    Code: 16515.X
#    product_code (V14): 16515
#    x_studio_product_code (V18): 16515
#    Name (V14): Halfrond Goud/Wit
#    Name (V18): Halfrond Goud/Wit
#    Category: 1. Lijsten
#    material_cost (V14): €24.36
#    x_studio_computed_cost (V18): €5.11
#    Difference: €19.25
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 15065
#    Code: SI.DIENST
#    product_code (V14): SI
#    Name: Junior inlijster (kopie)
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4498
#    ID (V18): 12066
#    Code: 73317.F17
#    product_code (V14): 73317
#    x_studio_product_code (V18): 73317
#    Name (V14): Kaslijst Beige Lage Uitsnijding 1,5 Cm
#    Name (V18): Kaslijst Beige Lage Uitsnijding 1,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €22.74
#    x_studio_computed_cost (V18): €4.63
#    Difference: €18.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4501
#    ID (V18): 12073
#    Code: 73346.F16
#    product_code (V14): 73346
#    x_studio_product_code (V18): 73346
#    Name (V14): Kaslijst Grijs Lage Uitsnijding 1,5 Cm
#    Name (V18): Kaslijst Grijs Lage Uitsnijding 1,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €22.74
#    x_studio_computed_cost (V18): €4.63
#    Difference: €18.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4500
#    ID (V18): 12074
#    Code: 73345.F16
#    product_code (V14): 73345
#    x_studio_product_code (V18): 73345
#    Name (V14): Kaslijst Grijs/Groen Lage Uitsnijding 1,5 Cm
#    Name (V18): Kaslijst Grijs/Groen Lage Uitsnijding 1,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €22.74
#    x_studio_computed_cost (V18): €4.63
#    Difference: €18.11
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17490
#    Code: 4110.X
#    product_code (V14): 4110
#    Name: Kaslijst Lichtbruin 2cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €3.43
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 3887
#    Code: 48310.A03+A04+A05+O03
#    product_code (V14): 48310
#    Name: Kaslijst Zwart 2 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €2.97
#
# ⚠️  COST MISMATCH:
#    ID (V14): 13454
#    ID (V18): 11913
#    Code: DummylijstDummy Lijst
#    product_code (V14): Dummylijst
#    x_studio_product_code (V18): Dummylijst
#    Name (V14): Kaslijst Zwart 2 cm (kopie)
#    Name (V18): Dummy Lijst
#    Category: 1. Lijsten
#    material_cost (V14): €24357.56
#    x_studio_computed_cost (V18): €0.00
#    Difference: €24357.56
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4032
#    ID (V18): 12165
#    Code: 4747.D14
#    product_code (V14): 4747
#    x_studio_product_code (V18): 4747
#    Name (V14): Lichtbruin Loodwit
#    Name (V18): Lichtbruin Loodwit
#    Category: 1. Lijsten
#    material_cost (V14): €25.33
#    x_studio_computed_cost (V18): €4.56
#    Difference: €20.77
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4695
#    ID (V18): 12169
#    Code: 16945.L03
#    product_code (V14): 16945
#    x_studio_product_code (V18): 16945
#    Name (V14): Lichtgrijs Geborsteld 2,3 Cm
#    Name (V18): Lichtgrijs Geborsteld 2,3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.04
#    x_studio_computed_cost (V18): €2.75
#    Difference: €21.29
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 717
#    Code: LS.DIENST
#    product_code (V14): LS.
#    Name: Lijst snijden
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 15064
#    Code: JI.DIENST
#    product_code (V14): JI
#    Name: Lijst snijden (kopie)
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 4479
#    Code: 41516.F06
#    product_code (V14): 41516
#    Name: Loft Wenge + Spacer 20X35
#    Category: 1. Lijsten
#    material_cost (V14): €7.67
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16584
#    ID (V18): 12199
#    Code: 40516.F06
#    product_code (V14): 40516
#    x_studio_product_code (V18): 40516
#    Name (V14): Loft Wenge + Spacer 20X35 (kopie)
#    Name (V18): Loft Wenge 20X35
#    Category: 1. Lijsten
#    material_cost (V14): €13.23
#    x_studio_computed_cost (V18): €6.39
#    Difference: €6.84
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 722
#    Code: False
#    product_code (V14): MDF3MM.
#    Name: MDF 3MM BRUT
#    Category: 4. Ruggen
#    material_cost (V14): €3.14
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4521
#    ID (V18): 12224
#    Code: 1372.X
#    product_code (V14): 1372
#    x_studio_product_code (V18): 1372
#    Name (V14): Marquetterie Olm 2Cm
#    Name (V18): Marquetterie Olm 2Cm
#    Category: 1. Lijsten
#    material_cost (V14): €23.55
#    x_studio_computed_cost (V18): €8.05
#    Difference: €15.50
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 723
#    Code: MG.GLAS
#    product_code (V14): MG.
#    Name: Mat glas
#    Category: 2. Glas
#    material_cost (V14): €20.10
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4607
#    ID (V18): 12254
#    Code: 57797.I15
#    product_code (V14): 57797
#    x_studio_product_code (V18): 57797
#    Name (V14): Metropoli Brons 5 Cm
#    Name (V18): Metropoli Brons 5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €28.42
#    x_studio_computed_cost (V18): €14.50
#    Difference: €13.92
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4271
#    ID (V18): 12296
#    Code: 1796.O34
#    product_code (V14): 1796
#    x_studio_product_code (V18): 1796
#    Name (V14): Noten Ant.Goud.Bies 7,5 Cm
#    Name (V18): Noten Ant.Goud.Bies 7,5 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €32.48
#    x_studio_computed_cost (V18): €12.14
#    Difference: €20.34
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17441
#    Code: 401.43.103.C39
#    product_code (V14): 401.43.103
#    Name: ORNAMENT ZWART GESATINEERD MET STRUCTUUR 79x49 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €4.86
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 729
#    Code: OIW.X
#    product_code (V14): OIW
#    Name: Ophalen in Wondelgem
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 13474
#    Code: Gratisverzending.X
#    product_code (V14): Gratisverzending
#    Name: Ophalen in Wondelgem (kopie)
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 16184
#    Code: OIA.X
#    product_code (V14): OIA
#    Name: Ophalen in Wondelgem (kopie)
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 730
#    Code: OS.DIENST
#    product_code (V14): OS.
#    Name: Opspannen spieraam
#    Category: 92. Interne productie diensten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4118
#    ID (V18): 12314
#    Code: 10715.N29
#    product_code (V14): 10715
#    x_studio_product_code (V18): 10715
#    Name (V14): Ornament Antiek Wit 1,4 Cm K1075
#    Name (V18): Ornament Antiek Wit 1,4 Cm K1075
#    Category: 1. Lijsten
#    material_cost (V14): €22.57
#    x_studio_computed_cost (V18): €6.75
#    Difference: €15.83
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4031
#    ID (V18): 12348
#    Code: 4743.X
#    product_code (V14): 4743
#    x_studio_product_code (V18): 4743
#    Name (V14): Perzik Loodwit 3 Cm
#    Name (V18): Perzik Loodwit 3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €25.33
#    x_studio_computed_cost (V18): €4.56
#    Difference: €20.77
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 12796
#    Code: PK4040.BOX
#    product_code (V14): PK4040
#    Name: Plooikost doos 40x40
#    Category: 91A. Verpakkingsdozen
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 12797
#    Code: PK4565.BOX
#    product_code (V14): PK4565
#    Name: Plooikost doos 40x40 (kopie)
#    Category: 91A. Verpakkingsdozen
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 12798
#    Code: PK6070.BOX
#    product_code (V14): PK6070
#    Name: Plooikost doos 45x65 (kopie)
#    Category: 91A. Verpakkingsdozen
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 12799
#    Code: PK70100.BOX
#    product_code (V14): PK70100
#    Name: Plooikost doos 60x70 (kopie)
#    Category: 91A. Verpakkingsdozen
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 12800
#    Code: PK75115.BOX
#    product_code (V14): PK75115
#    Name: Plooikost doos 70x100 (kopie)
#    Category: 91A. Verpakkingsdozen
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 6935
#    ID (V18): 13424
#    Code: 4754.A12
#    product_code (V14): 4754
#    x_studio_product_code (V18): 4754
#    Name (V14): Porcelain
#    Name (V18): Porcelain (kopie)
#    Category: 3. Passe-partout
#    material_cost (V14): €7.80
#    x_studio_computed_cost (V18): €13.20
#    Difference: €5.40
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 9936
#    Code: Printen.INT
#    product_code (V14): Printen
#    Name: Printen
#    Category: 92. Interne productie diensten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 735
#    ID (V18): 13436
#    Code: ZR.0
#    product_code (V14): ZR
#    x_studio_product_code (V18): ZR
#    Name (V14): Rugwand met voet
#    Name (V18): Rugwand met voet
#    Category: 41. Standaardruggen
#    material_cost (V14): €0.00
#    x_studio_computed_cost (V18): €5.75
#    Difference: €5.75
#
# ⚠️  COST MISMATCH:
#    ID (V14): 9927
#    ID (V18): 13265
#    Code: 974017.SP
#    product_code (V14): 974017
#    x_studio_product_code (V18): 974017
#    Name (V14): Si - frame Hoekverbinder (kopie)
#    Name (V18): Allsize Hoekverbinding
#    Category: 93. Andere producten
#    material_cost (V14): €0.00
#    x_studio_computed_cost (V18): €0.24
#    Difference: €0.24
#
# ⚠️  COST MISMATCH:
#    ID (V14): 9923
#    ID (V18): 13456
#    Code: 00210-05-I.SP
#    product_code (V14): 00210-05-I
#    x_studio_product_code (V18): 00210-05-I
#    Name (V14): Si - frame Kruislatverbinder (kopie)
#    Name (V18): Si - frame Hoekverbinder
#    Category: 93. Andere producten
#    material_cost (V14): €0.00
#    x_studio_computed_cost (V18): €2.28
#    Difference: €2.28
#
# ⚠️  COST MISMATCH:
#    ID (V14): 9922
#    ID (V18): 13458
#    Code: 00210-05-J.SP
#    product_code (V14): 00210-05-J
#    x_studio_product_code (V18): 00210-05-J
#    Name (V14): Si - frame Kruislatverbinder (kopie)
#    Name (V18): Si - frame Tussenlatverbinder
#    Category: 93. Andere producten
#    material_cost (V14): €0.00
#    x_studio_computed_cost (V18): €2.18
#    Difference: €2.18
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17494
#    Code: 40546.X
#    product_code (V14): 40546
#    Name: Spacer Mat Zwart 6 X 21 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €2.07
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17491
#    Code: 40554.X
#    product_code (V14): 40554
#    Name: Spacer Mat Zwart 6 X 30 (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €3.76
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17483
#    Code: 40015C.X
#    product_code (V14): 40015C
#    Name: Spacer Wit 5X10 mm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €2.84
#
# ⚠️  COST MISMATCH:
#    ID (V14): 17593
#    ID (V18): 11524
#    Code: 39910.X
#    product_code (V14): 39910
#    x_studio_product_code (V18): 39910
#    Name (V14): Spacer Wit 5X15 mm (kopie)
#    Name (V18): Afstandshouder Zwart 5X15 Mm
#    Category: 1. Lijsten
#    material_cost (V14): €2.29
#    x_studio_computed_cost (V18): €1.44
#    Difference: €0.85
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17486
#    Code: 40115C.X
#    product_code (V14): 40115C
#    Name: Spacer Wit Op Compo 5X20 mm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €4.34
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17484
#    Code: 14323003.X
#    product_code (V14): 14323003
#    Name: Spacer Wit op compo 5X10 mm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €1.39
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17482
#    Code: 395815.X
#    product_code (V14): 395815
#    Name: Spacer Zwart 5X10 mm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €1.39
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17485
#    Code: 40110C.X
#    product_code (V14): 40110C
#    Name: Spacer Zwart Op Compo 5X20mm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €4.34
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 6984
#    Code: STO.INL
#    product_code (V14): STO
#    Name: Stomen + opspelden Tshirt
#    Category: Vaste prijs producten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4696
#    ID (V18): 12527
#    Code: 17936.L04
#    product_code (V14): 17936
#    x_studio_product_code (V18): 17936
#    Name (V14): Terra Roestbruin Geborsteld 3,8 Cm
#    Name (V18): Terra Roestbruin Geborsteld 3,8 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €26.47
#    x_studio_computed_cost (V18): €6.07
#    Difference: €20.41
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17440
#    Code: G-0063/4035.X
#    product_code (V14): G-0063/4035
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €17.56
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17461
#    Code: 2902.P21
#    product_code (V14): 2902
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €2.69
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17690
#    Code: 3009.X
#    product_code (V14): 3009
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €12.11
#
# ⚠️  COST MISMATCH:
#    ID (V14): 15649
#    ID (V18): 12694
#    Code: 12-250.X
#    product_code (V14): 12-250
#    x_studio_product_code (V18): 12-250
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): Zwart aluminium + spacer 7 x 40
#    Category: 1. Lijsten
#    material_cost (V14): €16.91
#    x_studio_computed_cost (V18): €9.07
#    Difference: €7.84
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17629
#    Code: 83080.X
#    product_code (V14): 83080
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €8.81
#
# ⚠️  COST MISMATCH:
#    ID (V14): 17015
#    ID (V18): 10010
#    Code: 71515.C17
#    product_code (V14): 71515
#    x_studio_product_code (V18): 71515
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): "Gloss" Baklijst Lak Wit 5Cm K1162
#    Category: 1. Lijsten
#    material_cost (V14): €14.13
#    x_studio_computed_cost (V18): €13.35
#    Difference: €0.78
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17743
#    Code: R-801.20.895./
#    product_code (V14): R-801.20.895
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €14.40
#
# ⚠️  COST MISMATCH:
#    ID (V14): 15621
#    ID (V18): 11950
#    Code: 77163.N31
#    product_code (V14): 77163
#    x_studio_product_code (V18): 77163
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): FINEER ITALIAANSE NOTEN 15/25
#    Category: 1. Lijsten
#    material_cost (V14): €3.18
#    x_studio_computed_cost (V18): €3.13
#    Difference: €0.05
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17578
#    Code: R801.20.894.X
#    product_code (V14): R801.20.894
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €8.48
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17575
#    Code: 1291.X
#    product_code (V14): 1291
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €11.64
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17479
#    Code: 102485.X
#    product_code (V14): 102485
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €7.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17489
#    Code: 4120.X
#    product_code (V14): 4120
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €4.04
#
# ⚠️  COST MISMATCH:
#    ID (V14): 15639
#    ID (V18): 12163
#    Code: 63110.M29
#    product_code (V14): 63110
#    x_studio_product_code (V18): 63110
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): Lak Zwart 6,8 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €16.56
#    x_studio_computed_cost (V18): €16.48
#    Difference: €0.09
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17495
#    Code: 94810.X
#    product_code (V14): 94810
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €10.83
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16730
#    ID (V18): 12682
#    Code: 214-021.X
#    product_code (V14): 214-021
#    x_studio_product_code (V18): 214-021
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): Zwart Mat 1,3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €11.53
#    x_studio_computed_cost (V18): €7.61
#    Difference: €3.92
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17517
#    Code: 3382.O39
#    product_code (V14): 3382
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €3.46
#
# ⚠️  COST MISMATCH:
#    ID (V14): 16866
#    ID (V18): 11908
#    Code: 78046.x
#    product_code (V14): 78046
#    x_studio_product_code (V18): 78046
#    Name (V14): Tokio - Kaslijst Zwart 2 cm (kopie)
#    Name (V18): Donkergrijs
#    Category: 1. Lijsten
#    material_cost (V14): €4.58
#    x_studio_computed_cost (V18): €10.44
#    Difference: €5.86
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 17548
#    Code: S-999-15W.X
#    product_code (V14): S-999-15W
#    Name: Tokio - Kaslijst Zwart 2 cm (kopie)
#    Category: 1. Lijsten
#    material_cost (V14): €12.04
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 745
#    Code: VS.X
#    product_code (V14): VS
#    Name: Vellen snijden
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 856
#    Code: VLP.X
#    product_code (V14): VLP
#    Name: Verpakken losse producten
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 746
#    Code: VD.X
#    product_code (V14): VD
#    Name: Verpakking dienst
#    Category: Interne productie posten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 15865
#    Code: OPHAALSERVICE.X
#    product_code (V14): OPHAALSERVICE
#    Name: Verpakkingsrol (kopie)
#    Category: Vaste prijs producten
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 13465
#    Code: VERPDOOS.X
#    product_code (V14): VERPDOOS.
#    Name: Verpakkingsrol (kopie)
#    Category: Vaste prijs producten
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 17492
#    ID (V18): 12561
#    Code: 66102.X
#    product_code (V14): 66102
#    x_studio_product_code (V18): 66102
#    Name (V14): Verstevigingsprofiel Brut Ayous Groot 50x10 (kopie)
#    Name (V18): Verstevigingsprofiel Brut Ayous 40x10 66102
#    Category: 1. Lijsten
#    material_cost (V14): €3.09
#    x_studio_computed_cost (V18): €0.00
#    Difference: €3.09
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 747
#    Code: Interntransport.X
#    product_code (V14): Interntransport
#    Name: Vervoerskosten
#    Category: NTB
#    material_cost (V14): €0.00
#
# ❌ Product Template NOT FOUND in V18:
#    ID (V14): 748
#    Code: VZB.X
#    product_code (V14): VZB
#    Name: Verzenden via Bpost
#    Category: NTB
#    material_cost (V14): €0.00
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4868
#    ID (V18): 12575
#    Code: 034-516.O12
#    product_code (V14): 034-516
#    x_studio_product_code (V18): 034-516
#    Name (V14): Wenge Donker 0,5 Cm K1122
#    Name (V18): Wenge Donker 0,5 Cm K1122
#    Category: 1. Lijsten
#    material_cost (V14): €12.05
#    x_studio_computed_cost (V18): €9.62
#    Difference: €2.43
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4871
#    ID (V18): 12576
#    Code: 034-515.O14
#    product_code (V14): 034-515
#    x_studio_product_code (V18): 034-515
#    Name (V14): Wenge Licht 0,5 Cm K1118
#    Name (V18): Wenge Licht 0,5 Cm K1118
#    Category: 1. Lijsten
#    material_cost (V14): €12.05
#    x_studio_computed_cost (V18): €9.62
#    Difference: €2.43
#
# ⚠️  COST MISMATCH:
#    ID (V14): 17048
#    ID (V18): 13504
#    Code: BR844987.PP
#    product_code (V14): BR844987
#    x_studio_product_code (V18): BR844987
#    Name (V14): White -Red Core  (kopie)
#    Name (V18): White -Yellow Core
#    Category: 3. Passe-partout
#    material_cost (V14): €20.34
#    x_studio_computed_cost (V18): €0.00
#    Difference: €20.34
#
# ⚠️  COST MISMATCH:
#    ID (V14): 4087
#    ID (V18): 12586
#    Code: 16915.L03
#    product_code (V14): 16915
#    x_studio_product_code (V18): 16915
#    Name (V14): Wit Geborsteld 2,3 Cm
#    Name (V18): Wit Geborsteld 2,3 Cm
#    Category: 1. Lijsten
#    material_cost (V14): €24.04
#    x_studio_computed_cost (V18): €2.61
#    Difference: €21.43
#
# ================================================================================
# Cost comparison complete!
# Total product templates in V14 (excluding categories): 3318
# Product templates without product_code (skipped): 26
# Product templates checked: 3292
# Product templates not found in V18: 66
# Product templates with cost matches: 3148
# Product templates with cost mismatches: 78
# ================================================================================

# %%
# Compare BOMs between Odoo V14 and V18 to find mismatches

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables for V14
JUSTFRAMEIT_ODOO_V14_URL = os.getenv('JUSTFRAMEIT_ODOO_V14_URL')
JUSTFRAMEIT_ODOO_V14_DB = os.getenv('JUSTFRAMEIT_ODOO_V14_DB')
JUSTFRAMEIT_ODOO_V14_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_V14_USERNAME')
JUSTFRAMEIT_ODOO_V14_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_V14_API_KEY')

# Get environment variables for V18
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

print("=" * 80)
print("Comparing BOMs between Odoo V14 and V18")
print("=" * 80)

try:
    # Authenticate to V14
    print("\n[V14] Authenticating...")
    common_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/common", allow_none=True)
    uid_v14 = common_v14.authenticate(JUSTFRAMEIT_ODOO_V14_DB, JUSTFRAMEIT_ODOO_V14_USERNAME, JUSTFRAMEIT_ODOO_V14_API_KEY, {})
    print(f"✅ V14 Authenticated! UID: {uid_v14}")
    
    # Authenticate to V18
    print("\n[V18] Authenticating...")
    common_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
    uid_v18 = common_v18.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
    print(f"✅ V18 Authenticated! UID: {uid_v18}\n")
    
    # Create models proxies
    models_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/object", allow_none=True)
    models_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)
    
    # Define specific category IDs to check
    target_category_ids = [4, 8, 10, 57, 82]
    #target_category_ids = [10] #for testing
    
    print(f"Checking specific categories: {target_category_ids}\n")
    
    # Get category details from V14 (single call)
    categories = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.category', 'read',
        [target_category_ids],
        {'fields': ['display_name']})
    
    print("Categories to check:")
    for cat in categories:
        print(f"  - Category ID {cat['id']}: {cat['display_name']}")
    print()
    
    # Get all product templates in these categories from V14 (single call)
    print("[V14] Fetching product templates in these categories...")
    product_template_ids = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'search',
        [[['categ_id', 'in', target_category_ids]]])
    
    print(f"Found {len(product_template_ids)} product templates\n")
    
    # Search for BOMs with is_custom_made = False in V14 (single call) - including inactive BOMs
    print("[V14] Searching for BOMs with is_custom_made = False (including inactive BOMs)...")
    print("=" * 80)
    
    bom_ids_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'mrp.bom', 'search',
        [[['product_tmpl_id', 'in', product_template_ids], ['is_custom_made', '=', False]]],
        {'context': {'active_test': False}})
    
    print(f"\n[V14] Found {len(bom_ids_v14)} BOMs with is_custom_made = False (including inactive)\n")
    
    if not bom_ids_v14:
        print("No BOMs found with is_custom_made = False in V14")
    else:
        # Get ALL BOM details from V14 in a single call (including active field)
        boms_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
            'mrp.bom', 'read',
            [bom_ids_v14],
            {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'is_custom_made', 'bom_line_ids', 'active']})
        
        # Get ALL BOM lines from V14 in a single call
        all_bom_line_ids_v14 = []
        for bom in boms_v14:
            if bom['bom_line_ids']:
                all_bom_line_ids_v14.extend(bom['bom_line_ids'])
        
        bom_lines_v14_dict = {}
        if all_bom_line_ids_v14:
            all_bom_lines_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'mrp.bom.line', 'read',
                [all_bom_line_ids_v14],
                {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
            
            # Get all product IDs from BOM lines to fetch product codes
            product_ids_v14 = [line['product_id'][0] for line in all_bom_lines_v14 if line['product_id']]
            
            # Fetch product codes for all products in V14
            products_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.product', 'read',
                [product_ids_v14],
                {'fields': ['id', 'product_code']})
            
            # Create a mapping of product_id to product_code
            product_code_map_v14 = {p['id']: p['product_code'] for p in products_v14}
            
            # Organize by bom_id for easy lookup
            for line in all_bom_lines_v14:
                bom_id = line['bom_id'][0] if line['bom_id'] else None
                if bom_id not in bom_lines_v14_dict:
                    bom_lines_v14_dict[bom_id] = []
                # Add product_code to the line data
                product_id = line['product_id'][0] if line['product_id'] else None
                line['product_code'] = product_code_map_v14.get(product_id, 'N/A')
                bom_lines_v14_dict[bom_id].append(line)
        
        # Collect all BOM codes to search in V18
        bom_codes_v14 = [bom['code'] for bom in boms_v14 if bom['code']]
        
        # Search for ALL corresponding BOMs in V18 in a single call (including inactive)
        bom_ids_v18 = []
        if bom_codes_v14:
            bom_ids_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'search',
                [[['code', 'in', bom_codes_v14]]],
                {'context': {'active_test': False}})
        
        # Get ALL BOM details from V18 in a single call (including active field)
        boms_v18_dict = {}
        if bom_ids_v18:
            boms_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'read',
                [bom_ids_v18],
                {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'bom_line_ids', 'active']})
            
            # Organize by code for easy lookup (handle duplicates by storing as list)
            for bom in boms_v18:
                if bom['code']:
                    if bom['code'] not in boms_v18_dict:
                        boms_v18_dict[bom['code']] = []
                    boms_v18_dict[bom['code']].append(bom)
            
            # Get ALL BOM lines from V18 in a single call
            all_bom_line_ids_v18 = []
            for bom in boms_v18:
                if bom['bom_line_ids']:
                    all_bom_line_ids_v18.extend(bom['bom_line_ids'])
            
            bom_lines_v18_dict = {}
            if all_bom_line_ids_v18:
                all_bom_lines_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'mrp.bom.line', 'read',
                    [all_bom_line_ids_v18],
                    {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
                
                # Get all product IDs from BOM lines to fetch product codes
                product_ids_v18 = [line['product_id'][0] for line in all_bom_lines_v18 if line['product_id']]
                
                # Fetch product codes for all products in V18
                products_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'product.product', 'read',
                    [product_ids_v18],
                    {'fields': ['id', 'x_studio_product_code']})
                
                # Create a mapping of product_id to x_studio_product_code
                product_code_map_v18 = {p['id']: p['x_studio_product_code'] for p in products_v18}
                
                # Organize by bom_id for easy lookup
                for line in all_bom_lines_v18:
                    bom_id = line['bom_id'][0] if line['bom_id'] else None
                    if bom_id not in bom_lines_v18_dict:
                        bom_lines_v18_dict[bom_id] = []
                    # Add product_code to the line data
                    product_id = line['product_id'][0] if line['product_id'] else None
                    line['product_code'] = product_code_map_v18.get(product_id, 'N/A')
                    bom_lines_v18_dict[bom_id].append(line)
        
        # Fetch product codes for all product_ids in V14 BOMs for fallback matching
        all_product_ids_v14 = [bom['product_id'][0] for bom in boms_v14 if bom['product_id']]
        product_codes_v14_map = {}
        product_variants_v14_map = {}
        if all_product_ids_v14:
            products_for_boms_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.product', 'read',
                [all_product_ids_v14],
                {'fields': ['id', 'product_code', 'display_name']})
            product_codes_v14_map = {p['id']: p['product_code'] for p in products_for_boms_v14}
            product_variants_v14_map = {p['id']: p['display_name'] for p in products_for_boms_v14}
        
        # Fetch product variants for all product_ids in V18 BOMs for fallback matching
        all_product_ids_v18 = []
        for bom_list in boms_v18_dict.values():
            for bom in bom_list:
                if bom['product_id']:
                    all_product_ids_v18.append(bom['product_id'][0])
        
        product_variants_v18_map = {}
        if all_product_ids_v18:
            products_for_boms_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'product.product', 'read',
                [all_product_ids_v18],
                {'fields': ['id', 'x_studio_product_code', 'display_name']})
            product_variants_v18_map = {p['id']: {'code': p['x_studio_product_code'], 'name': p['display_name']} for p in products_for_boms_v18}
        
        print("Comparing BOMs between V14 and V18:")
        print("-" * 80)
        
        mismatches_found = 0
        
        for bom_v14 in boms_v14:
            product_tmpl_name = bom_v14['product_tmpl_id'][1] if bom_v14['product_tmpl_id'] else 'N/A'
            product_variant_name = bom_v14['product_id'][1] if bom_v14['product_id'] else 'N/A (Template BOM)'
            bom_reference = bom_v14['code'] if bom_v14['code'] else 'No reference'
            bom_display_name = bom_v14['display_name'] if bom_v14['display_name'] else 'No display name'
            bom_active_v14 = bom_v14.get('active', True)
            
            print(f"\n{'=' * 80}")
            print(f"BOM ID (V14): {bom_v14['id']}")
            print(f"  Reference: {bom_reference}")
            print(f"  Display Name: {bom_display_name}")
            print(f"  Product Template: {product_tmpl_name}")
            print(f"  Product Variant: {product_variant_name}")
            print(f"  is_custom_made (V14): {bom_v14['is_custom_made']}")
            print(f"  active (V14): {bom_active_v14}")
            
            # Get BOM line components from V14 (from pre-fetched data)
            components_v14 = {}
            bom_lines = bom_lines_v14_dict.get(bom_v14['id'], [])
            
            if bom_lines:
                print(f"\n  [V14] Components ({len(bom_lines)} items):")
                for line in bom_lines:
                    component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                    component_code = line['product_code']
                    component_qty = line['product_qty']
                    components_v14[component_code] = {'name': component_name, 'qty': component_qty}
                    print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
            else:
                print(f"\n  [V14] Components: None")
            
            # Find corresponding BOM in V18
            print(f"\n  [V18] Searching for corresponding BOM...")
            
            bom_v18 = None
            matching_method = None
            
            # Try matching by BOM reference (code) first
            if bom_reference and bom_reference != 'No reference':
                print(f"     Trying to match by BOM reference (code): {bom_reference}")
                
                matching_boms = boms_v18_dict.get(bom_reference, [])
                
                if len(matching_boms) == 1:
                    # Unique match by code
                    bom_v18 = matching_boms[0]
                    matching_method = "by BOM reference (code)"
                    print(f"  ✅ Found unique BOM in V18 by reference")
                elif len(matching_boms) > 1:
                    # Multiple BOMs with same code - need to use product_id fallback
                    print(f"  ⚠️  Found {len(matching_boms)} BOMs with same reference in V18, using product_id fallback")
                    
                    # Get product_code from V14 product_id
                    product_id_v14 = bom_v14['product_id'][0] if bom_v14['product_id'] else None
                    if product_id_v14:
                        product_code_v14 = product_codes_v14_map.get(product_id_v14)
                        product_variant_v14 = product_variants_v14_map.get(product_id_v14)
                        if product_code_v14:
                            print(f"     V14 product_code: {product_code_v14}")
                            print(f"     V14 product_variant: {product_variant_v14}")
                            
                            # Try to match by product_code in V18
                            for candidate_bom in matching_boms:
                                if candidate_bom['product_id']:
                                    product_id_v18 = candidate_bom['product_id'][0]
                                    product_info_v18 = product_variants_v18_map.get(product_id_v18, {})
                                    product_code_v18 = product_info_v18.get('code')
                                    product_variant_v18 = product_info_v18.get('name')
                                    
                                    print(f"       Checking candidate: product_code={product_code_v18}, variant={product_variant_v18}")
                                    
                                    if product_code_v18 == product_code_v14:
                                        bom_v18 = candidate_bom
                                        matching_method = "by BOM reference + product_code fallback"
                                        print(f"  ✅ Matched by product_code: {product_code_v18}")
                                        break
                            
                            # If still not matched, try comparing product variants (display_name)
                            if not bom_v18 and product_variant_v14:
                                print(f"     Trying to match by product variant display_name")
                                for candidate_bom in matching_boms:
                                    if candidate_bom['product_id']:
                                        product_id_v18 = candidate_bom['product_id'][0]
                                        product_info_v18 = product_variants_v18_map.get(product_id_v18, {})
                                        product_variant_v18 = product_info_v18.get('name')
                                        
                                        if product_variant_v18 == product_variant_v14:
                                            bom_v18 = candidate_bom
                                            matching_method = "by BOM reference + product variant display_name fallback"
                                            print(f"  ✅ Matched by product variant: {product_variant_v18}")
                                            break
                            
                            if not bom_v18:
                                print(f"  ❌ Could not match any of the {len(matching_boms)} BOMs by product_code or product variant")
                        else:
                            print(f"  ❌ Could not get product_code from V14 product_id")
                    else:
                        print(f"  ❌ No product_id in V14 BOM for fallback matching")
            
            # Fallback: try matching by product_code if no reference or reference didn't match
            if not bom_v18:
                print(f"     Trying fallback: matching by product_code")
                
                product_id_v14 = bom_v14['product_id'][0] if bom_v14['product_id'] else None
                if product_id_v14:
                    product_code_v14 = product_codes_v14_map.get(product_id_v14)
                    product_variant_v14 = product_variants_v14_map.get(product_id_v14)
                    if product_code_v14:
                        print(f"     V14 product_code: {product_code_v14}")
                        print(f"     V14 product_variant: {product_variant_v14}")
                        
                        # Search through all V18 BOMs for matching product_code
                        for code, bom_list in boms_v18_dict.items():
                            for candidate_bom in bom_list:
                                if candidate_bom['product_id']:
                                    product_id_v18 = candidate_bom['product_id'][0]
                                    product_info_v18 = product_variants_v18_map.get(product_id_v18, {})
                                    product_code_v18 = product_info_v18.get('code')
                                    if product_code_v18 == product_code_v14:
                                        bom_v18 = candidate_bom
                                        matching_method = "by product_code fallback"
                                        print(f"  ✅ Found BOM in V18 by product_code: {product_code_v18}")
                                        break
                            if bom_v18:
                                break
                        
                        # If still not matched, try comparing product variants (display_name)
                        if not bom_v18 and product_variant_v14:
                            print(f"     Trying to match by product variant display_name")
                            for code, bom_list in boms_v18_dict.items():
                                for candidate_bom in bom_list:
                                    if candidate_bom['product_id']:
                                        product_id_v18 = candidate_bom['product_id'][0]
                                        product_info_v18 = product_variants_v18_map.get(product_id_v18, {})
                                        product_variant_v18 = product_info_v18.get('name')
                                        
                                        if product_variant_v18 == product_variant_v14:
                                            bom_v18 = candidate_bom
                                            matching_method = "by product variant display_name fallback"
                                            print(f"  ✅ Found BOM in V18 by product variant: {product_variant_v18}")
                                            break
                                if bom_v18:
                                    break
                    else:
                        print(f"  ❌ Could not get product_code from V14 product_id")
                else:
                    print(f"  ❌ No product_id in V14 BOM for fallback matching")
            
            if not bom_v18:
                print(f"  ❌ NO CORRESPONDING BOM FOUND IN V18!")
                mismatches_found += 1
                continue
            
            bom_active_v18 = bom_v18.get('active', True)
            print(f"  ✅ Found corresponding BOM in V18 (ID: {bom_v18['id']}, Code: '{bom_v18['code']}', active: {bom_active_v18}, matched {matching_method})")
            
            # Get BOM line components from V18 (from pre-fetched data)
            components_v18 = {}
            bom_lines_v18 = bom_lines_v18_dict.get(bom_v18['id'], [])
            
            if bom_lines_v18:
                print(f"\n  [V18] Components ({len(bom_lines_v18)} items):")
                for line in bom_lines_v18:
                    component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                    component_code = line['product_code']
                    component_qty = line['product_qty']
                    components_v18[component_code] = {'name': component_name, 'qty': component_qty}
                    print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
            else:
                print(f"\n  [V18] Components: None")
            
            # Compare components
            print(f"\n  🔍 COMPARISON RESULTS:")
            has_mismatch = False
            
            # Check for missing components in V18
            for component_code, component_data in components_v14.items():
                if component_code not in components_v18:
                    print(f"    ❌ MISSING IN V18: {component_data['name']} (Code: {component_code}, Qty in V14: {component_data['qty']})")
                    has_mismatch = True
                elif components_v18[component_code]['qty'] != component_data['qty']:
                    print(f"    ⚠️  QUANTITY MISMATCH: {component_data['name']} (Code: {component_code})")
                    print(f"       V14 Qty: {component_data['qty']}")
                    print(f"       V18 Qty: {components_v18[component_code]['qty']}")
                    has_mismatch = True
            
            # Check for extra components in V18
            for component_code, component_data in components_v18.items():
                if component_code not in components_v14:
                    print(f"    ➕ EXTRA IN V18: {component_data['name']} (Code: {component_code}, Qty: {component_data['qty']})")
                    has_mismatch = True
            
            if not has_mismatch:
                print(f"    ✅ All components match!")
            else:
                mismatches_found += 1
    
    print("\n" + "=" * 80)
    print(f"BOM comparison complete!")
    print(f"Total BOMs checked: {len(bom_ids_v14) if bom_ids_v14 else 0}")
    print(f"BOMs with mismatches: {mismatches_found}")
    print("=" * 80)
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ================================================================================
# Comparing BOMs between Odoo V14 and V18
# ================================================================================
#
# [V14] Authenticating...
# ✅ V14 Authenticated! UID: 28
#
# [V18] Authenticating...
# ✅ V18 Authenticated! UID: 2
#
# Checking specific categories: [4, 8, 10, 57, 82]
#
# Categories to check:
#   - Category ID 4: 0. Presets / 1. Presets zonder PP
#   - Category ID 8: 0. Presets / 2. Presets met PP
#   - Category ID 10: 0. Presets / 3. Losse verkopen
#   - Category ID 57: 0. Presets / 4. Losse PP
#   - Category ID 82: 0. Presets / Fixed margin
#
# [V14] Fetching product templates in these categories...
# Found 28 product templates
#
# [V14] Searching for BOMs with is_custom_made = False (including inactive BOMs)...
# ================================================================================
#
# [V14] Found 250 BOMs with is_custom_made = False (including inactive)
#
# Comparing BOMs between V14 and V18:
# --------------------------------------------------------------------------------
#
# ================================================================================
# BOM ID (V14): 49
#   Reference: Los glas (Blinkend glas)
#   Display Name: Los glas (Blinkend glas): Los glas
#   Product Template: Los glas
#   Product Variant: [P10P] Los glas (Blinkend glas)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (4 items):
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Los glas (Blinkend glas)
#      Trying fallback: matching by product_code
#      V14 product_code: P10
#      V14 product_variant: [P10P] Los glas (Blinkend glas)
#      Trying to match by product variant display_name
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 39
#   Reference: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, A)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 4106
#   Reference: Puzzel + Kader custom (XXL)
#   Display Name: Puzzel + Kader custom (XXL): Puzzel + Kader custom
#   Product Template: Puzzel + Kader custom
#   Product Variant: Puzzel + Kader custom (XXL)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond3mm.x] Dibond 2mm (kopie) (Code: Dibond3mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Puzzel + Kader custom (XXL)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 124
#   Reference: Kader + Print (Mat glas, Etch (Fine Art Mat))
#   Display Name: Kader + Print (Mat glas, Etch (Fine Art Mat)): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, Etch (Fine Art Mat))
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print (Mat glas, Etch (Fine Art Mat))
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6565
#   Reference: Kader + FM + Print (Mat glas, 3mm)
#   Display Name: Kader + FM + Print (Mat glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Print (Mat glas, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6541
#   Reference: Kader + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Mat glas, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6547
#   Reference: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat pl, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6549
#   Reference: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR70, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6552
#   Reference: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Mat glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6560
#   Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6545
#   Reference: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6548
#   Reference: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend plexi glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6550
#   Reference: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR92, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6553
#   Reference: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6556
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Artglass AR70, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6561
#   Reference: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR70, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Artglass AR70, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6566
#   Reference: Kader + FM + Print (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Blinkend glas, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Print (Blinkend glas, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6551
#   Reference: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR99, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6554
#   Reference: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Mat pl, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6559
#   Reference: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Blinkend glas, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6563
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Artglass AR99, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6568
#   Reference: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend plexi glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Print (Blinkend plexi glas, 3mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 543, Code: 'Kader + FM + Print (Blinkend plexi glas, 3mm)', active: False, matched by BOM reference (code))
#
#   [V18] Components (7 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 2.0)
#     ➕ EXTRA IN V18: [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6555
#   Reference: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6562
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Artglass AR92, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6564
#   Reference: Kader + FM + Inlijsting (Geen glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Geen glas, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Geen glas, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6569
#   Reference: Kader + FM + Print (Artglass AR70, 3mm)
#   Display Name: Kader + FM + Print (Artglass AR70, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Artglass AR70, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Print (Artglass AR70, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6557
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Artglass AR92, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6570
#   Reference: Kader + FM + Print (Artglass AR92, 3mm)
#   Display Name: Kader + FM + Print (Artglass AR92, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Artglass AR92, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Print (Artglass AR92, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6558
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR99, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Artglass AR99, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Artglass AR99, Matt Fibre)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6571
#   Reference: Kader + FM + Print (Artglass AR99, 3mm)
#   Display Name: Kader + FM + Print (Artglass AR99, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Artglass AR99, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Print (Artglass AR99, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6567
#   Reference: Kader + FM + Print (Mat plexi glas, 3mm)
#   Display Name: Kader + FM + Print (Mat plexi glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (3mm)
#   is_custom_made (V14): False
#   active (V14): False
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Print (Mat plexi glas, 3mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 75
#   Reference: Kader + Inlijsting (Artglass AR70)
#   Display Name: Kader + Inlijsting (Artglass AR70): Kader op maat (kopie)
#   Product Template: Kader op maat (kopie)
#   Product Variant: Kader op maat (kopie) (Artglass AR70)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (6 items):
#     - [41513.F04] Loft Mat Zwart 2 Cm + Spacer (Code: 41513, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Inlijsting (Artglass AR70)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 105
#   Reference: Standaard formaat kader (10x15)
#   Display Name: Standaard formaat kader (10x15): Standaard formaat kader
#   Product Template: Standaard formaat kader
#   Product Variant: Standaard formaat kader (10x15)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [4124.K04] Kaslijst zwart 2 CM (Code: 4124., Qty: 1.0)
#     - Standaard maat glas mat (Code: False, Qty: 1.0)
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - Standaard maat glas mat (Code: False, Qty: 1.0)
#     - [ZR100150.RUG] Zwarte rug met voet 10x15 (Code: ZR100150, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Standaard formaat kader (10x15)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 149
#   Reference: Kader + PP + Inlijsting (Mat plexi glas)
#   Display Name: Kader + PP + Inlijsting (Mat plexi glas): Kader op maat + PP + Inlijsting
#   Product Template: Kader op maat + PP + Inlijsting
#   Product Variant: Kader op maat + PP + Inlijsting (Mat pl)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (7 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Inlijsting (Mat plexi glas)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 72
#   Reference: Kader op maat + Inlijsting (Mat glas)
#   Display Name: Kader op maat + Inlijsting (Mat glas): Kader op maat (kopie)
#   Product Template: Kader op maat (kopie)
#   Product Variant: Kader op maat (kopie) (Mat glas)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (6 items):
#     - [273-004.O25] Zilver Mat 1,3 Cm  (Code: 273-004, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader op maat + Inlijsting (Mat glas)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 148
#   Reference: [P5P] Kader + PP + Inlijsting (Blinkend glas)
#   Display Name: [P5P] Kader + PP + Inlijsting (Blinkend glas): Kader op maat + PP + Inlijsting
#   Product Template: Kader op maat + PP + Inlijsting
#   Product Variant: [P5P] Kader op maat + PP + Inlijsting (Blinkend glas)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (7 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): [P5P] Kader + PP + Inlijsting (Blinkend glas)
#      Trying fallback: matching by product_code
#      V14 product_code: P5
#      V14 product_variant: [P5P] Kader op maat + PP + Inlijsting (Blinkend glas)
#      Trying to match by product variant display_name
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 15325
#   Reference: Askaders (Esdoorn)
#   Display Name: Askaders (Esdoorn): Askaders
#   Product Template: Askaders
#   Product Variant: Askaders (Italiaanse noten)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (6 items):
#     - [77263.N32] Tokio - Kaslijst Zwart 2 cm (kopie) (Code: 77263, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [ZR105105.RUG] Zwarte rug met voet 10,5x10,5 (Code: ZR105105, Qty: 1.0)
#     - [AB.0] Asbuisje (Code: AB., Qty: 1.0)
# ...
# BOM ID (V14): 26
#   Reference: Kader standaardformaat + PP (10,5x10,5)
#   Display Name: Kader standaardformaat + PP (10,5x10,5): Standaard formaat kader + PP
#   Product Template: Standaard formaat kader + PP
#   Product Variant: Standaard formaat kader + PP (10,5x10,5)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (6 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - Standaard maat glas mat (Code: False, Qty: 1.0)
#     - [ZR105105.RUG] Zwarte rug met voet 10,5x10,5 (Code: ZR105105, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader standaardformaat + PP (10,5x10,5)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 245
#   Reference: Los Dozen (70x100)
#   Display Name: Los Dozen (70x100): Los Dozen
#   Product Template: Los Dozen
#   Product Variant: Los Dozen (70x100)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (4 items):
#     - [DOOS70100b.BOX] DOOS 70X100 CM (Code: DOOS70100b, Qty: 1.0)
#     - [DOOS70100o.BOX] DOOS 70X100 CM Bovenstuk (kopie) (Code: DOOS70100o, Qty: 1.0)
#     - [DOOS70100v.BOX] DOOS 70X100 CM Onderstuk (kopie) (Code: DOOS70100v, Qty: 1.0)
#     - [PK70100.BOX] Plooikost doos 60x70 (kopie) (Code: PK70100, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Los Dozen (70x100)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 246
#   Reference: Los Dozen (75x115)
#   Display Name: Los Dozen (75x115): Los Dozen
#   Product Template: Los Dozen
#   Product Variant: Los Dozen (75x115)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (4 items):
#     - [DOOS75115b.BOX] DOOS 75X114 CM (Code: DOOS75115b, Qty: 1.0)
#     - [DOOS75115o.BOX] DOOS 75X115,5 CM Bovenstuk (kopie) (Code: DOOS75115o, Qty: 1.0)
#     - [DOOS75115v.BOX] DOOS 75X115,5 CM Onderstuk (kopie) (Code: DOOS75115v, Qty: 1.0)
#     - [PK75115.BOX] Plooikost doos 70x100 (kopie) (Code: PK75115, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Los Dozen (75x115)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 153
#   Reference: Kader + Print (Mat plexi glas, Barytte (Fine Art))
#   Display Name: Kader + Print (Mat plexi glas, Barytte (Fine Art)): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat pl, B)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [BARYTTE.PRINT] Barytte (Fine Art) (Code: BARYTTE, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print (Mat plexi glas, Barytte (Fine Art))
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 242
#   Reference: Los Dozen (40x40)
#   Display Name: Los Dozen (40x40): Los Dozen
#   Product Template: Los Dozen
#   Product Variant: [LD.X] Los Dozen (40x40)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (2 items):
#     - [DOOS4040.BOX] DOOS 40X40 CM (Code: DOOS4040, Qty: 1.0)
#     - [PK4040.BOX] Plooikost doos 40x40 (Code: PK4040, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Los Dozen (40x40)
#      Trying fallback: matching by product_code
#      V14 product_code: LD
#      V14 product_variant: [LD.X] Los Dozen (40x40)
#      Trying to match by product variant display_name
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6140
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Artglass AR99, 2mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 146
#   Reference: Kader + PP (Artglass AR70)
#   Display Name: Kader + PP (Artglass AR70): Kader op maat + PP
#   Product Template: Kader op maat + PP
#   Product Variant: Kader op maat + PP (Artglass AR70)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (5 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [GSRM918.C7] Very White              (Code: GSRM918, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP (Artglass AR70)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 121
#   Reference: Kader + Print (Mat glas, Semi Matte Epson)
#   Display Name: Kader + Print (Mat glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, A)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print (Mat glas, Semi Matte Epson)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 4105
#   Reference: Puzzel + Kader custom (Normaal)
#   Display Name: Puzzel + Kader custom (Normaal): Puzzel + Kader custom
#   Product Template: Puzzel + Kader custom
#   Product Variant: [P109P] Puzzel + Kader custom (Normaal)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond2mm.X] Forex Wit 10mm (kopie) (Code: Dibond2mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Puzzel + Kader custom (Normaal)
#      Trying fallback: matching by product_code
#      V14 product_code: P109
#      V14 product_variant: [P109P] Puzzel + Kader custom (Normaal)
#      Trying to match by product variant display_name
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 413
#   Reference: [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)
#   Display Name: [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)
#      Trying fallback: matching by product_code
#      V14 product_code: KFMI
#      V14 product_variant: [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)
#      Trying to match by product variant display_name
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 199
#   Reference: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   Display Name: [KOF5MM.diensten] Kleven op Fomeboard (5mm): Kleven op Fomeboard
#   Product Template: Kleven op Fomeboard
#   Product Variant: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (2 items):
#     - [SK5MM.X] Schuimkarton 5mm (Code: SK5MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#      Trying fallback: matching by product_code
#      V14 product_code: KOF5MM
#      V14 product_variant: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#      Trying to match by product variant display_name
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6139
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Artglass AR92, 2mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 157
#   Reference: Kader + Print (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Kader + Print (Blinkend plexi glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend plexi glas, A)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print (Blinkend plexi glas, Semi Matte Epson)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6141
#   Reference: Kader + FM + Inlijsting (Geen glas, 2mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Geen glas, 2mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Geen glas, 2mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM comparison complete!
# Total BOMs checked: 250
# BOMs with mismatches: 250
# ================================================================================

# %%
# Compare BOMs between Odoo V14 and V18 to find mismatches

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables for V14
JUSTFRAMEIT_ODOO_V14_URL = os.getenv('JUSTFRAMEIT_ODOO_V14_URL')
JUSTFRAMEIT_ODOO_V14_DB = os.getenv('JUSTFRAMEIT_ODOO_V14_DB')
JUSTFRAMEIT_ODOO_V14_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_V14_USERNAME')
JUSTFRAMEIT_ODOO_V14_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_V14_API_KEY')

# Get environment variables for V18
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

print("=" * 80)
print("Comparing BOMs between Odoo V14 and V18")
print("=" * 80)

try:
    # Authenticate to V14
    print("\n[V14] Authenticating...")
    common_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/common", allow_none=True)
    uid_v14 = common_v14.authenticate(JUSTFRAMEIT_ODOO_V14_DB, JUSTFRAMEIT_ODOO_V14_USERNAME, JUSTFRAMEIT_ODOO_V14_API_KEY, {})
    print(f"✅ V14 Authenticated! UID: {uid_v14}")
    
    # Authenticate to V18
    print("\n[V18] Authenticating...")
    common_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
    uid_v18 = common_v18.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
    print(f"✅ V18 Authenticated! UID: {uid_v18}\n")
    
    # Create models proxies
    models_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/object", allow_none=True)
    models_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)
    
    # Define specific category IDs to check
    target_category_ids = [4, 8, 10, 57, 82]
    #target_category_ids = [10] #for testing
    
    print(f"Checking specific categories: {target_category_ids}\n")
    
    # Get category details from V14 (single call)
    categories = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.category', 'read',
        [target_category_ids],
        {'fields': ['display_name']})
    
    print("Categories to check:")
    for cat in categories:
        print(f"  - Category ID {cat['id']}: {cat['display_name']}")
    print()
    
    # Get all product templates in these categories from V14 (single call)
    print("[V14] Fetching product templates in these categories...")
    product_template_ids = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'search',
        [[['categ_id', 'in', target_category_ids]]])
    
    print(f"Found {len(product_template_ids)} product templates\n")
    
    # Search for BOMs with is_custom_made = False in V14 (including inactive BOMs)
    print("[V14] Searching for BOMs with is_custom_made = False (including inactive)...")
    print("=" * 80)
    
    bom_ids_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'mrp.bom', 'search',
        [[['product_tmpl_id', 'in', product_template_ids], ['is_custom_made', '=', False]]],
        {'context': {'active_test': False}})
    
    print(f"\n[V14] Found {len(bom_ids_v14)} BOMs with is_custom_made = False (including inactive)\n")
    
    if not bom_ids_v14:
        print("No BOMs found with is_custom_made = False in V14")
    else:
        # Get ALL BOM details from V14 in a single call
        boms_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
            'mrp.bom', 'read',
            [bom_ids_v14],
            {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'is_custom_made', 'bom_line_ids', 'active']})
        
        # Get ALL BOM lines from V14 in a single call
        all_bom_line_ids_v14 = []
        for bom in boms_v14:
            if bom['bom_line_ids']:
                all_bom_line_ids_v14.extend(bom['bom_line_ids'])
        
        bom_lines_v14_dict = {}
        if all_bom_line_ids_v14:
            all_bom_lines_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'mrp.bom.line', 'read',
                [all_bom_line_ids_v14],
                {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
            
            # Get all product IDs from BOM lines to fetch product codes
            product_ids_v14 = [line['product_id'][0] for line in all_bom_lines_v14 if line['product_id']]
            
            # Fetch product codes for all products in V14
            products_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.product', 'read',
                [product_ids_v14],
                {'fields': ['id', 'product_code']})
            
            # Create a mapping of product_id to product_code
            product_code_map_v14 = {p['id']: p['product_code'] for p in products_v14}
            
            # Organize by bom_id for easy lookup
            for line in all_bom_lines_v14:
                bom_id = line['bom_id'][0] if line['bom_id'] else None
                if bom_id not in bom_lines_v14_dict:
                    bom_lines_v14_dict[bom_id] = []
                # Add product_code to the line data
                product_id = line['product_id'][0] if line['product_id'] else None
                line['product_code'] = product_code_map_v14.get(product_id, 'N/A')
                bom_lines_v14_dict[bom_id].append(line)
        
        # Collect all BOM codes and product variant display names to search in V18
        bom_codes_v14 = [bom['code'] for bom in boms_v14 if bom['code']]
        
        # Get product variant IDs from V14 BOMs
        product_variant_ids_v14 = [bom['product_id'][0] for bom in boms_v14 if bom['product_id']]
        
        # Fetch display_name for all product variants in V14
        product_variants_v14 = []
        if product_variant_ids_v14:
            product_variants_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.product', 'read',
                [product_variant_ids_v14],
                {'fields': ['id', 'display_name']})
        
        # Create a mapping of product_id to display_name
        product_display_name_map_v14 = {p['id']: p['display_name'] for p in product_variants_v14}
        
        # Get all product variant display names
        product_variant_display_names_v14 = [product_display_name_map_v14.get(bom['product_id'][0]) for bom in boms_v14 if bom['product_id']]
        
        # Search for ALL corresponding BOMs in V18 by code
        bom_ids_v18_by_code = []
        if bom_codes_v14:
            bom_ids_v18_by_code = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'search',
                [[['code', 'in', bom_codes_v14]]])
        
        # Search for ALL corresponding BOMs in V18 by product variant display name (in code field)
        bom_ids_v18_by_variant_in_code = []
        if product_variant_display_names_v14:
            bom_ids_v18_by_variant_in_code = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'search',
                [[['code', 'in', product_variant_display_names_v14]]])
        
        # Search for ALL corresponding BOMs in V18 by product variant display name (in product_id field)
        bom_ids_v18_by_variant_in_product = []
        if product_variant_display_names_v14:
            # First get product IDs that match the variant display names
            product_ids_v18_matching = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'product.product', 'search',
                [[['display_name', 'in', product_variant_display_names_v14]]])
            
            if product_ids_v18_matching:
                bom_ids_v18_by_variant_in_product = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'mrp.bom', 'search',
                    [[['product_id', 'in', product_ids_v18_matching]]])
        
        # Combine all V18 BOM IDs
        all_bom_ids_v18 = list(set(bom_ids_v18_by_code + bom_ids_v18_by_variant_in_code + bom_ids_v18_by_variant_in_product))
        
        # Get ALL BOM details from V18 in a single call
        boms_v18_by_code = {}
        boms_v18_by_variant_display_name = {}
        if all_bom_ids_v18:
            boms_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'read',
                [all_bom_ids_v18],
                {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'bom_line_ids']})
            
            # Get product variant IDs from V18 BOMs to fetch display_name
            product_variant_ids_v18 = [bom['product_id'][0] for bom in boms_v18 if bom['product_id']]
            
            # Fetch display_name for all product variants in V18
            product_variants_v18 = []
            if product_variant_ids_v18:
                product_variants_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'product.product', 'read',
                    [product_variant_ids_v18],
                    {'fields': ['id', 'display_name']})
            
            # Create a mapping of product_id to display_name
            product_display_name_map_v18 = {p['id']: p['display_name'] for p in product_variants_v18}
            
            # Organize by code and by product variant display name for easy lookup
            for bom in boms_v18:
                if bom['code']:
                    if bom['code'] not in boms_v18_by_code:
                        boms_v18_by_code[bom['code']] = []
                    boms_v18_by_code[bom['code']].append(bom)
                
                if bom['product_id']:
                    variant_display_name = product_display_name_map_v18.get(bom['product_id'][0])
                    if variant_display_name:
                        if variant_display_name not in boms_v18_by_variant_display_name:
                            boms_v18_by_variant_display_name[variant_display_name] = []
                        boms_v18_by_variant_display_name[variant_display_name].append(bom)
            
            # Get ALL BOM lines from V18 in a single call
            all_bom_line_ids_v18 = []
            for bom in boms_v18:
                if bom['bom_line_ids']:
                    all_bom_line_ids_v18.extend(bom['bom_line_ids'])
            
            bom_lines_v18_dict = {}
            if all_bom_line_ids_v18:
                all_bom_lines_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'mrp.bom.line', 'read',
                    [all_bom_line_ids_v18],
                    {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
                
                # Get all product IDs from BOM lines to fetch product codes
                product_ids_v18 = [line['product_id'][0] for line in all_bom_lines_v18 if line['product_id']]
                
                # Fetch product codes for all products in V18
                products_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'product.product', 'read',
                    [product_ids_v18],
                    {'fields': ['id', 'x_studio_product_code']})
                
                # Create a mapping of product_id to x_studio_product_code
                product_code_map_v18 = {p['id']: p['x_studio_product_code'] for p in products_v18}
                
                # Organize by bom_id for easy lookup
                for line in all_bom_lines_v18:
                    bom_id = line['bom_id'][0] if line['bom_id'] else None
                    if bom_id not in bom_lines_v18_dict:
                        bom_lines_v18_dict[bom_id] = []
                    # Add product_code to the line data
                    product_id = line['product_id'][0] if line['product_id'] else None
                    line['product_code'] = product_code_map_v18.get(product_id, 'N/A')
                    bom_lines_v18_dict[bom_id].append(line)
        
        print("Comparing BOMs between V14 and V18:")
        print("-" * 80)
        
        mismatches_found = 0
        
        for bom_v14 in boms_v14:
            product_tmpl_name = bom_v14['product_tmpl_id'][1] if bom_v14['product_tmpl_id'] else 'N/A'
            product_variant_display_name = product_display_name_map_v14.get(bom_v14['product_id'][0]) if bom_v14['product_id'] else 'N/A (Template BOM)'
            bom_reference = bom_v14['code'] if bom_v14['code'] else 'No reference'
            bom_display_name = bom_v14['display_name'] if bom_v14['display_name'] else 'No display name'
            is_active = bom_v14.get('active', True)
            
            print(f"\n{'=' * 80}")
            print(f"BOM ID (V14): {bom_v14['id']}")
            print(f"  Reference: {bom_reference}")
            print(f"  Display Name: {bom_display_name}")
            print(f"  Product Template: {product_tmpl_name}")
            print(f"  Product Variant: {product_variant_display_name}")
            print(f"  is_custom_made (V14): {bom_v14['is_custom_made']}")
            print(f"  Active (V14): {is_active}")
            
            # Get BOM line components from V14 (from pre-fetched data)
            components_v14 = {}
            bom_lines = bom_lines_v14_dict.get(bom_v14['id'], [])
            
            if bom_lines:
                print(f"\n  [V14] Components ({len(bom_lines)} items):")
                for line in bom_lines:
                    component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                    component_code = line['product_code']
                    component_qty = line['product_qty']
                    components_v14[component_code] = {'name': component_name, 'qty': component_qty}
                    print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
            else:
                print(f"\n  [V14] Components: None")
            
            # Find corresponding BOM in V18 using multi-step matching strategy
            print(f"\n  [V18] Searching for corresponding BOM...")
            
            bom_v18 = None
            match_method = None
            
            # Step 1: Try matching by reference (code)
            if bom_reference and bom_reference != 'No reference':
                print(f"     Step 1: Trying to match by BOM reference (code): '{bom_reference}'")
                matching_boms = boms_v18_by_code.get(bom_reference, [])
                
                if len(matching_boms) == 1:
                    bom_v18 = matching_boms[0]
                    match_method = "reference (code)"
                    print(f"     ✅ Found unique match by reference")
                elif len(matching_boms) > 1:
                    print(f"     ⚠️  Found {len(matching_boms)} BOMs with same reference - trying next method")
                else:
                    print(f"     ❌ No match by reference")
            else:
                print(f"     Step 1: Skipped (no BOM reference in V14)")
            
            # Step 2: If no unique match, try matching product_id (variant display name) from V14 against code in V18
            if not bom_v18 and product_variant_display_name and product_variant_display_name != 'N/A (Template BOM)':
                print(f"     Step 2: Trying to match V14 product variant display name against V18 BOM code: '{product_variant_display_name}'")
                matching_boms = boms_v18_by_code.get(product_variant_display_name, [])
                
                if len(matching_boms) == 1:
                    bom_v18 = matching_boms[0]
                    match_method = "V14 variant display name vs V18 code"
                    print(f"     ✅ Found unique match")
                elif len(matching_boms) > 1:
                    print(f"     ⚠️  Found {len(matching_boms)} BOMs - trying next method")
                else:
                    print(f"     ❌ No match")
            
            # Step 3: If still no match, try matching product_id (variant display name) from V14 against product_id in V18
            if not bom_v18 and product_variant_display_name and product_variant_display_name != 'N/A (Template BOM)':
                print(f"     Step 3: Trying to match V14 product variant display name against V18 product variant display name: '{product_variant_display_name}'")
                matching_boms = boms_v18_by_variant_display_name.get(product_variant_display_name, [])
                
                if len(matching_boms) == 1:
                    bom_v18 = matching_boms[0]
                    match_method = "V14 variant display name vs V18 variant display name"
                    print(f"     ✅ Found unique match")
                elif len(matching_boms) > 1:
                    print(f"     ⚠️  Found {len(matching_boms)} BOMs with same variant display name")
                    # Take the first one but note the ambiguity
                    bom_v18 = matching_boms[0]
                    match_method = "V14 variant display name vs V18 variant display name (ambiguous - using first match)"
                    print(f"     ⚠️  Using first match (ID: {bom_v18['id']})")
                else:
                    print(f"     ❌ No match")
            
            if not bom_v18:
                print(f"  ❌ NO CORRESPONDING BOM FOUND IN V18 after all matching attempts!")
                mismatches_found += 1
                continue
            
            print(f"  ✅ Found corresponding BOM in V18 (ID: {bom_v18['id']}, Code: '{bom_v18['code']}') via {match_method}")
            
            # Get BOM line components from V18 (from pre-fetched data)
            components_v18 = {}
            bom_lines_v18 = bom_lines_v18_dict.get(bom_v18['id'], [])
            
            if bom_lines_v18:
                print(f"\n  [V18] Components ({len(bom_lines_v18)} items):")
                for line in bom_lines_v18:
                    component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                    component_code = line['product_code']
                    component_qty = line['product_qty']
                    components_v18[component_code] = {'name': component_name, 'qty': component_qty}
                    print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
            else:
                print(f"\n  [V18] Components: None")
            
            # Compare components
            print(f"\n  🔍 COMPARISON RESULTS:")
            has_mismatch = False
            
            # Check for missing components in V18
            for component_code, component_data in components_v14.items():
                if component_code not in components_v18:
                    print(f"    ❌ MISSING IN V18: {component_data['name']} (Code: {component_code}, Qty in V14: {component_data['qty']})")
                    has_mismatch = True
                elif components_v18[component_code]['qty'] != component_data['qty']:
                    print(f"    ⚠️  QUANTITY MISMATCH: {component_data['name']} (Code: {component_code})")
                    print(f"       V14 Qty: {component_data['qty']}")
                    print(f"       V18 Qty: {components_v18[component_code]['qty']}")
                    has_mismatch = True
            
            # Check for extra components in V18
            for component_code, component_data in components_v18.items():
                if component_code not in components_v14:
                    print(f"    ➕ EXTRA IN V18: {component_data['name']} (Code: {component_code}, Qty: {component_data['qty']})")
                    has_mismatch = True
            
            if not has_mismatch:
                print(f"    ✅ All components match!")
            else:
                mismatches_found += 1
    
    print("\n" + "=" * 80)
    print(f"BOM comparison complete!")
    print(f"Total BOMs checked: {len(bom_ids_v14) if bom_ids_v14 else 0}")
    print(f"BOMs with mismatches: {mismatches_found}")
    print("=" * 80)
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ================================================================================
# Comparing BOMs between Odoo V14 and V18
# ================================================================================
#
# [V14] Authenticating...
# ✅ V14 Authenticated! UID: 28
#
# [V18] Authenticating...
# ✅ V18 Authenticated! UID: 2
#
# Checking specific categories: [4, 8, 10, 57, 82]
#
# Categories to check:
#   - Category ID 4: 0. Presets / 1. Presets zonder PP
#   - Category ID 8: 0. Presets / 2. Presets met PP
#   - Category ID 10: 0. Presets / 3. Losse verkopen
#   - Category ID 57: 0. Presets / 4. Losse PP
#   - Category ID 82: 0. Presets / Fixed margin
#
# [V14] Fetching product templates in these categories...
# Found 28 product templates
#
# [V14] Searching for BOMs with is_custom_made = False (including inactive)...
# ================================================================================
#
# [V14] Found 250 BOMs with is_custom_made = False (including inactive)
#
# Comparing BOMs between V14 and V18:
# --------------------------------------------------------------------------------
#
# ================================================================================
# BOM ID (V14): 49
#   Reference: Los glas (Blinkend glas)
#   Display Name: Los glas (Blinkend glas): Los glas
#   Product Template: Los glas
#   Product Variant: [P10P] Los glas (Blinkend glas)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (4 items):
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Los glas (Blinkend glas)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 747, Code: 'Los glas (Blinkend glas)') via reference (code)
#
#   [V18] Components (3 items):
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT Verpakking (Code: MDF3MM, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT Verpakking (Code: MDF3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#
# ================================================================================
# BOM ID (V14): 39
#   Reference: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, A)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 723, Code: 'Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)') via reference (code)
#
#   [V18] Components (6 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 4106
#   Reference: Puzzel + Kader custom (XXL)
#   Display Name: Puzzel + Kader custom (XXL): Puzzel + Kader custom
#   Product Template: Puzzel + Kader custom
#   Product Variant: Puzzel + Kader custom (XXL)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond3mm.x] Dibond 2mm (kopie) (Code: Dibond3mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Puzzel + Kader custom (XXL)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 593, Code: 'Puzzel + Kader custom (XXL)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [Dibond3mmx] Dibond 2mm (kopie) (Code: Dibond3mm, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 124
#   Reference: Kader + Print (Mat glas, Etch (Fine Art Mat))
#   Display Name: Kader + Print (Mat glas, Etch (Fine Art Mat)): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, Etch (Fine Art Mat))
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + Print (Mat glas, Etch (Fine Art Mat))'
#      ❌ No match by reference
#      Step 2: Trying to match V14 product variant display name against V18 BOM code: 'Kader + PP + Print (kopie) (Mat glas, Etch (Fine Art Mat))'
#      ❌ No match
#      Step 3: Trying to match V14 product variant display name against V18 product variant display name: 'Kader + PP + Print (kopie) (Mat glas, Etch (Fine Art Mat))'
#      ❌ No match
#   ❌ NO CORRESPONDING BOM FOUND IN V18 after all matching attempts!
#
# ================================================================================
# BOM ID (V14): 6565
#   Reference: Kader + FM + Print (Mat glas, 3mm)
#   Display Name: Kader + FM + Print (Mat glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (3mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + FM + Print (Mat glas, 3mm)'
#      ❌ No match by reference
#      Step 2: Trying to match V14 product variant display name against V18 BOM code: 'Kader + FM + Print (3mm)'
#      ❌ No match
#      Step 3: Trying to match V14 product variant display name against V18 product variant display name: 'Kader + FM + Print (3mm)'
#      ❌ No match
#   ❌ NO CORRESPONDING BOM FOUND IN V18 after all matching attempts!
#
# ================================================================================
# BOM ID (V14): 6541
#   Reference: Kader + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + Print + Inlijsting (Mat glas, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 679, Code: 'Kader + Print + Inlijsting (Mat glas, Matt Fibre)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MG.GLAS] Mat glas (Code: MG., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6547
#   Reference: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat pl, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 680, Code: 'Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Mat plexiglas (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6549
#   Reference: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR70, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 674, Code: 'Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6552
#   Reference: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Mat glas, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 714, Code: 'Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)') via reference (code)
#
#   [V18] Components (6 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MG.GLAS] Mat glas (Code: MG., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MG.GLAS] Mat glas (Code: MG, Qty: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6560
#   Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 227, Code: 'Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6545
#   Reference: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend glas, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 677, Code: 'Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6548
#   Reference: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend plexi glas, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 678, Code: 'Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6550
#   Reference: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR92, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 675, Code: 'Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6553
#   Reference: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend glas, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 712, Code: 'Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)') via reference (code)
#
#   [V18] Components (6 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6556
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Artglass AR70, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 709, Code: 'Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)') via reference (code)
#
#   [V18] Components (6 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6561
#   Reference: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR70, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + FM + Inlijsting (Artglass AR70, 3mm)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 228, Code: 'Kader + FM + Inlijsting (Artglass AR70, 3mm)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6566
#   Reference: Kader + FM + Print (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Blinkend glas, 3mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + FM + Print (Blinkend glas, 3mm)'
#      ❌ No match by reference
#      Step 2: Trying to match V14 product variant display name against V18 BOM code: 'Kader + FM + Print (Blinkend glas, 3mm)'
#      ❌ No match
#      Step 3: Trying to match V14 product variant display name against V18 product variant display name: 'Kader + FM + Print (Blinkend glas, 3mm)'
#      ❌ No match
#   ❌ NO CORRESPONDING BOM FOUND IN V18 after all matching attempts!
#
# ================================================================================
# BOM ID (V14): 6551
#   Reference: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR99, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 676, Code: 'Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6554
#   Reference: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Mat pl, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)'
#      ❌ No match by reference
#      Step 2: Trying to match V14 product variant display name against V18 BOM code: 'Print + Kader + PP (Mat pl, Matt Fibre)'
#      ❌ No match
#      Step 3: Trying to match V14 product variant display name against V18 product variant display name: 'Print + Kader + PP (Mat pl, Matt Fibre)'
#      ❌ No match
#   ❌ NO CORRESPONDING BOM FOUND IN V18 after all matching attempts!
#
# ================================================================================
# BOM ID (V14): 6559
#   Reference: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + FM + Inlijsting (Blinkend glas, 3mm)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 213, Code: 'Kader + FM + Inlijsting (Blinkend glas, 3mm)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6563
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + FM + Inlijsting (Artglass AR99, 3mm)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 214, Code: 'Kader + FM + Inlijsting (Artglass AR99, 3mm)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6568
#   Reference: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend plexi glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + FM + Print (Blinkend plexi glas, 3mm)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 544, Code: 'Kader + FM + Print (Blinkend plexi glas, 3mm)') via reference (code)
#
#   [V18] Components (7 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 2.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6555
#   Reference: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, Matt Fibre)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 713, Code: 'Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)') via reference (code)
#
#   [V18] Components (6 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 6562
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 3mm)
# ...
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + FM + Inlijsting (Artglass AR99, 2mm)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 230, Code: 'Kader + FM + Inlijsting (Artglass AR99, 2mm)') via reference (code)
#
#   [V18] Components (6 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2Econospacer Transparant 3,2mm] Econospacer Transparant (Code: ECOST2, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 146
#   Reference: Kader + PP (Artglass AR70)
#   Display Name: Kader + PP (Artglass AR70): Kader op maat + PP
#   Product Template: Kader op maat + PP
#   Product Variant: Kader op maat + PP (Artglass AR70)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (5 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [GSRM918.C7] Very White              (Code: GSRM918, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + PP (Artglass AR70)'
#      ❌ No match by reference
#      Step 2: Trying to match V14 product variant display name against V18 BOM code: 'Kader op maat + PP (Artglass AR70)'
#      ✅ Found unique match
#   ✅ Found corresponding BOM in V18 (ID: 687, Code: 'Kader op maat + PP (Artglass AR70)') via V14 variant display name vs V18 code
#
#   [V18] Components (4 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [GSRM918.C7] Very White              (Code: GSRM918, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 121
#   Reference: Kader + Print (Mat glas, Semi Matte Epson)
#   Display Name: Kader + Print (Mat glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, A)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + Print (Mat glas, Semi Matte Epson)'
#      ❌ No match by reference
#      Step 2: Trying to match V14 product variant display name against V18 BOM code: 'Kader + PP + Print (kopie) (Mat glas, A)'
#      ❌ No match
#      Step 3: Trying to match V14 product variant display name against V18 product variant display name: 'Kader + PP + Print (kopie) (Mat glas, A)'
#      ❌ No match
#   ❌ NO CORRESPONDING BOM FOUND IN V18 after all matching attempts!
#
# ================================================================================
# BOM ID (V14): 4105
#   Reference: Puzzel + Kader custom (Normaal)
#   Display Name: Puzzel + Kader custom (Normaal): Puzzel + Kader custom
#   Product Template: Puzzel + Kader custom
#   Product Variant: [P109P] Puzzel + Kader custom (Normaal)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond2mm.X] Forex Wit 10mm (kopie) (Code: Dibond2mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Puzzel + Kader custom (Normaal)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 594, Code: 'Puzzel + Kader custom (Normaal)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [Dibond2mm.X] Forex Wit 10mm (kopie) (Code: Dibond2mm, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 413
#   Reference: [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)
#   Display Name: [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): '[KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 235, Code: '[KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)') via reference (code)
#
#   [V18] Components (5 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 199
#   Reference: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   Display Name: [KOF5MM.diensten] Kleven op Fomeboard (5mm): Kleven op Fomeboard
#   Product Template: Kleven op Fomeboard
#   Product Variant: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (2 items):
#     - [SK5MM.X] Schuimkarton 5mm (Code: SK5MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): '[KOF5MM.diensten] Kleven op Fomeboard (5mm)'
#      ❌ No match by reference
#      Step 2: Trying to match V14 product variant display name against V18 BOM code: '[KOF5MM.diensten] Kleven op Fomeboard (5mm)'
#      ❌ No match
#      Step 3: Trying to match V14 product variant display name against V18 product variant display name: '[KOF5MM.diensten] Kleven op Fomeboard (5mm)'
#      ❌ No match
#   ❌ NO CORRESPONDING BOM FOUND IN V18 after all matching attempts!
#
# ================================================================================
# BOM ID (V14): 6139
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + FM + Inlijsting (Artglass AR92, 2mm)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 236, Code: 'Kader + FM + Inlijsting (Artglass AR92, 2mm)') via reference (code)
#
#   [V18] Components (6 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2Econospacer Transparant 3,2mm] Econospacer Transparant (Code: ECOST2, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM ID (V14): 157
#   Reference: Kader + Print (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Kader + Print (Blinkend plexi glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend plexi glas, A)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + Print (Blinkend plexi glas, Semi Matte Epson)'
#      ❌ No match by reference
#      Step 2: Trying to match V14 product variant display name against V18 BOM code: 'Kader + PP + Print (kopie) (Blinkend plexi glas, A)'
#      ❌ No match
#      Step 3: Trying to match V14 product variant display name against V18 product variant display name: 'Kader + PP + Print (kopie) (Blinkend plexi glas, A)'
#      ❌ No match
#   ❌ NO CORRESPONDING BOM FOUND IN V18 after all matching attempts!
#
# ================================================================================
# BOM ID (V14): 6141
#   Reference: Kader + FM + Inlijsting (Geen glas, 2mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Geen glas, 2mm)
#   is_custom_made (V14): False
#   Active (V14): True
#
#   [V14] Components (9 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Step 1: Trying to match by BOM reference (code): 'Kader + FM + Inlijsting (Geen glas, 2mm)'
#      ✅ Found unique match by reference
#   ✅ Found corresponding BOM in V18 (ID: 231, Code: 'Kader + FM + Inlijsting (Geen glas, 2mm)') via reference (code)
#
#   [V18] Components (5 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - [ECOST2Econospacer Transparant 3,2mm] Econospacer Transparant (Code: ECOST2, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ❌ MISSING IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [IN.DIENST] Inlijsten (Code: IN, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [AK.DIENST] Assembleren kader (Code: AK., Qty in V14: 1.0)
#     ❌ MISSING IN V18: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty in V14: 1.0)
#     ❌ MISSING IN V18: [KK.Internedienst] Kleven (Code: KK, Qty in V14: 1.0)
#     ➕ EXTRA IN V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM, Qty: 1.0)
#
# ================================================================================
# BOM comparison complete!
# Total BOMs checked: 250
# BOMs with mismatches: 243
# ================================================================================

# %%
# Sync BOMs from Odoo V14 to V18 by deleting and recreating them

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables for V14
JUSTFRAMEIT_ODOO_V14_URL = os.getenv('JUSTFRAMEIT_ODOO_V14_URL')
JUSTFRAMEIT_ODOO_V14_DB = os.getenv('JUSTFRAMEIT_ODOO_V14_DB')
JUSTFRAMEIT_ODOO_V14_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_V14_USERNAME')
JUSTFRAMEIT_ODOO_V14_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_V14_API_KEY')

# Get environment variables for V18
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL_TEST')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB_TEST')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

print("=" * 80)
print("Syncing BOMs from Odoo V14 to V18")
print("=" * 80)

try:
    # Authenticate to V14
    print("\n[V14] Authenticating...")
    common_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/common", allow_none=True)
    uid_v14 = common_v14.authenticate(JUSTFRAMEIT_ODOO_V14_DB, JUSTFRAMEIT_ODOO_V14_USERNAME, JUSTFRAMEIT_ODOO_V14_API_KEY, {})
    print(f"✅ V14 Authenticated! UID: {uid_v14}")
    
    # Authenticate to V18
    print("\n[V18] Authenticating...")
    common_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
    uid_v18 = common_v18.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
    print(f"✅ V18 Authenticated! UID: {uid_v18}\n")
    
    # Create models proxies
    models_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/object", allow_none=True)
    models_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)
    
    # Define specific category IDs to check
    target_category_ids = [4, 8, 10, 57, 82]
    #target_category_ids = [10] #for testing
    
    print(f"Target categories: {target_category_ids}\n")
    
    # Get category details from V14 (single call)
    categories = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.category', 'read',
        [target_category_ids],
        {'fields': ['display_name']})
    
    print("Categories to sync:")
    for cat in categories:
        print(f"  - Category ID {cat['id']}: {cat['display_name']}")
    print()
    
    # Get all product templates in these categories from V14 (single call)
    print("[V14] Fetching product templates in these categories...")
    product_template_ids = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'search',
        [[['categ_id', 'in', target_category_ids]]])
    
    print(f"Found {len(product_template_ids)} product templates\n")
    
    # Search for BOMs with is_custom_made = False in V14 (single call)
    print("[V14] Searching for BOMs with is_custom_made = False...")
    print("=" * 80)
    
    bom_ids_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'mrp.bom', 'search',
        [[['product_tmpl_id', 'in', product_template_ids], ['is_custom_made', '=', False]]])
    
    print(f"\n[V14] Found {len(bom_ids_v14)} BOMs with is_custom_made = False\n")
    
    if not bom_ids_v14:
        print("No BOMs found with is_custom_made = False in V14")
    else:
        # Get ALL BOM details from V14 in a single call
        boms_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
            'mrp.bom', 'read',
            [bom_ids_v14],
            {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'is_custom_made', 'bom_line_ids', 'product_qty']})
        
        # Get ALL BOM lines from V14 in a single call
        all_bom_line_ids_v14 = []
        for bom in boms_v14:
            if bom['bom_line_ids']:
                all_bom_line_ids_v14.extend(bom['bom_line_ids'])
        
        bom_lines_v14_dict = {}
        if all_bom_line_ids_v14:
            all_bom_lines_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'mrp.bom.line', 'read',
                [all_bom_line_ids_v14],
                {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
            
            # Get all product IDs from BOM lines to fetch product codes
            product_ids_v14 = [line['product_id'][0] for line in all_bom_lines_v14 if line['product_id']]
            
            # Fetch product codes for all products in V14
            products_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.product', 'read',
                [product_ids_v14],
                {'fields': ['id', 'product_code', 'display_name']})
            
            # Create a mapping of product_id to product data
            product_data_map_v14 = {p['id']: {'code': p['product_code'], 'name': p['display_name']} for p in products_v14}
            
            # Organize by bom_id for easy lookup
            for line in all_bom_lines_v14:
                bom_id = line['bom_id'][0] if line['bom_id'] else None
                if bom_id not in bom_lines_v14_dict:
                    bom_lines_v14_dict[bom_id] = []
                # Add product_code to the line data
                product_id = line['product_id'][0] if line['product_id'] else None
                product_data = product_data_map_v14.get(product_id, {'code': 'N/A', 'name': 'N/A'})
                line['product_code'] = product_data['code']
                line['product_name'] = product_data['name']
                bom_lines_v14_dict[bom_id].append(line)
        
        # Step 1: Delete existing BOMs in V18 for these categories
        print("\n" + "=" * 80)
        print("[V18] STEP 1: Deleting existing BOMs in target categories...")
        print("=" * 80)
        
        # Get product templates in V18 for these categories
        product_template_ids_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
            'product.template', 'search',
            [[['categ_id', 'in', target_category_ids]]])
        
        # Find BOMs for these product templates in V18
        bom_ids_v18_to_delete = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
            'mrp.bom', 'search',
            [[['product_tmpl_id', 'in', product_template_ids_v18]]])
        
        print(f"Found {len(bom_ids_v18_to_delete)} BOMs to delete in V18")
        
        deleted_count = 0
        failed_to_delete = []
        
        for bom_id in bom_ids_v18_to_delete:
            try:
                models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'mrp.bom', 'unlink',
                    [[bom_id]])
                deleted_count += 1
                print(f"  ✅ Deleted BOM ID: {bom_id}")
            except Exception as e:
                failed_to_delete.append({'id': bom_id, 'error': str(e)})
                print(f"  ❌ Failed to delete BOM ID {bom_id}: {e}")
        
        print(f"\nDeleted {deleted_count} BOMs successfully")
        if failed_to_delete:
            print(f"Failed to delete {len(failed_to_delete)} BOMs")
        
        # Step 2: Create product code mapping in V18
        print("\n" + "=" * 80)
        print("[V18] STEP 2: Building product code mapping...")
        print("=" * 80)
        
        # Get all products in V18 with their codes
        all_products_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
            'product.product', 'search_read',
            [[]],
            {'fields': ['id', 'x_studio_product_code', 'display_name', 'product_tmpl_id']})
        
        # Create mapping: product_code -> product_id in V18
        product_code_to_id_v18 = {}
        for p in all_products_v18:
            if p['x_studio_product_code']:
                product_code_to_id_v18[p['x_studio_product_code']] = {
                    'id': p['id'],
                    'name': p['display_name'],
                    'tmpl_id': p['product_tmpl_id'][0] if p['product_tmpl_id'] else None
                }
        
        print(f"Mapped {len(product_code_to_id_v18)} products by code in V18")
        
        # Step 3: Recreate BOMs in V18
        print("\n" + "=" * 80)
        print("[V18] STEP 3: Recreating BOMs from V14...")
        print("=" * 80)
        
        created_count = 0
        failed_to_create = []
        created_products = []
        
        for bom_v14 in boms_v14:
            print(f"\n{'=' * 80}")
            print(f"Processing BOM ID (V14): {bom_v14['id']}")
            print(f"  Reference: {bom_v14['code']}")
            print(f"  Display Name: {bom_v14['display_name']}")
            
            # Get product template ID in V18
            product_tmpl_id_v14 = bom_v14['product_tmpl_id'][0] if bom_v14['product_tmpl_id'] else None
            
            if not product_tmpl_id_v14:
                print(f"  ❌ No product template in V14, skipping")
                failed_to_create.append({'bom_id': bom_v14['id'], 'error': 'No product template'})
                continue
            
            # Get product template details from V14
            product_tmpl_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.template', 'read',
                [[product_tmpl_id_v14]],
                {'fields': ['default_code', 'name']})
            
            if not product_tmpl_v14:
                print(f"  ❌ Could not read product template from V14, skipping")
                failed_to_create.append({'bom_id': bom_v14['id'], 'error': 'Could not read product template'})
                continue
            
            product_code_v14 = product_tmpl_v14[0]['default_code']
            
            # Find corresponding product template in V18 by code
            product_tmpl_v18_ids = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'product.template', 'search',
                [[['default_code', '=', product_code_v14]]])
            
            if not product_tmpl_v18_ids:
                print(f"  ❌ Product template not found in V18 (code: {product_code_v14}), skipping")
                failed_to_create.append({'bom_id': bom_v14['id'], 'error': f'Product template not found in V18 (code: {product_code_v14})'})
                continue
            
            product_tmpl_id_v18 = product_tmpl_v18_ids[0]
            
            # Handle product variant if specified
            product_id_v18 = False
            if bom_v14['product_id']:
                product_id_v14 = bom_v14['product_id'][0]
                # Get product variant details from V14
                product_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                    'product.product', 'read',
                    [[product_id_v14]],
                    {'fields': ['product_code']})
                
                if product_v14 and product_v14[0]['product_code']:
                    variant_code = product_v14[0]['product_code']
                    # Find variant in V18
                    product_v18_ids = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                        'product.product', 'search',
                        [[['x_studio_product_code', '=', variant_code]]])
                    
                    if product_v18_ids:
                        product_id_v18 = product_v18_ids[0]
            
            # Prepare BOM lines
            bom_lines_v14 = bom_lines_v14_dict.get(bom_v14['id'], [])
            bom_line_vals = []
            
            print(f"  Processing {len(bom_lines_v14)} BOM lines...")
            
            for line in bom_lines_v14:
                component_code = line['product_code']
                component_name = line['product_name']
                component_qty = line['product_qty']
                
                # Find component in V18
                if component_code in product_code_to_id_v18:
                    component_id_v18 = product_code_to_id_v18[component_code]['id']
                    print(f"    ✅ Found component: {component_name} (Code: {component_code})")
                else:
                    # Component doesn't exist, create it
                    print(f"    ⚠️  Component not found in V18: {component_name} (Code: {component_code})")
                    print(f"       Creating component...")
                    
                    try:
                        # Get full product details from V14
                        product_id_v14 = line['product_id'][0] if line['product_id'] else None
                        product_details_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                            'product.product', 'read',
                            [[product_id_v14]],
                            {'fields': ['name', 'product_code', 'categ_id', 'type', 'uom_id', 'uom_po_id']})
                        
                        if product_details_v14:
                            product_detail = product_details_v14[0]
                            
                            # Create product in V18
                            new_product_vals = {
                                'name': product_detail['name'],
                                'x_studio_product_code': component_code,
                                'type': product_detail.get('type', 'product'),
                            }
                            
                            # Add category if exists in V18
                            if product_detail.get('categ_id'):
                                categ_id_v14 = product_detail['categ_id'][0]
                                # Try to find same category in V18
                                categ_v18_ids = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                                    'product.category', 'search',
                                    [[['id', '=', categ_id_v14]]])
                                if categ_v18_ids:
                                    new_product_vals['categ_id'] = categ_v18_ids[0]
                            
                            component_id_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                                'product.product', 'create',
                                [new_product_vals])
                            
                            # Update mapping
                            product_code_to_id_v18[component_code] = {
                                'id': component_id_v18,
                                'name': product_detail['name'],
                                'tmpl_id': None
                            }
                            
                            created_products.append({
                                'id': component_id_v18,
                                'code': component_code,
                                'name': product_detail['name']
                            })
                            
                            print(f"       ✅ Created component ID: {component_id_v18}")
                        else:
                            print(f"       ❌ Could not read product details from V14, skipping component")
                            continue
                    except Exception as e:
                        print(f"       ❌ Failed to create component: {e}")
                        continue
                
                # Add BOM line
                bom_line_vals.append((0, 0, {
                    'product_id': component_id_v18,
                    'product_qty': component_qty,
                }))
            
            # Create BOM in V18
            try:
                bom_reference = f"{bom_v14['code']} (V14 BOM ID: {bom_v14['id']})" if bom_v14['code'] else f"BOM (V14 BOM ID: {bom_v14['id']})"
                
                bom_vals = {
                    'product_tmpl_id': product_tmpl_id_v18,
                    'code': bom_reference,
                    'product_qty': bom_v14.get('product_qty', 1.0),
                    'bom_line_ids': bom_line_vals,
                }
                
                if product_id_v18:
                    bom_vals['product_id'] = product_id_v18
                
                new_bom_id = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'mrp.bom', 'create',
                    [bom_vals])
                
                created_count += 1
                print(f"  ✅ Created BOM in V18 with ID: {new_bom_id}")
                print(f"     Reference: {bom_reference}")
                
            except Exception as e:
                print(f"  ❌ Failed to create BOM: {e}")
                failed_to_create.append({'bom_id': bom_v14['id'], 'error': str(e)})
        
        # Summary
        print("\n" + "=" * 80)
        print("SYNC SUMMARY")
        print("=" * 80)
        print(f"Total BOMs in V14: {len(boms_v14)}")
        print(f"BOMs deleted in V18: {deleted_count}")
        print(f"BOMs created in V18: {created_count}")
        print(f"Failed to create: {len(failed_to_create)}")
        print(f"Products created: {len(created_products)}")
        
        if created_products:
            print("\nProducts created in V18:")
            for prod in created_products:
                print(f"  - {prod['name']} (Code: {prod['code']}, ID: {prod['id']})")
        
        if failed_to_create:
            print("\nFailed to create BOMs:")
            for fail in failed_to_create:
                print(f"  - BOM ID (V14): {fail['bom_id']}, Error: {fail['error']}")
        
        print("=" * 80)
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ================================================================================
# Syncing BOMs from Odoo V14 to V18
# ================================================================================
#
# [V14] Authenticating...
# ✅ V14 Authenticated! UID: 28
#
# [V18] Authenticating...
# ✅ V18 Authenticated! UID: 2
#
# Target categories: [4, 8, 10, 57, 82]
#
# Categories to sync:
#   - Category ID 4: 0. Presets / 1. Presets zonder PP
#   - Category ID 8: 0. Presets / 2. Presets met PP
#   - Category ID 10: 0. Presets / 3. Losse verkopen
#   - Category ID 57: 0. Presets / 4. Losse PP
#   - Category ID 82: 0. Presets / Fixed margin
#
# [V14] Fetching product templates in these categories...
# Found 28 product templates
#
# [V14] Searching for BOMs with is_custom_made = False...
# ================================================================================
#
# [V14] Found 249 BOMs with is_custom_made = False
#
#
# ================================================================================
# [V18] STEP 1: Deleting existing BOMs in target categories...
# ================================================================================
# Found 1 BOMs to delete in V18
#   ❌ Failed to delete BOM ID 153: <Fault 2: 'You can not delete a Bill of Material with running manufacturing orders.\nPlease close or cancel it first.'>
#
# Deleted 0 BOMs successfully
# Failed to delete 1 BOMs
#
# ================================================================================
# [V18] STEP 2: Building product code mapping...
# ================================================================================
# Mapped 3229 products by code in V18
#
# ================================================================================
# [V18] STEP 3: Recreating BOMs from V14...
# ================================================================================
#
# ================================================================================
# Processing BOM ID (V14): 53
#   Reference: Los glas (Blinked plexi glas 2mm)
#   Display Name: Los glas (Blinked plexi glas 2mm): Los glas
#   Processing 4 BOM lines...
#     ✅ Found component: [BPG.GLAS] Blinkend plexiglas (Code: BPG)
#     ✅ Found component: [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM)
#     ✅ Found component: [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 844
#      Reference: Los glas (Blinked plexi glas 2mm) (V14 BOM ID: 53)
#
# ================================================================================
# Processing BOM ID (V14): 39
#   Reference: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BPG.GLAS] Blinkend plexiglas (Code: BPG)
#     ⚠️  Component not found in V18: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#        Creating component...
#        ✅ Created component ID: 15326
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ⚠️  Component not found in V18: [AK.DIENST] Assembleren kader (Code: AK.)
#        Creating component...
#        ✅ Created component ID: 15327
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON)
#     ⚠️  Component not found in V18: [IN.DIENST] Inlijsten (Code: IN)
#        Creating component...
#        ✅ Created component ID: 15328
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ⚠️  Component not found in V18: [KK.Internedienst] Kleven (Code: KK)
#        Creating component...
#        ✅ Created component ID: 15329
#   ✅ Created BOM in V18 with ID: 845
#      Reference: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson) (V14 BOM ID: 39)
#
# ================================================================================
# Processing BOM ID (V14): 62
#   Reference: Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat))
#   Display Name: Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat)): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BPG.GLAS] Blinkend plexiglas (Code: BPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 846
#      Reference: Print + Kader + PP (Blinkend plexi glas, Etch (Fine Art Mat)) (V14 BOM ID: 62)
#
# ================================================================================
# Processing BOM ID (V14): 4106
#   Reference: Puzzel + Kader custom (XXL)
#   Display Name: Puzzel + Kader custom (XXL): Puzzel + Kader custom
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR92.GLAS] Artglass AR92 (Code: AR92)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [Dibond3mm.x] Dibond 2mm (kopie) (Code: Dibond3mm)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [ZKF.X] Dibond 3mm (kopie) (Code: ZKF)
#   ✅ Created BOM in V18 with ID: 847
#      Reference: Puzzel + Kader custom (XXL) (V14 BOM ID: 4106)
#
# ================================================================================
# Processing BOM ID (V14): 124
#   Reference: Kader + Print (Mat glas, Etch (Fine Art Mat))
#   Display Name: Kader + Print (Mat glas, Etch (Fine Art Mat)): Kader + PP + Print (kopie)
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ⚠️  Component not found in V18: [MG.GLAS] Mat glas (Code: MG.)
#        Creating component...
#        ✅ Created component ID: 15330
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 848
#      Reference: Kader + Print (Mat glas, Etch (Fine Art Mat)) (V14 BOM ID: 124)
#
# ================================================================================
# Processing BOM ID (V14): 6565
#   Reference: Kader + FM + Print (Mat glas, 3mm)
#   Display Name: Kader + FM + Print (Mat glas, 3mm): Kader + FM + Print
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MG.GLAS] Mat glas (Code: MG.)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#   ✅ Created BOM in V18 with ID: 849
#      Reference: Kader + FM + Print (Mat glas, 3mm) (V14 BOM ID: 6565)
#
# ================================================================================
# Processing BOM ID (V14): 6541
#   Reference: Kader + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat glas, Matt Fibre): Kader + PP + Print (kopie)
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MG.GLAS] Mat glas (Code: MG.)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 850
#      Reference: Kader + Print + Inlijsting (Mat glas, Matt Fibre) (V14 BOM ID: 6541)
#
# ================================================================================
# Processing BOM ID (V14): 6547
#   Reference: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 851
#      Reference: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre) (V14 BOM ID: 6547)
#
# ================================================================================
# Processing BOM ID (V14): 6549
#   Reference: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre): Kader + PP + Print (kopie)
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR70.GLAS] Artglass AR70 (Code: AR70)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 852
#      Reference: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre) (V14 BOM ID: 6549)
#
# ================================================================================
# Processing BOM ID (V14): 6552
#   Reference: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MG.GLAS] Mat glas (Code: MG.)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 853
#      Reference: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre) (V14 BOM ID: 6552)
#
# ================================================================================
# Processing BOM ID (V14): 6560
#   Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm): Kader + FM + Inlijsting
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BPG.GLAS] Blinkend plexiglas (Code: BPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 854
#      Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm) (V14 BOM ID: 6560)
#
# ================================================================================
# Processing BOM ID (V14): 6545
#   Reference: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre): Kader + PP + Print (kopie)
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BG.GLAS] Blinkend glas (Code: BG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 855
#      Reference: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre) (V14 BOM ID: 6545)
#
# ================================================================================
# Processing BOM ID (V14): 6548
#   Reference: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BPG.GLAS] Blinkend plexiglas (Code: BPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 856
#      Reference: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre) (V14 BOM ID: 6548)
#
# ================================================================================
# Processing BOM ID (V14): 6550
#   Reference: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre): Kader + PP + Print (kopie)
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR92.GLAS] Artglass AR92 (Code: AR92)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 857
#      Reference: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre) (V14 BOM ID: 6550)
#
# ================================================================================
# Processing BOM ID (V14): 6553
#   Reference: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BG.GLAS] Blinkend glas (Code: BG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 858
#      Reference: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre) (V14 BOM ID: 6553)
#
# ================================================================================
# Processing BOM ID (V14): 6556
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR70.GLAS] Artglass AR70 (Code: AR70)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 859
#      Reference: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre) (V14 BOM ID: 6556)
#
# ================================================================================
# Processing BOM ID (V14): 6561
#   Reference: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR70, 3mm): Kader + FM + Inlijsting
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR70.GLAS] Artglass AR70 (Code: AR70)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 860
#      Reference: Kader + FM + Inlijsting (Artglass AR70, 3mm) (V14 BOM ID: 6561)
#
# ================================================================================
# Processing BOM ID (V14): 6566
#   Reference: Kader + FM + Print (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend glas, 3mm): Kader + FM + Print
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BG.GLAS] Blinkend glas (Code: BG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#   ✅ Created BOM in V18 with ID: 861
#      Reference: Kader + FM + Print (Blinkend glas, 3mm) (V14 BOM ID: 6566)
#
# ================================================================================
# Processing BOM ID (V14): 6551
#   Reference: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre): Kader + PP + Print (kopie)
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR99.GLAS] Artglass AR99 (Code: AR99)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 862
#      Reference: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre) (V14 BOM ID: 6551)
#
# ================================================================================
# Processing BOM ID (V14): 6554
#   Reference: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 863
#      Reference: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre) (V14 BOM ID: 6554)
#
# ================================================================================
# Processing BOM ID (V14): 6559
#   Reference: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend glas, 3mm): Kader + FM + Inlijsting
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BG.GLAS] Blinkend glas (Code: BG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 864
#      Reference: Kader + FM + Inlijsting (Blinkend glas, 3mm) (V14 BOM ID: 6559)
#
# ================================================================================
# Processing BOM ID (V14): 6563
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 3mm): Kader + FM + Inlijsting
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR99.GLAS] Artglass AR99 (Code: AR99)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 865
#      Reference: Kader + FM + Inlijsting (Artglass AR99, 3mm) (V14 BOM ID: 6563)
#
# ================================================================================
# Processing BOM ID (V14): 6568
#   Reference: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend plexi glas, 3mm): Kader + FM + Print
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BPG.GLAS] Blinkend plexiglas (Code: BPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#   ✅ Created BOM in V18 with ID: 866
#      Reference: Kader + FM + Print (Blinkend plexi glas, 3mm) (V14 BOM ID: 6568)
#
# ================================================================================
# Processing BOM ID (V14): 6555
#   Reference: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BPG.GLAS] Blinkend plexiglas (Code: BPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 867
#      Reference: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre) (V14 BOM ID: 6555)
#
# ================================================================================
# Processing BOM ID (V14): 6562
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 3mm): Kader + FM + Inlijsting
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR92.GLAS] Artglass AR92 (Code: AR92)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 868
#      Reference: Kader + FM + Inlijsting (Artglass AR92, 3mm) (V14 BOM ID: 6562)
#
# ================================================================================
# Processing BOM ID (V14): 6564
#   Reference: Kader + FM + Inlijsting (Geen glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 3mm): Kader + FM + Inlijsting
#   Processing 8 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 869
#      Reference: Kader + FM + Inlijsting (Geen glas, 3mm) (V14 BOM ID: 6564)
#
# ================================================================================
# Processing BOM ID (V14): 6569
#   Reference: Kader + FM + Print (Artglass AR70, 3mm)
#   Display Name: Kader + FM + Print (Artglass AR70, 3mm): Kader + FM + Print
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR70.GLAS] Artglass AR70 (Code: AR70)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#   ✅ Created BOM in V18 with ID: 870
#      Reference: Kader + FM + Print (Artglass AR70, 3mm) (V14 BOM ID: 6569)
#
# ================================================================================
# Processing BOM ID (V14): 6557
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR92.GLAS] Artglass AR92 (Code: AR92)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 871
#      Reference: Kader + PP + Print + Inlijsting (Artglass AR92, Matt Fibre) (V14 BOM ID: 6557)
#
# ================================================================================
# Processing BOM ID (V14): 6570
#   Reference: Kader + FM + Print (Artglass AR92, 3mm)
#   Display Name: Kader + FM + Print (Artglass AR92, 3mm): Kader + FM + Print
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR92.GLAS] Artglass AR92 (Code: AR92)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#   ✅ Created BOM in V18 with ID: 872
#      Reference: Kader + FM + Print (Artglass AR92, 3mm) (V14 BOM ID: 6570)
#
# ================================================================================
# Processing BOM ID (V14): 6558
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR99, Matt Fibre): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR99.GLAS] Artglass AR99 (Code: AR99)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 873
#      Reference: Kader + PP + Print + Inlijsting (Artglass AR99, Matt Fibre) (V14 BOM ID: 6558)
#
# ================================================================================
# Processing BOM ID (V14): 6571
#   Reference: Kader + FM + Print (Artglass AR99, 3mm)
#   Display Name: Kader + FM + Print (Artglass AR99, 3mm): Kader + FM + Print
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR99.GLAS] Artglass AR99 (Code: AR99)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON)
#     ✅ Found component: [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#   ✅ Created BOM in V18 with ID: 874
#      Reference: Kader + FM + Print (Artglass AR99, 3mm) (V14 BOM ID: 6571)
#
# ================================================================================
# Processing BOM ID (V14): 75
#   Reference: Kader + Inlijsting (Artglass AR70)
#   Display Name: Kader + Inlijsting (Artglass AR70): Kader op maat (kopie)
#   Processing 6 BOM lines...
#     ✅ Found component: [41513.F04] Loft Mat Zwart 2 Cm + Spacer (Code: 41513)
#     ✅ Found component: [AR70.GLAS] Artglass AR70 (Code: AR70)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#   ✅ Created BOM in V18 with ID: 875
#      Reference: Kader + Inlijsting (Artglass AR70) (V14 BOM ID: 75)
#
# ================================================================================
# Processing BOM ID (V14): 105
#   Reference: Standaard formaat kader (10x15)
#   Display Name: Standaard formaat kader (10x15): Standaard formaat kader
#   Processing 9 BOM lines...
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ⚠️  Component not found in V18: [4124.K04] Kaslijst zwart 2 CM (Code: 4124.)
#        Creating component...
#        ✅ Created component ID: 15331
#     ⚠️  Component not found in V18: Standaard maat glas mat (Code: False)
#        Creating component...
#        ✅ Created component ID: 15332
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: Standaard maat glas mat (Code: False)
#     ✅ Found component: [ZR100150.RUG] Zwarte rug met voet 10x15 (Code: ZR100150)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 876
#      Reference: Standaard formaat kader (10x15) (V14 BOM ID: 105)
#
# ================================================================================
# Processing BOM ID (V14): 149
#   Reference: Kader + PP + Inlijsting (Mat plexi glas)
#   Display Name: Kader + PP + Inlijsting (Mat plexi glas): Kader op maat + PP + Inlijsting
#   Processing 7 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 877
#      Reference: Kader + PP + Inlijsting (Mat plexi glas) (V14 BOM ID: 149)
#
# ================================================================================
# Processing BOM ID (V14): 72
#   Reference: Kader op maat + Inlijsting (Mat glas)
#   Display Name: Kader op maat + Inlijsting (Mat glas): Kader op maat (kopie)
#   Processing 6 BOM lines...
#     ✅ Found component: [273-004.O25] Zilver Mat 1,3 Cm  (Code: 273-004)
#     ✅ Found component: [MG.GLAS] Mat glas (Code: MG.)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#   ✅ Created BOM in V18 with ID: 878
#      Reference: Kader op maat + Inlijsting (Mat glas) (V14 BOM ID: 72)
#
# ================================================================================
# Processing BOM ID (V14): 148
#   Reference: [P5P] Kader + PP + Inlijsting (Blinkend glas)
#   Display Name: [P5P] Kader + PP + Inlijsting (Blinkend glas): Kader op maat + PP + Inlijsting
#   Processing 7 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BG.GLAS] Blinkend glas (Code: BG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 879
#      Reference: [P5P] Kader + PP + Inlijsting (Blinkend glas) (V14 BOM ID: 148)
#
# ================================================================================
# Processing BOM ID (V14): 15325
#   Reference: Askaders (Esdoorn)
#   Display Name: Askaders (Esdoorn): Askaders
#   Processing 6 BOM lines...
#     ✅ Found component: [77263.N32] Tokio - Kaslijst Zwart 2 cm (kopie) (Code: 77263)
#     ✅ Found component: [BG.GLAS] Blinkend glas (Code: BG)
#     ✅ Found component: [ZR105105.RUG] Zwarte rug met voet 10,5x10,5 (Code: ZR105105)
#     ⚠️  Component not found in V18: [AB.0] Asbuisje (Code: AB.)
#        Creating component...
#        ✅ Created component ID: 15333
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [SHR.X] Shrinken (Code: SHR)
#   ✅ Created BOM in V18 with ID: 880
#      Reference: Askaders (Esdoorn) (V14 BOM ID: 15325)
#
# ================================================================================
# Processing BOM ID (V14): 15324
#   Reference: Askaders (Eik)
#   Display Name: Askaders (Eik): Askaders
#   Processing 6 BOM lines...
#     ✅ Found component: [69067.X] "Solid Wood" Kaslijst Eik 4Cm (Code: 69067)
#     ✅ Found component: [BG.GLAS] Blinkend glas (Code: BG)
#     ✅ Found component: [ZR105105.RUG] Zwarte rug met voet 10,5x10,5 (Code: ZR105105)
#     ✅ Found component: [AB.0] Asbuisje (Code: AB.)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [SHR.X] Shrinken (Code: SHR)
#   ✅ Created BOM in V18 with ID: 881
#      Reference: Askaders (Eik) (V14 BOM ID: 15324)
#
# ================================================================================
# Processing BOM ID (V14): 29
#   Reference: Print + Kader + PP (Mat glas, Rag (Fine Art Mat))
#   Display Name: Print + Kader + PP (Mat glas, Rag (Fine Art Mat)): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MG.GLAS] Mat glas (Code: MG.)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [RAG.PRINT] Rag (Code: RAG)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 882
#      Reference: Print + Kader + PP (Mat glas, Rag (Fine Art Mat)) (V14 BOM ID: 29)
#
# ================================================================================
# Processing BOM ID (V14): 12
#   Reference: Kader op maat + PP (Blinkend glas)
#   Display Name: Kader op maat + PP (Blinkend glas): Kader op maat + PP
#   Processing 6 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BG.GLAS] Blinkend glas (Code: BG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 883
#      Reference: Kader op maat + PP (Blinkend glas) (V14 BOM ID: 12)
#
# ================================================================================
# Processing BOM ID (V14): 119
#   Reference: Kader standaardformaat + PP (21x29,7)
#   Display Name: Kader standaardformaat + PP (21x29,7): Standaard formaat kader + PP
#   Processing 6 BOM lines...
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: Standaard maat glas mat (Code: False)
#     ✅ Found component: [ZR210297.RUG] Zwarte rug met voet 21x29,7 (Code: ZR210297)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 884
#      Reference: Kader standaardformaat + PP (21x29,7) (V14 BOM ID: 119)
#
# ================================================================================
# Processing BOM ID (V14): 30
#   Reference: Print + Kader + PP (Mat glas, Rag (Fine Art Mat))
#   Display Name: Print + Kader + PP (Mat glas, Rag (Fine Art Mat)): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MG.GLAS] Mat glas (Code: MG.)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 885
#      Reference: Print + Kader + PP (Mat glas, Rag (Fine Art Mat)) (V14 BOM ID: 30)
#
# ================================================================================
# Processing BOM ID (V14): 113
#   Reference: Kader standaardformaat + PP (10x15)
#   Display Name: Kader standaardformaat + PP (10x15): Standaard formaat kader + PP
#   Processing 6 BOM lines...
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: Standaard maat glas mat (Code: False)
#     ✅ Found component: [ZR100150.RUG] Zwarte rug met voet 10x15 (Code: ZR100150)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 886
#      Reference: Kader standaardformaat + PP (10x15) (V14 BOM ID: 113)
#
# ================================================================================
# Processing BOM ID (V14): 41
#   Reference: Print + Kader + PP (Mat plexi glas, Rag (Fine Art Mat))
#   Display Name: Print + Kader + PP (Mat plexi glas, Rag (Fine Art Mat)): Print + Kader + PP
#   Processing 10 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [RAG.PRINT] Rag (Code: RAG)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 887
#      Reference: Print + Kader + PP (Mat plexi glas, Rag (Fine Art Mat)) (V14 BOM ID: 41)
#
# ================================================================================
# Processing BOM ID (V14): 120
#   Reference: Kader standaardformaat + PP (40x50)
#   Display Name: Kader standaardformaat + PP (40x50): Standaard formaat kader + PP
#   Processing 6 BOM lines...
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: Standaard maat glas mat (Code: False)
#     ✅ Found component: [ZRZV4050.RUG] Zwarte rug zonder voet 40x50 (Code: ZRZV4050)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 888
#      Reference: Kader standaardformaat + PP (40x50) (V14 BOM ID: 120)
#
# ================================================================================
# Processing BOM ID (V14): 116
#   Reference: Kader standaardformaat + PP (18x24)
#   Display Name: Kader standaardformaat + PP (18x24): Standaard formaat kader + PP
#   Processing 6 BOM lines...
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: Standaard maat glas mat (Code: False)
#     ✅ Found component: [ZR180240.RUG] Zwarte rug met voet 18x24 (Code: ZR180240)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 889
#      Reference: Kader standaardformaat + PP (18x24) (V14 BOM ID: 116)
#
# ================================================================================
# Processing BOM ID (V14): 13
#   Reference: Kader op maat + PP (Mat plexi glas)
#   Display Name: Kader op maat + PP (Mat plexi glas): Kader op maat + PP
#   Processing 6 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
# ...
#
# ================================================================================
# Processing BOM ID (V14): 243
#   Reference: Los Dozen (45x65)
#   Display Name: Los Dozen (45x65): Los Dozen
#   Processing 2 BOM lines...
#     ✅ Found component: [DOOS4564.BOX] DOOS 45X65 CM (Code: DOOS4564)
#     ⚠️  Component not found in V18: [PK4565.BOX] Plooikost doos 40x40 (kopie) (Code: PK4565)
#        Creating component...
#        ✅ Created component ID: 15338
#   ✅ Created BOM in V18 with ID: 1074
#      Reference: Los Dozen (45x65) (V14 BOM ID: 243)
#
# ================================================================================
# Processing BOM ID (V14): 24
#   Reference: Standaard formaat kader (10,5x10,5)
#   Display Name: Standaard formaat kader (10,5x10,5): Standaard formaat kader
#   Processing 4 BOM lines...
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: [ZR105105.RUG] Zwarte rug met voet 10,5x10,5 (Code: ZR105105)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 1075
#      Reference: Standaard formaat kader (10,5x10,5) (V14 BOM ID: 24)
#
# ================================================================================
# Processing BOM ID (V14): 244
#   Reference: Los Dozen (60x70)
#   Display Name: Los Dozen (60x70): Los Dozen
#   Processing 3 BOM lines...
#     ✅ Found component: [DOOS6070.BOX] DOOS 60X70 CM (Code: DOOS6070)
#     ✅ Found component: [DOOS6070v.BOX] DOOS 60X70 CM (kopie) (Code: DOOS6070v)
#     ⚠️  Component not found in V18: [PK6070.BOX] Plooikost doos 45x65 (kopie) (Code: PK6070)
#        Creating component...
#        ✅ Created component ID: 15339
#   ✅ Created BOM in V18 with ID: 1076
#      Reference: Los Dozen (60x70) (V14 BOM ID: 244)
#
# ================================================================================
# Processing BOM ID (V14): 11
#   Reference: Kader op maat + PP (Mat glas)
#   Display Name: Kader op maat + PP (Mat glas): Kader op maat + PP
#   Processing 6 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MG.GLAS] Mat glas (Code: MG.)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 1077
#      Reference: Kader op maat + PP (Mat glas) (V14 BOM ID: 11)
#
# ================================================================================
# Processing BOM ID (V14): 26
#   Reference: Kader standaardformaat + PP (10,5x10,5)
#   Display Name: Kader standaardformaat + PP (10,5x10,5): Standaard formaat kader + PP
#   Processing 6 BOM lines...
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: Standaard maat glas mat (Code: False)
#     ✅ Found component: [ZR105105.RUG] Zwarte rug met voet 10,5x10,5 (Code: ZR105105)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#   ✅ Created BOM in V18 with ID: 1078
#      Reference: Kader standaardformaat + PP (10,5x10,5) (V14 BOM ID: 26)
#
# ================================================================================
# Processing BOM ID (V14): 245
#   Reference: Los Dozen (70x100)
#   Display Name: Los Dozen (70x100): Los Dozen
#   Processing 4 BOM lines...
#     ✅ Found component: [DOOS70100b.BOX] DOOS 70X100 CM (Code: DOOS70100b)
#     ✅ Found component: [DOOS70100o.BOX] DOOS 70X100 CM Bovenstuk (kopie) (Code: DOOS70100o)
#     ✅ Found component: [DOOS70100v.BOX] DOOS 70X100 CM Onderstuk (kopie) (Code: DOOS70100v)
#     ⚠️  Component not found in V18: [PK70100.BOX] Plooikost doos 60x70 (kopie) (Code: PK70100)
#        Creating component...
#        ✅ Created component ID: 15340
#   ✅ Created BOM in V18 with ID: 1079
#      Reference: Los Dozen (70x100) (V14 BOM ID: 245)
#
# ================================================================================
# Processing BOM ID (V14): 246
#   Reference: Los Dozen (75x115)
#   Display Name: Los Dozen (75x115): Los Dozen
#   Processing 4 BOM lines...
#     ✅ Found component: [DOOS75115b.BOX] DOOS 75X114 CM (Code: DOOS75115b)
#     ✅ Found component: [DOOS75115o.BOX] DOOS 75X115,5 CM Bovenstuk (kopie) (Code: DOOS75115o)
#     ✅ Found component: [DOOS75115v.BOX] DOOS 75X115,5 CM Onderstuk (kopie) (Code: DOOS75115v)
#     ⚠️  Component not found in V18: [PK75115.BOX] Plooikost doos 70x100 (kopie) (Code: PK75115)
#        Creating component...
#        ✅ Created component ID: 15341
#   ✅ Created BOM in V18 with ID: 1080
#      Reference: Los Dozen (75x115) (V14 BOM ID: 246)
#
# ================================================================================
# Processing BOM ID (V14): 153
#   Reference: Kader + Print (Mat plexi glas, Barytte (Fine Art))
#   Display Name: Kader + Print (Mat plexi glas, Barytte (Fine Art)): Kader + PP + Print (kopie)
#   Processing 8 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [BARYTTE.PRINT] Barytte (Fine Art) (Code: BARYTTE)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [P16K] Kleven op PVC (PVC) (Code: P16)
#   ✅ Created BOM in V18 with ID: 1081
#      Reference: Kader + Print (Mat plexi glas, Barytte (Fine Art)) (V14 BOM ID: 153)
#
# ================================================================================
# Processing BOM ID (V14): 242
#   Reference: Los Dozen (40x40)
#   Display Name: Los Dozen (40x40): Los Dozen
#   Processing 2 BOM lines...
#     ✅ Found component: [DOOS4040.BOX] DOOS 40X40 CM (Code: DOOS4040)
#     ⚠️  Component not found in V18: [PK4040.BOX] Plooikost doos 40x40 (Code: PK4040)
#        Creating component...
#        ✅ Created component ID: 15342
#   ✅ Created BOM in V18 with ID: 1082
#      Reference: Los Dozen (40x40) (V14 BOM ID: 242)
#
# ================================================================================
# Processing BOM ID (V14): 6140
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 2mm): Kader + FM + Inlijsting
#   Processing 10 BOM lines...
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: [AR99.GLAS] Artglass AR99 (Code: AR99)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2)
#   ✅ Created BOM in V18 with ID: 1083
#      Reference: Kader + FM + Inlijsting (Artglass AR99, 2mm) (V14 BOM ID: 6140)
#
# ================================================================================
# Processing BOM ID (V14): 146
#   Reference: Kader + PP (Artglass AR70)
#   Display Name: Kader + PP (Artglass AR70): Kader op maat + PP
#   Processing 5 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR70.GLAS] Artglass AR70 (Code: AR70)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [GSRM918.C7] Very White              (Code: GSRM918)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#   ✅ Created BOM in V18 with ID: 1084
#      Reference: Kader + PP (Artglass AR70) (V14 BOM ID: 146)
#
# ================================================================================
# Processing BOM ID (V14): 121
#   Reference: Kader + Print (Mat glas, Semi Matte Epson)
#   Display Name: Kader + Print (Mat glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Processing 8 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [MG.GLAS] Mat glas (Code: MG.)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [P16K] Kleven op PVC (PVC) (Code: P16)
#   ✅ Created BOM in V18 with ID: 1085
#      Reference: Kader + Print (Mat glas, Semi Matte Epson) (V14 BOM ID: 121)
#
# ================================================================================
# Processing BOM ID (V14): 4105
#   Reference: Puzzel + Kader custom (Normaal)
#   Display Name: Puzzel + Kader custom (Normaal): Puzzel + Kader custom
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [AR92.GLAS] Artglass AR92 (Code: AR92)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [Dibond2mm.X] Forex Wit 10mm (kopie) (Code: Dibond2mm)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [ZKF.X] Dibond 3mm (kopie) (Code: ZKF)
#   ✅ Created BOM in V18 with ID: 1086
#      Reference: Puzzel + Kader custom (Normaal) (V14 BOM ID: 4105)
#
# ================================================================================
# Processing BOM ID (V14): 6139
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 2mm): Kader + FM + Inlijsting
#   Processing 10 BOM lines...
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: [AR92.GLAS] Artglass AR92 (Code: AR92)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2)
#   ✅ Created BOM in V18 with ID: 1087
#      Reference: Kader + FM + Inlijsting (Artglass AR92, 2mm) (V14 BOM ID: 6139)
#
# ================================================================================
# Processing BOM ID (V14): 199
#   Reference: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   Display Name: [KOF5MM.diensten] Kleven op Fomeboard (5mm): Kleven op Fomeboard
#   Processing 2 BOM lines...
#     ✅ Found component: [SK5MM.X] Schuimkarton 5mm (Code: SK5MM)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#   ✅ Created BOM in V18 with ID: 1088
#      Reference: [KOF5MM.diensten] Kleven op Fomeboard (5mm) (V14 BOM ID: 199)
#
# ================================================================================
# Processing BOM ID (V14): 6138
#   Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 2mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend plexi glas, 2mm): Kader + FM + Inlijsting
#   Processing 10 BOM lines...
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: [BPG.GLAS] Blinkend plexiglas (Code: BPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2)
#   ✅ Created BOM in V18 with ID: 1089
#      Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 2mm) (V14 BOM ID: 6138)
#
# ================================================================================
# Processing BOM ID (V14): 157
#   Reference: Kader + Print (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Kader + Print (Blinkend plexi glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Processing 9 BOM lines...
#     ✅ Found component: [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst)
#     ✅ Found component: [BPG.GLAS] Blinkend plexiglas (Code: BPG)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM)
#     ✅ Found component: [P16K] Kleven op PVC (PVC) (Code: P16)
#   ✅ Created BOM in V18 with ID: 1090
#      Reference: Kader + Print (Blinkend plexi glas, Semi Matte Epson) (V14 BOM ID: 157)
#
# ================================================================================
# Processing BOM ID (V14): 6141
#   Reference: Kader + FM + Inlijsting (Geen glas, 2mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 2mm): Kader + FM + Inlijsting
#   Processing 9 BOM lines...
#     ✅ Found component: [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124)
#     ✅ Found component: [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM.)
#     ✅ Found component: [4346.A9] Lime White (Code: 4346)
#     ✅ Found component: [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM)
#     ✅ Found component: [IN.DIENST] Inlijsten (Code: IN)
#     ✅ Found component: [AK.DIENST] Assembleren kader (Code: AK.)
#     ✅ Found component: [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF)
#     ✅ Found component: [KK.Internedienst] Kleven (Code: KK)
#     ✅ Found component: [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2)
#   ✅ Created BOM in V18 with ID: 1091
#      Reference: Kader + FM + Inlijsting (Geen glas, 2mm) (V14 BOM ID: 6141)
#
# ================================================================================
# SYNC SUMMARY
# ================================================================================
# Total BOMs in V14: 249
# BOMs deleted in V18: 0
# BOMs created in V18: 248
# Failed to create: 1
# Products created: 17
#
# Products created in V18:
#   - MDF 3MM BRUT (Code: MDF3MM., ID: 15326)
#   - Assembleren kader (Code: AK., ID: 15327)
#   - Inlijsten (Code: IN, ID: 15328)
#   - Kleven (Code: KK, ID: 15329)
#   - Mat glas (Code: MG., ID: 15330)
#   - Kaslijst zwart 2 CM (Code: 4124., ID: 15331)
#   - Standaard maat glas mat (Code: False, ID: 15332)
#   - Asbuisje (Code: AB., ID: 15333)
#   - Opspannen spieraam (Code: OS., ID: 15334)
#   - Assembleren spieraam (Code: AS., ID: 15335)
#   - Stomen + opspelden Tshirt (Code: STO, ID: 15336)
#   - Kleven op PVC (Code: P16, ID: 15337)
#   - Plooikost doos 40x40 (kopie) (Code: PK4565, ID: 15338)
#   - Plooikost doos 45x65 (kopie) (Code: PK6070, ID: 15339)
#   - Plooikost doos 60x70 (kopie) (Code: PK70100, ID: 15340)
#   - Plooikost doos 70x100 (kopie) (Code: PK75115, ID: 15341)
#   - Plooikost doos 40x40 (Code: PK4040, ID: 15342)
#
# Failed to create BOMs:
#   - BOM ID (V14): 3640, Error: Product template not found in V18 (code: P11P)
# ================================================================================

# %%
# Compare BOMs between Odoo V14 and V18 to find mismatches

import os
import xmlrpc.client
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Get environment variables for V14
JUSTFRAMEIT_ODOO_V14_URL = os.getenv('JUSTFRAMEIT_ODOO_V14_URL')
JUSTFRAMEIT_ODOO_V14_DB = os.getenv('JUSTFRAMEIT_ODOO_V14_DB')
JUSTFRAMEIT_ODOO_V14_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_V14_USERNAME')
JUSTFRAMEIT_ODOO_V14_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_V14_API_KEY')

# Get environment variables for V18
JUSTFRAMEIT_ODOO_URL = os.getenv('JUSTFRAMEIT_ODOO_URL_TEST')
JUSTFRAMEIT_ODOO_DB = os.getenv('JUSTFRAMEIT_ODOO_DB_TEST')
JUSTFRAMEIT_ODOO_USERNAME = os.getenv('JUSTFRAMEIT_ODOO_USERNAME')
JUSTFRAMEIT_ODOO_API_KEY = os.getenv('JUSTFRAMEIT_ODOO_API_KEY')

print("=" * 80)
print("Comparing BOMs between Odoo V14 and V18")
print("=" * 80)

try:
    # Authenticate to V14
    print("\n[V14] Authenticating...")
    common_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/common", allow_none=True)
    uid_v14 = common_v14.authenticate(JUSTFRAMEIT_ODOO_V14_DB, JUSTFRAMEIT_ODOO_V14_USERNAME, JUSTFRAMEIT_ODOO_V14_API_KEY, {})
    print(f"✅ V14 Authenticated! UID: {uid_v14}")
    
    # Authenticate to V18
    print("\n[V18] Authenticating...")
    common_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/common", allow_none=True)
    uid_v18 = common_v18.authenticate(JUSTFRAMEIT_ODOO_DB, JUSTFRAMEIT_ODOO_USERNAME, JUSTFRAMEIT_ODOO_API_KEY, {})
    print(f"✅ V18 Authenticated! UID: {uid_v18}\n")
    
    # Create models proxies
    models_v14 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_V14_URL}/xmlrpc/2/object", allow_none=True)
    models_v18 = xmlrpc.client.ServerProxy(f"{JUSTFRAMEIT_ODOO_URL}/xmlrpc/2/object", allow_none=True)
    
    # Define specific category IDs to check
    target_category_ids = [4, 8, 10, 57, 82]
    #target_category_ids = [10] #for testing
    
    print(f"Checking specific categories: {target_category_ids}\n")
    
    # Get category details from V14 (single call)
    categories = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.category', 'read',
        [target_category_ids],
        {'fields': ['display_name']})
    
    print("Categories to check:")
    for cat in categories:
        print(f"  - Category ID {cat['id']}: {cat['display_name']}")
    print()
    
    # Get all product templates in these categories from V14 (single call)
    print("[V14] Fetching product templates in these categories...")
    product_template_ids = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'product.template', 'search',
        [[['categ_id', 'in', target_category_ids]]])
    
    print(f"Found {len(product_template_ids)} product templates\n")
    
    # Search for BOMs with is_custom_made = False in V14 (single call) - including inactive BOMs
    print("[V14] Searching for BOMs with is_custom_made = False (including inactive BOMs)...")
    print("=" * 80)
    
    bom_ids_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
        'mrp.bom', 'search',
        [[['product_tmpl_id', 'in', product_template_ids], ['is_custom_made', '=', False]]],
        {'context': {'active_test': False}})
    
    print(f"\n[V14] Found {len(bom_ids_v14)} BOMs with is_custom_made = False (including inactive)\n")
    
    if not bom_ids_v14:
        print("No BOMs found with is_custom_made = False in V14")
    else:
        # Get ALL BOM details from V14 in a single call (including active field)
        boms_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
            'mrp.bom', 'read',
            [bom_ids_v14],
            {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'is_custom_made', 'bom_line_ids', 'active']})
        
        # Get ALL BOM lines from V14 in a single call
        all_bom_line_ids_v14 = []
        for bom in boms_v14:
            if bom['bom_line_ids']:
                all_bom_line_ids_v14.extend(bom['bom_line_ids'])
        
        bom_lines_v14_dict = {}
        if all_bom_line_ids_v14:
            all_bom_lines_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'mrp.bom.line', 'read',
                [all_bom_line_ids_v14],
                {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
            
            # Get all product IDs from BOM lines to fetch product codes
            product_ids_v14 = [line['product_id'][0] for line in all_bom_lines_v14 if line['product_id']]
            
            # Fetch product codes for all products in V14
            products_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.product', 'read',
                [product_ids_v14],
                {'fields': ['id', 'product_code']})
            
            # Create a mapping of product_id to product_code
            product_code_map_v14 = {p['id']: p['product_code'] for p in products_v14}
            
            # Organize by bom_id for easy lookup
            for line in all_bom_lines_v14:
                bom_id = line['bom_id'][0] if line['bom_id'] else None
                if bom_id not in bom_lines_v14_dict:
                    bom_lines_v14_dict[bom_id] = []
                # Add product_code to the line data
                product_id = line['product_id'][0] if line['product_id'] else None
                line['product_code'] = product_code_map_v14.get(product_id, 'N/A')
                bom_lines_v14_dict[bom_id].append(line)
        
        # Collect all BOM codes to search in V18
        bom_codes_v14 = [bom['code'] for bom in boms_v14 if bom['code']]
        
        # Search for ALL corresponding BOMs in V18 in a single call (including inactive)
        bom_ids_v18 = []
        if bom_codes_v14:
            bom_ids_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'search',
                [[['code', 'in', bom_codes_v14]]],
                {'context': {'active_test': False}})
        
        # Get ALL BOM details from V18 in a single call (including active field)
        boms_v18_dict = {}
        if bom_ids_v18:
            boms_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'mrp.bom', 'read',
                [bom_ids_v18],
                {'fields': ['id', 'code', 'display_name', 'product_tmpl_id', 'product_id', 'bom_line_ids', 'active']})
            
            # Organize by code for easy lookup (handle duplicates by storing as list)
            for bom in boms_v18:
                if bom['code']:
                    if bom['code'] not in boms_v18_dict:
                        boms_v18_dict[bom['code']] = []
                    boms_v18_dict[bom['code']].append(bom)
            
            # Get ALL BOM lines from V18 in a single call
            all_bom_line_ids_v18 = []
            for bom in boms_v18:
                if bom['bom_line_ids']:
                    all_bom_line_ids_v18.extend(bom['bom_line_ids'])
            
            bom_lines_v18_dict = {}
            if all_bom_line_ids_v18:
                all_bom_lines_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'mrp.bom.line', 'read',
                    [all_bom_line_ids_v18],
                    {'fields': ['id', 'product_id', 'product_qty', 'bom_id']})
                
                # Get all product IDs from BOM lines to fetch product codes
                product_ids_v18 = [line['product_id'][0] for line in all_bom_lines_v18 if line['product_id']]
                
                # Fetch product codes for all products in V18
                products_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                    'product.product', 'read',
                    [product_ids_v18],
                    {'fields': ['id', 'x_studio_product_code']})
                
                # Create a mapping of product_id to x_studio_product_code
                product_code_map_v18 = {p['id']: p['x_studio_product_code'] for p in products_v18}
                
                # Organize by bom_id for easy lookup
                for line in all_bom_lines_v18:
                    bom_id = line['bom_id'][0] if line['bom_id'] else None
                    if bom_id not in bom_lines_v18_dict:
                        bom_lines_v18_dict[bom_id] = []
                    # Add product_code to the line data
                    product_id = line['product_id'][0] if line['product_id'] else None
                    line['product_code'] = product_code_map_v18.get(product_id, 'N/A')
                    bom_lines_v18_dict[bom_id].append(line)
        
        # Fetch product codes for all product_ids in V14 BOMs for fallback matching
        all_product_ids_v14 = [bom['product_id'][0] for bom in boms_v14 if bom['product_id']]
        product_codes_v14_map = {}
        product_variants_v14_map = {}
        if all_product_ids_v14:
            products_for_boms_v14 = models_v14.execute_kw(JUSTFRAMEIT_ODOO_V14_DB, uid_v14, JUSTFRAMEIT_ODOO_V14_API_KEY,
                'product.product', 'read',
                [all_product_ids_v14],
                {'fields': ['id', 'product_code', 'display_name']})
            product_codes_v14_map = {p['id']: p['product_code'] for p in products_for_boms_v14}
            product_variants_v14_map = {p['id']: p['display_name'] for p in products_for_boms_v14}
        
        # Fetch product variants for all product_ids in V18 BOMs for fallback matching
        all_product_ids_v18 = []
        for bom_list in boms_v18_dict.values():
            for bom in bom_list:
                if bom['product_id']:
                    all_product_ids_v18.append(bom['product_id'][0])
        
        product_variants_v18_map = {}
        if all_product_ids_v18:
            products_for_boms_v18 = models_v18.execute_kw(JUSTFRAMEIT_ODOO_DB, uid_v18, JUSTFRAMEIT_ODOO_API_KEY,
                'product.product', 'read',
                [all_product_ids_v18],
                {'fields': ['id', 'x_studio_product_code', 'display_name']})
            product_variants_v18_map = {p['id']: {'code': p['x_studio_product_code'], 'name': p['display_name']} for p in products_for_boms_v18}
        
        print("Comparing BOMs between V14 and V18:")
        print("-" * 80)
        
        mismatches_found = 0
        
        for bom_v14 in boms_v14:
            product_tmpl_name = bom_v14['product_tmpl_id'][1] if bom_v14['product_tmpl_id'] else 'N/A'
            product_variant_name = bom_v14['product_id'][1] if bom_v14['product_id'] else 'N/A (Template BOM)'
            bom_reference = bom_v14['code'] if bom_v14['code'] else 'No reference'
            bom_display_name = bom_v14['display_name'] if bom_v14['display_name'] else 'No display name'
            bom_active_v14 = bom_v14.get('active', True)
            
            print(f"\n{'=' * 80}")
            print(f"BOM ID (V14): {bom_v14['id']}")
            print(f"  Reference: {bom_reference}")
            print(f"  Display Name: {bom_display_name}")
            print(f"  Product Template: {product_tmpl_name}")
            print(f"  Product Variant: {product_variant_name}")
            print(f"  is_custom_made (V14): {bom_v14['is_custom_made']}")
            print(f"  active (V14): {bom_active_v14}")
            
            # Get BOM line components from V14 (from pre-fetched data)
            components_v14 = {}
            bom_lines = bom_lines_v14_dict.get(bom_v14['id'], [])
            
            if bom_lines:
                print(f"\n  [V14] Components ({len(bom_lines)} items):")
                for line in bom_lines:
                    component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                    component_code = line['product_code']
                    component_qty = line['product_qty']
                    components_v14[component_code] = {'name': component_name, 'qty': component_qty}
                    print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
            else:
                print(f"\n  [V14] Components: None")
            
            # Find corresponding BOM in V18
            print(f"\n  [V18] Searching for corresponding BOM...")
            
            bom_v18 = None
            matching_method = None
            
            # Try matching by BOM reference (code) first
            if bom_reference and bom_reference != 'No reference':
                print(f"     Trying to match by BOM reference (code): {bom_reference}")
                
                matching_boms = boms_v18_dict.get(bom_reference, [])
                
                if len(matching_boms) == 1:
                    # Unique match by code
                    bom_v18 = matching_boms[0]
                    matching_method = "by BOM reference (code)"
                    print(f"  ✅ Found unique BOM in V18 by reference")
                elif len(matching_boms) > 1:
                    # Multiple BOMs with same code - need to use product_id fallback
                    print(f"  ⚠️  Found {len(matching_boms)} BOMs with same reference in V18, using product_id fallback")
                    
                    # Get product_code from V14 product_id
                    product_id_v14 = bom_v14['product_id'][0] if bom_v14['product_id'] else None
                    if product_id_v14:
                        product_code_v14 = product_codes_v14_map.get(product_id_v14)
                        product_variant_v14 = product_variants_v14_map.get(product_id_v14)
                        if product_code_v14:
                            print(f"     V14 product_code: {product_code_v14}")
                            print(f"     V14 product_variant: {product_variant_v14}")
                            
                            # Try to match by product_code in V18
                            for candidate_bom in matching_boms:
                                if candidate_bom['product_id']:
                                    product_id_v18 = candidate_bom['product_id'][0]
                                    product_info_v18 = product_variants_v18_map.get(product_id_v18, {})
                                    product_code_v18 = product_info_v18.get('code')
                                    product_variant_v18 = product_info_v18.get('name')
                                    
                                    print(f"       Checking candidate: product_code={product_code_v18}, variant={product_variant_v18}")
                                    
                                    if product_code_v18 == product_code_v14:
                                        bom_v18 = candidate_bom
                                        matching_method = "by BOM reference + product_code fallback"
                                        print(f"  ✅ Matched by product_code: {product_code_v18}")
                                        break
                            
                            # If still not matched, try comparing product variants (display_name)
                            if not bom_v18 and product_variant_v14:
                                print(f"     Trying to match by product variant display_name")
                                for candidate_bom in matching_boms:
                                    if candidate_bom['product_id']:
                                        product_id_v18 = candidate_bom['product_id'][0]
                                        product_info_v18 = product_variants_v18_map.get(product_id_v18, {})
                                        product_variant_v18 = product_info_v18.get('name')
                                        
                                        if product_variant_v18 == product_variant_v14:
                                            bom_v18 = candidate_bom
                                            matching_method = "by BOM reference + product variant display_name fallback"
                                            print(f"  ✅ Matched by product variant: {product_variant_v18}")
                                            break
                            
                            if not bom_v18:
                                print(f"  ❌ Could not match any of the {len(matching_boms)} BOMs by product_code or product variant")
                        else:
                            print(f"  ❌ Could not get product_code from V14 product_id")
                    else:
                        print(f"  ❌ No product_id in V14 BOM for fallback matching")
            
            # Fallback: try matching by product_code if no reference or reference didn't match
            if not bom_v18:
                print(f"     Trying fallback: matching by product_code")
                
                product_id_v14 = bom_v14['product_id'][0] if bom_v14['product_id'] else None
                if product_id_v14:
                    product_code_v14 = product_codes_v14_map.get(product_id_v14)
                    product_variant_v14 = product_variants_v14_map.get(product_id_v14)
                    if product_code_v14:
                        print(f"     V14 product_code: {product_code_v14}")
                        print(f"     V14 product_variant: {product_variant_v14}")
                        
                        # Search through all V18 BOMs for matching product_code
                        for code, bom_list in boms_v18_dict.items():
                            for candidate_bom in bom_list:
                                if candidate_bom['product_id']:
                                    product_id_v18 = candidate_bom['product_id'][0]
                                    product_info_v18 = product_variants_v18_map.get(product_id_v18, {})
                                    product_code_v18 = product_info_v18.get('code')
                                    if product_code_v18 == product_code_v14:
                                        bom_v18 = candidate_bom
                                        matching_method = "by product_code fallback"
                                        print(f"  ✅ Found BOM in V18 by product_code: {product_code_v18}")
                                        break
                            if bom_v18:
                                break
                        
                        # If still not matched, try comparing product variants (display_name)
                        if not bom_v18 and product_variant_v14:
                            print(f"     Trying to match by product variant display_name")
                            for code, bom_list in boms_v18_dict.items():
                                for candidate_bom in bom_list:
                                    if candidate_bom['product_id']:
                                        product_id_v18 = candidate_bom['product_id'][0]
                                        product_info_v18 = product_variants_v18_map.get(product_id_v18, {})
                                        product_variant_v18 = product_info_v18.get('name')
                                        
                                        if product_variant_v18 == product_variant_v14:
                                            bom_v18 = candidate_bom
                                            matching_method = "by product variant display_name fallback"
                                            print(f"  ✅ Found BOM in V18 by product variant: {product_variant_v18}")
                                            break
                                if bom_v18:
                                    break
                    else:
                        print(f"  ❌ Could not get product_code from V14 product_id")
                else:
                    print(f"  ❌ No product_id in V14 BOM for fallback matching")
            
            if not bom_v18:
                print(f"  ❌ NO CORRESPONDING BOM FOUND IN V18!")
                mismatches_found += 1
                continue
            
            bom_active_v18 = bom_v18.get('active', True)
            print(f"  ✅ Found corresponding BOM in V18 (ID: {bom_v18['id']}, Code: '{bom_v18['code']}', active: {bom_active_v18}, matched {matching_method})")
            
            # Get BOM line components from V18 (from pre-fetched data)
            components_v18 = {}
            bom_lines_v18 = bom_lines_v18_dict.get(bom_v18['id'], [])
            
            if bom_lines_v18:
                print(f"\n  [V18] Components ({len(bom_lines_v18)} items):")
                for line in bom_lines_v18:
                    component_name = line['product_id'][1] if line['product_id'] else 'N/A'
                    component_code = line['product_code']
                    component_qty = line['product_qty']
                    components_v18[component_code] = {'name': component_name, 'qty': component_qty}
                    print(f"    - {component_name} (Code: {component_code}, Qty: {component_qty})")
            else:
                print(f"\n  [V18] Components: None")
            
            # Compare components
            print(f"\n  🔍 COMPARISON RESULTS:")
            has_mismatch = False
            
            # Check for missing components in V18
            for component_code, component_data in components_v14.items():
                if component_code not in components_v18:
                    print(f"    ❌ MISSING IN V18: {component_data['name']} (Code: {component_code}, Qty in V14: {component_data['qty']})")
                    has_mismatch = True
                elif components_v18[component_code]['qty'] != component_data['qty']:
                    print(f"    ⚠️  QUANTITY MISMATCH: {component_data['name']} (Code: {component_code})")
                    print(f"       V14 Qty: {component_data['qty']}")
                    print(f"       V18 Qty: {components_v18[component_code]['qty']}")
                    has_mismatch = True
            
            # Check for extra components in V18
            for component_code, component_data in components_v18.items():
                if component_code not in components_v14:
                    print(f"    ➕ EXTRA IN V18: {component_data['name']} (Code: {component_code}, Qty: {component_data['qty']})")
                    has_mismatch = True
            
            if not has_mismatch:
                print(f"    ✅ All components match!")
            else:
                mismatches_found += 1
    
    print("\n" + "=" * 80)
    print(f"BOM comparison complete!")
    print(f"Total BOMs checked: {len(bom_ids_v14) if bom_ids_v14 else 0}")
    print(f"BOMs with mismatches: {mismatches_found}")
    print("=" * 80)
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ================================================================================
# Comparing BOMs between Odoo V14 and V18
# ================================================================================
#
# [V14] Authenticating...
# ✅ V14 Authenticated! UID: 28
#
# [V18] Authenticating...
# ✅ V18 Authenticated! UID: 2
#
# Checking specific categories: [4, 8, 10, 57, 82]
#
# Categories to check:
#   - Category ID 4: 0. Presets / 1. Presets zonder PP
#   - Category ID 8: 0. Presets / 2. Presets met PP
#   - Category ID 10: 0. Presets / 3. Losse verkopen
#   - Category ID 57: 0. Presets / 4. Losse PP
#   - Category ID 82: 0. Presets / Fixed margin
#
# [V14] Fetching product templates in these categories...
# Found 28 product templates
#
# [V14] Searching for BOMs with is_custom_made = False (including inactive BOMs)...
# ================================================================================
#
# [V14] Found 250 BOMs with is_custom_made = False (including inactive)
#
# Comparing BOMs between V14 and V18:
# --------------------------------------------------------------------------------
#
# ================================================================================
# BOM ID (V14): 49
#   Reference: Los glas (Blinkend glas)
#   Display Name: Los glas (Blinkend glas): Los glas
#   Product Template: Los glas
#   Product Variant: [P10P] Los glas (Blinkend glas)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (4 items):
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT (kopie) (Code: MDF3MM, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Los glas (Blinkend glas)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1539, Code: 'Los glas (Blinkend glas)', active: True, matched by BOM reference (code))
#
#   [V18] Components (4 items):
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT Verpakking (Code: MDF3MM, Qty: 1.0)
#     - [MDF3MM.PLAAT] MDF 3MM BRUT Verpakking (Code: MDF3MM, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 39
#   Reference: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, A)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1341, Code: 'Print + Kader + PP (Blinkend plexi glas, Semi Matte Epson)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 4106
#   Reference: Puzzel + Kader custom (XXL)
#   Display Name: Puzzel + Kader custom (XXL): Puzzel + Kader custom
#   Product Template: Puzzel + Kader custom
#   Product Variant: Puzzel + Kader custom (XXL)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond3mm.x] Dibond 2mm (kopie) (Code: Dibond3mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Puzzel + Kader custom (XXL)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1343, Code: 'Puzzel + Kader custom (XXL)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond3mmx] Dibond 2mm (kopie) (Code: Dibond3mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 124
#   Reference: Kader + Print (Mat glas, Etch (Fine Art Mat))
#   Display Name: Kader + Print (Mat glas, Etch (Fine Art Mat)): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, Etch (Fine Art Mat))
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print (Mat glas, Etch (Fine Art Mat))
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1344, Code: 'Kader + Print (Mat glas, Etch (Fine Art Mat))', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - Mat glas (Code: MG., Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [ETCH.PRINT] Etch (Fine Art Mat) (Code: ETCH, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6565
#   Reference: Kader + FM + Print (Mat glas, 3mm)
#   Display Name: Kader + FM + Print (Mat glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Print (Mat glas, 3mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1345, Code: 'Kader + FM + Print (Mat glas, 3mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - Mat glas (Code: MG., Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6541
#   Reference: Kader + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Mat glas, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1346, Code: 'Kader + Print + Inlijsting (Mat glas, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - Mat glas (Code: MG., Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6547
#   Reference: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat pl, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1347, Code: 'Kader + Print + Inlijsting (Mat plexi glas, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Mat plexiglas (Code: MPG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6549
#   Reference: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR70, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR70, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1348, Code: 'Kader + Print + Inlijsting (Artglass AR70, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6552
#   Reference: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Mat glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1349, Code: 'Kader + PP + Print + Inlijsting (Mat glas, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - Mat glas (Code: MG., Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6560
#   Reference: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1350, Code: 'Kader + FM + Inlijsting (Blinkend plexi glas, 3mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6545
#   Reference: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1351, Code: 'Kader + Print + Inlijsting (Blinkend glas, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6548
#   Reference: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend plexi glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1352, Code: 'Kader + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6550
#   Reference: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR92, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR92, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1353, Code: 'Kader + Print + Inlijsting (Artglass AR92, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6553
#   Reference: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1354, Code: 'Kader + PP + Print + Inlijsting (Blinkend glas, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6556
#   Reference: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Artglass AR70, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1355, Code: 'Kader + PP + Print + Inlijsting (Artglass AR70, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6561
#   Reference: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR70, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Artglass AR70, 3mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1356, Code: 'Kader + FM + Inlijsting (Artglass AR70, 3mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6566
#   Reference: Kader + FM + Print (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Blinkend glas, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Print (Blinkend glas, 3mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1357, Code: 'Kader + FM + Print (Blinkend glas, 3mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6551
#   Reference: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   Display Name: Kader + Print + Inlijsting (Artglass AR99, Matt Fibre): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Artglass AR99, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1358, Code: 'Kader + Print + Inlijsting (Artglass AR99, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6554
#   Reference: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Mat pl, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Blinkend plexiglas (kopie) (Code: MPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1359, Code: 'Kader + PP + Print + Inlijsting (Mat plexi glas, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Mat plexiglas (Code: MPG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6559
#   Reference: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Blinkend glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Blinkend glas (Code: BG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Blinkend glas, 3mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1360, Code: 'Kader + FM + Inlijsting (Blinkend glas, 3mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BG.GLAS] Shiny glass (Code: BG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6563
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Artglass AR99, 3mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1361, Code: 'Kader + FM + Inlijsting (Artglass AR99, 3mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6568
#   Reference: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   Display Name: Kader + FM + Print (Blinkend plexi glas, 3mm): Kader + FM + Print
#   Product Template: Kader + FM + Print
#   Product Variant: Kader + FM + Print (Blinkend plexi glas, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 2.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Print (Blinkend plexi glas, 3mm)
#   ⚠️  Found 2 BOMs with same reference in V18, using product_id fallback
#   ❌ Could not get product_code from V14 product_id
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6555
#   Reference: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   Display Name: Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre): Print + Kader + PP
#   Product Template: Print + Kader + PP
#   Product Variant: Print + Kader + PP (Blinkend plexi glas, Matt Fibre)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMF.X] Hahnemühle German Etching ®️ 310gr (kopie) (Code: HMF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1363, Code: 'Kader + PP + Print + Inlijsting (Blinkend plexi glas, Matt Fibre)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [HMFX] Hahnemühle Matt Fibre  (Code: HMF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6562
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Artglass AR92, 3mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1364, Code: 'Kader + FM + Inlijsting (Artglass AR92, 3mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6564
#   Reference: Kader + FM + Inlijsting (Geen glas, 3mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 3mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Geen glas, 3mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 2mm (kopie) (Code: SK3MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Geen glas, 3mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1365, Code: 'Kader + FM + Inlijsting (Geen glas, 3mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (8 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK3MM.X] Schuimkarton 3mm (Code: SK3MM, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ...
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1577, Code: 'Kader + Print (Mat plexi glas, Barytte (Fine Art))', active: True, matched by BOM reference (code))
#
#   [V18] Components (8 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [MPG.GLAS] Mat plexiglas (Code: MPG, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [BARYTTE.PRINT] Barytte (Fine Art) (Code: BARYTTE, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Kleven op PVC (Code: P16, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 242
#   Reference: Los Dozen (40x40)
#   Display Name: Los Dozen (40x40): Los Dozen
#   Product Template: Los Dozen
#   Product Variant: [LD.X] Los Dozen (40x40)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (2 items):
#     - [DOOS4040.BOX] DOOS 40X40 CM (Code: DOOS4040, Qty: 1.0)
#     - [PK4040.BOX] Plooikost doos 40x40 (Code: PK4040, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Los Dozen (40x40)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1578, Code: 'Los Dozen (40x40)', active: True, matched by BOM reference (code))
#
#   [V18] Components (2 items):
#     - [DOOS4040.BOX] DOOS 40X40 CM (Code: DOOS4040, Qty: 1.0)
#     - Plooikost doos 40x40 (Code: PK4040, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 6140
#   Reference: Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR99, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Artglass AR99, 2mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1579, Code: 'Kader + FM + Inlijsting (Artglass AR99, 2mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR99.GLAS] Artglass AR99 (Code: AR99, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2Econospacer Transparant 3,2mm] Econospacer Transparant (Code: ECOST2, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 146
#   Reference: Kader + PP (Artglass AR70)
#   Display Name: Kader + PP (Artglass AR70): Kader op maat + PP
#   Product Template: Kader op maat + PP
#   Product Variant: Kader op maat + PP (Artglass AR70)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (5 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [GSRM918.C7] Very White              (Code: GSRM918, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + PP (Artglass AR70)
#   ⚠️  Found 2 BOMs with same reference in V18, using product_id fallback
#   ❌ Could not get product_code from V14 product_id
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 121
#   Reference: Kader + Print (Mat glas, Semi Matte Epson)
#   Display Name: Kader + Print (Mat glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Mat glas, A)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (8 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [MG.GLAS] Mat glas (Code: MG., Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print (Mat glas, Semi Matte Epson)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1581, Code: 'Kader + Print (Mat glas, Semi Matte Epson)', active: True, matched by BOM reference (code))
#
#   [V18] Components (8 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - Mat glas (Code: MG., Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Kleven op PVC (Code: P16, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 4105
#   Reference: Puzzel + Kader custom (Normaal)
#   Display Name: Puzzel + Kader custom (Normaal): Puzzel + Kader custom
#   Product Template: Puzzel + Kader custom
#   Product Variant: [P109P] Puzzel + Kader custom (Normaal)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond2mm.X] Forex Wit 10mm (kopie) (Code: Dibond2mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Puzzel + Kader custom (Normaal)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1582, Code: 'Puzzel + Kader custom (Normaal)', active: True, matched by BOM reference (code))
#
#   [V18] Components (9 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - [Dibond2mm.X] Forex Wit 10mm (kopie) (Code: Dibond2mm, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ZKF.X] Dibond 3mm (kopie) (Code: ZKF, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 413
#   Reference: [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)
#   Display Name: [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): [KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1569, Code: '[KFMI.X] Kader + FM + Inlijsting (Artglass AR70, 2mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [DummylijstDummy Lijst] Dummy Lijst (Code: Dummylijst, Qty: 1.0)
#     - [AR70.GLAS] Artglass AR70 (Code: AR70, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [ECOST2Econospacer Transparant 3,2mm] Econospacer Transparant (Code: ECOST2, Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 199
#   Reference: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   Display Name: [KOF5MM.diensten] Kleven op Fomeboard (5mm): Kleven op Fomeboard
#   Product Template: Kleven op Fomeboard
#   Product Variant: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (2 items):
#     - [SK5MM.X] Schuimkarton 5mm (Code: SK5MM, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#      Trying fallback: matching by product_code
#      V14 product_code: KOF5MM
#      V14 product_variant: [KOF5MM.diensten] Kleven op Fomeboard (5mm)
#      Trying to match by product variant display_name
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6139
#   Reference: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   Display Name: Kader + FM + Inlijsting (Artglass AR92, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Artglass AR92, 2mm)
#   ✅ Found unique BOM in V18 by reference
#   ✅ Found corresponding BOM in V18 (ID: 1583, Code: 'Kader + FM + Inlijsting (Artglass AR92, 2mm)', active: True, matched by BOM reference (code))
#
#   [V18] Components (10 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [AR92.GLAS] Artglass AR92 (Code: AR92, Qty: 1.0)
#     - MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 2mm (Code: SK2MM, Qty: 1.0)
#     - Inlijsten (Code: IN, Qty: 1.0)
#     - Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2Econospacer Transparant 3,2mm] Econospacer Transparant (Code: ECOST2, Qty: 1.0)
#
#   🔍 COMPARISON RESULTS:
#     ✅ All components match!
#
# ================================================================================
# BOM ID (V14): 157
#   Reference: Kader + Print (Blinkend plexi glas, Semi Matte Epson)
#   Display Name: Kader + Print (Blinkend plexi glas, Semi Matte Epson): Kader + PP + Print (kopie)
#   Product Template: Kader + PP + Print (kopie)
#   Product Variant: Kader + PP + Print (kopie) (Blinkend plexi glas, A)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [DummylijstDummy Lijst] Kaslijst Zwart 2 cm (kopie) (Code: Dummylijst, Qty: 1.0)
#     - [BPG.GLAS] Blinkend plexiglas (Code: BPG, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [SMEPSON.PRINT] Semi Matte Epson (Code: SMEPSON, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [PVC1MM.PLAAT] PVC 1mm (Code: PVC1MM, Qty: 1.0)
#     - [P16K] Kleven op PVC (PVC) (Code: P16, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + Print (Blinkend plexi glas, Semi Matte Epson)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM ID (V14): 6141
#   Reference: Kader + FM + Inlijsting (Geen glas, 2mm)
#   Display Name: Kader + FM + Inlijsting (Geen glas, 2mm): Kader + FM + Inlijsting
#   Product Template: Kader + FM + Inlijsting
#   Product Variant: Kader + FM + Inlijsting (Geen glas, 2mm)
#   is_custom_made (V14): False
#   active (V14): True
#
#   [V14] Components (9 items):
#     - [4124.K04+K05+A06] Kaslijst Zwart 2 Cm (Code: 4124, Qty: 1.0)
#     - [MDF3MM.0] MDF 3MM BRUT (Code: MDF3MM., Qty: 1.0)
#     - [4346.A9] Lime White (Code: 4346, Qty: 1.0)
#     - [SK2MM.X] Schuimkarton 5mm (kopie) (Code: SK2MM, Qty: 1.0)
#     - [IN.DIENST] Inlijsten (Code: IN, Qty: 1.0)
#     - [AK.DIENST] Assembleren kader (Code: AK., Qty: 1.0)
#     - [BF.X] Bubbelfolie 100cm (80My - 100m) (Code: BF, Qty: 1.0)
#     - [KK.Internedienst] Kleven (Code: KK, Qty: 1.0)
#     - [ECOST2.X] Econospacer Wit (kopie) (Code: ECOST2, Qty: 1.0)
#
#   [V18] Searching for corresponding BOM...
#      Trying to match by BOM reference (code): Kader + FM + Inlijsting (Geen glas, 2mm)
#      Trying fallback: matching by product_code
#   ❌ Could not get product_code from V14 product_id
#   ❌ NO CORRESPONDING BOM FOUND IN V18!
#
# ================================================================================
# BOM comparison complete!
# Total BOMs checked: 250
# BOMs with mismatches: 35
# ================================================================================
